# %% [markdown]
# # Write an IP problem in <'lp'> format - deer habitat model

# %%
# %load_ext autoreload
# %autoreload 2

from pulp import * 
import pandas as pd 
import numpy as np 
import math 
import re
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
### This version corrects the constraint on variables alpha, account for split polygons 
#### change to the alpha constraint 

#Import files 
## Read excel files with panda 
#! pip install xlrd 
#!  pip install docplex
#conda install -c ibmdecisionoptimization docplex
#conda update -c ibmdecisionoptimization docplex

### Parcels, adjacency, area
        ###df_sheet_3 = pd.read_excel('IP_PB_simpledeerhab_SI.xlsx', sheet_name=1)
df_sheet_3 = pd.read_excel('Adj_200mbuffer.xlsx', sheet_name=2)
df_sheet_3 = df_sheet_3.fillna(0)
### growth model equations 
equation = pd.read_csv('Growth_volume_inc.csv', delimiter =';')
#df_sheet_3 = df_sheet_3.iloc[:10]

# %%
### TO DO 
##### TASKS ##### 
## initial class age ## 

## (WK_1: 09/05-09/10)  solve the optimization problem for an area of X stands (TB - 91 stands)
#### Done - Deer1 --> optimal 

##### Observations: 
## PCT ### most treatments arrive at the end (no i class age)
## All treatments at the same period 

## (WK_2) ensure that deer habitat would be maintained along the planning horizon.  
#### Option 1 
##### Could set an arbitrary threshold ~ Deer1 model OV : 12108 ac 
# ==> divide by the time period here 14 
# constraint ensures Sum a m*alpha m,p for all p >= OV/14 
# would it be good to add slack etc for sensitivity analysis? 

#### Option 2 
#### Overall buget splitted along 14 years 
#### PCT budget - just cost 
###### ANDREW 
#### 2017 cost of PCT/ac = $420/ac

#### harvest budget - cost? - LEV? - etc. close to road network
### find some proxi - maybe scheduling models for harvest 

#### Option 3
### define a constraint limiting the number of treatment per periods 
    ### Sum of PCT over all stands <= ai 
    ### Sum of harvest over all stands <= bi 
### run some sensitivity analysis
### number of actions or ac to cut per year*5 

#### (WK_3) Exclusivity problem 
### carying capacity 

#### OPTION 1: 
#### if cover is selected then sum of adjacent aphas*area (available forage) <= area cover 
###### since a maximization problem don't need a constraint that would force alpha so alpha can be tuned of 

#### OPTION 2: 
# Var Co 1 if cover selected 0 otherwise 
#I could set a shelter capacity to each old growth parcel and 
#whenever the forage quantity reached the shelter capacity requirements it would stop the 
#forage allocation (minimize surplus) …  

#WK_4 Wrap up:
#Do some sensibility analysis and assess 
#how many deer could stay on the area. 
#Track harvest events and estimate the volume of wood that we could collect.
#Present some maps of treatments allocations. 
#Compare results from “Max total” and “Max each period”. 
#Prepare for further research: What to do next? Ex: climate change considerations where snow 
#can kill 33% of fawns (is said to be most critical factor compared to predation), 
#hunt success indicator, forets productivity, wildlife corridor concerns …  

#### To do #1 
# add all the reference used for this model 

#### To do #2
# look for age-classes 

#### To do #3 
# do we need to set a constraint on harvest actions around 55 years? 
### COULD Set a contraint for Y m,t 
### Assume that forage is available 15 years after harvest 
### Assume : did not consider that PCT would transform faster the cover availability

# %%
# Volume increment function 
    #### first download the dataframe 
    #### create a dictionary with site class_site index as main key for polynomial equations
    #### then create exponents keys and its corresponding coefficient value for each site class_site index key
    #### {SC+SI : {Exp1:Coeff1;Exp2:Coeff2 etc.}}

### create index "SC_"+str(i)+"_"+str(j)
    # data.frame with 1# SC 2# SI and 3#equation
SC = equation["SC"]
SI = equation["SI"]
eq = equation["eq"]
growth_eq = {}
 
for i in range (len(equation)): 
    # combine SC and SI in index 
    index = ("SC_"+str(SC[i])+"_SI_"+str(SI[i]))
    # extract the equation and transform this into a disctionary object 
    term = str(eq[i])
    term = re.split('[+]|(-)',eq[i])
    term = list(filter(None, term))
    count = []
    r = 0 #element to remove 
    for j in range(len(term)):
        if "E" in term[j]:
            term[j] = term[j]+term[j+1]+term[j+2]  
            count.append(j+1-r)
            r=r+1
            count.append(j+2-r)
    for k in count: 
        term.remove(term[k])
    count = []
    r = 0 
    for j in range(len(term)):
        if "-" == term[j]:
            term[j] = term[j]+term[j+1]
            count.append(j+1-r)
            r = r + 1
    for k in count: 
        term.remove(term[k])
    
    eq_elt = {}
    for j in range(len(term)): 
        info = term[j].split('x')
        info = [i.replace(",", ".") for i in info]
        if "E" in info: 
            exp_number = info[0]
            float_number = float(exp_number)
            info[0] = float_number
        if ' ' in info: 
            info[0] = float(info[0])
            eq_elt.update({1 :info[0], 0:0})
        elif len(info) ==1:
            for l in range(len(info)):
                if info[l] == '': 
                    info[l] = 0
            info = [i.replace(" ", "") for i in info]
            info = [float(i) for i in info]
            eq_elt.update({0 :info[0]})
        else:
            for l in range(len(info)):
                if info[l] == '': 
                    info[l] = 0
            info = [i.replace(" ", "") for i in info]
            info = [float(i) for i in info]
            eq_elt.update({info[1]:info[0]})
        #print(eq_elt, "equ"+str(j))
    #dictionary with SC_SI and it equation encoded as an embeded dictionary 
    growth_eq.update({index: eq_elt})

# Set a function that would read the equations stored in your dictionary 
def eval_poly_dict(poly, x, y):
    return sum([poly[y][power]*x**power for power in poly[y]])

#test 
X = 200
a =eval_poly_dict(growth_eq, X, 'SC_VI_SI_60')  
print(a)
# Out:
# 7513.08

# %%
# Data definition 
mid_point = 2.5 # if PCT or harvest, estimated to happen at mid-point of 5 year periods 
n_periods = 14 # if 70 years horizon, and 5-year periods then 70/5 = 14 

i_yr = 2020

##PCT
min_yr = 15
max_yr = 40

# Cover 
min_yr_cover = 120

#Harvest 
min_hyr = 55
### set the number of period after PCT before allowed harvest 
n_harv_pct = 2

M = n_stands + 1  
HPCT = pd.DataFrame()
HPCT = HPCT.assign(stand_i=df_sheet_3["Stand_IPid"], H=df_sheet_3["Harvest"], 
                   PCT = df_sheet_3["PCT_YR"], SI = df_sheet_3["SSIZEC"], area=df_sheet_3["Acre"], 
                   adj_i=df_sheet_3["Neighbor"], SC_SI= df_sheet_3["SC_SI"])
HPCT = HPCT.drop_duplicates()

N_stands = np.array(HPCT["stand_i"])
n_stands = len(HPCT)
Yr_harvest = np.array(HPCT["H"])
Yr_PCT = np.array(HPCT["PCT"])
Yr_OG = np.array(HPCT["SI"])
A_stands = np.array(HPCT["area"])
## Area --> dictionary 
area_dic = {}
for m in range(len(N_stands)):
    stand = N_stands[m]
    area = A_stands[m]
    area_dic.update({stand:area})

#Adj_stands[["stand_i","stand_j"]] = df_sheet_3[["Stand_IPid", "Neigbor"]]
Adj_stands = pd.DataFrame()
Adj_stands = Adj_stands.assign(stand_i=np.array(HPCT["stand_i"]), adj_i=np.array(HPCT["adj_i"]))
Adj = Adj_stands["adj_i"].values.tolist()
i_Adj = Adj_stands["stand_i"].values.tolist()



### generate variables for previous harvest - RECORD X m,-t :         
new_Y_m = []
new_Y_p = []
for i in range (len(Yr_harvest)): 
    if Yr_harvest[i] != 0: 
        new_Y_m.append(N_stands[i])
        new_Y_p.append(math.floor((Yr_harvest[i]-i_yr-1)/5))
    elif Yr_OG[i] == 4:
        new_Y_m.append(N_stands[i])
        new_Y_p.append(-((min_yr_cover/5) +1)) #considered min age for old growth (period of 5 years so 5*26)
    else: 
        new_Y_m.append(N_stands[i])
        new_Y_p.append(-((min_yr_cover/5) +1)) # to think 
### generate variables for previous PCT - RECORD X m,-t : 
add_var = []
new_X_m = []
new_X_p = []
for i in range (len(Yr_PCT)): 
    if Yr_PCT[i] != 0: 
        new_X_m.append(N_stands[i])
        new_X_p.append(math.floor((Yr_PCT[i]-i_yr-1)/5))
        
#site class and site index of parcels 
SC_SI = pd.DataFrame()
SC_SI = SC_SI.assign(stand_i=np.array(HPCT["stand_i"]), SC_SI=np.array(HPCT["SC_SI"]))
# volume
volume = {}
for k in range(len(N_stands)):
    a = []
    for i in range(n_periods+1):
        Age_mt = i-new_Y_p[k]
        #SC_SIm = SC_SI["SC_SI"][k] if information available 
        SC_SIm = SC_SI["SC_SI"][k]
        b = eval_poly_dict(growth_eq, Age_mt, SC_SIm)*12/1000
        b=round(b)
        if b < 0: 
            b = 0 
        a.append(b)#MBF/ac
    volume.update({N_stands[k]:a})              
min_vol = 20.5 #MBF/ac ! here stump and tip 
### reference 
# https://tind-customer-agecon.s3.amazonaws.com/0d218c56-21cd-4a6f-9ded-711620b176dd?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27tb1273.pdf&response-content-type=application%2Fpdf&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-Credential=AKIAXL7W7Q3XHXDVDQYS%2F20220519%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Date=20220519T211917Z&X-Amz-Signature=2f733b3d86f854ddb3b1fbab86865135966db323573c7649a480441933c66d95
### Info for unmanaged hemlock

# %%
# # Model initialization
model= LpProblem("Deer1", LpMaximize)

# %%
# Decision variables 
## X m, t - stand m to be PCTed in time period t  _ Xm,t=1; 0 otherwise 
X_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
DV_X_variables = LpVariable.matrix("X", X_variable_names, cat = "Binary", lowBound= 0 )
X_allocation = np.array(DV_X_variables).reshape(n_stands,14+1)

## Y m, t - stand m to be harvested in time period t _ Ym,t=1; 0 otherwise 
Y_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
DV_Y_variables = LpVariable.matrix("Y", Y_variable_names, cat = "Binary", lowBound= 0 )
Y_allocation = np.array(DV_Y_variables).reshape(n_stands,14+1)

## No action - assume forest left as it is, carbon store 
C_variable_names = [str(i) for i in N_stands]
DV_C_variables = LpVariable.matrix("C", C_variable_names, cat = "Binary", lowBound= 0 )
C_allocation = np.array(DV_C_variables).reshape(n_stands)


#past activities variables

record_X_variables = [str(j) + ',' + str(new_X_p[new_X_m.index(j)]) for j in new_X_m]
DV_Xr_variables = LpVariable.matrix("X", record_X_variables, cat = "Binary", lowBound= 0 )
Xr_allocation = np.array(DV_Xr_variables).reshape(len(new_X_p))
        
record_Y_variables = [str(j) + ',' + str(new_Y_p[new_Y_m.index(j)]) for j in new_Y_m]
DV_Yr_variables = LpVariable.matrix("Y", record_Y_variables, cat = "Binary", lowBound= 0 )
Yr_allocation = np.array(DV_Yr_variables).reshape(len(new_Y_p))

# Indicator variable 
## delta m,t - stand m to be considered as forage stand in time t _ delta m,t =1; 0 otherwise 
### generate for all stands 
#"\zeta[tab]"
#delta
delta_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
IV_delta_variables = LpVariable.matrix("delta", delta_variable_names, cat = "Binary", lowBound= 0 )
delta_allocation = np.array(IV_delta_variables).reshape(n_stands,14+1)
## omega m,t - cover habitat
#omega
omega_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
IV_omega_variables = LpVariable.matrix("omega", omega_variable_names, cat = "Binary", lowBound= 0 )
omega_allocation = np.array(IV_omega_variables).reshape(n_stands,14+1)
### find later how to replace string elements  

## alpha m,t - usable habitat by deer 
### generate for all stands 
#alpha
alpha_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
IV_alpha_variables = LpVariable.matrix("alpha", alpha_variable_names, cat = "Binary", lowBound= 0 )
alpha_allocation = np.array(IV_alpha_variables).reshape(n_stands,14+1)

alpha_min_variable_names = [str(i) for i in range (n_periods+1)]
IV_alpha_min_variables = LpVariable.matrix("alpha_min", alpha_min_variable_names, cat = "Integer", lowBound= 0 )
alpha_min_allocation = np.array(IV_alpha_min_variables).reshape(14+1)

#zeta variable m,t - enable to know the total amount of forage habitat period allowed by treatment 
zeta_variable_names = [str(i) for i in N_stands]
IV_zeta_variables = LpVariable.matrix("zeta", zeta_variable_names, cat = "Binary", lowBound= 0 )
zeta_allocation = np.array(IV_zeta_variables).reshape(n_stands)

#age
age_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
IV_age_variables = LpVariable.matrix("age", age_variable_names, cat = "Integer", lowBound= 0 )
age_allocation = np.array(IV_age_variables).reshape(n_stands,14+1)

# %%
# Constraints 

## set the constraints 

## Constrain 1: Forage habitat 
### SUM (p+1, p+2) delta m,p' = 2*Xm,p + 2*Ym,p 
    ### add constraint if p > P 

## Constraint 2: One PCT and one harvest 
### SUM Xm,p <= 1 
### SUM Ym,p <= 1 with p >= 0 

## Constraint 3: PCT conditions 
### Xm,p * min_n_periods <= Age m,p  HERE min_n_periods = 3 means 15 years
### (40-Age m,p) + (1-Xm,p)*m >= 0 

## Constraint 4: Forage constraint, turn off 
### SUM delta m,p <= 2*Sum Xm,p + 2*Sum Ym,p + (1 + Zm - (Sum Xm,p + Sum Ym,p))M 
#### must add an indicator variable Z m,t = Sum Xm,p * Sum Ym,p 
    #### 2*Zm <= Sum Xm,p* Sum Ym,p 
    #### Sum Ym,p + Sum Xm,p - Zm <= 1 
    
## Age function 
### Age m,p = p - (Sum [-150, p-1] Ym,p' * p')
    ### if harvested year 0 then Age m,0 = 0 

## Constraints 5: Old growth - cover type 

#### Cover constraint 1 : ### 
### Age m,p - 24*omega m,p >= 0 
######  ==> forces omega to turn 0 if too young 

#### Cover constraint 2 : ### 
### m*omega m,p + 24 >= (1- Sum Ym,p) + Age m,p 
##### ==> if age is equal to or greater than 120 years omega would be forced to turn on 

## Constraint 6: Habitat availability 

## 1st ATTEMPT# |Sm|*alpha m,p - Sum omega k,p <= delta m,p (|Sm| - 1)
### alpha m,p <= delta m,t + omega m,p 
## 2nd ATTEMPT#
    #### 2*alpha m,p <= delta m,p + omega k,p for all k 
    #### delta m,p + omega k,p  - alpha m,p <= 1 for all k 
    ###### do not need since maximization problem!!!
## 3rd ATTEMPT# 
    #### alpha m,p <= (delta m,p + SUM omega k,p for all k)/|Sk|+1
    #### IF MAX then that is all 

## Constraint 7: turn ancient harvest and PCT treatment on 
## Yr and Xr_allocation = 1 
print(record_Y_variables)
# Out:
# ['1,-25.0', '10,-25.0', '11,-25.0', '12,-25.0', '13,-25.0', '14,-25.0', '15,-25.0', '16,-25.0', '19,-25.0', '2,-7', '20,-25.0', '21,-25.0', '22,-25.0', '23,-25.0', '24,-25.0', '25,-25.0', '26,-25.0', '27,-25.0', '28,-25.0', '29,-25.0', '3,-25.0', '30,-25.0', '31,-25.0', '32,-25.0', '33,-25.0', '34,-25.0', '35,-12', '37,-7', '38,-7', '39,-25.0', '4,-25.0', '40,-25.0', '41,-25.0', '42,-25.0', '43,-25.0', '44,-12', '45,-25.0', '46,-25.0', '47,-25.0', '48,-25.0', '49,-25.0', '5,-25.0', '50,-25.0', '51,-25.0', '52,-25.0', '53,-25.0', '54,-25.0', '55,-25.0', '56,-25.0', '57,-25.0', '58,-25.0', '59,-25.0', '6,-25.0', '60,-25.0', '61,-25.0', '62,-25.0', '63,-25.0', '64,-25.0', '66,-25.0', '660,-25.0', '661,-25.0', '662,-25.0', '67,-25.0', '68,-25.0', '69,-25.0', '71,-25.0', '72,-25.0', '730,-12', '731,-12', '732,-12', '733,-12', '734,-12', '74,-25.0', '750,-12', '751,-12', '752,-12', '753,-12', '754,-12', '755,-12', '756,-12', '757,-12', '758,-12', '759,-12', '760,-10', '761,-10', '762,-10', '763,-10', '764,-10', '770,-12', '771,-12', '772,-12', '773,-12', '774,-12', '775,-12', '776,-12', '777,-12', '778,-12', '779,-12', '78,-7', '79,-7', '8,-25.0', '800,-12', '801,-12', '802,-12', '803,-12', '804,-12', '81,-7', '82,-7', '83,-7', '84,-7', '85,-7', '86,-7', '87,-7', '88,-2', '890,-10', '891,-10', '892,-10', '893,-10', '9,-25.0', '90,-12', '91,-7']

# %% [markdown]
# ##### Constraint 1: forage habitat

# %%
for m in range (n_stands):
    for p in range (n_periods):
        if p < n_periods-1 & p>0 :
            model += (delta_allocation[m][p+1] == X_allocation[m][p] + Y_allocation[m][p] + 
                      X_allocation[m][p-1] + Y_allocation[m][p-1]
                      , "Forhab_p1" + str(m+1) + "_" + str(p))
            model += (delta_allocation[m][p+2] == X_allocation[m][p] + Y_allocation[m][p] + 
                      X_allocation[m][p+1] + Y_allocation[m][p+1]
                      , "Forhab_p2" + str(m+1) + "_" + str(p))
        elif p == 0: 
            model += (delta_allocation[m][p+1] == X_allocation[m][p] + Y_allocation[m][p]
                      , "Forhab_p1" + str(m+1) + "_" + str(p))
            model += (delta_allocation[m][p+2] == X_allocation[m][p] + Y_allocation[m][p] + 
                      X_allocation[m][p+1] + Y_allocation[m][p+1]
                      , "Forhab_p2" + str(m+1) + "_" + str(p))
        elif p == n_periods-1:   
            model += delta_allocation[m][p+1] == X_allocation[m][p] + Y_allocation[m][p], "Forhab_f" + str(m+1) + "_" + str(p)

# %%
## Constraint 2: One PCT and one harvest 
### SUM Xm,p <= 1 
### SUM Ym,p <= 1 with p >= 0 

for m in range(n_stands): 
    model += lpSum(X_allocation[m][p] for p in range(0,n_periods+1))<=1, "One_PCT_" + str(m+1)
    model += lpSum(Y_allocation[m][p] for p in range(0,n_periods+1))<=1, "One_harv_" + str(m+1)

for m in range(n_stands):
    model+= (lpSum(X_allocation[m][p] + Y_allocation[m][p] for p in range(n_periods+1)) + C_allocation[m] >= 1, 
                 "No_action"+ str(m)+ "_"+ str(p))
    model+= (lpSum(X_allocation[m][p] for p in range(n_periods+1)) + C_allocation[m] <= 1, 
                 "No_actionX"+ str(m)+ "_"+ str(p))
    model+= (lpSum(Y_allocation[m][p] for p in range(n_periods+1)) + C_allocation[m] <= 1, 
                 "No_actionY"+ str(m)+ "_"+ str(p))

# %%
# Constraint 2': no harvest after 2 periods after PCT 
for m in range(n_stands): 
    for p in range(n_periods+1):
        if p < n_periods-1:
            model+=(lpSum(Y_allocation[m][t] for t in range(p+1,p+n_harv_pct+1)) <= (n_harv_pct+1)*(1-X_allocation[m][p]),
                    "harv_PCT_"+str(m)+"_"+str(p))
        elif p < n_periods: 
            model+=(lpSum(Y_allocation[m][t] for t in range(p+1,n_periods+1)) <= 3*(1-X_allocation[m][p]),
                   "harv_PCT_"+str(m)+"_"+str(p))

# %%
# Function Age :

for m in range(len(N_stands)): 
    for t in range(n_periods+1): 
        model +=(age_allocation[m][t] == 
               t - new_Y_p[m] + lpSum(Y_allocation[m][p]*(new_Y_p[m]-p) for p in range(0, t)) 
                        , "age_" + str(m) + "_"+ str(t))

# %%
age_allocation[m][t]
# Out:
# age_91,14

# %%
## Constraint 3: PCT conditions 
## a) ensure that stand is over 15 to be allowed to be PCTed 
### Xm,p * 15/5 <= Age m,p 

for m in range(n_stands+1): 
    for k in range(len(new_Y_p)): 
        if new_Y_m[k] == m:
            for t in range(n_periods + 1):
                model +=(X_allocation[m-1][t]*min_yr/5 <= t - new_Y_p[k] + 
                         lpSum(Y_allocation[m-1][p]*(new_Y_p[k]-p) for p in range(0, t)) 
                      , "PCT15_"+ str(m)+ "_"+ str(t))

# %%
## Constraint 3: PCT conditions
### b) make sure that stand is bellow 40 to be allowed to be PCTed 
### (40-Age m,p) + (1-Xm,p)*M >= 0 

for m in range(n_stands+1): 
    for k in range(len(new_Y_p)): 
        if new_Y_m[k] == m:
            for t in range(n_periods + 1):
                model += (0 <= (1-X_allocation[m-1][t])*M + max_yr/5 - 
                          (t - new_Y_p[k] + lpSum(Y_allocation[m-1][p]*(new_Y_p[k]-p) for p in range(0, t))) 
                     , "PCT40_"+ str(m)+ "_"+ str(t))

# %%
## Constraint 4: Forage constraint, turn off 
### SUM delta m,t <= 2*Sum Xm,t + 2*Sum Ym,t + (1 + Sum Zm,t - (Sum Xm,t + Sum Ymt))M  
    ### turn the model infeasible !!!
for m in range(n_stands):
    model +=(lpSum(delta_allocation[m][p] for p in range(n_periods+1)) <= lpSum(2*X_allocation[m][p]
                                                                        + 2*Y_allocation[m][p]
                                                                        + (1 + zeta_allocation[m] #add zeta 
                                                                          - (X_allocation[m][p]
                                                                          + Y_allocation[m][p]))*M
                                                                        for p in range(n_periods+1)), 
              "Turnoff_forage_" + str(m))

# %%
## Constraint 4': Forage constraint, indicator variable = switch zeta on or off 
#### 2*Zm <= Sum Xm,t + Sum Ym,t 
for m in range(n_stands):
    (lpSum(X_allocation[m][p] + Y_allocation[m][p] for p in range(n_periods+1)) >= 2*zeta_allocation[m], "zeta_con1_" + str(m)+ "_"+ str(p))      
#### Sum Ym,t + Sum Xm,t - Zm <= 1 
for m in range(n_stands):
    (lpSum(X_allocation[m][p] + Y_allocation[m][p] for p in range(n_periods+1)) - zeta_allocation[m] <= 1, "zeta_con2_" + str(m)+ "_"+ str(p))

# %%
## Constraints 5: Old growth - cover type 
## a) turn all young stage to 0 
# Age m,p - 24*omega m,p >= 0 

for m in range(n_stands+1): 
    for k in range(len(new_Y_p)): 
        if new_Y_m[k] == m:
            for t in range(n_periods + 1):
                model += (t - new_Y_p[k] + lpSum(Y_allocation[m-1][p]*(new_Y_p[k]-p) for p in range(0, t)) 
                        - (omega_allocation[m-1][t]*min_yr_cover/5) >= 0
                     , "Cover24_"+ str(m) + "_" +str(t))

# %%
## Constraint 5: Old growth - cover type 
### b) ensure that all stands over 24 will turn 1 
### m*omega m,p + 24 >= (1- Sum Ym,p) + Age m,p 

for m in range(n_stands+1): 
    for k in range(len(new_Y_p)): 
        if new_Y_m[k] == m:
            for t in range(n_periods + 1):
                model+= (M*omega_allocation[m-1][t] + min_yr_cover/5 
                         >= 1-lpSum(Y_allocation[m-1][t]) + t - new_Y_p[k] 
                         + lpSum(Y_allocation[m-1][p]*(new_Y_p[k]-p) for p in range(0, t)) 
                         , "Cover_on_"+str(m)+ "_" +str(t))

# %%
## Constraint 6': 
#####alpha m,p <= delta m,p + SUM omega k,p for all k/|Sk|
for i in range(len(N_stands)):
    if isinstance(Adj_stands["adj_i"][i], int):
        a = Adj_stands["adj_i"][i]
        if a != 0:
            adj_ind = i_Adj.index(a) 
            for p in range(n_periods + 1):
                model+=(alpha_allocation[i][p] <= (omega_allocation[adj_ind][p] 
                        + delta_allocation[i][p])/2
                        , "hab_av_" + str(i) + "_" + str(p))
    elif isinstance(Adj_stands["adj_i"][i], float):
        print(i, "_is_a_nan")
        for p in range(n_periods + 1):
            model+= alpha_allocation[i][p] == 0, "hab_av_" + str(i) + "_" + str(p)
                # shall we add a constraint there? 
    else:
        adj_ind = []
        a = Adj_stands["adj_i"][i].split("_")
        a = [int(i) for i in a]
        for c in range(len(a)): 
            if a[c] in i_Adj:
                adj_ind.append(i_Adj.index(a[c]))
        for p in range(n_periods + 1):
            model+= (alpha_allocation[i][p] 
                    <= (lpSum(omega_allocation[adj_ind[n]][p] for n in range(len(adj_ind)))
                    + (delta_allocation[i][p]*len(adj_ind)))/(len(adj_ind)+1), "hab_av_" + str(i) + "_" + str(p))

# %%
#Constraint 7 : recorded PCT and harvest treatment = 1 
for m in range(len(new_Y_m)): 
    model += (Yr_allocation[m] == 1), "rec_harv_" + str(m)    
for m in range(len(new_X_m)):
    model += (Xr_allocation[m] == 1), "rec_PCT" + str(m)

# %%
#Constraint 8 : period requirements WRONG --> do a min instead 
for p in range(n_periods+1):
      model+=(lpSum(alpha_allocation[m][p] for m in range(n_stands)) >= alpha_min_allocation[p]), "period_con_" + str(m) + "_" + str(p)

# %%
# Constraint 9 : no harvest before stand attains merchantable age (+55) or min vol  
### Ym,p * 55/5 <= Age m,p 
### and/or 
### min vol : Ym,p*volume[m][t]

for m in range(n_stands): 
    for t in range(n_periods + 1):
        model+=((Y_allocation[m][t]*min_vol <= volume[N_stands[m]][t], "Harv_vol" + str(m)+ "_"+ str(t)))

for m in range(n_stands+1): 
    for k in range(len(new_Y_p)): 
        if new_Y_m[k] == m:
            for t in range(n_periods + 1):
                model+=(Y_allocation[m-1][t]*min_hyr/5 <= t - new_Y_p[k] + 
                         lpSum(Y_allocation[m-1][p]*(new_Y_p[k]-p) for p in range(0, t)) 
                      , "Harv55_"+ str(m)+ "_"+ str(t))

# %%
# Constraint 10 
# area constraint 
#model+= (lpSum(alpha_allocation[i][j]*area_dic[i+1] 
              # for i in range(n_stands) for j in range(n_periods+1))>= 2000, "Tot_area")

# %%
# Evaluation functions 
area_variable_names = [str(i) for i in range (n_periods+1)]
area_variables = LpVariable.matrix("Area", area_variable_names, cat = "Continuous", lowBound= 0 )
area_allocation = np.array(area_variables).reshape(n_periods+1)

Vharv_variable_names = [str(i) for i in range (n_periods+1)]
Vharv_variables = LpVariable.matrix("Vharv", Vharv_variable_names, cat = "Continuous", lowBound= 0 )
Vharv_allocation = np.array(Vharv_variables).reshape(n_periods+1)

### could convert that to biomass 
VC_variable_names = [str(i) for i in range (n_stands+1)]
VC_variables = LpVariable.matrix("VC", VC_variable_names, cat = "Continuous", lowBound= 0 )
VC_allocation = np.array(VC_variables).reshape(n_stands+1)

AREA = LpVariable("AREA", cat="Continuous", lowBound=0)

model+= (lpSum(area_dic[i] for i in N_stands)==AREA, "TOT_AREA")

for j in range(n_periods+1):
    # sum just alpha as some omegas are cover and forage habitat 
    model+= (lpSum(alpha_allocation[i][j]*area_dic[N_stands[i]] 
                for i in range(n_stands))==area_allocation[j], "Area"+str(j))
for j in range(n_periods+1):
    model += (lpSum(Y_allocation[i][j]*volume[N_stands[i]][j]*area_dic[N_stands[i]]  
                for i in range(n_stands))==Vharv_allocation[j], "VolHarv"+str(j))
for i in range(n_stands):
    model += (lpSum(C_allocation[i]*volume[N_stands[i]][n_periods]*area_dic[N_stands[i]]
                   ) == VC_allocation[i+1], "VolCarb"+str(i+1))

# %%
# Objective function ###TO CHANGE TO BECOME GENERIC
obj_func = lpSum(alpha_min_allocation)
model += obj_func

# %%
#Save code into a lp file 
model.writeLP("model_0609.lp")
# Out:
# [AREA,
#  Area_0,
#  Area_1,
#  Area_10,
#  Area_11,
#  Area_12,
#  Area_13,
#  Area_14,
#  Area_2,
#  Area_3,
#  Area_4,
#  Area_5,
#  Area_6,
#  Area_7,
#  Area_8,
#  Area_9,
#  C_1,
#  C_10,
#  C_11,
#  C_12,
#  C_13,
#  C_14,
#  C_15,
#  C_16,
#  C_19,
#  C_2,
#  C_20,
#  C_21,
#  C_22,
#  C_23,
#  C_24,
#  C_25,
#  C_26,
#  C_27,
#  C_28,
#  C_29,
#  C_3,
#  C_30,
#  C_31,
#  C_32,
#  C_33,
#  C_34,
#  C_35,
#  C_37,
#  C_38,
#  C_39,
#  C_4,
#  C_40,
#  C_41,
#  C_42,
#  C_43,
#  C_44,
#  C_45,
#  C_46,
#  C_47,
#  C_48,
#  C_49,
#  C_5,
#  C_50,
#  C_51,
#  C_52,
#  C_53,
#  C_54,
#  C_55,
#  C_56,
#  C_57,
#  C_58,
#  C_59,
#  C_6,
#  C_60,
#  C_61,
#  C_62,
#  C_63,
#  C_64,
#  C_66,
#  C_660,
#  C_661,
#  C_662,
#  C_67,
#  C_68,
#  C_69,
#  C_71,
#  C_72,
#  C_730,
#  C_731,
#  C_732,
#  C_733,
#  C_734,
#  C_74,
#  C_750,
#  C_751,
#  C_752,
#  C_753,
#  C_754,
#  C_755,
#  C_756,
#  C_757,
#  C_758,
#  C_759,
#  C_760,
#  C_761,
#  C_762,
#  C_763,
#  C_764,
#  C_770,
#  C_771,
#  C_772,
#  C_773,
#  C_774,
#  C_775,
#  C_776,
#  C_777,
#  C_778,
#  C_779,
#  C_78,
#  C_79,
#  C_8,
#  C_800,
#  C_801,
#  C_802,
#  C_803,
#  C_804,
#  C_81,
#  C_82,
#  C_83,
#  C_84,
#  C_85,
#  C_86,
#  C_87,
#  C_88,
#  C_890,
#  C_891,
#  C_892,
#  C_893,
#  C_9,
#  C_90,
#  C_91,
#  VC_1,
#  VC_10,
#  VC_100,
#  VC_101,
#  VC_102,
#  VC_103,
#  VC_104,
#  VC_105,
#  VC_106,
#  VC_107,
#  VC_108,
#  VC_109,
#  VC_11,
#  VC_110,
#  VC_111,
#  VC_112,
#  VC_113,
#  VC_114,
#  VC_115,
#  VC_116,
#  VC_117,
#  VC_118,
#  VC_119,
#  VC_12,
#  VC_120,
#  VC_121,
#  VC_13,
#  VC_14,
#  VC_15,
#  VC_16,
#  VC_17,
#  VC_18,
#  VC_19,
#  VC_2,
#  VC_20,
#  VC_21,
#  VC_22,
#  VC_23,
#  VC_24,
#  VC_25,
#  VC_26,
#  VC_27,
#  VC_28,
#  VC_29,
#  VC_3,
#  VC_30,
#  VC_31,
#  VC_32,
#  VC_33,
#  VC_34,
#  VC_35,
#  VC_36,
#  VC_37,
#  VC_38,
#  VC_39,
#  VC_4,
#  VC_40,
#  VC_41,
#  VC_42,
#  VC_43,
#  VC_44,
#  VC_45,
#  VC_46,
#  VC_47,
#  VC_48,
#  VC_49,
#  VC_5,
#  VC_50,
#  VC_51,
#  VC_52,
#  VC_53,
#  VC_54,
#  VC_55,
#  VC_56,
#  VC_57,
#  VC_58,
#  VC_59,
#  VC_6,
#  VC_60,
#  VC_61,
#  VC_62,
#  VC_63,
#  VC_64,
#  VC_65,
#  VC_66,
#  VC_67,
#  VC_68,
#  VC_69,
#  VC_7,
#  VC_70,
#  VC_71,
#  VC_72,
#  VC_73,
#  VC_74,
#  VC_75,
#  VC_76,
#  VC_77,
#  VC_78,
#  VC_79,
#  VC_8,
#  VC_80,
#  VC_81,
#  VC_82,
#  VC_83,
#  VC_84,
#  VC_85,
#  VC_86,
#  VC_87,
#  VC_88,
#  VC_89,
#  VC_9,
#  VC_90,
#  VC_91,
#  VC_92,
#  VC_93,
#  VC_94,
#  VC_95,
#  VC_96,
#  VC_97,
#  VC_98,
#  VC_99,
#  Vharv_0,
#  Vharv_1,
#  Vharv_10,
#  Vharv_11,
#  Vharv_12,
#  Vharv_13,
#  Vharv_14,
#  Vharv_2,
#  Vharv_3,
#  Vharv_4,
#  Vharv_5,
#  Vharv_6,
#  Vharv_7,
#  Vharv_8,
#  Vharv_9,
#  X_1,0,
#  X_1,1,
#  X_1,10,
#  X_1,11,
#  X_1,12,
#  X_1,13,
#  X_1,14,
#  X_1,2,
#  X_1,3,
#  X_1,4,
#  X_1,5,
#  X_1,6,
#  X_1,7,
#  X_1,8,
#  X_1,9,
#  X_1,_4,
#  X_10,0,
#  X_10,1,
#  X_10,10,
#  X_10,11,
#  X_10,12,
#  X_10,13,
#  X_10,14,
#  X_10,2,
#  X_10,3,
#  X_10,4,
#  X_10,5,
#  X_10,6,
#  X_10,7,
#  X_10,8,
#  X_10,9,
#  X_11,0,
#  X_11,1,
#  X_11,10,
#  X_11,11,
#  X_11,12,
#  X_11,13,
#  X_11,14,
#  X_11,2,
#  X_11,3,
#  X_11,4,
#  X_11,5,
#  X_11,6,
#  X_11,7,
#  X_11,8,
#  X_11,9,
#  X_12,0,
#  X_12,1,
#  X_12,10,
#  X_12,11,
#  X_12,12,
#  X_12,13,
#  X_12,14,
#  X_12,2,
#  X_12,3,
#  X_12,4,
#  X_12,5,
#  X_12,6,
#  X_12,7,
#  X_12,8,
#  X_12,9,
#  X_13,0,
#  X_13,1,
#  X_13,10,
#  X_13,11,
#  X_13,12,
#  X_13,13,
#  X_13,14,
#  X_13,2,
#  X_13,3,
#  X_13,4,
#  X_13,5,
#  X_13,6,
#  X_13,7,
#  X_13,8,
#  X_13,9,
#  X_14,0,
#  X_14,1,
#  X_14,10,
#  X_14,11,
#  X_14,12,
#  X_14,13,
#  X_14,14,
#  X_14,2,
#  X_14,3,
#  X_14,4,
#  X_14,5,
#  X_14,6,
#  X_14,7,
#  X_14,8,
#  X_14,9,
#  X_15,0,
#  X_15,1,
#  X_15,10,
#  X_15,11,
#  X_15,12,
#  X_15,13,
#  X_15,14,
#  X_15,2,
#  X_15,3,
#  X_15,4,
#  X_15,5,
#  X_15,6,
#  X_15,7,
#  X_15,8,
#  X_15,9,
#  X_15,_4,
#  X_16,0,
#  X_16,1,
#  X_16,10,
#  X_16,11,
#  X_16,12,
#  X_16,13,
#  X_16,14,
#  X_16,2,
#  X_16,3,
#  X_16,4,
#  X_16,5,
#  X_16,6,
#  X_16,7,
#  X_16,8,
#  X_16,9,
#  X_19,0,
#  X_19,1,
#  X_19,10,
#  X_19,11,
#  X_19,12,
#  X_19,13,
#  X_19,14,
#  X_19,2,
#  X_19,3,
#  X_19,4,
#  X_19,5,
#  X_19,6,
#  X_19,7,
#  X_19,8,
#  X_19,9,
#  X_2,0,
#  X_2,1,
#  X_2,10,
#  X_2,11,
#  X_2,12,
#  X_2,13,
#  X_2,14,
#  X_2,2,
#  X_2,3,
#  X_2,4,
#  X_2,5,
#  X_2,6,
#  X_2,7,
#  X_2,8,
#  X_2,9,
#  X_20,0,
#  X_20,1,
#  X_20,10,
#  X_20,11,
#  X_20,12,
#  X_20,13,
#  X_20,14,
#  X_20,2,
#  X_20,3,
#  X_20,4,
#  X_20,5,
#  X_20,6,
#  X_20,7,
#  X_20,8,
#  X_20,9,
#  X_21,0,
#  X_21,1,
#  X_21,10,
#  X_21,11,
#  X_21,12,
#  X_21,13,
#  X_21,14,
#  X_21,2,
#  X_21,3,
#  X_21,4,
#  X_21,5,
#  X_21,6,
#  X_21,7,
#  X_21,8,
#  X_21,9,
#  X_22,0,
#  X_22,1,
#  X_22,10,
#  X_22,11,
#  X_22,12,
#  X_22,13,
#  X_22,14,
#  X_22,2,
#  X_22,3,
#  X_22,4,
#  X_22,5,
#  X_22,6,
#  X_22,7,
#  X_22,8,
#  X_22,9,
#  X_23,0,
#  X_23,1,
#  X_23,10,
#  X_23,11,
#  X_23,12,
#  X_23,13,
#  X_23,14,
#  X_23,2,
#  X_23,3,
#  X_23,4,
#  X_23,5,
#  X_23,6,
#  X_23,7,
#  X_23,8,
#  X_23,9,
#  X_24,0,
#  X_24,1,
#  X_24,10,
#  X_24,11,
#  X_24,12,
#  X_24,13,
#  X_24,14,
#  X_24,2,
#  X_24,3,
#  X_24,4,
#  X_24,5,
#  X_24,6,
#  X_24,7,
#  X_24,8,
#  X_24,9,
#  X_25,0,
#  X_25,1,
#  X_25,10,
#  X_25,11,
#  X_25,12,
#  X_25,13,
#  X_25,14,
#  X_25,2,
#  X_25,3,
#  X_25,4,
#  X_25,5,
#  X_25,6,
#  X_25,7,
#  X_25,8,
#  X_25,9,
#  X_26,0,
#  X_26,1,
#  X_26,10,
#  X_26,11,
#  X_26,12,
#  X_26,13,
#  X_26,14,
#  X_26,2,
#  X_26,3,
#  X_26,4,
#  X_26,5,
#  X_26,6,
#  X_26,7,
#  X_26,8,
#  X_26,9,
#  X_27,0,
#  X_27,1,
#  X_27,10,
#  X_27,11,
#  X_27,12,
#  X_27,13,
#  X_27,14,
#  X_27,2,
#  X_27,3,
#  X_27,4,
#  X_27,5,
#  X_27,6,
#  X_27,7,
#  X_27,8,
#  X_27,9,
#  X_28,0,
#  X_28,1,
#  X_28,10,
#  X_28,11,
#  X_28,12,
#  X_28,13,
#  X_28,14,
#  X_28,2,
#  X_28,3,
#  X_28,4,
#  X_28,5,
#  X_28,6,
#  X_28,7,
#  X_28,8,
#  X_28,9,
#  X_29,0,
#  X_29,1,
#  X_29,10,
#  X_29,11,
#  X_29,12,
#  X_29,13,
#  X_29,14,
#  X_29,2,
#  X_29,3,
#  X_29,4,
#  X_29,5,
#  X_29,6,
#  X_29,7,
#  X_29,8,
#  X_29,9,
#  X_3,0,
#  X_3,1,
#  X_3,10,
#  X_3,11,
#  X_3,12,
#  X_3,13,
#  X_3,14,
#  X_3,2,
#  X_3,3,
#  X_3,4,
#  X_3,5,
#  X_3,6,
#  X_3,7,
#  X_3,8,
#  X_3,9,
#  X_30,0,
#  X_30,1,
#  X_30,10,
#  X_30,11,
#  X_30,12,
#  X_30,13,
#  X_30,14,
#  X_30,2,
#  X_30,3,
#  X_30,4,
#  X_30,5,
#  X_30,6,
#  X_30,7,
#  X_30,8,
#  X_30,9,
#  X_31,0,
#  X_31,1,
#  X_31,10,
#  X_31,11,
#  X_31,12,
#  X_31,13,
#  X_31,14,
#  X_31,2,
#  X_31,3,
#  X_31,4,
#  X_31,5,
#  X_31,6,
#  X_31,7,
#  X_31,8,
#  X_31,9,
#  X_32,0,
#  X_32,1,
#  X_32,10,
#  X_32,11,
#  X_32,12,
#  X_32,13,
#  X_32,14,
#  X_32,2,
#  X_32,3,
#  X_32,4,
#  X_32,5,
#  X_32,6,
#  X_32,7,
#  X_32,8,
#  X_32,9,
#  X_33,0,
#  X_33,1,
#  X_33,10,
#  X_33,11,
#  X_33,12,
#  X_33,13,
#  X_33,14,
#  X_33,2,
#  X_33,3,
#  X_33,4,
#  X_33,5,
#  X_33,6,
#  X_33,7,
#  X_33,8,
#  X_33,9,
#  X_34,0,
#  X_34,1,
#  X_34,10,
#  X_34,11,
#  X_34,12,
#  X_34,13,
#  X_34,14,
#  X_34,2,
#  X_34,3,
#  X_34,4,
#  X_34,5,
#  X_34,6,
#  X_34,7,
#  X_34,8,
#  X_34,9,
#  X_35,0,
#  X_35,1,
#  X_35,10,
#  X_35,11,
#  X_35,12,
#  X_35,13,
#  X_35,14,
#  X_35,2,
#  X_35,3,
#  X_35,4,
#  X_35,5,
#  X_35,6,
#  X_35,7,
#  X_35,8,
#  X_35,9,
#  X_37,0,
#  X_37,1,
#  X_37,10,
#  X_37,11,
#  X_37,12,
#  X_37,13,
#  X_37,14,
#  X_37,2,
#  X_37,3,
#  X_37,4,
#  X_37,5,
#  X_37,6,
#  X_37,7,
#  X_37,8,
#  X_37,9,
#  X_38,0,
#  X_38,1,
#  X_38,10,
#  X_38,11,
#  X_38,12,
#  X_38,13,
#  X_38,14,
#  X_38,2,
#  X_38,3,
#  X_38,4,
#  X_38,5,
#  X_38,6,
#  X_38,7,
#  X_38,8,
#  X_38,9,
#  X_39,0,
#  X_39,1,
#  X_39,10,
#  X_39,11,
#  X_39,12,
#  X_39,13,
#  X_39,14,
#  X_39,2,
#  X_39,3,
#  X_39,4,
#  X_39,5,
#  X_39,6,
#  X_39,7,
#  X_39,8,
#  X_39,9,
#  X_4,0,
#  X_4,1,
#  X_4,10,
#  X_4,11,
#  X_4,12,
#  X_4,13,
#  X_4,14,
#  X_4,2,
#  X_4,3,
#  X_4,4,
#  X_4,5,
#  X_4,6,
#  X_4,7,
#  X_4,8,
#  X_4,9,
#  X_40,0,
#  X_40,1,
#  X_40,10,
#  X_40,11,
#  X_40,12,
#  X_40,13,
#  X_40,14,
#  X_40,2,
#  X_40,3,
#  X_40,4,
#  X_40,5,
#  X_40,6,
#  X_40,7,
#  X_40,8,
#  X_40,9,
#  X_41,0,
#  X_41,1,
#  X_41,10,
#  X_41,11,
#  X_41,12,
#  X_41,13,
#  X_41,14,
#  X_41,2,
#  X_41,3,
#  X_41,4,
#  X_41,5,
#  X_41,6,
#  X_41,7,
#  X_41,8,
#  X_41,9,
#  X_42,0,
#  X_42,1,
#  X_42,10,
#  X_42,11,
#  X_42,12,
#  X_42,13,
#  X_42,14,
#  X_42,2,
#  X_42,3,
#  X_42,4,
#  X_42,5,
#  X_42,6,
#  X_42,7,
#  X_42,8,
#  X_42,9,
#  X_43,0,
#  X_43,1,
#  X_43,10,
#  X_43,11,
#  X_43,12,
#  X_43,13,
#  X_43,14,
#  X_43,2,
#  X_43,3,
#  X_43,4,
#  X_43,5,
#  X_43,6,
#  X_43,7,
#  X_43,8,
#  X_43,9,
#  X_44,0,
#  X_44,1,
#  X_44,10,
#  X_44,11,
#  X_44,12,
#  X_44,13,
#  X_44,14,
#  X_44,2,
#  X_44,3,
#  X_44,4,
#  X_44,5,
#  X_44,6,
#  X_44,7,
#  X_44,8,
#  X_44,9,
#  X_45,0,
#  X_45,1,
#  X_45,10,
#  X_45,11,
#  X_45,12,
#  X_45,13,
#  X_45,14,
#  X_45,2,
#  X_45,3,
#  X_45,4,
#  X_45,5,
#  X_45,6,
#  X_45,7,
#  X_45,8,
#  X_45,9,
#  X_46,0,
#  X_46,1,
#  X_46,10,
#  X_46,11,
#  X_46,12,
#  X_46,13,
#  X_46,14,
#  X_46,2,
#  X_46,3,
#  X_46,4,
#  X_46,5,
#  X_46,6,
#  X_46,7,
#  X_46,8,
#  X_46,9,
#  X_47,0,
#  X_47,1,
#  X_47,10,
#  X_47,11,
#  X_47,12,
#  X_47,13,
#  X_47,14,
#  X_47,2,
#  X_47,3,
#  X_47,4,
#  X_47,5,
#  X_47,6,
#  X_47,7,
#  X_47,8,
#  X_47,9,
#  X_48,0,
#  X_48,1,
#  X_48,10,
#  X_48,11,
#  X_48,12,
#  X_48,13,
#  X_48,14,
#  X_48,2,
#  X_48,3,
#  X_48,4,
#  X_48,5,
#  X_48,6,
#  X_48,7,
#  X_48,8,
#  X_48,9,
#  X_49,0,
#  X_49,1,
#  X_49,10,
#  X_49,11,
#  X_49,12,
#  X_49,13,
#  X_49,14,
#  X_49,2,
#  X_49,3,
#  X_49,4,
#  X_49,5,
#  X_49,6,
#  X_49,7,
#  X_49,8,
#  X_49,9,
#  X_5,0,
#  X_5,1,
#  X_5,10,
#  X_5,11,
#  X_5,12,
#  X_5,13,
#  X_5,14,
#  X_5,2,
#  X_5,3,
#  X_5,4,
#  X_5,5,
#  X_5,6,
#  X_5,7,
#  X_5,8,
#  X_5,9,
#  X_50,0,
#  X_50,1,
#  X_50,10,
#  X_50,11,
#  X_50,12,
#  X_50,13,
#  X_50,14,
#  X_50,2,
#  X_50,3,
#  X_50,4,
#  X_50,5,
#  X_50,6,
#  X_50,7,
#  X_50,8,
#  X_50,9,
#  X_51,0,
#  X_51,1,
#  X_51,10,
#  X_51,11,
#  X_51,12,
#  X_51,13,
#  X_51,14,
#  X_51,2,
#  X_51,3,
#  X_51,4,
#  X_51,5,
#  X_51,6,
#  X_51,7,
#  X_51,8,
#  X_51,9,
#  X_52,0,
#  X_52,1,
#  X_52,10,
#  X_52,11,
#  X_52,12,
#  X_52,13,
#  X_52,14,
#  X_52,2,
#  X_52,3,
#  X_52,4,
#  X_52,5,
#  X_52,6,
#  X_52,7,
#  X_52,8,
#  X_52,9,
#  X_53,0,
#  X_53,1,
#  X_53,10,
#  X_53,11,
#  X_53,12,
#  X_53,13,
#  X_53,14,
#  X_53,2,
#  X_53,3,
#  X_53,4,
#  X_53,5,
#  X_53,6,
#  X_53,7,
#  X_53,8,
#  X_53,9,
#  X_54,0,
#  X_54,1,
#  X_54,10,
#  X_54,11,
#  X_54,12,
#  X_54,13,
#  X_54,14,
#  X_54,2,
#  X_54,3,
#  X_54,4,
#  X_54,5,
#  X_54,6,
#  X_54,7,
#  X_54,8,
#  X_54,9,
#  X_55,0,
#  X_55,1,
#  X_55,10,
#  X_55,11,
#  X_55,12,
#  X_55,13,
#  X_55,14,
#  X_55,2,
#  X_55,3,
#  X_55,4,
#  X_55,5,
#  X_55,6,
#  X_55,7,
#  X_55,8,
#  X_55,9,
#  X_56,0,
#  X_56,1,
#  X_56,10,
#  X_56,11,
#  X_56,12,
#  ...]

# %%
#print(model)
for i in range(n_stands):
    (lpSum(C_allocation[i]*volume[i+1][n_periods]*area_dic[i+1] 
                   ) == VC_allocation[i+1], "VolCarb"+str(i+1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-404-bec615494c60> in <module>
#       1 #print(model)
#       2 for i in range(n_stands):
# ----> 3     (lpSum(C_allocation[i]*volume[i+1][n_periods]*area_dic[i+1]
#       4                    ) == VC_allocation[i+1], "VolCarb"+str(i+1))
#
# KeyError: 7

# %%
#play around with CBC solver 
model.solve(PULP_CBC_CMD(msg=1))

status =  LpStatus[model.status]

print(status)
# Out:
# Optimal

# %%
model
# Out:
# Deer1:
# MAXIMIZE
# 1*alpha_min_0 + 1*alpha_min_1 + 1*alpha_min_10 + 1*alpha_min_11 + 1*alpha_min_12 + 1*alpha_min_13 + 1*alpha_min_14 + 1*alpha_min_2 + 1*alpha_min_3 + 1*alpha_min_4 + 1*alpha_min_5 + 1*alpha_min_6 + 1*alpha_min_7 + 1*alpha_min_8 + 1*alpha_min_9 + 0
# SUBJECT TO
# Forhab_p11_0: - X_1,0 - Y_1,0 + delta_1,1 = 0
#
# Forhab_p21_0: - X_1,0 - X_1,1 - Y_1,0 - Y_1,1 + delta_1,2 = 0
#
# Forhab_f1_13: - X_1,13 - Y_1,13 + delta_1,14 = 0
#
# Forhab_p12_0: - X_10,0 - Y_10,0 + delta_10,1 = 0
#
# Forhab_p22_0: - X_10,0 - X_10,1 - Y_10,0 - Y_10,1 + delta_10,2 = 0
#
# Forhab_f2_13: - X_10,13 - Y_10,13 + delta_10,14 = 0
#
# Forhab_p13_0: - X_11,0 - Y_11,0 + delta_11,1 = 0
#
# Forhab_p23_0: - X_11,0 - X_11,1 - Y_11,0 - Y_11,1 + delta_11,2 = 0
#
# Forhab_f3_13: - X_11,13 - Y_11,13 + delta_11,14 = 0
#
# Forhab_p14_0: - X_12,0 - Y_12,0 + delta_12,1 = 0
#
# Forhab_p24_0: - X_12,0 - X_12,1 - Y_12,0 - Y_12,1 + delta_12,2 = 0
#
# Forhab_f4_13: - X_12,13 - Y_12,13 + delta_12,14 = 0
#
# Forhab_p15_0: - X_13,0 - Y_13,0 + delta_13,1 = 0
#
# Forhab_p25_0: - X_13,0 - X_13,1 - Y_13,0 - Y_13,1 + delta_13,2 = 0
#
# Forhab_f5_13: - X_13,13 - Y_13,13 + delta_13,14 = 0
#
# Forhab_p16_0: - X_14,0 - Y_14,0 + delta_14,1 = 0
#
# Forhab_p26_0: - X_14,0 - X_14,1 - Y_14,0 - Y_14,1 + delta_14,2 = 0
#
# Forhab_f6_13: - X_14,13 - Y_14,13 + delta_14,14 = 0
#
# Forhab_p17_0: - X_15,0 - Y_15,0 + delta_15,1 = 0
#
# Forhab_p27_0: - X_15,0 - X_15,1 - Y_15,0 - Y_15,1 + delta_15,2 = 0
#
# Forhab_f7_13: - X_15,13 - Y_15,13 + delta_15,14 = 0
#
# Forhab_p18_0: - X_16,0 - Y_16,0 + delta_16,1 = 0
#
# Forhab_p28_0: - X_16,0 - X_16,1 - Y_16,0 - Y_16,1 + delta_16,2 = 0
#
# Forhab_f8_13: - X_16,13 - Y_16,13 + delta_16,14 = 0
#
# Forhab_p19_0: - X_19,0 - Y_19,0 + delta_19,1 = 0
#
# Forhab_p29_0: - X_19,0 - X_19,1 - Y_19,0 - Y_19,1 + delta_19,2 = 0
#
# Forhab_f9_13: - X_19,13 - Y_19,13 + delta_19,14 = 0
#
# Forhab_p110_0: - X_2,0 - Y_2,0 + delta_2,1 = 0
#
# Forhab_p210_0: - X_2,0 - X_2,1 - Y_2,0 - Y_2,1 + delta_2,2 = 0
#
# Forhab_f10_13: - X_2,13 - Y_2,13 + delta_2,14 = 0
#
# Forhab_p111_0: - X_20,0 - Y_20,0 + delta_20,1 = 0
#
# Forhab_p211_0: - X_20,0 - X_20,1 - Y_20,0 - Y_20,1 + delta_20,2 = 0
#
# Forhab_f11_13: - X_20,13 - Y_20,13 + delta_20,14 = 0
#
# Forhab_p112_0: - X_21,0 - Y_21,0 + delta_21,1 = 0
#
# Forhab_p212_0: - X_21,0 - X_21,1 - Y_21,0 - Y_21,1 + delta_21,2 = 0
#
# Forhab_f12_13: - X_21,13 - Y_21,13 + delta_21,14 = 0
#
# Forhab_p113_0: - X_22,0 - Y_22,0 + delta_22,1 = 0
#
# Forhab_p213_0: - X_22,0 - X_22,1 - Y_22,0 - Y_22,1 + delta_22,2 = 0
#
# Forhab_f13_13: - X_22,13 - Y_22,13 + delta_22,14 = 0
#
# Forhab_p114_0: - X_23,0 - Y_23,0 + delta_23,1 = 0
#
# Forhab_p214_0: - X_23,0 - X_23,1 - Y_23,0 - Y_23,1 + delta_23,2 = 0
#
# Forhab_f14_13: - X_23,13 - Y_23,13 + delta_23,14 = 0
#
# Forhab_p115_0: - X_24,0 - Y_24,0 + delta_24,1 = 0
#
# Forhab_p215_0: - X_24,0 - X_24,1 - Y_24,0 - Y_24,1 + delta_24,2 = 0
#
# Forhab_f15_13: - X_24,13 - Y_24,13 + delta_24,14 = 0
#
# Forhab_p116_0: - X_25,0 - Y_25,0 + delta_25,1 = 0
#
# Forhab_p216_0: - X_25,0 - X_25,1 - Y_25,0 - Y_25,1 + delta_25,2 = 0
#
# Forhab_f16_13: - X_25,13 - Y_25,13 + delta_25,14 = 0
#
# Forhab_p117_0: - X_26,0 - Y_26,0 + delta_26,1 = 0
#
# Forhab_p217_0: - X_26,0 - X_26,1 - Y_26,0 - Y_26,1 + delta_26,2 = 0
#
# Forhab_f17_13: - X_26,13 - Y_26,13 + delta_26,14 = 0
#
# Forhab_p118_0: - X_27,0 - Y_27,0 + delta_27,1 = 0
#
# Forhab_p218_0: - X_27,0 - X_27,1 - Y_27,0 - Y_27,1 + delta_27,2 = 0
#
# Forhab_f18_13: - X_27,13 - Y_27,13 + delta_27,14 = 0
#
# Forhab_p119_0: - X_28,0 - Y_28,0 + delta_28,1 = 0
#
# Forhab_p219_0: - X_28,0 - X_28,1 - Y_28,0 - Y_28,1 + delta_28,2 = 0
#
# Forhab_f19_13: - X_28,13 - Y_28,13 + delta_28,14 = 0
#
# Forhab_p120_0: - X_29,0 - Y_29,0 + delta_29,1 = 0
#
# Forhab_p220_0: - X_29,0 - X_29,1 - Y_29,0 - Y_29,1 + delta_29,2 = 0
#
# Forhab_f20_13: - X_29,13 - Y_29,13 + delta_29,14 = 0
#
# Forhab_p121_0: - X_3,0 - Y_3,0 + delta_3,1 = 0
#
# Forhab_p221_0: - X_3,0 - X_3,1 - Y_3,0 - Y_3,1 + delta_3,2 = 0
#
# Forhab_f21_13: - X_3,13 - Y_3,13 + delta_3,14 = 0
#
# Forhab_p122_0: - X_30,0 - Y_30,0 + delta_30,1 = 0
#
# Forhab_p222_0: - X_30,0 - X_30,1 - Y_30,0 - Y_30,1 + delta_30,2 = 0
#
# Forhab_f22_13: - X_30,13 - Y_30,13 + delta_30,14 = 0
#
# Forhab_p123_0: - X_31,0 - Y_31,0 + delta_31,1 = 0
#
# Forhab_p223_0: - X_31,0 - X_31,1 - Y_31,0 - Y_31,1 + delta_31,2 = 0
#
# Forhab_f23_13: - X_31,13 - Y_31,13 + delta_31,14 = 0
#
# Forhab_p124_0: - X_32,0 - Y_32,0 + delta_32,1 = 0
#
# Forhab_p224_0: - X_32,0 - X_32,1 - Y_32,0 - Y_32,1 + delta_32,2 = 0
#
# Forhab_f24_13: - X_32,13 - Y_32,13 + delta_32,14 = 0
#
# Forhab_p125_0: - X_33,0 - Y_33,0 + delta_33,1 = 0
#
# Forhab_p225_0: - X_33,0 - X_33,1 - Y_33,0 - Y_33,1 + delta_33,2 = 0
#
# Forhab_f25_13: - X_33,13 - Y_33,13 + delta_33,14 = 0
#
# Forhab_p126_0: - X_34,0 - Y_34,0 + delta_34,1 = 0
#
# Forhab_p226_0: - X_34,0 - X_34,1 - Y_34,0 - Y_34,1 + delta_34,2 = 0
#
# Forhab_f26_13: - X_34,13 - Y_34,13 + delta_34,14 = 0
#
# Forhab_p127_0: - X_35,0 - Y_35,0 + delta_35,1 = 0
#
# Forhab_p227_0: - X_35,0 - X_35,1 - Y_35,0 - Y_35,1 + delta_35,2 = 0
#
# Forhab_f27_13: - X_35,13 - Y_35,13 + delta_35,14 = 0
#
# Forhab_p128_0: - X_37,0 - Y_37,0 + delta_37,1 = 0
#
# Forhab_p228_0: - X_37,0 - X_37,1 - Y_37,0 - Y_37,1 + delta_37,2 = 0
#
# Forhab_f28_13: - X_37,13 - Y_37,13 + delta_37,14 = 0
#
# Forhab_p129_0: - X_38,0 - Y_38,0 + delta_38,1 = 0
#
# Forhab_p229_0: - X_38,0 - X_38,1 - Y_38,0 - Y_38,1 + delta_38,2 = 0
#
# Forhab_f29_13: - X_38,13 - Y_38,13 + delta_38,14 = 0
#
# Forhab_p130_0: - X_39,0 - Y_39,0 + delta_39,1 = 0
#
# Forhab_p230_0: - X_39,0 - X_39,1 - Y_39,0 - Y_39,1 + delta_39,2 = 0
#
# Forhab_f30_13: - X_39,13 - Y_39,13 + delta_39,14 = 0
#
# Forhab_p131_0: - X_4,0 - Y_4,0 + delta_4,1 = 0
#
# Forhab_p231_0: - X_4,0 - X_4,1 - Y_4,0 - Y_4,1 + delta_4,2 = 0
#
# Forhab_f31_13: - X_4,13 - Y_4,13 + delta_4,14 = 0
#
# Forhab_p132_0: - X_40,0 - Y_40,0 + delta_40,1 = 0
#
# Forhab_p232_0: - X_40,0 - X_40,1 - Y_40,0 - Y_40,1 + delta_40,2 = 0
#
# Forhab_f32_13: - X_40,13 - Y_40,13 + delta_40,14 = 0
#
# Forhab_p133_0: - X_41,0 - Y_41,0 + delta_41,1 = 0
#
# Forhab_p233_0: - X_41,0 - X_41,1 - Y_41,0 - Y_41,1 + delta_41,2 = 0
#
# Forhab_f33_13: - X_41,13 - Y_41,13 + delta_41,14 = 0
#
# Forhab_p134_0: - X_42,0 - Y_42,0 + delta_42,1 = 0
#
# Forhab_p234_0: - X_42,0 - X_42,1 - Y_42,0 - Y_42,1 + delta_42,2 = 0
#
# Forhab_f34_13: - X_42,13 - Y_42,13 + delta_42,14 = 0
#
# Forhab_p135_0: - X_43,0 - Y_43,0 + delta_43,1 = 0
#
# Forhab_p235_0: - X_43,0 - X_43,1 - Y_43,0 - Y_43,1 + delta_43,2 = 0
#
# Forhab_f35_13: - X_43,13 - Y_43,13 + delta_43,14 = 0
#
# Forhab_p136_0: - X_44,0 - Y_44,0 + delta_44,1 = 0
#
# Forhab_p236_0: - X_44,0 - X_44,1 - Y_44,0 - Y_44,1 + delta_44,2 = 0
#
# Forhab_f36_13: - X_44,13 - Y_44,13 + delta_44,14 = 0
#
# Forhab_p137_0: - X_45,0 - Y_45,0 + delta_45,1 = 0
#
# Forhab_p237_0: - X_45,0 - X_45,1 - Y_45,0 - Y_45,1 + delta_45,2 = 0
#
# Forhab_f37_13: - X_45,13 - Y_45,13 + delta_45,14 = 0
#
# Forhab_p138_0: - X_46,0 - Y_46,0 + delta_46,1 = 0
#
# Forhab_p238_0: - X_46,0 - X_46,1 - Y_46,0 - Y_46,1 + delta_46,2 = 0
#
# Forhab_f38_13: - X_46,13 - Y_46,13 + delta_46,14 = 0
#
# Forhab_p139_0: - X_47,0 - Y_47,0 + delta_47,1 = 0
#
# Forhab_p239_0: - X_47,0 - X_47,1 - Y_47,0 - Y_47,1 + delta_47,2 = 0
#
# Forhab_f39_13: - X_47,13 - Y_47,13 + delta_47,14 = 0
#
# Forhab_p140_0: - X_48,0 - Y_48,0 + delta_48,1 = 0
#
# Forhab_p240_0: - X_48,0 - X_48,1 - Y_48,0 - Y_48,1 + delta_48,2 = 0
#
# Forhab_f40_13: - X_48,13 - Y_48,13 + delta_48,14 = 0
#
# Forhab_p141_0: - X_49,0 - Y_49,0 + delta_49,1 = 0
#
# Forhab_p241_0: - X_49,0 - X_49,1 - Y_49,0 - Y_49,1 + delta_49,2 = 0
#
# Forhab_f41_13: - X_49,13 - Y_49,13 + delta_49,14 = 0
#
# Forhab_p142_0: - X_5,0 - Y_5,0 + delta_5,1 = 0
#
# Forhab_p242_0: - X_5,0 - X_5,1 - Y_5,0 - Y_5,1 + delta_5,2 = 0
#
# Forhab_f42_13: - X_5,13 - Y_5,13 + delta_5,14 = 0
#
# Forhab_p143_0: - X_50,0 - Y_50,0 + delta_50,1 = 0
#
# Forhab_p243_0: - X_50,0 - X_50,1 - Y_50,0 - Y_50,1 + delta_50,2 = 0
#
# Forhab_f43_13: - X_50,13 - Y_50,13 + delta_50,14 = 0
#
# Forhab_p144_0: - X_51,0 - Y_51,0 + delta_51,1 = 0
#
# Forhab_p244_0: - X_51,0 - X_51,1 - Y_51,0 - Y_51,1 + delta_51,2 = 0
#
# Forhab_f44_13: - X_51,13 - Y_51,13 + delta_51,14 = 0
#
# Forhab_p145_0: - X_52,0 - Y_52,0 + delta_52,1 = 0
#
# Forhab_p245_0: - X_52,0 - X_52,1 - Y_52,0 - Y_52,1 + delta_52,2 = 0
#
# Forhab_f45_13: - X_52,13 - Y_52,13 + delta_52,14 = 0
#
# Forhab_p146_0: - X_53,0 - Y_53,0 + delta_53,1 = 0
#
# Forhab_p246_0: - X_53,0 - X_53,1 - Y_53,0 - Y_53,1 + delta_53,2 = 0
#
# Forhab_f46_13: - X_53,13 - Y_53,13 + delta_53,14 = 0
#
# Forhab_p147_0: - X_54,0 - Y_54,0 + delta_54,1 = 0
#
# Forhab_p247_0: - X_54,0 - X_54,1 - Y_54,0 - Y_54,1 + delta_54,2 = 0
#
# Forhab_f47_13: - X_54,13 - Y_54,13 + delta_54,14 = 0
#
# Forhab_p148_0: - X_55,0 - Y_55,0 + delta_55,1 = 0
#
# Forhab_p248_0: - X_55,0 - X_55,1 - Y_55,0 - Y_55,1 + delta_55,2 = 0
#
# Forhab_f48_13: - X_55,13 - Y_55,13 + delta_55,14 = 0
#
# Forhab_p149_0: - X_56,0 - Y_56,0 + delta_56,1 = 0
#
# Forhab_p249_0: - X_56,0 - X_56,1 - Y_56,0 - Y_56,1 + delta_56,2 = 0
#
# Forhab_f49_13: - X_56,13 - Y_56,13 + delta_56,14 = 0
#
# Forhab_p150_0: - X_57,0 - Y_57,0 + delta_57,1 = 0
#
# Forhab_p250_0: - X_57,0 - X_57,1 - Y_57,0 - Y_57,1 + delta_57,2 = 0
#
# Forhab_f50_13: - X_57,13 - Y_57,13 + delta_57,14 = 0
#
# Forhab_p151_0: - X_58,0 - Y_58,0 + delta_58,1 = 0
#
# Forhab_p251_0: - X_58,0 - X_58,1 - Y_58,0 - Y_58,1 + delta_58,2 = 0
#
# Forhab_f51_13: - X_58,13 - Y_58,13 + delta_58,14 = 0
#
# Forhab_p152_0: - X_59,0 - Y_59,0 + delta_59,1 = 0
#
# Forhab_p252_0: - X_59,0 - X_59,1 - Y_59,0 - Y_59,1 + delta_59,2 = 0
#
# Forhab_f52_13: - X_59,13 - Y_59,13 + delta_59,14 = 0
#
# Forhab_p153_0: - X_6,0 - Y_6,0 + delta_6,1 = 0
#
# Forhab_p253_0: - X_6,0 - X_6,1 - Y_6,0 - Y_6,1 + delta_6,2 = 0
#
# Forhab_f53_13: - X_6,13 - Y_6,13 + delta_6,14 = 0
#
# Forhab_p154_0: - X_60,0 - Y_60,0 + delta_60,1 = 0
#
# Forhab_p254_0: - X_60,0 - X_60,1 - Y_60,0 - Y_60,1 + delta_60,2 = 0
#
# Forhab_f54_13: - X_60,13 - Y_60,13 + delta_60,14 = 0
#
# Forhab_p155_0: - X_61,0 - Y_61,0 + delta_61,1 = 0
#
# Forhab_p255_0: - X_61,0 - X_61,1 - Y_61,0 - Y_61,1 + delta_61,2 = 0
#
# Forhab_f55_13: - X_61,13 - Y_61,13 + delta_61,14 = 0
#
# Forhab_p156_0: - X_62,0 - Y_62,0 + delta_62,1 = 0
#
# Forhab_p256_0: - X_62,0 - X_62,1 - Y_62,0 - Y_62,1 + delta_62,2 = 0
#
# Forhab_f56_13: - X_62,13 - Y_62,13 + delta_62,14 = 0
#
# Forhab_p157_0: - X_63,0 - Y_63,0 + delta_63,1 = 0
#
# Forhab_p257_0: - X_63,0 - X_63,1 - Y_63,0 - Y_63,1 + delta_63,2 = 0
#
# Forhab_f57_13: - X_63,13 - Y_63,13 + delta_63,14 = 0
#
# Forhab_p158_0: - X_64,0 - Y_64,0 + delta_64,1 = 0
#
# Forhab_p258_0: - X_64,0 - X_64,1 - Y_64,0 - Y_64,1 + delta_64,2 = 0
#
# Forhab_f58_13: - X_64,13 - Y_64,13 + delta_64,14 = 0
#
# Forhab_p159_0: - X_66,0 - Y_66,0 + delta_66,1 = 0
#
# Forhab_p259_0: - X_66,0 - X_66,1 - Y_66,0 - Y_66,1 + delta_66,2 = 0
#
# Forhab_f59_13: - X_66,13 - Y_66,13 + delta_66,14 = 0
#
# Forhab_p160_0: - X_660,0 - Y_660,0 + delta_660,1 = 0
#
# Forhab_p260_0: - X_660,0 - X_660,1 - Y_660,0 - Y_660,1 + delta_660,2 = 0
#
# Forhab_f60_13: - X_660,13 - Y_660,13 + delta_660,14 = 0
#
# Forhab_p161_0: - X_661,0 - Y_661,0 + delta_661,1 = 0
#
# Forhab_p261_0: - X_661,0 - X_661,1 - Y_661,0 - Y_661,1 + delta_661,2 = 0
#
# Forhab_f61_13: - X_661,13 - Y_661,13 + delta_661,14 = 0
#
# Forhab_p162_0: - X_662,0 - Y_662,0 + delta_662,1 = 0
#
# Forhab_p262_0: - X_662,0 - X_662,1 - Y_662,0 - Y_662,1 + delta_662,2 = 0
#
# Forhab_f62_13: - X_662,13 - Y_662,13 + delta_662,14 = 0
#
# Forhab_p163_0: - X_67,0 - Y_67,0 + delta_67,1 = 0
#
# Forhab_p263_0: - X_67,0 - X_67,1 - Y_67,0 - Y_67,1 + delta_67,2 = 0
#
# Forhab_f63_13: - X_67,13 - Y_67,13 + delta_67,14 = 0
#
# Forhab_p164_0: - X_68,0 - Y_68,0 + delta_68,1 = 0
#
# Forhab_p264_0: - X_68,0 - X_68,1 - Y_68,0 - Y_68,1 + delta_68,2 = 0
#
# Forhab_f64_13: - X_68,13 - Y_68,13 + delta_68,14 = 0
#
# Forhab_p165_0: - X_69,0 - Y_69,0 + delta_69,1 = 0
#
# Forhab_p265_0: - X_69,0 - X_69,1 - Y_69,0 - Y_69,1 + delta_69,2 = 0
#
# Forhab_f65_13: - X_69,13 - Y_69,13 + delta_69,14 = 0
#
# Forhab_p166_0: - X_71,0 - Y_71,0 + delta_71,1 = 0
#
# Forhab_p266_0: - X_71,0 - X_71,1 - Y_71,0 - Y_71,1 + delta_71,2 = 0
#
# Forhab_f66_13: - X_71,13 - Y_71,13 + delta_71,14 = 0
#
# Forhab_p167_0: - X_72,0 - Y_72,0 + delta_72,1 = 0
#
# Forhab_p267_0: - X_72,0 - X_72,1 - Y_72,0 - Y_72,1 + delta_72,2 = 0
#
# Forhab_f67_13: - X_72,13 - Y_72,13 + delta_72,14 = 0
#
# Forhab_p168_0: - X_730,0 - Y_730,0 + delta_730,1 = 0
#
# Forhab_p268_0: - X_730,0 - X_730,1 - Y_730,0 - Y_730,1 + delta_730,2 = 0
#
# Forhab_f68_13: - X_730,13 - Y_730,13 + delta_730,14 = 0
#
# Forhab_p169_0: - X_731,0 - Y_731,0 + delta_731,1 = 0
#
# Forhab_p269_0: - X_731,0 - X_731,1 - Y_731,0 - Y_731,1 + delta_731,2 = 0
#
# Forhab_f69_13: - X_731,13 - Y_731,13 + delta_731,14 = 0
#
# Forhab_p170_0: - X_732,0 - Y_732,0 + delta_732,1 = 0
#
# Forhab_p270_0: - X_732,0 - X_732,1 - Y_732,0 - Y_732,1 + delta_732,2 = 0
#
# Forhab_f70_13: - X_732,13 - Y_732,13 + delta_732,14 = 0
#
# Forhab_p171_0: - X_733,0 - Y_733,0 + delta_733,1 = 0
#
# Forhab_p271_0: - X_733,0 - X_733,1 - Y_733,0 - Y_733,1 + delta_733,2 = 0
#
# Forhab_f71_13: - X_733,13 - Y_733,13 + delta_733,14 = 0
#
# Forhab_p172_0: - X_734,0 - Y_734,0 + delta_734,1 = 0
#
# Forhab_p272_0: - X_734,0 - X_734,1 - Y_734,0 - Y_734,1 + delta_734,2 = 0
#
# Forhab_f72_13: - X_734,13 - Y_734,13 + delta_734,14 = 0
#
# Forhab_p173_0: - X_74,0 - Y_74,0 + delta_74,1 = 0
#
# Forhab_p273_0: - X_74,0 - X_74,1 - Y_74,0 - Y_74,1 + delta_74,2 = 0
#
# Forhab_f73_13: - X_74,13 - Y_74,13 + delta_74,14 = 0
#
# Forhab_p174_0: - X_750,0 - Y_750,0 + delta_750,1 = 0
#
# Forhab_p274_0: - X_750,0 - X_750,1 - Y_750,0 - Y_750,1 + delta_750,2 = 0
#
# Forhab_f74_13: - X_750,13 - Y_750,13 + delta_750,14 = 0
#
# Forhab_p175_0: - X_751,0 - Y_751,0 + delta_751,1 = 0
#
# Forhab_p275_0: - X_751,0 - X_751,1 - Y_751,0 - Y_751,1 + delta_751,2 = 0
#
# Forhab_f75_13: - X_751,13 - Y_751,13 + delta_751,14 = 0
#
# Forhab_p176_0: - X_752,0 - Y_752,0 + delta_752,1 = 0
#
# Forhab_p276_0: - X_752,0 - X_752,1 - Y_752,0 - Y_752,1 + delta_752,2 = 0
#
# Forhab_f76_13: - X_752,13 - Y_752,13 + delta_752,14 = 0
#
# Forhab_p177_0: - X_753,0 - Y_753,0 + delta_753,1 = 0
#
# Forhab_p277_0: - X_753,0 - X_753,1 - Y_753,0 - Y_753,1 + delta_753,2 = 0
#
# Forhab_f77_13: - X_753,13 - Y_753,13 + delta_753,14 = 0
#
# Forhab_p178_0: - X_754,0 - Y_754,0 + delta_754,1 = 0
#
# Forhab_p278_0: - X_754,0 - X_754,1 - Y_754,0 - Y_754,1 + delta_754,2 = 0
#
# Forhab_f78_13: - X_754,13 - Y_754,13 + delta_754,14 = 0
#
# Forhab_p179_0: - X_755,0 - Y_755,0 + delta_755,1 = 0
#
# Forhab_p279_0: - X_755,0 - X_755,1 - Y_755,0 - Y_755,1 + delta_755,2 = 0
#
# Forhab_f79_13: - X_755,13 - Y_755,13 + delta_755,14 = 0
#
# Forhab_p180_0: - X_756,0 - Y_756,0 + delta_756,1 = 0
#
# Forhab_p280_0: - X_756,0 - X_756,1 - Y_756,0 - Y_756,1 + delta_756,2 = 0
#
# Forhab_f80_13: - X_756,13 - Y_756,13 + delta_756,14 = 0
#
# Forhab_p181_0: - X_757,0 - Y_757,0 + delta_757,1 = 0
#
# Forhab_p281_0: - X_757,0 - X_757,1 - Y_757,0 - Y_757,1 + delta_757,2 = 0
#
# Forhab_f81_13: - X_757,13 - Y_757,13 + delta_757,14 = 0
#
# Forhab_p182_0: - X_758,0 - Y_758,0 + delta_758,1 = 0
#
# Forhab_p282_0: - X_758,0 - X_758,1 - Y_758,0 - Y_758,1 + delta_758,2 = 0
#
# Forhab_f82_13: - X_758,13 - Y_758,13 + delta_758,14 = 0
#
# Forhab_p183_0: - X_759,0 - Y_759,0 + delta_759,1 = 0
#
# Forhab_p283_0: - X_759,0 - X_759,1 - Y_759,0 - Y_759,1 + delta_759,2 = 0
#
# Forhab_f83_13: - X_759,13 - Y_759,13 + delta_759,14 = 0
#
# Forhab_p184_0: - X_760,0 - Y_760,0 + delta_760,1 = 0
#
# Forhab_p284_0: - X_760,0 - X_760,1 - Y_760,0 - Y_760,1 + delta_760,2 = 0
#
# Forhab_f84_13: - X_760,13 - Y_760,13 + delta_760,14 = 0
#
# Forhab_p185_0: - X_761,0 - Y_761,0 + delta_761,1 = 0
#
# Forhab_p285_0: - X_761,0 - X_761,1 - Y_761,0 - Y_761,1 + delta_761,2 = 0
#
# Forhab_f85_13: - X_761,13 - Y_761,13 + delta_761,14 = 0
#
# Forhab_p186_0: - X_762,0 - Y_762,0 + delta_762,1 = 0
#
# Forhab_p286_0: - X_762,0 - X_762,1 - Y_762,0 - Y_762,1 + delta_762,2 = 0
#
# Forhab_f86_13: - X_762,13 - Y_762,13 + delta_762,14 = 0
#
# Forhab_p187_0: - X_763,0 - Y_763,0 + delta_763,1 = 0
#
# Forhab_p287_0: - X_763,0 - X_763,1 - Y_763,0 - Y_763,1 + delta_763,2 = 0
#
# Forhab_f87_13: - X_763,13 - Y_763,13 + delta_763,14 = 0
#
# Forhab_p188_0: - X_764,0 - Y_764,0 + delta_764,1 = 0
#
# Forhab_p288_0: - X_764,0 - X_764,1 - Y_764,0 - Y_764,1 + delta_764,2 = 0
#
# Forhab_f88_13: - X_764,13 - Y_764,13 + delta_764,14 = 0
#
# Forhab_p189_0: - X_770,0 - Y_770,0 + delta_770,1 = 0
#
# Forhab_p289_0: - X_770,0 - X_770,1 - Y_770,0 - Y_770,1 + delta_770,2 = 0
#
# Forhab_f89_13: - X_770,13 - Y_770,13 + delta_770,14 = 0
#
# Forhab_p190_0: - X_771,0 - Y_771,0 + delta_771,1 = 0
#
# Forhab_p290_0: - X_771,0 - X_771,1 - Y_771,0 - Y_771,1 + delta_771,2 = 0
#
# Forhab_f90_13: - X_771,13 - Y_771,13 + delta_771,14 = 0
#
# Forhab_p191_0: - X_772,0 - Y_772,0 + delta_772,1 = 0
#
# Forhab_p291_0: - X_772,0 - X_772,1 - Y_772,0 - Y_772,1 + delta_772,2 = 0
#
# Forhab_f91_13: - X_772,13 - Y_772,13 + delta_772,14 = 0
#
# Forhab_p192_0: - X_773,0 - Y_773,0 + delta_773,1 = 0
#
# Forhab_p292_0: - X_773,0 - X_773,1 - Y_773,0 - Y_773,1 + delta_773,2 = 0
#
# Forhab_f92_13: - X_773,13 - Y_773,13 + delta_773,14 = 0
#
# Forhab_p193_0: - X_774,0 - Y_774,0 + delta_774,1 = 0
#
# Forhab_p293_0: - X_774,0 - X_774,1 - Y_774,0 - Y_774,1 + delta_774,2 = 0
#
# Forhab_f93_13: - X_774,13 - Y_774,13 + delta_774,14 = 0
#
# Forhab_p194_0: - X_775,0 - Y_775,0 + delta_775,1 = 0
#
# Forhab_p294_0: - X_775,0 - X_775,1 - Y_775,0 - Y_775,1 + delta_775,2 = 0
#
# Forhab_f94_13: - X_775,13 - Y_775,13 + delta_775,14 = 0
#
# Forhab_p195_0: - X_776,0 - Y_776,0 + delta_776,1 = 0
#
# Forhab_p295_0: - X_776,0 - X_776,1 - Y_776,0 - Y_776,1 + delta_776,2 = 0
#
# Forhab_f95_13: - X_776,13 - Y_776,13 + delta_776,14 = 0
#
# Forhab_p196_0: - X_777,0 - Y_777,0 + delta_777,1 = 0
#
# Forhab_p296_0: - X_777,0 - X_777,1 - Y_777,0 - Y_777,1 + delta_777,2 = 0
#
# Forhab_f96_13: - X_777,13 - Y_777,13 + delta_777,14 = 0
#
# Forhab_p197_0: - X_778,0 - Y_778,0 + delta_778,1 = 0
#
# Forhab_p297_0: - X_778,0 - X_778,1 - Y_778,0 - Y_778,1 + delta_778,2 = 0
#
# Forhab_f97_13: - X_778,13 - Y_778,13 + delta_778,14 = 0
#
# Forhab_p198_0: - X_779,0 - Y_779,0 + delta_779,1 = 0
#
# Forhab_p298_0: - X_779,0 - X_779,1 - Y_779,0 - Y_779,1 + delta_779,2 = 0
#
# Forhab_f98_13: - X_779,13 - Y_779,13 + delta_779,14 = 0
#
# Forhab_p199_0: - X_78,0 - Y_78,0 + delta_78,1 = 0
#
# Forhab_p299_0: - X_78,0 - X_78,1 - Y_78,0 - Y_78,1 + delta_78,2 = 0
#
# Forhab_f99_13: - X_78,13 - Y_78,13 + delta_78,14 = 0
#
# Forhab_p1100_0: - X_79,0 - Y_79,0 + delta_79,1 = 0
#
# Forhab_p2100_0: - X_79,0 - X_79,1 - Y_79,0 - Y_79,1 + delta_79,2 = 0
#
# Forhab_f100_13: - X_79,13 - Y_79,13 + delta_79,14 = 0
#
# Forhab_p1101_0: - X_8,0 - Y_8,0 + delta_8,1 = 0
#
# Forhab_p2101_0: - X_8,0 - X_8,1 - Y_8,0 - Y_8,1 + delta_8,2 = 0
#
# Forhab_f101_13: - X_8,13 - Y_8,13 + delta_8,14 = 0
#
# Forhab_p1102_0: - X_800,0 - Y_800,0 + delta_800,1 = 0
#
# Forhab_p2102_0: - X_800,0 - X_800,1 - Y_800,0 - Y_800,1 + delta_800,2 = 0
#
# Forhab_f102_13: - X_800,13 - Y_800,13 + delta_800,14 = 0
#
# Forhab_p1103_0: - X_801,0 - Y_801,0 + delta_801,1 = 0
#
# Forhab_p2103_0: - X_801,0 - X_801,1 - Y_801,0 - Y_801,1 + delta_801,2 = 0
#
# Forhab_f103_13: - X_801,13 - Y_801,13 + delta_801,14 = 0
#
# Forhab_p1104_0: - X_802,0 - Y_802,0 + delta_802,1 = 0
#
# Forhab_p2104_0: - X_802,0 - X_802,1 - Y_802,0 - Y_802,1 + delta_802,2 = 0
#
# Forhab_f104_13: - X_802,13 - Y_802,13 + delta_802,14 = 0
#
# Forhab_p1105_0: - X_803,0 - Y_803,0 + delta_803,1 = 0
#
# Forhab_p2105_0: - X_803,0 - X_803,1 - Y_803,0 - Y_803,1 + delta_803,2 = 0
#
# Forhab_f105_13: - X_803,13 - Y_803,13 + delta_803,14 = 0
#
# Forhab_p1106_0: - X_804,0 - Y_804,0 + delta_804,1 = 0
#
# Forhab_p2106_0: - X_804,0 - X_804,1 - Y_804,0 - Y_804,1 + delta_804,2 = 0
#
# Forhab_f106_13: - X_804,13 - Y_804,13 + delta_804,14 = 0
#
# Forhab_p1107_0: - X_81,0 - Y_81,0 + delta_81,1 = 0
#
# Forhab_p2107_0: - X_81,0 - X_81,1 - Y_81,0 - Y_81,1 + delta_81,2 = 0
#
# Forhab_f107_13: - X_81,13 - Y_81,13 + delta_81,14 = 0
#
# Forhab_p1108_0: - X_82,0 - Y_82,0 + delta_82,1 = 0
#
# Forhab_p2108_0: - X_82,0 - X_82,1 - Y_82,0 - Y_82,1 + delta_82,2 = 0
#
# Forhab_f108_13: - X_82,13 - Y_82,13 + delta_82,14 = 0
#
# Forhab_p1109_0: - X_83,0 - Y_83,0 + delta_83,1 = 0
#
# Forhab_p2109_0: - X_83,0 - X_83,1 - Y_83,0 - Y_83,1 + delta_83,2 = 0
#
# Forhab_f109_13: - X_83,13 - Y_83,13 + delta_83,14 = 0
#
# Forhab_p1110_0: - X_84,0 - Y_84,0 + delta_84,1 = 0
#
# Forhab_p2110_0: - X_84,0 - X_84,1 - Y_84,0 - Y_84,1 + delta_84,2 = 0
#
# Forhab_f110_13: - X_84,13 - Y_84,13 + delta_84,14 = 0
#
# Forhab_p1111_0: - X_85,0 - Y_85,0 + delta_85,1 = 0
#
# Forhab_p2111_0: - X_85,0 - X_85,1 - Y_85,0 - Y_85,1 + delta_85,2 = 0
#
# Forhab_f111_13: - X_85,13 - Y_85,13 + delta_85,14 = 0
#
# Forhab_p1112_0: - X_86,0 - Y_86,0 + delta_86,1 = 0
#
# Forhab_p2112_0: - X_86,0 - X_86,1 - Y_86,0 - Y_86,1 + delta_86,2 = 0
#
# Forhab_f112_13: - X_86,13 - Y_86,13 + delta_86,14 = 0
#
# Forhab_p1113_0: - X_87,0 - Y_87,0 + delta_87,1 = 0
#
# Forhab_p2113_0: - X_87,0 - X_87,1 - Y_87,0 - Y_87,1 + delta_87,2 = 0
#
# Forhab_f113_13: - X_87,13 - Y_87,13 + delta_87,14 = 0
#
# Forhab_p1114_0: - X_88,0 - Y_88,0 + delta_88,1 = 0
#
# Forhab_p2114_0: - X_88,0 - X_88,1 - Y_88,0 - Y_88,1 + delta_88,2 = 0
#
# Forhab_f114_13: - X_88,13 - Y_88,13 + delta_88,14 = 0
#
# Forhab_p1115_0: - X_890,0 - Y_890,0 + delta_890,1 = 0
#
# Forhab_p2115_0: - X_890,0 - X_890,1 - Y_890,0 - Y_890,1 + delta_890,2 = 0
#
# Forhab_f115_13: - X_890,13 - Y_890,13 + delta_890,14 = 0
#
# Forhab_p1116_0: - X_891,0 - Y_891,0 + delta_891,1 = 0
#
# Forhab_p2116_0: - X_891,0 - X_891,1 - Y_891,0 - Y_891,1 + delta_891,2 = 0
#
# Forhab_f116_13: - X_891,13 - Y_891,13 + delta_891,14 = 0
#
# Forhab_p1117_0: - X_892,0 - Y_892,0 + delta_892,1 = 0
#
# Forhab_p2117_0: - X_892,0 - X_892,1 - Y_892,0 - Y_892,1 + delta_892,2 = 0
#
# Forhab_f117_13: - X_892,13 - Y_892,13 + delta_892,14 = 0
#
# Forhab_p1118_0: - X_893,0 - Y_893,0 + delta_893,1 = 0
#
# Forhab_p2118_0: - X_893,0 - X_893,1 - Y_893,0 - Y_893,1 + delta_893,2 = 0
#
# Forhab_f118_13: - X_893,13 - Y_893,13 + delta_893,14 = 0
#
# Forhab_p1119_0: - X_9,0 - Y_9,0 + delta_9,1 = 0
#
# Forhab_p2119_0: - X_9,0 - X_9,1 - Y_9,0 - Y_9,1 + delta_9,2 = 0
#
# Forhab_f119_13: - X_9,13 - Y_9,13 + delta_9,14 = 0
#
# Forhab_p1120_0: - X_90,0 - Y_90,0 + delta_90,1 = 0
#
# Forhab_p2120_0: - X_90,0 - X_90,1 - Y_90,0 - Y_90,1 + delta_90,2 = 0
#
# Forhab_f120_13: - X_90,13 - Y_90,13 + delta_90,14 = 0
#
# Forhab_p1121_0: - X_91,0 - Y_91,0 + delta_91,1 = 0
#
# Forhab_p2121_0: - X_91,0 - X_91,1 - Y_91,0 - Y_91,1 + delta_91,2 = 0
#
# Forhab_f121_13: - X_91,13 - Y_91,13 + delta_91,14 = 0
#
# One_PCT_1: X_1,0 + X_1,1 + X_1,10 + X_1,11 + X_1,12 + X_1,13 + X_1,14 + X_1,2
#  + X_1,3 + X_1,4 + X_1,5 + X_1,6 + X_1,7 + X_1,8 + X_1,9 <= 1
#
# One_harv_1: Y_1,0 + Y_1,1 + Y_1,10 + Y_1,11 + Y_1,12 + Y_1,13 + Y_1,14 + Y_1,2
#  + Y_1,3 + Y_1,4 + Y_1,5 + Y_1,6 + Y_1,7 + Y_1,8 + Y_1,9 <= 1
#
# One_PCT_2: X_10,0 + X_10,1 + X_10,10 + X_10,11 + X_10,12 + X_10,13 + X_10,14
#  + X_10,2 + X_10,3 + X_10,4 + X_10,5 + X_10,6 + X_10,7 + X_10,8 + X_10,9 <= 1
#
# One_harv_2: Y_10,0 + Y_10,1 + Y_10,10 + Y_10,11 + Y_10,12 + Y_10,13 + Y_10,14
#  + Y_10,2 + Y_10,3 + Y_10,4 + Y_10,5 + Y_10,6 + Y_10,7 + Y_10,8 + Y_10,9 <= 1
#
# One_PCT_3: X_11,0 + X_11,1 + X_11,10 + X_11,11 + X_11,12 + X_11,13 + X_11,14
#  + X_11,2 + X_11,3 + X_11,4 + X_11,5 + X_11,6 + X_11,7 + X_11,8 + X_11,9 <= 1
#
# One_harv_3: Y_11,0 + Y_11,1 + Y_11,10 + Y_11,11 + Y_11,12 + Y_11,13 + Y_11,14
#  + Y_11,2 + Y_11,3 + Y_11,4 + Y_11,5 + Y_11,6 + Y_11,7 + Y_11,8 + Y_11,9 <= 1
#
# One_PCT_4: X_12,0 + X_12,1 + X_12,10 + X_12,11 + X_12,12 + X_12,13 + X_12,14
#  + X_12,2 + X_12,3 + X_12,4 + X_12,5 + X_12,6 + X_12,7 + X_12,8 + X_12,9 <= 1
#
# One_harv_4: Y_12,0 + Y_12,1 + Y_12,10 + Y_12,11 + Y_12,12 + Y_12,13 + Y_12,14
#  + Y_12,2 + Y_12,3 + Y_12,4 + Y_12,5 + Y_12,6 + Y_12,7 + Y_12,8 + Y_12,9 <= 1
#
# One_PCT_5: X_13,0 + X_13,1 + X_13,10 + X_13,11 + X_13,12 + X_13,13 + X_13,14
#  + X_13,2 + X_13,3 + X_13,4 + X_13,5 + X_13,6 + X_13,7 + X_13,8 + X_13,9 <= 1
#
# One_harv_5: Y_13,0 + Y_13,1 + Y_13,10 + Y_13,11 + Y_13,12 + Y_13,13 + Y_13,14
#  + Y_13,2 + Y_13,3 + Y_13,4 + Y_13,5 + Y_13,6 + Y_13,7 + Y_13,8 + Y_13,9 <= 1
#
# One_PCT_6: X_14,0 + X_14,1 + X_14,10 + X_14,11 + X_14,12 + X_14,13 + X_14,14
#  + X_14,2 + X_14,3 + X_14,4 + X_14,5 + X_14,6 + X_14,7 + X_14,8 + X_14,9 <= 1
#
# One_harv_6: Y_14,0 + Y_14,1 + Y_14,10 + Y_14,11 + Y_14,12 + Y_14,13 + Y_14,14
#  + Y_14,2 + Y_14,3 + Y_14,4 + Y_14,5 + Y_14,6 + Y_14,7 + Y_14,8 + Y_14,9 <= 1
#
# One_PCT_7: X_15,0 + X_15,1 + X_15,10 + X_15,11 + X_15,12 + X_15,13 + X_15,14
#  + X_15,2 + X_15,3 + X_15,4 + X_15,5 + X_15,6 + X_15,7 + X_15,8 + X_15,9 <= 1
#
# One_harv_7: Y_15,0 + Y_15,1 + Y_15,10 + Y_15,11 + Y_15,12 + Y_15,13 + Y_15,14
#  + Y_15,2 + Y_15,3 + Y_15,4 + Y_15,5 + Y_15,6 + Y_15,7 + Y_15,8 + Y_15,9 <= 1
#
# One_PCT_8: X_16,0 + X_16,1 + X_16,10 + X_16,11 + X_16,12 + X_16,13 + X_16,14
#  + X_16,2 + X_16,3 + X_16,4 + X_16,5 + X_16,6 + X_16,7 + X_16,8 + X_16,9 <= 1
#
# One_harv_8: Y_16,0 + Y_16,1 + Y_16,10 + Y_16,11 + Y_16,12 + Y_16,13 + Y_16,14
#  + Y_16,2 + Y_16,3 + Y_16,4 + Y_16,5 + Y_16,6 + Y_16,7 + Y_16,8 + Y_16,9 <= 1
#
# One_PCT_9: X_19,0 + X_19,1 + X_19,10 + X_19,11 + X_19,12 + X_19,13 + X_19,14
#  + X_19,2 + X_19,3 + X_19,4 + X_19,5 + X_19,6 + X_19,7 + X_19,8 + X_19,9 <= 1
#
# One_harv_9: Y_19,0 + Y_19,1 + Y_19,10 + Y_19,11 + Y_19,12 + Y_19,13 + Y_19,14
#  + Y_19,2 + Y_19,3 + Y_19,4 + Y_19,5 + Y_19,6 + Y_19,7 + Y_19,8 + Y_19,9 <= 1
#
# One_PCT_10: X_2,0 + X_2,1 + X_2,10 + X_2,11 + X_2,12 + X_2,13 + X_2,14 + X_2,2
#  + X_2,3 + X_2,4 + X_2,5 + X_2,6 + X_2,7 + X_2,8 + X_2,9 <= 1
#
# One_harv_10: Y_2,0 + Y_2,1 + Y_2,10 + Y_2,11 + Y_2,12 + Y_2,13 + Y_2,14
#  + Y_2,2 + Y_2,3 + Y_2,4 + Y_2,5 + Y_2,6 + Y_2,7 + Y_2,8 + Y_2,9 <= 1
#
# One_PCT_11: X_20,0 + X_20,1 + X_20,10 + X_20,11 + X_20,12 + X_20,13 + X_20,14
#  + X_20,2 + X_20,3 + X_20,4 + X_20,5 + X_20,6 + X_20,7 + X_20,8 + X_20,9 <= 1
#
# One_harv_11: Y_20,0 + Y_20,1 + Y_20,10 + Y_20,11 + Y_20,12 + Y_20,13 + Y_20,14
#  + Y_20,2 + Y_20,3 + Y_20,4 + Y_20,5 + Y_20,6 + Y_20,7 + Y_20,8 + Y_20,9 <= 1
#
# One_PCT_12: X_21,0 + X_21,1 + X_21,10 + X_21,11 + X_21,12 + X_21,13 + X_21,14
#  + X_21,2 + X_21,3 + X_21,4 + X_21,5 + X_21,6 + X_21,7 + X_21,8 + X_21,9 <= 1
#
# One_harv_12: Y_21,0 + Y_21,1 + Y_21,10 + Y_21,11 + Y_21,12 + Y_21,13 + Y_21,14
#  + Y_21,2 + Y_21,3 + Y_21,4 + Y_21,5 + Y_21,6 + Y_21,7 + Y_21,8 + Y_21,9 <= 1
#
# One_PCT_13: X_22,0 + X_22,1 + X_22,10 + X_22,11 + X_22,12 + X_22,13 + X_22,14
#  + X_22,2 + X_22,3 + X_22,4 + X_22,5 + X_22,6 + X_22,7 + X_22,8 + X_22,9 <= 1
#
# One_harv_13: Y_22,0 + Y_22,1 + Y_22,10 + Y_22,11 + Y_22,12 + Y_22,13 + Y_22,14
#  + Y_22,2 + Y_22,3 + Y_22,4 + Y_22,5 + Y_22,6 + Y_22,7 + Y_22,8 + Y_22,9 <= 1
#
# One_PCT_14: X_23,0 + X_23,1 + X_23,10 + X_23,11 + X_23,12 + X_23,13 + X_23,14
#  + X_23,2 + X_23,3 + X_23,4 + X_23,5 + X_23,6 + X_23,7 + X_23,8 + X_23,9 <= 1
#
# One_harv_14: Y_23,0 + Y_23,1 + Y_23,10 + Y_23,11 + Y_23,12 + Y_23,13 + Y_23,14
#  + Y_23,2 + Y_23,3 + Y_23,4 + Y_23,5 + Y_23,6 + Y_23,7 + Y_23,8 + Y_23,9 <= 1
#
# One_PCT_15: X_24,0 + X_24,1 + X_24,10 + X_24,11 + X_24,12 + X_24,13 + X_24,14
#  + X_24,2 + X_24,3 + X_24,4 + X_24,5 + X_24,6 + X_24,7 + X_24,8 + X_24,9 <= 1
#
# One_harv_15: Y_24,0 + Y_24,1 + Y_24,10 + Y_24,11 + Y_24,12 + Y_24,13 + Y_24,14
#  + Y_24,2 + Y_24,3 + Y_24,4 + Y_24,5 + Y_24,6 + Y_24,7 + Y_24,8 + Y_24,9 <= 1
#
# One_PCT_16: X_25,0 + X_25,1 + X_25,10 + X_25,11 + X_25,12 + X_25,13 + X_25,14
#  + X_25,2 + X_25,3 + X_25,4 + X_25,5 + X_25,6 + X_25,7 + X_25,8 + X_25,9 <= 1
#
# One_harv_16: Y_25,0 + Y_25,1 + Y_25,10 + Y_25,11 + Y_25,12 + Y_25,13 + Y_25,14
#  + Y_25,2 + Y_25,3 + Y_25,4 + Y_25,5 + Y_25,6 + Y_25,7 + Y_25,8 + Y_25,9 <= 1
#
# One_PCT_17: X_26,0 + X_26,1 + X_26,10 + X_26,11 + X_26,12 + X_26,13 + X_26,14
#  + X_26,2 + X_26,3 + X_26,4 + X_26,5 + X_26,6 + X_26,7 + X_26,8 + X_26,9 <= 1
#
# One_harv_17: Y_26,0 + Y_26,1 + Y_26,10 + Y_26,11 + Y_26,12 + Y_26,13 + Y_26,14
#  + Y_26,2 + Y_26,3 + Y_26,4 + Y_26,5 + Y_26,6 + Y_26,7 + Y_26,8 + Y_26,9 <= 1
#
# One_PCT_18: X_27,0 + X_27,1 + X_27,10 + X_27,11 + X_27,12 + X_27,13 + X_27,14
#  + X_27,2 + X_27,3 + X_27,4 + X_27,5 + X_27,6 + X_27,7 + X_27,8 + X_27,9 <= 1
#
# One_harv_18: Y_27,0 + Y_27,1 + Y_27,10 + Y_27,11 + Y_27,12 + Y_27,13 + Y_27,14
#  + Y_27,2 + Y_27,3 + Y_27,4 + Y_27,5 + Y_27,6 + Y_27,7 + Y_27,8 + Y_27,9 <= 1
#
# One_PCT_19: X_28,0 + X_28,1 + X_28,10 + X_28,11 + X_28,12 + X_28,13 + X_28,14
#  + X_28,2 + X_28,3 + X_28,4 + X_28,5 + X_28,6 + X_28,7 + X_28,8 + X_28,9 <= 1
#
# One_harv_19: Y_28,0 + Y_28,1 + Y_28,10 + Y_28,11 + Y_28,12 + Y_28,13 + Y_28,14
#  + Y_28,2 + Y_28,3 + Y_28,4 + Y_28,5 + Y_28,6 + Y_28,7 + Y_28,8 + Y_28,9 <= 1
#
# One_PCT_20: X_29,0 + X_29,1 + X_29,10 + X_29,11 + X_29,12 + X_29,13 + X_29,14
#  + X_29,2 + X_29,3 + X_29,4 + X_29,5 + X_29,6 + X_29,7 + X_29,8 + X_29,9 <= 1
#
# One_harv_20: Y_29,0 + Y_29,1 + Y_29,10 + Y_29,11 + Y_29,12 + Y_29,13 + Y_29,14
#  + Y_29,2 + Y_29,3 + Y_29,4 + Y_29,5 + Y_29,6 + Y_29,7 + Y_29,8 + Y_29,9 <= 1
#
# One_PCT_21: X_3,0 + X_3,1 + X_3,10 + X_3,11 + X_3,12 + X_3,13 + X_3,14 + X_3,2
#  + X_3,3 + X_3,4 + X_3,5 + X_3,6 + X_3,7 + X_3,8 + X_3,9 <= 1
#
# One_harv_21: Y_3,0 + Y_3,1 + Y_3,10 + Y_3,11 + Y_3,12 + Y_3,13 + Y_3,14
#  + Y_3,2 + Y_3,3 + Y_3,4 + Y_3,5 + Y_3,6 + Y_3,7 + Y_3,8 + Y_3,9 <= 1
#
# One_PCT_22: X_30,0 + X_30,1 + X_30,10 + X_30,11 + X_30,12 + X_30,13 + X_30,14
#  + X_30,2 + X_30,3 + X_30,4 + X_30,5 + X_30,6 + X_30,7 + X_30,8 + X_30,9 <= 1
#
# One_harv_22: Y_30,0 + Y_30,1 + Y_30,10 + Y_30,11 + Y_30,12 + Y_30,13 + Y_30,14
#  + Y_30,2 + Y_30,3 + Y_30,4 + Y_30,5 + Y_30,6 + Y_30,7 + Y_30,8 + Y_30,9 <= 1
#
# One_PCT_23: X_31,0 + X_31,1 + X_31,10 + X_31,11 + X_31,12 + X_31,13 + X_31,14
#  + X_31,2 + X_31,3 + X_31,4 + X_31,5 + X_31,6 + X_31,7 + X_31,8 + X_31,9 <= 1
#
# One_harv_23: Y_31,0 + Y_31,1 + Y_31,10 + Y_31,11 + Y_31,12 + Y_31,13 + Y_31,14
#  + Y_31,2 + Y_31,3 + Y_31,4 + Y_31,5 + Y_31,6 + Y_31,7 + Y_31,8 + Y_31,9 <= 1
#
# One_PCT_24: X_32,0 + X_32,1 + X_32,10 + X_32,11 + X_32,12 + X_32,13 + X_32,14
#  + X_32,2 + X_32,3 + X_32,4 + X_32,5 + X_32,6 + X_32,7 + X_32,8 + X_32,9 <= 1
#
# One_harv_24: Y_32,0 + Y_32,1 + Y_32,10 + Y_32,11 + Y_32,12 + Y_32,13 + Y_32,14
#  + Y_32,2 + Y_32,3 + Y_32,4 + Y_32,5 + Y_32,6 + Y_32,7 + Y_32,8 + Y_32,9 <= 1
#
# One_PCT_25: X_33,0 + X_33,1 + X_33,10 + X_33,11 + X_33,12 + X_33,13 + X_33,14
#  + X_33,2 + X_33,3 + X_33,4 + X_33,5 + X_33,6 + X_33,7 + X_33,8 + X_33,9 <= 1
#
# One_harv_25: Y_33,0 + Y_33,1 + Y_33,10 + Y_33,11 + Y_33,12 + Y_33,13 + Y_33,14
#  + Y_33,2 + Y_33,3 + Y_33,4 + Y_33,5 + Y_33,6 + Y_33,7 + Y_33,8 + Y_33,9 <= 1
#
# One_PCT_26: X_34,0 + X_34,1 + X_34,10 + X_34,11 + X_34,12 + X_34,13 + X_34,14
#  + X_34,2 + X_34,3 + X_34,4 + X_34,5 + X_34,6 + X_34,7 + X_34,8 + X_34,9 <= 1
#
# One_harv_26: Y_34,0 + Y_34,1 + Y_34,10 + Y_34,11 + Y_34,12 + Y_34,13 + Y_34,14
#  + Y_34,2 + Y_34,3 + Y_34,4 + Y_34,5 + Y_34,6 + Y_34,7 + Y_34,8 + Y_34,9 <= 1
#
# One_PCT_27: X_35,0 + X_35,1 + X_35,10 + X_35,11 + X_35,12 + X_35,13 + X_35,14
#  + X_35,2 + X_35,3 + X_35,4 + X_35,5 + X_35,6 + X_35,7 + X_35,8 + X_35,9 <= 1
#
# One_harv_27: Y_35,0 + Y_35,1 + Y_35,10 + Y_35,11 + Y_35,12 + Y_35,13 + Y_35,14
#  + Y_35,2 + Y_35,3 + Y_35,4 + Y_35,5 + Y_35,6 + Y_35,7 + Y_35,8 + Y_35,9 <= 1
#
# One_PCT_28: X_37,0 + X_37,1 + X_37,10 + X_37,11 + X_37,12 + X_37,13 + X_37,14
#  + X_37,2 + X_37,3 + X_37,4 + X_37,5 + X_37,6 + X_37,7 + X_37,8 + X_37,9 <= 1
#
# One_harv_28: Y_37,0 + Y_37,1 + Y_37,10 + Y_37,11 + Y_37,12 + Y_37,13 + Y_37,14
#  + Y_37,2 + Y_37,3 + Y_37,4 + Y_37,5 + Y_37,6 + Y_37,7 + Y_37,8 + Y_37,9 <= 1
#
# One_PCT_29: X_38,0 + X_38,1 + X_38,10 + X_38,11 + X_38,12 + X_38,13 + X_38,14
#  + X_38,2 + X_38,3 + X_38,4 + X_38,5 + X_38,6 + X_38,7 + X_38,8 + X_38,9 <= 1
#
# One_harv_29: Y_38,0 + Y_38,1 + Y_38,10 + Y_38,11 + Y_38,12 + Y_38,13 + Y_38,14
#  + Y_38,2 + Y_38,3 + Y_38,4 + Y_38,5 + Y_38,6 + Y_38,7 + Y_38,8 + Y_38,9 <= 1
#
# One_PCT_30: X_39,0 + X_39,1 + X_39,10 + X_39,11 + X_39,12 + X_39,13 + X_39,14
#  + X_39,2 + X_39,3 + X_39,4 + X_39,5 + X_39,6 + X_39,7 + X_39,8 + X_39,9 <= 1
#
# One_harv_30: Y_39,0 + Y_39,1 + Y_39,10 + Y_39,11 + Y_39,12 + Y_39,13 + Y_39,14
#  + Y_39,2 + Y_39,3 + Y_39,4 + Y_39,5 + Y_39,6 + Y_39,7 + Y_39,8 + Y_39,9 <= 1
#
# One_PCT_31: X_4,0 + X_4,1 + X_4,10 + X_4,11 + X_4,12 + X_4,13 + X_4,14 + X_4,2
#  + X_4,3 + X_4,4 + X_4,5 + X_4,6 + X_4,7 + X_4,8 + X_4,9 <= 1
#
# One_harv_31: Y_4,0 + Y_4,1 + Y_4,10 + Y_4,11 + Y_4,12 + Y_4,13 + Y_4,14
#  + Y_4,2 + Y_4,3 + Y_4,4 + Y_4,5 + Y_4,6 + Y_4,7 + Y_4,8 + Y_4,9 <= 1
#
# One_PCT_32: X_40,0 + X_40,1 + X_40,10 + X_40,11 + X_40,12 + X_40,13 + X_40,14
#  + X_40,2 + X_40,3 + X_40,4 + X_40,5 + X_40,6 + X_40,7 + X_40,8 + X_40,9 <= 1
#
# One_harv_32: Y_40,0 + Y_40,1 + Y_40,10 + Y_40,11 + Y_40,12 + Y_40,13 + Y_40,14
#  + Y_40,2 + Y_40,3 + Y_40,4 + Y_40,5 + Y_40,6 + Y_40,7 + Y_40,8 + Y_40,9 <= 1
#
# One_PCT_33: X_41,0 + X_41,1 + X_41,10 + X_41,11 + X_41,12 + X_41,13 + X_41,14
#  + X_41,2 + X_41,3 + X_41,4 + X_41,5 + X_41,6 + X_41,7 + X_41,8 + X_41,9 <= 1
#
# One_harv_33: Y_41,0 + Y_41,1 + Y_41,10 + Y_41,11 + Y_41,12 + Y_41,13 + Y_41,14
#  + Y_41,2 + Y_41,3 + Y_41,4 + Y_41,5 + Y_41,6 + Y_41,7 + Y_41,8 + Y_41,9 <= 1
#
# One_PCT_34: X_42,0 + X_42,1 + X_42,10 + X_42,11 + X_42,12 + X_42,13 + X_42,14
#  + X_42,2 + X_42,3 + X_42,4 + X_42,5 + X_42,6 + X_42,7 + X_42,8 + X_42,9 <= 1
#
# One_harv_34: Y_42,0 + Y_42,1 + Y_42,10 + Y_42,11 + Y_42,12 + Y_42,13 + Y_42,14
#  + Y_42,2 + Y_42,3 + Y_42,4 + Y_42,5 + Y_42,6 + Y_42,7 + Y_42,8 + Y_42,9 <= 1
#
# One_PCT_35: X_43,0 + X_43,1 + X_43,10 + X_43,11 + X_43,12 + X_43,13 + X_43,14
#  + X_43,2 + X_43,3 + X_43,4 + X_43,5 + X_43,6 + X_43,7 + X_43,8 + X_43,9 <= 1
#
# One_harv_35: Y_43,0 + Y_43,1 + Y_43,10 + Y_43,11 + Y_43,12 + Y_43,13 + Y_43,14
#  + Y_43,2 + Y_43,3 + Y_43,4 + Y_43,5 + Y_43,6 + Y_43,7 + Y_43,8 + Y_43,9 <= 1
#
# One_PCT_36: X_44,0 + X_44,1 + X_44,10 + X_44,11 + X_44,12 + X_44,13 + X_44,14
#  + X_44,2 + X_44,3 + X_44,4 + X_44,5 + X_44,6 + X_44,7 + X_44,8 + X_44,9 <= 1
#
# One_harv_36: Y_44,0 + Y_44,1 + Y_44,10 + Y_44,11 + Y_44,12 + Y_44,13 + Y_44,14
#  + Y_44,2 + Y_44,3 + Y_44,4 + Y_44,5 + Y_44,6 + Y_44,7 + Y_44,8 + Y_44,9 <= 1
#
# One_PCT_37: X_45,0 + X_45,1 + X_45,10 + X_45,11 + X_45,12 + X_45,13 + X_45,14
#  + X_45,2 + X_45,3 + X_45,4 + X_45,5 + X_45,6 + X_45,7 + X_45,8 + X_45,9 <= 1
#
# One_harv_37: Y_45,0 + Y_45,1 + Y_45,10 + Y_45,11 + Y_45,12 + Y_45,13 + Y_45,14
#  + Y_45,2 + Y_45,3 + Y_45,4 + Y_45,5 + Y_45,6 + Y_45,7 + Y_45,8 + Y_45,9 <= 1
#
# One_PCT_38: X_46,0 + X_46,1 + X_46,10 + X_46,11 + X_46,12 + X_46,13 + X_46,14
#  + X_46,2 + X_46,3 + X_46,4 + X_46,5 + X_46,6 + X_46,7 + X_46,8 + X_46,9 <= 1
#
# One_harv_38: Y_46,0 + Y_46,1 + Y_46,10 + Y_46,11 + Y_46,12 + Y_46,13 + Y_46,14
#  + Y_46,2 + Y_46,3 + Y_46,4 + Y_46,5 + Y_46,6 + Y_46,7 + Y_46,8 + Y_46,9 <= 1
#
# One_PCT_39: X_47,0 + X_47,1 + X_47,10 + X_47,11 + X_47,12 + X_47,13 + X_47,14
#  + X_47,2 + X_47,3 + X_47,4 + X_47,5 + X_47,6 + X_47,7 + X_47,8 + X_47,9 <= 1
#
# One_harv_39: Y_47,0 + Y_47,1 + Y_47,10 + Y_47,11 + Y_47,12 + Y_47,13 + Y_47,14
#  + Y_47,2 + Y_47,3 + Y_47,4 + Y_47,5 + Y_47,6 + Y_47,7 + Y_47,8 + Y_47,9 <= 1
#
# One_PCT_40: X_48,0 + X_48,1 + X_48,10 + X_48,11 + X_48,12 + X_48,13 + X_48,14
#  + X_48,2 + X_48,3 + X_48,4 + X_48,5 + X_48,6 + X_48,7 + X_48,8 + X_48,9 <= 1
#
# One_harv_40: Y_48,0 + Y_48,1 + Y_48,10 + Y_48,11 + Y_48,12 + Y_48,13 + Y_48,14
#  + Y_48,2 + Y_48,3 + Y_48,4 + Y_48,5 + Y_48,6 + Y_48,7 + Y_48,8 + Y_48,9 <= 1
#
# One_PCT_41: X_49,0 + X_49,1 + X_49,10 + X_49,11 + X_49,12 + X_49,13 + X_49,14
#  + X_49,2 + X_49,3 + X_49,4 + X_49,5 + X_49,6 + X_49,7 + X_49,8 + X_49,9 <= 1
#
# One_harv_41: Y_49,0 + Y_49,1 + Y_49,10 + Y_49,11 + Y_49,12 + Y_49,13 + Y_49,14
#  + Y_49,2 + Y_49,3 + Y_49,4 + Y_49,5 + Y_49,6 + Y_49,7 + Y_49,8 + Y_49,9 <= 1
#
# One_PCT_42: X_5,0 + X_5,1 + X_5,10 + X_5,11 + X_5,12 + X_5,13 + X_5,14 + X_5,2
#  + X_5,3 + X_5,4 + X_5,5 + X_5,6 + X_5,7 + X_5,8 + X_5,9 <= 1
#
# One_harv_42: Y_5,0 + Y_5,1 + Y_5,10 + Y_5,11 + Y_5,12 + Y_5,13 + Y_5,14
#  + Y_5,2 + Y_5,3 + Y_5,4 + Y_5,5 + Y_5,6 + Y_5,7 + Y_5,8 + Y_5,9 <= 1
#
# One_PCT_43: X_50,0 + X_50,1 + X_50,10 + X_50,11 + X_50,12 + X_50,13 + X_50,14
#  + X_50,2 + X_50,3 + X_50,4 + X_50,5 + X_50,6 + X_50,7 + X_50,8 + X_50,9 <= 1
#
# One_harv_43: Y_50,0 + Y_50,1 + Y_50,10 + Y_50,11 + Y_50,12 + Y_50,13 + Y_50,14
#  + Y_50,2 + Y_50,3 + Y_50,4 + Y_50,5 + Y_50,6 + Y_50,7 + Y_50,8 + Y_50,9 <= 1
#
# One_PCT_44: X_51,0 + X_51,1 + X_51,10 + X_51,11 + X_51,12 + X_51,13 + X_51,14
#  + X_51,2 + X_51,3 + X_51,4 + X_51,5 + X_51,6 + X_51,7 + X_51,8 + X_51,9 <= 1
#
# One_harv_44: Y_51,0 + Y_51,1 + Y_51,10 + Y_51,11 + Y_51,12 + Y_51,13 + Y_51,14
#  + Y_51,2 + Y_51,3 + Y_51,4 + Y_51,5 + Y_51,6 + Y_51,7 + Y_51,8 + Y_51,9 <= 1
#
# One_PCT_45: X_52,0 + X_52,1 + X_52,10 + X_52,11 + X_52,12 + X_52,13 + X_52,14
#  + X_52,2 + X_52,3 + X_52,4 + X_52,5 + X_52,6 + X_52,7 + X_52,8 + X_52,9 <= 1
#
# One_harv_45: Y_52,0 + Y_52,1 + Y_52,10 + Y_52,11 + Y_52,12 + Y_52,13 + Y_52,14
#  + Y_52,2 + Y_52,3 + Y_52,4 + Y_52,5 + Y_52,6 + Y_52,7 + Y_52,8 + Y_52,9 <= 1
#
# One_PCT_46: X_53,0 + X_53,1 + X_53,10 + X_53,11 + X_53,12 + X_53,13 + X_53,14
#  + X_53,2 + X_53,3 + X_53,4 + X_53,5 + X_53,6 + X_53,7 + X_53,8 + X_53,9 <= 1
#
# One_harv_46: Y_53,0 + Y_53,1 + Y_53,10 + Y_53,11 + Y_53,12 + Y_53,13 + Y_53,14
#  + Y_53,2 + Y_53,3 + Y_53,4 + Y_53,5 + Y_53,6 + Y_53,7 + Y_53,8 + Y_53,9 <= 1
#
# One_PCT_47: X_54,0 + X_54,1 + X_54,10 + X_54,11 + X_54,12 + X_54,13 + X_54,14
#  + X_54,2 + X_54,3 + X_54,4 + X_54,5 + X_54,6 + X_54,7 + X_54,8 + X_54,9 <= 1
#
# One_harv_47: Y_54,0 + Y_54,1 + Y_54,10 + Y_54,11 + Y_54,12 + Y_54,13 + Y_54,14
#  + Y_54,2 + Y_54,3 + Y_54,4 + Y_54,5 + Y_54,6 + Y_54,7 + Y_54,8 + Y_54,9 <= 1
#
# One_PCT_48: X_55,0 + X_55,1 + X_55,10 + X_55,11 + X_55,12 + X_55,13 + X_55,14
#  + X_55,2 + X_55,3 + X_55,4 + X_55,5 + X_55,6 + X_55,7 + X_55,8 + X_55,9 <= 1
#
# One_harv_48: Y_55,0 + Y_55,1 + Y_55,10 + Y_55,11 + Y_55,12 + Y_55,13 + Y_55,14
#  + Y_55,2 + Y_55,3 + Y_55,4 + Y_55,5 + Y_55,6 + Y_55,7 + Y_55,8 + Y_55,9 <= 1
#
# One_PCT_49: X_56,0 + X_56,1 + X_56,10 + X_56,11 + X_56,12 + X_56,13 + X_56,14
#  + X_56,2 + X_56,3 + X_56,4 + X_56,5 + X_56,6 + X_56,7 + X_56,8 + X_56,9 <= 1
#
# One_harv_49: Y_56,0 + Y_56,1 + Y_56,10 + Y_56,11 + Y_56,12 + Y_56,13 + Y_56,14
#  + Y_56,2 + Y_56,3 + Y_56,4 + Y_56,5 + Y_56,6 + Y_56,7 + Y_56,8 + Y_56,9 <= 1
#
# One_PCT_50: X_57,0 + X_57,1 + X_57,10 + X_57,11 + X_57,12 + X_57,13 + X_57,14
#  + X_57,2 + X_57,3 + X_57,4 + X_57,5 + X_57,6 + X_57,7 + X_57,8 + X_57,9 <= 1
#
# One_harv_50: Y_57,0 + Y_57,1 + Y_57,10 + Y_57,11 + Y_57,12 + Y_57,13 + Y_57,14
#  + Y_57,2 + Y_57,3 + Y_57,4 + Y_57,5 + Y_57,6 + Y_57,7 + Y_57,8 + Y_57,9 <= 1
#
# One_PCT_51: X_58,0 + X_58,1 + X_58,10 + X_58,11 + X_58,12 + X_58,13 + X_58,14
#  + X_58,2 + X_58,3 + X_58,4 + X_58,5 + X_58,6 + X_58,7 + X_58,8 + X_58,9 <= 1
#
# One_harv_51: Y_58,0 + Y_58,1 + Y_58,10 + Y_58,11 + Y_58,12 + Y_58,13 + Y_58,14
#  + Y_58,2 + Y_58,3 + Y_58,4 + Y_58,5 + Y_58,6 + Y_58,7 + Y_58,8 + Y_58,9 <= 1
#
# One_PCT_52: X_59,0 + X_59,1 + X_59,10 + X_59,11 + X_59,12 + X_59,13 + X_59,14
#  + X_59,2 + X_59,3 + X_59,4 + X_59,5 + X_59,6 + X_59,7 + X_59,8 + X_59,9 <= 1
#
# One_harv_52: Y_59,0 + Y_59,1 + Y_59,10 + Y_59,11 + Y_59,12 + Y_59,13 + Y_59,14
#  + Y_59,2 + Y_59,3 + Y_59,4 + Y_59,5 + Y_59,6 + Y_59,7 + Y_59,8 + Y_59,9 <= 1
#
# One_PCT_53: X_6,0 + X_6,1 + X_6,10 + X_6,11 + X_6,12 + X_6,13 + X_6,14 + X_6,2
#  + X_6,3 + X_6,4 + X_6,5 + X_6,6 + X_6,7 + X_6,8 + X_6,9 <= 1
#
# One_harv_53: Y_6,0 + Y_6,1 + Y_6,10 + Y_6,11 + Y_6,12 + Y_6,13 + Y_6,14
#  + Y_6,2 + Y_6,3 + Y_6,4 + Y_6,5 + Y_6,6 + Y_6,7 + Y_6,8 + Y_6,9 <= 1
#
# One_PCT_54: X_60,0 + X_60,1 + X_60,10 + X_60,11 + X_60,12 + X_60,13 + X_60,14
#  + X_60,2 + X_60,3 + X_60,4 + X_60,5 + X_60,6 + X_60,7 + X_60,8 + X_60,9 <= 1
#
# One_harv_54: Y_60,0 + Y_60,1 + Y_60,10 + Y_60,11 + Y_60,12 + Y_60,13 + Y_60,14
#  + Y_60,2 + Y_60,3 + Y_60,4 + Y_60,5 + Y_60,6 + Y_60,7 + Y_60,8 + Y_60,9 <= 1
#
# One_PCT_55: X_61,0 + X_61,1 + X_61,10 + X_61,11 + X_61,12 + X_61,13 + X_61,14
#  + X_61,2 + X_61,3 + X_61,4 + X_61,5 + X_61,6 + X_61,7 + X_61,8 + X_61,9 <= 1
#
# One_harv_55: Y_61,0 + Y_61,1 + Y_61,10 + Y_61,11 + Y_61,12 + Y_61,13 + Y_61,14
#  + Y_61,2 + Y_61,3 + Y_61,4 + Y_61,5 + Y_61,6 + Y_61,7 + Y_61,8 + Y_61,9 <= 1
#
# One_PCT_56: X_62,0 + X_62,1 + X_62,10 + X_62,11 + X_62,12 + X_62,13 + X_62,14
#  + X_62,2 + X_62,3 + X_62,4 + X_62,5 + X_62,6 + X_62,7 + X_62,8 + X_62,9 <= 1
#
# One_harv_56: Y_62,0 + Y_62,1 + Y_62,10 + Y_62,11 + Y_62,12 + Y_62,13 + Y_62,14
#  + Y_62,2 + Y_62,3 + Y_62,4 + Y_62,5 + Y_62,6 + Y_62,7 + Y_62,8 + Y_62,9 <= 1
#
# One_PCT_57: X_63,0 + X_63,1 + X_63,10 + X_63,11 + X_63,12 + X_63,13 + X_63,14
#  + X_63,2 + X_63,3 + X_63,4 + X_63,5 + X_63,6 + X_63,7 + X_63,8 + X_63,9 <= 1
#
# One_harv_57: Y_63,0 + Y_63,1 + Y_63,10 + Y_63,11 + Y_63,12 + Y_63,13 + Y_63,14
#  + Y_63,2 + Y_63,3 + Y_63,4 + Y_63,5 + Y_63,6 + Y_63,7 + Y_63,8 + Y_63,9 <= 1
#
# One_PCT_58: X_64,0 + X_64,1 + X_64,10 + X_64,11 + X_64,12 + X_64,13 + X_64,14
#  + X_64,2 + X_64,3 + X_64,4 + X_64,5 + X_64,6 + X_64,7 + X_64,8 + X_64,9 <= 1
#
# One_harv_58: Y_64,0 + Y_64,1 + Y_64,10 + Y_64,11 + Y_64,12 + Y_64,13 + Y_64,14
#  + Y_64,2 + Y_64,3 + Y_64,4 + Y_64,5 + Y_64,6 + Y_64,7 + Y_64,8 + Y_64,9 <= 1
#
# One_PCT_59: X_66,0 + X_66,1 + X_66,10 + X_66,11 + X_66,12 + X_66,13 + X_66,14
#  + X_66,2 + X_66,3 + X_66,4 + X_66,5 + X_66,6 + X_66,7 + X_66,8 + X_66,9 <= 1
#
# One_harv_59: Y_66,0 + Y_66,1 + Y_66,10 + Y_66,11 + Y_66,12 + Y_66,13 + Y_66,14
#  + Y_66,2 + Y_66,3 + Y_66,4 + Y_66,5 + Y_66,6 + Y_66,7 + Y_66,8 + Y_66,9 <= 1
#
# One_PCT_60: X_660,0 + X_660,1 + X_660,10 + X_660,11 + X_660,12 + X_660,13
#  + X_660,14 + X_660,2 + X_660,3 + X_660,4 + X_660,5 + X_660,6 + X_660,7
#  + X_660,8 + X_660,9 <= 1
#
# One_harv_60: Y_660,0 + Y_660,1 + Y_660,10 + Y_660,11 + Y_660,12 + Y_660,13
#  + Y_660,14 + Y_660,2 + Y_660,3 + Y_660,4 + Y_660,5 + Y_660,6 + Y_660,7
#  + Y_660,8 + Y_660,9 <= 1
#
# One_PCT_61: X_661,0 + X_661,1 + X_661,10 + X_661,11 + X_661,12 + X_661,13
#  + X_661,14 + X_661,2 + X_661,3 + X_661,4 + X_661,5 + X_661,6 + X_661,7
#  + X_661,8 + X_661,9 <= 1
#
# One_harv_61: Y_661,0 + Y_661,1 + Y_661,10 + Y_661,11 + Y_661,12 + Y_661,13
#  + Y_661,14 + Y_661,2 + Y_661,3 + Y_661,4 + Y_661,5 + Y_661,6 + Y_661,7
#  + Y_661,8 + Y_661,9 <= 1
#
# One_PCT_62: X_662,0 + X_662,1 + X_662,10 + X_662,11 + X_662,12 + X_662,13
#  + X_662,14 + X_662,2 + X_662,3 + X_662,4 + X_662,5 + X_662,6 + X_662,7
#  + X_662,8 + X_662,9 <= 1
#
# One_harv_62: Y_662,0 + Y_662,1 + Y_662,10 + Y_662,11 + Y_662,12 + Y_662,13
#  + Y_662,14 + Y_662,2 + Y_662,3 + Y_662,4 + Y_662,5 + Y_662,6 + Y_662,7
#  + Y_662,8 + Y_662,9 <= 1
#
# One_PCT_63: X_67,0 + X_67,1 + X_67,10 + X_67,11 + X_67,12 + X_67,13 + X_67,14
#  + X_67,2 + X_67,3 + X_67,4 + X_67,5 + X_67,6 + X_67,7 + X_67,8 + X_67,9 <= 1
#
# One_harv_63: Y_67,0 + Y_67,1 + Y_67,10 + Y_67,11 + Y_67,12 + Y_67,13 + Y_67,14
#  + Y_67,2 + Y_67,3 + Y_67,4 + Y_67,5 + Y_67,6 + Y_67,7 + Y_67,8 + Y_67,9 <= 1
#
# One_PCT_64: X_68,0 + X_68,1 + X_68,10 + X_68,11 + X_68,12 + X_68,13 + X_68,14
#  + X_68,2 + X_68,3 + X_68,4 + X_68,5 + X_68,6 + X_68,7 + X_68,8 + X_68,9 <= 1
#
# One_harv_64: Y_68,0 + Y_68,1 + Y_68,10 + Y_68,11 + Y_68,12 + Y_68,13 + Y_68,14
#  + Y_68,2 + Y_68,3 + Y_68,4 + Y_68,5 + Y_68,6 + Y_68,7 + Y_68,8 + Y_68,9 <= 1
#
# One_PCT_65: X_69,0 + X_69,1 + X_69,10 + X_69,11 + X_69,12 + X_69,13 + X_69,14
#  + X_69,2 + X_69,3 + X_69,4 + X_69,5 + X_69,6 + X_69,7 + X_69,8 + X_69,9 <= 1
#
# One_harv_65: Y_69,0 + Y_69,1 + Y_69,10 + Y_69,11 + Y_69,12 + Y_69,13 + Y_69,14
#  + Y_69,2 + Y_69,3 + Y_69,4 + Y_69,5 + Y_69,6 + Y_69,7 + Y_69,8 + Y_69,9 <= 1
#
# One_PCT_66: X_71,0 + X_71,1 + X_71,10 + X_71,11 + X_71,12 + X_71,13 + X_71,14
#  + X_71,2 + X_71,3 + X_71,4 + X_71,5 + X_71,6 + X_71,7 + X_71,8 + X_71,9 <= 1
#
# One_harv_66: Y_71,0 + Y_71,1 + Y_71,10 + Y_71,11 + Y_71,12 + Y_71,13 + Y_71,14
#  + Y_71,2 + Y_71,3 + Y_71,4 + Y_71,5 + Y_71,6 + Y_71,7 + Y_71,8 + Y_71,9 <= 1
#
# One_PCT_67: X_72,0 + X_72,1 + X_72,10 + X_72,11 + X_72,12 + X_72,13 + X_72,14
#  + X_72,2 + X_72,3 + X_72,4 + X_72,5 + X_72,6 + X_72,7 + X_72,8 + X_72,9 <= 1
#
# One_harv_67: Y_72,0 + Y_72,1 + Y_72,10 + Y_72,11 + Y_72,12 + Y_72,13 + Y_72,14
#  + Y_72,2 + Y_72,3 + Y_72,4 + Y_72,5 + Y_72,6 + Y_72,7 + Y_72,8 + Y_72,9 <= 1
#
# One_PCT_68: X_730,0 + X_730,1 + X_730,10 + X_730,11 + X_730,12 + X_730,13
#  + X_730,14 + X_730,2 + X_730,3 + X_730,4 + X_730,5 + X_730,6 + X_730,7
#  + X_730,8 + X_730,9 <= 1
#
# One_harv_68: Y_730,0 + Y_730,1 + Y_730,10 + Y_730,11 + Y_730,12 + Y_730,13
#  + Y_730,14 + Y_730,2 + Y_730,3 + Y_730,4 + Y_730,5 + Y_730,6 + Y_730,7
#  + Y_730,8 + Y_730,9 <= 1
#
# One_PCT_69: X_731,0 + X_731,1 + X_731,10 + X_731,11 + X_731,12 + X_731,13
#  + X_731,14 + X_731,2 + X_731,3 + X_731,4 + X_731,5 + X_731,6 + X_731,7
#  + X_731,8 + X_731,9 <= 1
#
# One_harv_69: Y_731,0 + Y_731,1 + Y_731,10 + Y_731,11 + Y_731,12 + Y_731,13
#  + Y_731,14 + Y_731,2 + Y_731,3 + Y_731,4 + Y_731,5 + Y_731,6 + Y_731,7
#  + Y_731,8 + Y_731,9 <= 1
#
# One_PCT_70: X_732,0 + X_732,1 + X_732,10 + X_732,11 + X_732,12 + X_732,13
#  + X_732,14 + X_732,2 + X_732,3 + X_732,4 + X_732,5 + X_732,6 + X_732,7
#  + X_732,8 + X_732,9 <= 1
#
# One_harv_70: Y_732,0 + Y_732,1 + Y_732,10 + Y_732,11 + Y_732,12 + Y_732,13
#  + Y_732,14 + Y_732,2 + Y_732,3 + Y_732,4 + Y_732,5 + Y_732,6 + Y_732,7
#  + Y_732,8 + Y_732,9 <= 1
#
# One_PCT_71: X_733,0 + X_733,1 + X_733,10 + X_733,11 + X_733,12 + X_733,13
#  + X_733,14 + X_733,2 + X_733,3 + X_733,4 + X_733,5 + X_733,6 + X_733,7
#  + X_733,8 + X_733,9 <= 1
#
# One_harv_71: Y_733,0 + Y_733,1 + Y_733,10 + Y_733,11 + Y_733,12 + Y_733,13
#  + Y_733,14 + Y_733,2 + Y_733,3 + Y_733,4 + Y_733,5 + Y_733,6 + Y_733,7
#  + Y_733,8 + Y_733,9 <= 1
#
# One_PCT_72: X_734,0 + X_734,1 + X_734,10 + X_734,11 + X_734,12 + X_734,13
#  + X_734,14 + X_734,2 + X_734,3 + X_734,4 + X_734,5 + X_734,6 + X_734,7
#  + X_734,8 + X_734,9 <= 1
#
# One_harv_72: Y_734,0 + Y_734,1 + Y_734,10 + Y_734,11 + Y_734,12 + Y_734,13
#  + Y_734,14 + Y_734,2 + Y_734,3 + Y_734,4 + Y_734,5 + Y_734,6 + Y_734,7
#  + Y_734,8 + Y_734,9 <= 1
#
# One_PCT_73: X_74,0 + X_74,1 + X_74,10 + X_74,11 + X_74,12 + X_74,13 + X_74,14
#  + X_74,2 + X_74,3 + X_74,4 + X_74,5 + X_74,6 + X_74,7 + X_74,8 + X_74,9 <= 1
#
# One_harv_73: Y_74,0 + Y_74,1 + Y_74,10 + Y_74,11 + Y_74,12 + Y_74,13 + Y_74,14
#  + Y_74,2 + Y_74,3 + Y_74,4 + Y_74,5 + Y_74,6 + Y_74,7 + Y_74,8 + Y_74,9 <= 1
#
# One_PCT_74: X_750,0 + X_750,1 + X_750,10 + X_750,11 + X_750,12 + X_750,13
#  + X_750,14 + X_750,2 + X_750,3 + X_750,4 + X_750,5 + X_750,6 + X_750,7
#  + X_750,8 + X_750,9 <= 1
#
# One_harv_74: Y_750,0 + Y_750,1 + Y_750,10 + Y_750,11 + Y_750,12 + Y_750,13
#  + Y_750,14 + Y_750,2 + Y_750,3 + Y_750,4 + Y_750,5 + Y_750,6 + Y_750,7
#  + Y_750,8 + Y_750,9 <= 1
#
# One_PCT_75: X_751,0 + X_751,1 + X_751,10 + X_751,11 + X_751,12 + X_751,13
#  + X_751,14 + X_751,2 + X_751,3 + X_751,4 + X_751,5 + X_751,6 + X_751,7
#  + X_751,8 + X_751,9 <= 1
#
# One_harv_75: Y_751,0 + Y_751,1 + Y_751,10 + Y_751,11 + Y_751,12 + Y_751,13
#  + Y_751,14 + Y_751,2 + Y_751,3 + Y_751,4 + Y_751,5 + Y_751,6 + Y_751,7
#  + Y_751,8 + Y_751,9 <= 1
#
# One_PCT_76: X_752,0 + X_752,1 + X_752,10 + X_752,11 + X_752,12 + X_752,13
#  + X_752,14 + X_752,2 + X_752,3 + X_752,4 + X_752,5 + X_752,6 + X_752,7
#  + X_752,8 + X_752,9 <= 1
#
# One_harv_76: Y_752,0 + Y_752,1 + Y_752,10 + Y_752,11 + Y_752,12 + Y_752,13
#  + Y_752,14 + Y_752,2 + Y_752,3 + Y_752,4 + Y_752,5 + Y_752,6 + Y_752,7
#  + Y_752,8 + Y_752,9 <= 1
#
# One_PCT_77: X_753,0 + X_753,1 + X_753,10 + X_753,11 + X_753,12 + X_753,13
#  + X_753,14 + X_753,2 + X_753,3 + X_753,4 + X_753,5 + X_753,6 + X_753,7
#  + X_753,8 + X_753,9 <= 1
#
# One_harv_77: Y_753,0 + Y_753,1 + Y_753,10 + Y_753,11 + Y_753,12 + Y_753,13
#  + Y_753,14 + Y_753,2 + Y_753,3 + Y_753,4 + Y_753,5 + Y_753,6 + Y_753,7
#  + Y_753,8 + Y_753,9 <= 1
#
# One_PCT_78: X_754,0 + X_754,1 + X_754,10 + X_754,11 + X_754,12 + X_754,13
#  + X_754,14 + X_754,2 + X_754,3 + X_754,4 + X_754,5 + X_754,6 + X_754,7
#  + X_754,8 + X_754,9 <= 1
#
# One_harv_78: Y_754,0 + Y_754,1 + Y_754,10 + Y_754,11 + Y_754,12 + Y_754,13
#  + Y_754,14 + Y_754,2 + Y_754,3 + Y_754,4 + Y_754,5 + Y_754,6 + Y_754,7
#  + Y_754,8 + Y_754,9 <= 1
#
# One_PCT_79: X_755,0 + X_755,1 + X_755,10 + X_755,11 + X_755,12 + X_755,13
#  + X_755,14 + X_755,2 + X_755,3 + X_755,4 + X_755,5 + X_755,6 + X_755,7
#  + X_755,8 + X_755,9 <= 1
#
# One_harv_79: Y_755,0 + Y_755,1 + Y_755,10 + Y_755,11 + Y_755,12 + Y_755,13
#  + Y_755,14 + Y_755,2 + Y_755,3 + Y_755,4 + Y_755,5 + Y_755,6 + Y_755,7
#  + Y_755,8 + Y_755,9 <= 1
#
# One_PCT_80: X_756,0 + X_756,1 + X_756,10 + X_756,11 + X_756,12 + X_756,13
#  + X_756,14 + X_756,2 + X_756,3 + X_756,4 + X_756,5 + X_756,6 + X_756,7
#  + X_756,8 + X_756,9 <= 1
#
# One_harv_80: Y_756,0 + Y_756,1 + Y_756,10 + Y_756,11 + Y_756,12 + Y_756,13
#  + Y_756,14 + Y_756,2 + Y_756,3 + Y_756,4 + Y_756,5 + Y_756,6 + Y_756,7
#  + Y_756,8 + Y_756,9 <= 1
#
# One_PCT_81: X_757,0 + X_757,1 + X_757,10 + X_757,11 + X_757,12 + X_757,13
#  + X_757,14 + X_757,2 + X_757,3 + X_757,4 + X_757,5 + X_757,6 + X_757,7
#  + X_757,8 + X_757,9 <= 1
#
# One_harv_81: Y_757,0 + Y_757,1 + Y_757,10 + Y_757,11 + Y_757,12 + Y_757,13
#  + Y_757,14 + Y_757,2 + Y_757,3 + Y_757,4 + Y_757,5 + Y_757,6 + Y_757,7
#  + Y_757,8 + Y_757,9 <= 1
#
# One_PCT_82: X_758,0 + X_758,1 + X_758,10 + X_758,11 + X_758,12 + X_758,13
#  + X_758,14 + X_758,2 + X_758,3 + X_758,4 + X_758,5 + X_758,6 + X_758,7
#  + X_758,8 + X_758,9 <= 1
#
# One_harv_82: Y_758,0 + Y_758,1 + Y_758,10 + Y_758,11 + Y_758,12 + Y_758,13
#  + Y_758,14 + Y_758,2 + Y_758,3 + Y_758,4 + Y_758,5 + Y_758,6 + Y_758,7
#  + Y_758,8 + Y_758,9 <= 1
#
# One_PCT_83: X_759,0 + X_759,1 + X_759,10 + X_759,11 + X_759,12 + X_759,13
# ...
# 0 <= omega_72,4 <= 1 Integer
# 0 <= omega_72,5 <= 1 Integer
# 0 <= omega_72,6 <= 1 Integer
# 0 <= omega_72,7 <= 1 Integer
# 0 <= omega_72,8 <= 1 Integer
# 0 <= omega_72,9 <= 1 Integer
# 0 <= omega_730,0 <= 1 Integer
# 0 <= omega_730,1 <= 1 Integer
# 0 <= omega_730,10 <= 1 Integer
# 0 <= omega_730,11 <= 1 Integer
# 0 <= omega_730,12 <= 1 Integer
# 0 <= omega_730,13 <= 1 Integer
# 0 <= omega_730,14 <= 1 Integer
# 0 <= omega_730,2 <= 1 Integer
# 0 <= omega_730,3 <= 1 Integer
# 0 <= omega_730,4 <= 1 Integer
# 0 <= omega_730,5 <= 1 Integer
# 0 <= omega_730,6 <= 1 Integer
# 0 <= omega_730,7 <= 1 Integer
# 0 <= omega_730,8 <= 1 Integer
# 0 <= omega_730,9 <= 1 Integer
# 0 <= omega_731,0 <= 1 Integer
# 0 <= omega_731,1 <= 1 Integer
# 0 <= omega_731,10 <= 1 Integer
# 0 <= omega_731,11 <= 1 Integer
# 0 <= omega_731,12 <= 1 Integer
# 0 <= omega_731,13 <= 1 Integer
# 0 <= omega_731,14 <= 1 Integer
# 0 <= omega_731,2 <= 1 Integer
# 0 <= omega_731,3 <= 1 Integer
# 0 <= omega_731,4 <= 1 Integer
# 0 <= omega_731,5 <= 1 Integer
# 0 <= omega_731,6 <= 1 Integer
# 0 <= omega_731,7 <= 1 Integer
# 0 <= omega_731,8 <= 1 Integer
# 0 <= omega_731,9 <= 1 Integer
# 0 <= omega_732,0 <= 1 Integer
# 0 <= omega_732,1 <= 1 Integer
# 0 <= omega_732,10 <= 1 Integer
# 0 <= omega_732,11 <= 1 Integer
# 0 <= omega_732,12 <= 1 Integer
# 0 <= omega_732,13 <= 1 Integer
# 0 <= omega_732,14 <= 1 Integer
# 0 <= omega_732,2 <= 1 Integer
# 0 <= omega_732,3 <= 1 Integer
# 0 <= omega_732,4 <= 1 Integer
# 0 <= omega_732,5 <= 1 Integer
# 0 <= omega_732,6 <= 1 Integer
# 0 <= omega_732,7 <= 1 Integer
# 0 <= omega_732,8 <= 1 Integer
# 0 <= omega_732,9 <= 1 Integer
# 0 <= omega_733,0 <= 1 Integer
# 0 <= omega_733,1 <= 1 Integer
# 0 <= omega_733,10 <= 1 Integer
# 0 <= omega_733,11 <= 1 Integer
# 0 <= omega_733,12 <= 1 Integer
# 0 <= omega_733,13 <= 1 Integer
# 0 <= omega_733,14 <= 1 Integer
# 0 <= omega_733,2 <= 1 Integer
# 0 <= omega_733,3 <= 1 Integer
# 0 <= omega_733,4 <= 1 Integer
# 0 <= omega_733,5 <= 1 Integer
# 0 <= omega_733,6 <= 1 Integer
# 0 <= omega_733,7 <= 1 Integer
# 0 <= omega_733,8 <= 1 Integer
# 0 <= omega_733,9 <= 1 Integer
# 0 <= omega_734,0 <= 1 Integer
# 0 <= omega_734,1 <= 1 Integer
# 0 <= omega_734,10 <= 1 Integer
# 0 <= omega_734,11 <= 1 Integer
# 0 <= omega_734,12 <= 1 Integer
# 0 <= omega_734,13 <= 1 Integer
# 0 <= omega_734,14 <= 1 Integer
# 0 <= omega_734,2 <= 1 Integer
# 0 <= omega_734,3 <= 1 Integer
# 0 <= omega_734,4 <= 1 Integer
# 0 <= omega_734,5 <= 1 Integer
# 0 <= omega_734,6 <= 1 Integer
# 0 <= omega_734,7 <= 1 Integer
# 0 <= omega_734,8 <= 1 Integer
# 0 <= omega_734,9 <= 1 Integer
# 0 <= omega_74,0 <= 1 Integer
# 0 <= omega_74,1 <= 1 Integer
# 0 <= omega_74,10 <= 1 Integer
# 0 <= omega_74,11 <= 1 Integer
# 0 <= omega_74,12 <= 1 Integer
# 0 <= omega_74,13 <= 1 Integer
# 0 <= omega_74,14 <= 1 Integer
# 0 <= omega_74,2 <= 1 Integer
# 0 <= omega_74,3 <= 1 Integer
# 0 <= omega_74,4 <= 1 Integer
# 0 <= omega_74,5 <= 1 Integer
# 0 <= omega_74,6 <= 1 Integer
# 0 <= omega_74,7 <= 1 Integer
# 0 <= omega_74,8 <= 1 Integer
# 0 <= omega_74,9 <= 1 Integer
# 0 <= omega_750,0 <= 1 Integer
# 0 <= omega_750,1 <= 1 Integer
# 0 <= omega_750,10 <= 1 Integer
# 0 <= omega_750,11 <= 1 Integer
# 0 <= omega_750,12 <= 1 Integer
# 0 <= omega_750,13 <= 1 Integer
# 0 <= omega_750,14 <= 1 Integer
# 0 <= omega_750,2 <= 1 Integer
# 0 <= omega_750,3 <= 1 Integer
# 0 <= omega_750,4 <= 1 Integer
# 0 <= omega_750,5 <= 1 Integer
# 0 <= omega_750,6 <= 1 Integer
# 0 <= omega_750,7 <= 1 Integer
# 0 <= omega_750,8 <= 1 Integer
# 0 <= omega_750,9 <= 1 Integer
# 0 <= omega_751,0 <= 1 Integer
# 0 <= omega_751,1 <= 1 Integer
# 0 <= omega_751,10 <= 1 Integer
# 0 <= omega_751,11 <= 1 Integer
# 0 <= omega_751,12 <= 1 Integer
# 0 <= omega_751,13 <= 1 Integer
# 0 <= omega_751,14 <= 1 Integer
# 0 <= omega_751,2 <= 1 Integer
# 0 <= omega_751,3 <= 1 Integer
# 0 <= omega_751,4 <= 1 Integer
# 0 <= omega_751,5 <= 1 Integer
# 0 <= omega_751,6 <= 1 Integer
# 0 <= omega_751,7 <= 1 Integer
# 0 <= omega_751,8 <= 1 Integer
# 0 <= omega_751,9 <= 1 Integer
# 0 <= omega_752,0 <= 1 Integer
# 0 <= omega_752,1 <= 1 Integer
# 0 <= omega_752,10 <= 1 Integer
# 0 <= omega_752,11 <= 1 Integer
# 0 <= omega_752,12 <= 1 Integer
# 0 <= omega_752,13 <= 1 Integer
# 0 <= omega_752,14 <= 1 Integer
# 0 <= omega_752,2 <= 1 Integer
# 0 <= omega_752,3 <= 1 Integer
# 0 <= omega_752,4 <= 1 Integer
# 0 <= omega_752,5 <= 1 Integer
# 0 <= omega_752,6 <= 1 Integer
# 0 <= omega_752,7 <= 1 Integer
# 0 <= omega_752,8 <= 1 Integer
# 0 <= omega_752,9 <= 1 Integer
# 0 <= omega_753,0 <= 1 Integer
# 0 <= omega_753,1 <= 1 Integer
# 0 <= omega_753,10 <= 1 Integer
# 0 <= omega_753,11 <= 1 Integer
# 0 <= omega_753,12 <= 1 Integer
# 0 <= omega_753,13 <= 1 Integer
# 0 <= omega_753,14 <= 1 Integer
# 0 <= omega_753,2 <= 1 Integer
# 0 <= omega_753,3 <= 1 Integer
# 0 <= omega_753,4 <= 1 Integer
# 0 <= omega_753,5 <= 1 Integer
# 0 <= omega_753,6 <= 1 Integer
# 0 <= omega_753,7 <= 1 Integer
# 0 <= omega_753,8 <= 1 Integer
# 0 <= omega_753,9 <= 1 Integer
# 0 <= omega_754,0 <= 1 Integer
# 0 <= omega_754,1 <= 1 Integer
# 0 <= omega_754,10 <= 1 Integer
# 0 <= omega_754,11 <= 1 Integer
# 0 <= omega_754,12 <= 1 Integer
# 0 <= omega_754,13 <= 1 Integer
# 0 <= omega_754,14 <= 1 Integer
# 0 <= omega_754,2 <= 1 Integer
# 0 <= omega_754,3 <= 1 Integer
# 0 <= omega_754,4 <= 1 Integer
# 0 <= omega_754,5 <= 1 Integer
# 0 <= omega_754,6 <= 1 Integer
# 0 <= omega_754,7 <= 1 Integer
# 0 <= omega_754,8 <= 1 Integer
# 0 <= omega_754,9 <= 1 Integer
# 0 <= omega_755,0 <= 1 Integer
# 0 <= omega_755,1 <= 1 Integer
# 0 <= omega_755,10 <= 1 Integer
# 0 <= omega_755,11 <= 1 Integer
# 0 <= omega_755,12 <= 1 Integer
# 0 <= omega_755,13 <= 1 Integer
# 0 <= omega_755,14 <= 1 Integer
# 0 <= omega_755,2 <= 1 Integer
# 0 <= omega_755,3 <= 1 Integer
# 0 <= omega_755,4 <= 1 Integer
# 0 <= omega_755,5 <= 1 Integer
# 0 <= omega_755,6 <= 1 Integer
# 0 <= omega_755,7 <= 1 Integer
# 0 <= omega_755,8 <= 1 Integer
# 0 <= omega_755,9 <= 1 Integer
# 0 <= omega_756,0 <= 1 Integer
# 0 <= omega_756,1 <= 1 Integer
# 0 <= omega_756,10 <= 1 Integer
# 0 <= omega_756,11 <= 1 Integer
# 0 <= omega_756,12 <= 1 Integer
# 0 <= omega_756,13 <= 1 Integer
# 0 <= omega_756,14 <= 1 Integer
# 0 <= omega_756,2 <= 1 Integer
# 0 <= omega_756,3 <= 1 Integer
# 0 <= omega_756,4 <= 1 Integer
# 0 <= omega_756,5 <= 1 Integer
# 0 <= omega_756,6 <= 1 Integer
# 0 <= omega_756,7 <= 1 Integer
# 0 <= omega_756,8 <= 1 Integer
# 0 <= omega_756,9 <= 1 Integer
# 0 <= omega_757,0 <= 1 Integer
# 0 <= omega_757,1 <= 1 Integer
# 0 <= omega_757,10 <= 1 Integer
# 0 <= omega_757,11 <= 1 Integer
# 0 <= omega_757,12 <= 1 Integer
# 0 <= omega_757,13 <= 1 Integer
# 0 <= omega_757,14 <= 1 Integer
# 0 <= omega_757,2 <= 1 Integer
# 0 <= omega_757,3 <= 1 Integer
# 0 <= omega_757,4 <= 1 Integer
# 0 <= omega_757,5 <= 1 Integer
# 0 <= omega_757,6 <= 1 Integer
# 0 <= omega_757,7 <= 1 Integer
# 0 <= omega_757,8 <= 1 Integer
# 0 <= omega_757,9 <= 1 Integer
# 0 <= omega_758,0 <= 1 Integer
# 0 <= omega_758,1 <= 1 Integer
# 0 <= omega_758,10 <= 1 Integer
# 0 <= omega_758,11 <= 1 Integer
# 0 <= omega_758,12 <= 1 Integer
# 0 <= omega_758,13 <= 1 Integer
# 0 <= omega_758,14 <= 1 Integer
# 0 <= omega_758,2 <= 1 Integer
# 0 <= omega_758,3 <= 1 Integer
# 0 <= omega_758,4 <= 1 Integer
# 0 <= omega_758,5 <= 1 Integer
# 0 <= omega_758,6 <= 1 Integer
# 0 <= omega_758,7 <= 1 Integer
# 0 <= omega_758,8 <= 1 Integer
# 0 <= omega_758,9 <= 1 Integer
# 0 <= omega_759,0 <= 1 Integer
# 0 <= omega_759,1 <= 1 Integer
# 0 <= omega_759,10 <= 1 Integer
# 0 <= omega_759,11 <= 1 Integer
# 0 <= omega_759,12 <= 1 Integer
# 0 <= omega_759,13 <= 1 Integer
# 0 <= omega_759,14 <= 1 Integer
# 0 <= omega_759,2 <= 1 Integer
# 0 <= omega_759,3 <= 1 Integer
# 0 <= omega_759,4 <= 1 Integer
# 0 <= omega_759,5 <= 1 Integer
# 0 <= omega_759,6 <= 1 Integer
# 0 <= omega_759,7 <= 1 Integer
# 0 <= omega_759,8 <= 1 Integer
# 0 <= omega_759,9 <= 1 Integer
# 0 <= omega_760,0 <= 1 Integer
# 0 <= omega_760,1 <= 1 Integer
# 0 <= omega_760,10 <= 1 Integer
# 0 <= omega_760,11 <= 1 Integer
# 0 <= omega_760,12 <= 1 Integer
# 0 <= omega_760,13 <= 1 Integer
# 0 <= omega_760,14 <= 1 Integer
# 0 <= omega_760,2 <= 1 Integer
# 0 <= omega_760,3 <= 1 Integer
# 0 <= omega_760,4 <= 1 Integer
# 0 <= omega_760,5 <= 1 Integer
# 0 <= omega_760,6 <= 1 Integer
# 0 <= omega_760,7 <= 1 Integer
# 0 <= omega_760,8 <= 1 Integer
# 0 <= omega_760,9 <= 1 Integer
# 0 <= omega_761,0 <= 1 Integer
# 0 <= omega_761,1 <= 1 Integer
# 0 <= omega_761,10 <= 1 Integer
# 0 <= omega_761,11 <= 1 Integer
# 0 <= omega_761,12 <= 1 Integer
# 0 <= omega_761,13 <= 1 Integer
# 0 <= omega_761,14 <= 1 Integer
# 0 <= omega_761,2 <= 1 Integer
# 0 <= omega_761,3 <= 1 Integer
# 0 <= omega_761,4 <= 1 Integer
# 0 <= omega_761,5 <= 1 Integer
# 0 <= omega_761,6 <= 1 Integer
# 0 <= omega_761,7 <= 1 Integer
# 0 <= omega_761,8 <= 1 Integer
# 0 <= omega_761,9 <= 1 Integer
# 0 <= omega_762,0 <= 1 Integer
# 0 <= omega_762,1 <= 1 Integer
# 0 <= omega_762,10 <= 1 Integer
# 0 <= omega_762,11 <= 1 Integer
# 0 <= omega_762,12 <= 1 Integer
# 0 <= omega_762,13 <= 1 Integer
# 0 <= omega_762,14 <= 1 Integer
# 0 <= omega_762,2 <= 1 Integer
# 0 <= omega_762,3 <= 1 Integer
# 0 <= omega_762,4 <= 1 Integer
# 0 <= omega_762,5 <= 1 Integer
# 0 <= omega_762,6 <= 1 Integer
# 0 <= omega_762,7 <= 1 Integer
# 0 <= omega_762,8 <= 1 Integer
# 0 <= omega_762,9 <= 1 Integer
# 0 <= omega_763,0 <= 1 Integer
# 0 <= omega_763,1 <= 1 Integer
# 0 <= omega_763,10 <= 1 Integer
# 0 <= omega_763,11 <= 1 Integer
# 0 <= omega_763,12 <= 1 Integer
# 0 <= omega_763,13 <= 1 Integer
# 0 <= omega_763,14 <= 1 Integer
# 0 <= omega_763,2 <= 1 Integer
# 0 <= omega_763,3 <= 1 Integer
# 0 <= omega_763,4 <= 1 Integer
# 0 <= omega_763,5 <= 1 Integer
# 0 <= omega_763,6 <= 1 Integer
# 0 <= omega_763,7 <= 1 Integer
# 0 <= omega_763,8 <= 1 Integer
# 0 <= omega_763,9 <= 1 Integer
# 0 <= omega_764,0 <= 1 Integer
# 0 <= omega_764,1 <= 1 Integer
# 0 <= omega_764,10 <= 1 Integer
# 0 <= omega_764,11 <= 1 Integer
# 0 <= omega_764,12 <= 1 Integer
# 0 <= omega_764,13 <= 1 Integer
# 0 <= omega_764,14 <= 1 Integer
# 0 <= omega_764,2 <= 1 Integer
# 0 <= omega_764,3 <= 1 Integer
# 0 <= omega_764,4 <= 1 Integer
# 0 <= omega_764,5 <= 1 Integer
# 0 <= omega_764,6 <= 1 Integer
# 0 <= omega_764,7 <= 1 Integer
# 0 <= omega_764,8 <= 1 Integer
# 0 <= omega_764,9 <= 1 Integer
# 0 <= omega_771,0 <= 1 Integer
# 0 <= omega_771,1 <= 1 Integer
# 0 <= omega_771,10 <= 1 Integer
# 0 <= omega_771,11 <= 1 Integer
# 0 <= omega_771,12 <= 1 Integer
# 0 <= omega_771,13 <= 1 Integer
# 0 <= omega_771,14 <= 1 Integer
# 0 <= omega_771,2 <= 1 Integer
# 0 <= omega_771,3 <= 1 Integer
# 0 <= omega_771,4 <= 1 Integer
# 0 <= omega_771,5 <= 1 Integer
# 0 <= omega_771,6 <= 1 Integer
# 0 <= omega_771,7 <= 1 Integer
# 0 <= omega_771,8 <= 1 Integer
# 0 <= omega_771,9 <= 1 Integer
# 0 <= omega_772,0 <= 1 Integer
# 0 <= omega_772,1 <= 1 Integer
# 0 <= omega_772,10 <= 1 Integer
# 0 <= omega_772,11 <= 1 Integer
# 0 <= omega_772,12 <= 1 Integer
# 0 <= omega_772,13 <= 1 Integer
# 0 <= omega_772,14 <= 1 Integer
# 0 <= omega_772,2 <= 1 Integer
# 0 <= omega_772,3 <= 1 Integer
# 0 <= omega_772,4 <= 1 Integer
# 0 <= omega_772,5 <= 1 Integer
# 0 <= omega_772,6 <= 1 Integer
# 0 <= omega_772,7 <= 1 Integer
# 0 <= omega_772,8 <= 1 Integer
# 0 <= omega_772,9 <= 1 Integer
# 0 <= omega_779,0 <= 1 Integer
# 0 <= omega_779,1 <= 1 Integer
# 0 <= omega_779,10 <= 1 Integer
# 0 <= omega_779,11 <= 1 Integer
# 0 <= omega_779,12 <= 1 Integer
# 0 <= omega_779,13 <= 1 Integer
# 0 <= omega_779,14 <= 1 Integer
# 0 <= omega_779,2 <= 1 Integer
# 0 <= omega_779,3 <= 1 Integer
# 0 <= omega_779,4 <= 1 Integer
# 0 <= omega_779,5 <= 1 Integer
# 0 <= omega_779,6 <= 1 Integer
# 0 <= omega_779,7 <= 1 Integer
# 0 <= omega_779,8 <= 1 Integer
# 0 <= omega_779,9 <= 1 Integer
# 0 <= omega_79,0 <= 1 Integer
# 0 <= omega_79,1 <= 1 Integer
# 0 <= omega_79,10 <= 1 Integer
# 0 <= omega_79,11 <= 1 Integer
# 0 <= omega_79,12 <= 1 Integer
# 0 <= omega_79,13 <= 1 Integer
# 0 <= omega_79,14 <= 1 Integer
# 0 <= omega_79,2 <= 1 Integer
# 0 <= omega_79,3 <= 1 Integer
# 0 <= omega_79,4 <= 1 Integer
# 0 <= omega_79,5 <= 1 Integer
# 0 <= omega_79,6 <= 1 Integer
# 0 <= omega_79,7 <= 1 Integer
# 0 <= omega_79,8 <= 1 Integer
# 0 <= omega_79,9 <= 1 Integer
# 0 <= omega_8,0 <= 1 Integer
# 0 <= omega_8,1 <= 1 Integer
# 0 <= omega_8,10 <= 1 Integer
# 0 <= omega_8,11 <= 1 Integer
# 0 <= omega_8,12 <= 1 Integer
# 0 <= omega_8,13 <= 1 Integer
# 0 <= omega_8,14 <= 1 Integer
# 0 <= omega_8,2 <= 1 Integer
# 0 <= omega_8,3 <= 1 Integer
# 0 <= omega_8,4 <= 1 Integer
# 0 <= omega_8,5 <= 1 Integer
# 0 <= omega_8,6 <= 1 Integer
# 0 <= omega_8,7 <= 1 Integer
# 0 <= omega_8,8 <= 1 Integer
# 0 <= omega_8,9 <= 1 Integer
# 0 <= omega_800,0 <= 1 Integer
# 0 <= omega_800,1 <= 1 Integer
# 0 <= omega_800,10 <= 1 Integer
# 0 <= omega_800,11 <= 1 Integer
# 0 <= omega_800,12 <= 1 Integer
# 0 <= omega_800,13 <= 1 Integer
# 0 <= omega_800,14 <= 1 Integer
# 0 <= omega_800,2 <= 1 Integer
# 0 <= omega_800,3 <= 1 Integer
# 0 <= omega_800,4 <= 1 Integer
# 0 <= omega_800,5 <= 1 Integer
# 0 <= omega_800,6 <= 1 Integer
# 0 <= omega_800,7 <= 1 Integer
# 0 <= omega_800,8 <= 1 Integer
# 0 <= omega_800,9 <= 1 Integer
# 0 <= omega_801,0 <= 1 Integer
# 0 <= omega_801,1 <= 1 Integer
# 0 <= omega_801,10 <= 1 Integer
# 0 <= omega_801,11 <= 1 Integer
# 0 <= omega_801,12 <= 1 Integer
# 0 <= omega_801,13 <= 1 Integer
# 0 <= omega_801,14 <= 1 Integer
# 0 <= omega_801,2 <= 1 Integer
# 0 <= omega_801,3 <= 1 Integer
# 0 <= omega_801,4 <= 1 Integer
# 0 <= omega_801,5 <= 1 Integer
# 0 <= omega_801,6 <= 1 Integer
# 0 <= omega_801,7 <= 1 Integer
# 0 <= omega_801,8 <= 1 Integer
# 0 <= omega_801,9 <= 1 Integer
# 0 <= omega_83,0 <= 1 Integer
# 0 <= omega_83,1 <= 1 Integer
# 0 <= omega_83,10 <= 1 Integer
# 0 <= omega_83,11 <= 1 Integer
# 0 <= omega_83,12 <= 1 Integer
# 0 <= omega_83,13 <= 1 Integer
# 0 <= omega_83,14 <= 1 Integer
# 0 <= omega_83,2 <= 1 Integer
# 0 <= omega_83,3 <= 1 Integer
# 0 <= omega_83,4 <= 1 Integer
# 0 <= omega_83,5 <= 1 Integer
# 0 <= omega_83,6 <= 1 Integer
# 0 <= omega_83,7 <= 1 Integer
# 0 <= omega_83,8 <= 1 Integer
# 0 <= omega_83,9 <= 1 Integer
# 0 <= omega_87,0 <= 1 Integer
# 0 <= omega_87,1 <= 1 Integer
# 0 <= omega_87,10 <= 1 Integer
# 0 <= omega_87,11 <= 1 Integer
# 0 <= omega_87,12 <= 1 Integer
# 0 <= omega_87,13 <= 1 Integer
# 0 <= omega_87,14 <= 1 Integer
# 0 <= omega_87,2 <= 1 Integer
# 0 <= omega_87,3 <= 1 Integer
# 0 <= omega_87,4 <= 1 Integer
# 0 <= omega_87,5 <= 1 Integer
# 0 <= omega_87,6 <= 1 Integer
# 0 <= omega_87,7 <= 1 Integer
# 0 <= omega_87,8 <= 1 Integer
# 0 <= omega_87,9 <= 1 Integer
# 0 <= omega_88,0 <= 1 Integer
# 0 <= omega_88,1 <= 1 Integer
# 0 <= omega_88,10 <= 1 Integer
# 0 <= omega_88,11 <= 1 Integer
# 0 <= omega_88,12 <= 1 Integer
# 0 <= omega_88,13 <= 1 Integer
# 0 <= omega_88,14 <= 1 Integer
# 0 <= omega_88,2 <= 1 Integer
# 0 <= omega_88,3 <= 1 Integer
# 0 <= omega_88,4 <= 1 Integer
# 0 <= omega_88,5 <= 1 Integer
# 0 <= omega_88,6 <= 1 Integer
# 0 <= omega_88,7 <= 1 Integer
# 0 <= omega_88,8 <= 1 Integer
# 0 <= omega_88,9 <= 1 Integer
# 0 <= omega_890,0 <= 1 Integer
# 0 <= omega_890,1 <= 1 Integer
# 0 <= omega_890,10 <= 1 Integer
# 0 <= omega_890,11 <= 1 Integer
# 0 <= omega_890,12 <= 1 Integer
# 0 <= omega_890,13 <= 1 Integer
# 0 <= omega_890,14 <= 1 Integer
# 0 <= omega_890,2 <= 1 Integer
# 0 <= omega_890,3 <= 1 Integer
# 0 <= omega_890,4 <= 1 Integer
# 0 <= omega_890,5 <= 1 Integer
# 0 <= omega_890,6 <= 1 Integer
# 0 <= omega_890,7 <= 1 Integer
# 0 <= omega_890,8 <= 1 Integer
# 0 <= omega_890,9 <= 1 Integer
# 0 <= omega_891,0 <= 1 Integer
# 0 <= omega_891,1 <= 1 Integer
# 0 <= omega_891,10 <= 1 Integer
# 0 <= omega_891,11 <= 1 Integer
# 0 <= omega_891,12 <= 1 Integer
# 0 <= omega_891,13 <= 1 Integer
# 0 <= omega_891,14 <= 1 Integer
# 0 <= omega_891,2 <= 1 Integer
# 0 <= omega_891,3 <= 1 Integer
# 0 <= omega_891,4 <= 1 Integer
# 0 <= omega_891,5 <= 1 Integer
# 0 <= omega_891,6 <= 1 Integer
# 0 <= omega_891,7 <= 1 Integer
# 0 <= omega_891,8 <= 1 Integer
# 0 <= omega_891,9 <= 1 Integer
# 0 <= omega_892,0 <= 1 Integer
# 0 <= omega_892,1 <= 1 Integer
# 0 <= omega_892,10 <= 1 Integer
# 0 <= omega_892,11 <= 1 Integer
# 0 <= omega_892,12 <= 1 Integer
# 0 <= omega_892,13 <= 1 Integer
# 0 <= omega_892,14 <= 1 Integer
# 0 <= omega_892,2 <= 1 Integer
# 0 <= omega_892,3 <= 1 Integer
# 0 <= omega_892,4 <= 1 Integer
# 0 <= omega_892,5 <= 1 Integer
# 0 <= omega_892,6 <= 1 Integer
# 0 <= omega_892,7 <= 1 Integer
# 0 <= omega_892,8 <= 1 Integer
# 0 <= omega_892,9 <= 1 Integer
# 0 <= omega_893,0 <= 1 Integer
# 0 <= omega_893,1 <= 1 Integer
# 0 <= omega_893,10 <= 1 Integer
# 0 <= omega_893,11 <= 1 Integer
# 0 <= omega_893,12 <= 1 Integer
# 0 <= omega_893,13 <= 1 Integer
# 0 <= omega_893,14 <= 1 Integer
# 0 <= omega_893,2 <= 1 Integer
# 0 <= omega_893,3 <= 1 Integer
# 0 <= omega_893,4 <= 1 Integer
# 0 <= omega_893,5 <= 1 Integer
# 0 <= omega_893,6 <= 1 Integer
# 0 <= omega_893,7 <= 1 Integer
# 0 <= omega_893,8 <= 1 Integer
# 0 <= omega_893,9 <= 1 Integer

# %%
print("Total:", model.objective.value())

# Decision Variables
count_X = 0 
count_Y = 0 
count_alpha = 0 
count_C = 0 
for v in model.variables():
    try:
        print(v.name,"=", v.value())
        match_X = re.search('^X',v.name)
        match_Y = re.search('^Y', v.name)
        match_alpha = re.search('^(al)', v.name)
        match_age = re.search('^(age)', v.name)
        match_area = re.search('^(Area)', v.name)
        match_vol = re.search('^(V)', v.name)
        match_C = re.search('^(C)', v.name)
        if match_X:
            if v.value()== 1.0:
                count_X += 1
                print(v.name)
        if match_Y:
            if v.value()== 1.0:
                count_Y += 1
                print(v.name)
        if match_alpha:
            if v.value() <= 1.0:    
                count_alpha +=1 
                print(v.name)
        if match_age:
            #print(v.name, "=", v.value() )
            1
        if match_area:
            print(v.name, "=", v.value())
        if match_vol:
            print(v.name, "=", v.value())
        if match_C:
            if v.value() == 1.0:    
                count_C +=1 
                print(v.name)
            
    except:
        print("error couldnt find value")
print(count_X-2, "PCT")
print(count_Y-91, "Harvest")
print(count_alpha, "habitat")
print(count_C, "Carbon")
#Cplex.conflict.refine
# Out:
# Total: 1674.0
# AREA = 9093.2373
# Area_0 = 9093.2373
# Area_0 = 9093.2373
# Area_1 = 7305.5818
# Area_1 = 7305.5818
# Area_10 = 9093.2373
# Area_10 = 9093.2373
# Area_11 = 9093.2373
# Area_11 = 9093.2373
# Area_12 = 9093.2373
# Area_12 = 9093.2373
# Area_13 = 9093.2373
# Area_13 = 9093.2373
# Area_14 = 8168.6829
# Area_14 = 8168.6829
# Area_2 = 7369.6332
# Area_2 = 7369.6332
# Area_3 = 9093.2373
# Area_3 = 9093.2373
# Area_4 = 9093.2373
# Area_4 = 9093.2373
# Area_5 = 9093.2373
# Area_5 = 9093.2373
# Area_6 = 9093.2373
# Area_6 = 9093.2373
# Area_7 = 9093.2373
# Area_7 = 9093.2373
# Area_8 = 9093.2373
# Area_8 = 9093.2373
# Area_9 = 9093.2373
# Area_9 = 9093.2373
# C_1 = 0.0
# C_10 = 0.0
# C_11 = 0.0
# C_12 = 0.0
# C_13 = 0.0
# C_14 = 0.0
# C_15 = 0.0
# C_16 = 0.0
# C_19 = 1.0
# C_19
# C_2 = 1.0
# C_2
# C_20 = 0.0
# C_21 = 0.0
# C_22 = 0.0
# C_23 = 0.0
# C_24 = 0.0
# C_25 = 0.0
# C_26 = 0.0
# C_27 = 1.0
# C_27
# C_28 = 0.0
# C_29 = 0.0
# C_3 = 0.0
# C_30 = 0.0
# C_31 = 0.0
# C_32 = 0.0
# C_33 = 0.0
# C_34 = 0.0
# C_35 = 0.0
# C_37 = 1.0
# C_37
# C_38 = 1.0
# Y_38,11 = 0.0
# Y_38,12 = 0.0
# Y_38,13 = 0.0
# Y_38,14 = 0.0
# Y_38,2 = 0.0
# Y_38,3 = 0.0
# Y_38,4 = 0.0
# Y_38,5 = 0.0
# Y_38,6 = 0.0
# Y_38,7 = 0.0
# Y_38,8 = 0.0
# Y_38,9 = 0.0
# Y_38,_7 = 1.0
# Y_38,_7
# Y_39,0 = 0.0
# Y_39,1 = 0.0
# Y_39,10 = 0.0
# Y_39,11 = 0.0
# Y_39,12 = 0.0
# Y_39,13 = 0.0
# Y_39,14 = 0.0
# Y_39,2 = 0.0
# Y_39,3 = 0.0
# Y_39,4 = 0.0
# Y_39,5 = 0.0
# Y_39,6 = 0.0
# Y_39,7 = 0.0
# Y_39,8 = 0.0
# Y_39,9 = 0.0
# Y_39,_25.0 = 1.0
# Y_39,_25.0
# Y_4,0 = 0.0
# Y_4,1 = 0.0
# Y_4,10 = 0.0
# Y_4,11 = 0.0
# Y_4,12 = 0.0
# Y_4,13 = 0.0
# Y_4,14 = 0.0
# Y_4,2 = 0.0
# Y_4,3 = 0.0
# Y_4,4 = 0.0
# Y_4,5 = 0.0
# Y_4,6 = 1.0
# Y_4,6
# Y_4,7 = 0.0
# Y_4,8 = 0.0
# Y_4,9 = 0.0
# Y_4,_25.0 = 1.0
# Y_4,_25.0
# Y_40,0 = 0.0
# Y_40,1 = 0.0
# Y_40,10 = 0.0
# Y_40,11 = 0.0
# Y_40,12 = 0.0
# Y_40,13 = 0.0
# Y_40,14 = 0.0
# Y_40,2 = 0.0
# Y_40,3 = 0.0
# Y_40,4 = 0.0
# Y_40,5 = 0.0
# Y_40,6 = 0.0
# Y_40,7 = 0.0
# Y_40,8 = 0.0
# Y_40,9 = 0.0
# Y_40,_25.0 = 1.0
# Y_40,_25.0
# Y_41,0 = 0.0
# Y_41,1 = 0.0
# Y_41,10 = 1.0
# Y_41,10
# Y_41,11 = 0.0
# Y_41,12 = 0.0
# Y_41,13 = 0.0
# Y_41,14 = 0.0
# Y_41,2 = 0.0
# Y_41,3 = 0.0
# Y_41,4 = 0.0
# Y_41,5 = 0.0
# Y_41,6 = 0.0
# Y_41,7 = 0.0
# Y_41,8 = 0.0
# Y_41,9 = 0.0
# Y_41,_25.0 = 1.0
# Y_41,_25.0
# Y_42,0 = 0.0
# Y_42,1 = 0.0
# Y_42,10 = 1.0
# Y_42,10
# Y_42,11 = 0.0
# Y_42,12 = 0.0
# Y_42,13 = 0.0
# Y_42,14 = 0.0
# Y_42,2 = 0.0
# Y_42,3 = 0.0
# Y_42,4 = 0.0
# Y_42,5 = 0.0
# Y_42,6 = 0.0
# Y_42,7 = 0.0
# Y_42,8 = 0.0
# Y_42,9 = 0.0
# Y_42,_25.0 = 1.0
# Y_42,_25.0
# Y_43,0 = 0.0
# Y_43,1 = 0.0
# Y_43,10 = 0.0
# Y_43,11 = 0.0
# Y_43,12 = 0.0
# Y_43,13 = 1.0
# Y_43,13
# Y_43,14 = 0.0
# Y_43,2 = 0.0
# Y_43,3 = 0.0
# Y_72,1 = 0.0
# Y_72,10 = 0.0
# Y_72,11 = 0.0
# Y_72,12 = 0.0
# Y_72,13 = 1.0
# Y_72,13
# Y_72,14 = 0.0
# Y_72,2 = 0.0
# Y_72,3 = 0.0
# Y_72,4 = 0.0
# Y_72,5 = 0.0
# Y_72,6 = 0.0
# Y_72,7 = 0.0
# Y_72,8 = 0.0
# Y_72,9 = 0.0
# Y_72,_25.0 = 1.0
# Y_72,_25.0
# Y_730,0 = 0.0
# Y_730,1 = 0.0
# Y_730,10 = 0.0
# Y_730,11 = 0.0
# Y_730,12 = 0.0
# Y_730,13 = 1.0
# Y_730,13
# Y_730,14 = 0.0
# Y_730,2 = 0.0
# Y_730,3 = 0.0
# Y_730,4 = 0.0
# Y_730,5 = 0.0
# Y_730,6 = 0.0
# Y_730,7 = 0.0
# Y_730,8 = 0.0
# Y_730,9 = 0.0
# Y_730,_12 = 1.0
# Y_730,_12
# Y_731,0 = 0.0
# Y_731,1 = 0.0
# Y_731,10 = 0.0
# Y_731,11 = 0.0
# Y_731,12 = 0.0
# Y_731,13 = 1.0
# Y_731,13
# Y_731,14 = 0.0
# Y_731,2 = 0.0
# Y_731,3 = 0.0
# Y_731,4 = 0.0
# Y_731,5 = 0.0
# Y_731,6 = 0.0
# Y_731,7 = 0.0
# Y_731,8 = 0.0
# Y_731,9 = 0.0
# Y_731,_12 = 1.0
# Y_731,_12
# Y_732,0 = 0.0
# Y_732,1 = 0.0
# Y_732,10 = 0.0
# Y_732,11 = 0.0
# Y_732,12 = 1.0
# Y_732,12
# Y_732,13 = 0.0
# Y_732,14 = 0.0
# Y_732,2 = 0.0
# Y_732,3 = 0.0
# Y_732,4 = 0.0
# Y_732,5 = 0.0
# Y_732,6 = 0.0
# Y_732,7 = 0.0
# Y_732,8 = 0.0
# Y_732,9 = 0.0
# Y_732,_12 = 1.0
# Y_732,_12
# Y_733,0 = 0.0
# Y_733,1 = 0.0
# Y_733,10 = 0.0
# Y_733,11 = 0.0
# Y_733,12 = 0.0
# Y_733,13 = 1.0
# Y_733,13
# Y_733,14 = 0.0
# Y_733,2 = 0.0
# Y_733,3 = 0.0
# Y_733,4 = 0.0
# Y_733,5 = 0.0
# Y_733,6 = 0.0
# Y_733,7 = 0.0
# Y_733,8 = 0.0
# Y_733,9 = 0.0
# Y_733,_12 = 1.0
# Y_733,_12
# Y_734,0 = 0.0
# Y_734,1 = 0.0
# Y_734,10 = 0.0
# Y_734,11 = 0.0
# Y_734,12 = 0.0
# Y_734,13 = 1.0
# Y_734,13
# Y_734,14 = 0.0
# Y_734,2 = 0.0
# Y_734,3 = 0.0
# ...
# omega_50,14 = 1.0
# omega_50,2 = 1.0
# omega_50,3 = 1.0
# omega_50,4 = 1.0
# omega_50,5 = 1.0
# omega_50,6 = 1.0
# omega_50,7 = 1.0
# omega_50,8 = 1.0
# omega_50,9 = 1.0
# omega_51,0 = 0.0
# omega_51,1 = 0.0
# omega_51,10 = 0.0
# omega_51,11 = 0.0
# omega_51,12 = 0.0
# omega_51,13 = 0.0
# omega_51,14 = 0.0
# omega_51,2 = 0.0
# omega_51,3 = 0.0
# omega_51,4 = 0.0
# omega_51,5 = 0.0
# omega_51,6 = 0.0
# omega_51,7 = 0.0
# omega_51,8 = 0.0
# omega_51,9 = 0.0
# omega_52,0 = 1.0
# omega_52,1 = 1.0
# omega_52,10 = 0.0
# omega_52,11 = 0.0
# omega_52,12 = 0.0
# omega_52,13 = 0.0
# omega_52,14 = 0.0
# omega_52,2 = 1.0
# omega_52,3 = 1.0
# omega_52,4 = 1.0
# omega_52,5 = 1.0
# omega_52,6 = 1.0
# omega_52,7 = 1.0
# omega_52,8 = 1.0
# omega_52,9 = 0.0
# omega_53,0 = 1.0
# omega_53,1 = 1.0
# omega_53,10 = 0.0
# omega_53,11 = 0.0
# omega_53,12 = 0.0
# omega_53,13 = 0.0
# omega_53,14 = 0.0
# omega_53,2 = 1.0
# omega_53,3 = 1.0
# omega_53,4 = 1.0
# omega_53,5 = 1.0
# omega_53,6 = 1.0
# omega_53,7 = 1.0
# omega_53,8 = 0.0
# omega_53,9 = 0.0
# omega_54,0 = 1.0
# omega_54,1 = 1.0
# omega_54,10 = 1.0
# omega_54,11 = 1.0
# omega_54,12 = 1.0
# omega_54,13 = 1.0
# omega_54,14 = 0.0
# omega_54,2 = 1.0
# omega_54,3 = 1.0
# omega_54,4 = 1.0
# omega_54,5 = 1.0
# omega_54,6 = 1.0
# omega_54,7 = 1.0
# omega_54,8 = 1.0
# omega_54,9 = 1.0
# omega_55,0 = 1.0
# omega_55,1 = 1.0
# omega_55,10 = 0.0
# omega_55,11 = 0.0
# omega_55,12 = 0.0
# omega_55,13 = 0.0
# omega_55,14 = 0.0
# omega_55,2 = 1.0
# omega_55,3 = 1.0
# omega_55,4 = 1.0
# omega_55,5 = 1.0
# omega_55,6 = 1.0
# omega_55,7 = 1.0
# omega_55,8 = 1.0
# omega_55,9 = 1.0
# omega_56,0 = 1.0
# omega_56,1 = 1.0
# omega_56,10 = 0.0
# omega_56,11 = 0.0
# omega_56,12 = 0.0
# omega_56,13 = 0.0
# omega_56,14 = 0.0
# omega_56,2 = 1.0
# omega_56,3 = 1.0
# omega_56,4 = 1.0
# omega_56,5 = 1.0
# omega_56,6 = 1.0
# omega_56,7 = 0.0
# omega_56,8 = 0.0
# omega_56,9 = 0.0
# omega_57,0 = 1.0
# omega_57,1 = 1.0
# omega_57,10 = 1.0
# omega_57,11 = 1.0
# omega_57,12 = 1.0
# omega_57,13 = 1.0
# omega_57,14 = 0.0
# omega_57,2 = 1.0
# omega_57,3 = 1.0
# omega_57,4 = 1.0
# omega_57,5 = 1.0
# omega_57,6 = 1.0
# omega_57,7 = 1.0
# omega_57,8 = 1.0
# omega_57,9 = 1.0
# omega_58,0 = 1.0
# omega_58,1 = 1.0
# omega_58,10 = 1.0
# omega_58,11 = 1.0
# omega_58,12 = 1.0
# omega_58,13 = 1.0
# omega_58,14 = 1.0
# omega_58,2 = 1.0
# omega_58,3 = 1.0
# omega_58,4 = 1.0
# omega_58,5 = 1.0
# omega_58,6 = 1.0
# omega_58,7 = 1.0
# omega_58,8 = 1.0
# omega_58,9 = 1.0
# omega_59,0 = 1.0
# omega_59,1 = 1.0
# omega_59,10 = 1.0
# omega_59,11 = 1.0
# omega_59,12 = 1.0
# omega_59,13 = 1.0
# omega_59,14 = 0.0
# omega_59,2 = 1.0
# omega_59,3 = 1.0
# omega_59,4 = 1.0
# omega_59,5 = 1.0
# omega_59,6 = 1.0
# omega_59,7 = 1.0
# omega_59,8 = 1.0
# omega_59,9 = 1.0
# omega_6,0 = 1.0
# omega_6,1 = 1.0
# omega_6,10 = 0.0
# omega_6,11 = 0.0
# omega_6,12 = 0.0
# omega_6,13 = 0.0
# omega_6,14 = 0.0
# omega_6,2 = 1.0
# omega_6,3 = 1.0
# omega_6,4 = 1.0
# omega_6,5 = 1.0
# omega_6,6 = 0.0
# omega_6,7 = 0.0
# omega_6,8 = 0.0
# omega_6,9 = 0.0
# omega_60,0 = 1.0
# omega_60,1 = 1.0
# omega_60,10 = 0.0
# omega_60,11 = 0.0
# omega_60,12 = 0.0
# omega_60,13 = 0.0
# omega_60,14 = 0.0
# omega_60,2 = 1.0
# omega_60,3 = 1.0
# omega_60,4 = 1.0
# omega_60,5 = 1.0
# omega_60,6 = 0.0
# omega_60,7 = 0.0
# omega_60,8 = 0.0
# omega_60,9 = 0.0
# omega_61,0 = 1.0
# omega_61,1 = 1.0
# omega_61,10 = 1.0
# omega_61,11 = 1.0
# omega_61,12 = 1.0
# omega_61,13 = 1.0
# omega_61,14 = 0.0
# omega_61,2 = 1.0
# omega_61,3 = 1.0
# omega_61,4 = 1.0
# omega_61,5 = 1.0
# omega_61,6 = 1.0
# omega_61,7 = 1.0
# omega_61,8 = 1.0
# omega_61,9 = 1.0
# omega_62,0 = 1.0
# omega_62,1 = 1.0
# omega_62,10 = 1.0
# omega_62,11 = 0.0
# omega_62,12 = 0.0
# omega_62,13 = 0.0
# omega_62,14 = 0.0
# omega_62,2 = 1.0
# omega_62,3 = 1.0
# omega_62,4 = 1.0
# omega_62,5 = 1.0
# omega_62,6 = 1.0
# omega_62,7 = 1.0
# omega_62,8 = 1.0
# omega_62,9 = 1.0
# omega_63,0 = 1.0
# omega_63,1 = 1.0
# omega_63,10 = 0.0
# omega_63,11 = 0.0
# omega_63,12 = 0.0
# omega_63,13 = 0.0
# omega_63,14 = 0.0
# omega_63,2 = 1.0
# omega_63,3 = 1.0
# omega_63,4 = 1.0
# omega_63,5 = 1.0
# omega_63,6 = 1.0
# omega_63,7 = 1.0
# omega_63,8 = 1.0
# omega_63,9 = 1.0
# omega_64,0 = 1.0
# omega_64,1 = 0.0
# omega_64,10 = 0.0
# omega_64,11 = 0.0
# omega_64,12 = 0.0
# omega_64,13 = 0.0
# omega_64,14 = 0.0
# omega_64,2 = 0.0
# omega_64,3 = 0.0
# omega_64,4 = 0.0
# omega_64,5 = 0.0
# omega_64,6 = 0.0
# omega_64,7 = 0.0
# omega_64,8 = 0.0
# omega_64,9 = 0.0
# omega_66,0 = 1.0
# omega_66,1 = 1.0
# omega_66,10 = 0.0
# omega_66,11 = 0.0
# omega_66,12 = 0.0
# omega_66,13 = 0.0
# omega_66,14 = 0.0
# omega_66,2 = 1.0
# omega_66,3 = 1.0
# omega_66,4 = 1.0
# omega_66,5 = 1.0
# omega_66,6 = 1.0
# omega_66,7 = 1.0
# omega_66,8 = 1.0
# omega_66,9 = 1.0
# omega_660,0 = 1.0
# omega_660,1 = 1.0
# omega_660,10 = 1.0
# omega_660,11 = 0.0
# omega_660,12 = 0.0
# omega_660,13 = 0.0
# omega_660,14 = 0.0
# omega_660,2 = 1.0
# omega_660,3 = 1.0
# omega_660,4 = 1.0
# omega_660,5 = 1.0
# omega_660,6 = 1.0
# omega_660,7 = 1.0
# omega_660,8 = 1.0
# omega_660,9 = 1.0
# omega_661,0 = 1.0
# omega_661,1 = 1.0
# omega_661,10 = 1.0
# omega_661,11 = 1.0
# omega_661,12 = 1.0
# omega_661,13 = 1.0
# omega_661,14 = 0.0
# omega_661,2 = 1.0
# omega_661,3 = 1.0
# omega_661,4 = 1.0
# omega_661,5 = 1.0
# omega_661,6 = 1.0
# omega_661,7 = 1.0
# omega_661,8 = 1.0
# omega_661,9 = 1.0
# omega_662,0 = 1.0
# omega_662,1 = 1.0
# omega_662,10 = 1.0
# omega_662,11 = 1.0
# omega_662,12 = 1.0
# omega_662,13 = 1.0
# omega_662,14 = 0.0
# omega_662,2 = 1.0
# omega_662,3 = 1.0
# omega_662,4 = 1.0
# omega_662,5 = 1.0
# omega_662,6 = 1.0
# omega_662,7 = 1.0
# omega_662,8 = 1.0
# omega_662,9 = 1.0
# omega_67,0 = 1.0
# omega_67,1 = 1.0
# omega_67,10 = 1.0
# omega_67,11 = 1.0
# omega_67,12 = 1.0
# omega_67,13 = 1.0
# omega_67,14 = 1.0
# omega_67,2 = 1.0
# omega_67,3 = 1.0
# omega_67,4 = 1.0
# omega_67,5 = 1.0
# omega_67,6 = 1.0
# omega_67,7 = 1.0
# omega_67,8 = 1.0
# omega_67,9 = 1.0
# omega_68,0 = 1.0
# omega_68,1 = 1.0
# omega_68,10 = 0.0
# omega_68,11 = 0.0
# omega_68,12 = 0.0
# omega_68,13 = 0.0
# omega_68,14 = 0.0
# omega_68,2 = 1.0
# omega_68,3 = 1.0
# omega_68,4 = 1.0
# omega_68,5 = 1.0
# omega_68,6 = 1.0
# omega_68,7 = 0.0
# omega_68,8 = 0.0
# omega_68,9 = 0.0
# omega_69,0 = 1.0
# omega_69,1 = 1.0
# omega_69,10 = 1.0
# omega_69,11 = 1.0
# omega_69,12 = 1.0
# omega_69,13 = 1.0
# omega_69,14 = 1.0
# omega_69,2 = 1.0
# omega_69,3 = 1.0
# omega_69,4 = 1.0
# omega_69,5 = 1.0
# omega_69,6 = 1.0
# omega_69,7 = 1.0
# omega_69,8 = 1.0
# omega_69,9 = 1.0
# omega_71,0 = 1.0
# omega_71,1 = 1.0
# omega_71,10 = 0.0
# omega_71,11 = 0.0
# omega_71,12 = 0.0
# omega_71,13 = 0.0
# omega_71,14 = 0.0
# omega_71,2 = 1.0
# omega_71,3 = 1.0
# omega_71,4 = 1.0
# omega_71,5 = 1.0
# omega_71,6 = 1.0
# omega_71,7 = 0.0
# omega_71,8 = 0.0
# omega_71,9 = 0.0
# omega_72,0 = 1.0
# omega_72,1 = 1.0
# omega_72,10 = 1.0
# omega_72,11 = 1.0
# omega_72,12 = 1.0
# omega_72,13 = 1.0
# omega_72,14 = 0.0
# omega_72,2 = 1.0
# omega_72,3 = 1.0
# omega_72,4 = 1.0
# omega_72,5 = 1.0
# omega_72,6 = 1.0
# omega_72,7 = 1.0
# omega_72,8 = 1.0
# omega_72,9 = 1.0
# omega_730,0 = 1.0
# omega_730,1 = 1.0
# omega_730,10 = 1.0
# omega_730,11 = 1.0
# omega_730,12 = 1.0
# omega_730,13 = 1.0
# omega_730,14 = 0.0
# omega_730,2 = 1.0
# omega_730,3 = 1.0
# omega_730,4 = 1.0
# omega_730,5 = 1.0
# omega_730,6 = 1.0
# omega_730,7 = 1.0
# omega_730,8 = 1.0
# omega_730,9 = 1.0
# omega_731,0 = 1.0
# omega_731,1 = 1.0
# omega_731,10 = 1.0
# omega_731,11 = 1.0
# omega_731,12 = 1.0
# omega_731,13 = 1.0
# omega_731,14 = 0.0
# omega_731,2 = 1.0
# omega_731,3 = 1.0
# omega_731,4 = 1.0
# omega_731,5 = 1.0
# omega_731,6 = 1.0
# omega_731,7 = 1.0
# omega_731,8 = 1.0
# omega_731,9 = 1.0
# omega_732,0 = 1.0
# omega_732,1 = 1.0
# omega_732,10 = 1.0
# omega_732,11 = 1.0
# omega_732,12 = 1.0
# omega_732,13 = 1.0
# omega_732,14 = 1.0
# omega_732,2 = 1.0
# omega_732,3 = 1.0
# omega_732,4 = 1.0
# omega_732,5 = 1.0
# omega_732,6 = 1.0
# omega_732,7 = 1.0
# omega_732,8 = 1.0
# omega_732,9 = 1.0
# omega_733,0 = 1.0
# omega_733,1 = 1.0
# omega_733,10 = 1.0
# omega_733,11 = 1.0
# omega_733,12 = 1.0
# omega_733,13 = 1.0
# omega_733,14 = 0.0
# omega_733,2 = 1.0
# omega_733,3 = 1.0
# omega_733,4 = 1.0
# omega_733,5 = 1.0
# omega_733,6 = 1.0
# omega_733,7 = 1.0
# omega_733,8 = 1.0
# omega_733,9 = 1.0
# omega_734,0 = 1.0
# omega_734,1 = 1.0
# omega_734,10 = 1.0
# omega_734,11 = 1.0
# omega_734,12 = 1.0
# omega_734,13 = 1.0
# omega_734,14 = 0.0
# omega_734,2 = 1.0
# omega_734,3 = 1.0
# omega_734,4 = 1.0
# omega_734,5 = 1.0
# omega_734,6 = 1.0
# omega_734,7 = 1.0
# omega_734,8 = 1.0
# omega_734,9 = 1.0
# omega_74,0 = 1.0
# omega_74,1 = 1.0
# omega_74,10 = 1.0
# omega_74,11 = 1.0
# omega_74,12 = 1.0
# omega_74,13 = 1.0
# omega_74,14 = 1.0
# omega_74,2 = 1.0
# omega_74,3 = 1.0
# omega_74,4 = 1.0
# omega_74,5 = 1.0
# omega_74,6 = 1.0
# omega_74,7 = 1.0
# omega_74,8 = 1.0
# omega_74,9 = 1.0
# omega_750,0 = 1.0
# omega_750,1 = 1.0
# omega_750,10 = 1.0
# omega_750,11 = 1.0
# omega_750,12 = 1.0
# omega_750,13 = 1.0
# omega_750,14 = 0.0
# omega_750,2 = 1.0
# omega_750,3 = 1.0
# omega_750,4 = 1.0
# omega_750,5 = 1.0
# omega_750,6 = 1.0
# omega_750,7 = 1.0
# omega_750,8 = 1.0
# omega_750,9 = 1.0
# omega_751,0 = 1.0
# omega_751,1 = 1.0
# omega_751,10 = 1.0
# omega_751,11 = 1.0
# omega_751,12 = 1.0
# omega_751,13 = 1.0
# omega_751,14 = 1.0
# omega_751,2 = 1.0
# omega_751,3 = 1.0
# omega_751,4 = 1.0
# omega_751,5 = 1.0
# omega_751,6 = 1.0
# omega_751,7 = 1.0
# omega_751,8 = 1.0
# omega_751,9 = 1.0
# omega_752,0 = 1.0
# omega_752,1 = 1.0
# omega_752,10 = 1.0
# omega_752,11 = 1.0
# omega_752,12 = 1.0
# omega_752,13 = 1.0
# omega_752,14 = 1.0
# omega_752,2 = 1.0
# omega_752,3 = 1.0
# omega_752,4 = 1.0
# omega_752,5 = 1.0
# omega_752,6 = 1.0
# omega_752,7 = 1.0
# omega_752,8 = 1.0
# omega_752,9 = 1.0
# omega_753,0 = 1.0
# omega_753,1 = 1.0
# omega_753,10 = 1.0
# omega_753,11 = 1.0
# omega_753,12 = 1.0
# omega_753,13 = 1.0
# omega_753,14 = 1.0
# omega_753,2 = 1.0
# omega_753,3 = 1.0
# omega_753,4 = 1.0
# omega_753,5 = 1.0
# omega_753,6 = 1.0
# omega_753,7 = 1.0
# omega_753,8 = 1.0
# omega_753,9 = 1.0
# omega_754,0 = 0.0
# omega_754,1 = 0.0
# omega_754,10 = 0.0
# omega_754,11 = 0.0
# omega_754,12 = 0.0
# omega_754,13 = 0.0
# omega_754,14 = 0.0
# omega_754,2 = 0.0
# omega_754,3 = 0.0
# omega_754,4 = 0.0
# omega_754,5 = 0.0
# omega_754,6 = 0.0
# omega_754,7 = 0.0
# omega_754,8 = 0.0
# omega_754,9 = 0.0
# omega_755,0 = 0.0
# omega_755,1 = 0.0
# omega_755,10 = 0.0
# omega_755,11 = 0.0
# omega_755,12 = 0.0
# omega_755,13 = 0.0
# omega_755,14 = 0.0
# omega_755,2 = 0.0
# omega_755,3 = 0.0
# omega_755,4 = 0.0
# omega_755,5 = 0.0
# omega_755,6 = 0.0
# omega_755,7 = 0.0
# omega_755,8 = 0.0
# omega_755,9 = 0.0
# omega_756,0 = 1.0
# omega_756,1 = 1.0
# omega_756,10 = 1.0
# omega_756,11 = 1.0
# omega_756,12 = 1.0
# omega_756,13 = 1.0
# omega_756,14 = 1.0
# omega_756,2 = 1.0
# omega_756,3 = 1.0
# omega_756,4 = 1.0
# omega_756,5 = 1.0
# omega_756,6 = 1.0
# omega_756,7 = 1.0
# omega_756,8 = 1.0
# omega_756,9 = 1.0
# omega_757,0 = 0.0
# omega_757,1 = 0.0
# omega_757,10 = 0.0
# omega_757,11 = 0.0
# omega_757,12 = 0.0
# omega_757,13 = 0.0
# omega_757,14 = 0.0
# omega_757,2 = 0.0
# omega_757,3 = 0.0
# omega_757,4 = 0.0
# omega_757,5 = 0.0
# omega_757,6 = 0.0
# omega_757,7 = 0.0
# omega_757,8 = 0.0
# omega_757,9 = 0.0
# omega_758,0 = 0.0
# omega_758,1 = 0.0
# omega_758,10 = 0.0
# omega_758,11 = 0.0
# omega_758,12 = 0.0
# omega_758,13 = 0.0
# omega_758,14 = 0.0
# omega_758,2 = 0.0
# omega_758,3 = 0.0
# omega_758,4 = 0.0
# omega_758,5 = 0.0
# omega_758,6 = 0.0
# omega_758,7 = 0.0
# omega_758,8 = 0.0
# omega_758,9 = 0.0
# omega_759,0 = 0.0
# omega_759,1 = 0.0
# omega_759,10 = 0.0
# omega_759,11 = 0.0
# omega_759,12 = 0.0
# omega_759,13 = 0.0
# omega_759,14 = 0.0
# omega_759,2 = 0.0
# omega_759,3 = 0.0
# omega_759,4 = 0.0
# omega_759,5 = 0.0
# omega_759,6 = 0.0
# omega_759,7 = 0.0
# omega_759,8 = 0.0
# omega_759,9 = 0.0
# omega_760,0 = 0.0
# omega_760,1 = 0.0
# omega_760,10 = 0.0
# omega_760,11 = 0.0
# omega_760,12 = 0.0
# omega_760,13 = 0.0
# omega_760,14 = 0.0
# omega_760,2 = 0.0
# omega_760,3 = 0.0
# omega_760,4 = 0.0
# omega_760,5 = 0.0
# omega_760,6 = 0.0
# omega_760,7 = 0.0
# omega_760,8 = 0.0
# omega_760,9 = 0.0
# omega_761,0 = 0.0
# omega_761,1 = 0.0
# omega_761,10 = 0.0
# omega_761,11 = 0.0
# omega_761,12 = 0.0
# omega_761,13 = 0.0
# omega_761,14 = 0.0
# omega_761,2 = 0.0
# omega_761,3 = 0.0
# omega_761,4 = 0.0
# omega_761,5 = 0.0
# omega_761,6 = 0.0
# omega_761,7 = 0.0
# omega_761,8 = 0.0
# omega_761,9 = 0.0
# omega_762,0 = 0.0
# omega_762,1 = 0.0
# omega_762,10 = 0.0
# omega_762,11 = 0.0
# omega_762,12 = 0.0
# omega_762,13 = 0.0
# omega_762,14 = 0.0
# omega_762,2 = 0.0
# omega_762,3 = 0.0
# omega_762,4 = 0.0
# omega_762,5 = 0.0
# omega_762,6 = 0.0
# omega_762,7 = 0.0
# omega_762,8 = 0.0
# omega_762,9 = 0.0
# omega_763,0 = 0.0
# omega_763,1 = 0.0
# omega_763,10 = 0.0
# omega_763,11 = 0.0
# omega_763,12 = 0.0
# omega_763,13 = 0.0
# omega_763,14 = 0.0
# omega_763,2 = 0.0
# omega_763,3 = 0.0
# omega_763,4 = 0.0
# omega_763,5 = 0.0
# omega_763,6 = 0.0
# omega_763,7 = 0.0
# omega_763,8 = 0.0
# omega_763,9 = 0.0
# omega_764,0 = 0.0
# omega_764,1 = 0.0
# omega_764,10 = 0.0
# omega_764,11 = 0.0
# omega_764,12 = 0.0
# omega_764,13 = 0.0
# omega_764,14 = 0.0
# omega_764,2 = 0.0
# omega_764,3 = 0.0
# omega_764,4 = 0.0
# omega_764,5 = 0.0
# omega_764,6 = 0.0
# omega_764,7 = 0.0
# omega_764,8 = 0.0
# omega_764,9 = 0.0
# omega_771,0 = 0.0
# omega_771,1 = 0.0
# omega_771,10 = 0.0
# omega_771,11 = 0.0
# omega_771,12 = 0.0
# omega_771,13 = 0.0
# omega_771,14 = 0.0
# omega_771,2 = 0.0
# omega_771,3 = 0.0
# omega_771,4 = 0.0
# omega_771,5 = 0.0
# omega_771,6 = 0.0
# omega_771,7 = 0.0
# omega_771,8 = 0.0
# omega_771,9 = 0.0
# omega_772,0 = 0.0
# omega_772,1 = 0.0
# omega_772,10 = 0.0
# omega_772,11 = 0.0
# omega_772,12 = 0.0
# omega_772,13 = 0.0
# omega_772,14 = 0.0
# omega_772,2 = 0.0
# omega_772,3 = 0.0
# omega_772,4 = 0.0
# omega_772,5 = 0.0
# omega_772,6 = 0.0
# omega_772,7 = 0.0
# omega_772,8 = 0.0
# omega_772,9 = 0.0
# omega_779,0 = 1.0
# omega_779,1 = 1.0
# omega_779,10 = 1.0
# omega_779,11 = 1.0
# omega_779,12 = 1.0
# omega_779,13 = 1.0
# omega_779,14 = 1.0
# omega_779,2 = 1.0
# omega_779,3 = 1.0
# omega_779,4 = 1.0
# omega_779,5 = 1.0
# omega_779,6 = 1.0
# omega_779,7 = 1.0
# omega_779,8 = 1.0
# omega_779,9 = 1.0
# omega_79,0 = 1.0
# omega_79,1 = 1.0
# omega_79,10 = 1.0
# omega_79,11 = 1.0
# omega_79,12 = 1.0
# omega_79,13 = 1.0
# omega_79,14 = 1.0
# omega_79,2 = 1.0
# omega_79,3 = 1.0
# omega_79,4 = 1.0
# omega_79,5 = 1.0
# omega_79,6 = 1.0
# omega_79,7 = 1.0
# omega_79,8 = 1.0
# omega_79,9 = 1.0
# omega_8,0 = 1.0
# omega_8,1 = 1.0
# omega_8,10 = 1.0
# omega_8,11 = 1.0
# omega_8,12 = 1.0
# omega_8,13 = 1.0
# omega_8,14 = 1.0
# omega_8,2 = 1.0
# omega_8,3 = 1.0
# omega_8,4 = 1.0
# omega_8,5 = 1.0
# omega_8,6 = 1.0
# omega_8,7 = 1.0
# omega_8,8 = 1.0
# omega_8,9 = 1.0
# omega_800,0 = 1.0
# omega_800,1 = 1.0
# omega_800,10 = 1.0
# omega_800,11 = 1.0
# omega_800,12 = 1.0
# omega_800,13 = 1.0
# omega_800,14 = 1.0
# omega_800,2 = 1.0
# omega_800,3 = 1.0
# omega_800,4 = 1.0
# omega_800,5 = 1.0
# omega_800,6 = 1.0
# omega_800,7 = 1.0
# omega_800,8 = 1.0
# omega_800,9 = 1.0
# omega_801,0 = 1.0
# omega_801,1 = 1.0
# omega_801,10 = 1.0
# omega_801,11 = 1.0
# omega_801,12 = 1.0
# omega_801,13 = 1.0
# omega_801,14 = 1.0
# omega_801,2 = 1.0
# omega_801,3 = 1.0
# omega_801,4 = 1.0
# omega_801,5 = 1.0
# omega_801,6 = 1.0
# omega_801,7 = 1.0
# omega_801,8 = 1.0
# omega_801,9 = 1.0
# omega_83,0 = 1.0
# omega_83,1 = 1.0
# omega_83,10 = 1.0
# omega_83,11 = 1.0
# omega_83,12 = 1.0
# omega_83,13 = 1.0
# omega_83,14 = 1.0
# omega_83,2 = 1.0
# omega_83,3 = 1.0
# omega_83,4 = 1.0
# omega_83,5 = 1.0
# omega_83,6 = 1.0
# omega_83,7 = 1.0
# omega_83,8 = 1.0
# omega_83,9 = 1.0
# omega_87,0 = 1.0
# omega_87,1 = 1.0
# omega_87,10 = 1.0
# omega_87,11 = 1.0
# omega_87,12 = 1.0
# omega_87,13 = 1.0
# omega_87,14 = 1.0
# omega_87,2 = 1.0
# omega_87,3 = 1.0
# omega_87,4 = 1.0
# omega_87,5 = 1.0
# omega_87,6 = 1.0
# omega_87,7 = 1.0
# omega_87,8 = 1.0
# omega_87,9 = 1.0
# omega_88,0 = 1.0
# omega_88,1 = 1.0
# omega_88,10 = 1.0
# omega_88,11 = 1.0
# omega_88,12 = 1.0
# omega_88,13 = 1.0
# omega_88,14 = 1.0
# omega_88,2 = 1.0
# omega_88,3 = 1.0
# omega_88,4 = 1.0
# omega_88,5 = 1.0
# omega_88,6 = 1.0
# omega_88,7 = 1.0
# omega_88,8 = 1.0
# omega_88,9 = 1.0
# omega_890,0 = 1.0
# omega_890,1 = 1.0
# omega_890,10 = 1.0
# omega_890,11 = 1.0
# omega_890,12 = 1.0
# omega_890,13 = 1.0
# omega_890,14 = 1.0
# omega_890,2 = 1.0
# omega_890,3 = 1.0
# omega_890,4 = 1.0
# omega_890,5 = 1.0
# omega_890,6 = 1.0
# omega_890,7 = 1.0
# omega_890,8 = 1.0
# omega_890,9 = 1.0
# omega_891,0 = 1.0
# omega_891,1 = 1.0
# omega_891,10 = 1.0
# omega_891,11 = 1.0
# omega_891,12 = 1.0
# omega_891,13 = 1.0
# omega_891,14 = 1.0
# omega_891,2 = 1.0
# omega_891,3 = 1.0
# omega_891,4 = 1.0
# omega_891,5 = 1.0
# omega_891,6 = 1.0
# omega_891,7 = 1.0
# omega_891,8 = 1.0
# omega_891,9 = 1.0
# omega_892,0 = 1.0
# omega_892,1 = 1.0
# omega_892,10 = 1.0
# omega_892,11 = 1.0
# omega_892,12 = 1.0
# omega_892,13 = 1.0
# omega_892,14 = 1.0
# omega_892,2 = 1.0
# omega_892,3 = 1.0
# omega_892,4 = 1.0
# omega_892,5 = 1.0
# omega_892,6 = 1.0
# omega_892,7 = 1.0
# omega_892,8 = 1.0
# omega_892,9 = 1.0
# omega_893,0 = 1.0
# omega_893,1 = 1.0
# omega_893,10 = 1.0
# omega_893,11 = 1.0
# omega_893,12 = 1.0
# omega_893,13 = 1.0
# omega_893,14 = 1.0
# omega_893,2 = 1.0
# omega_893,3 = 1.0
# omega_893,4 = 1.0
# omega_893,5 = 1.0
# omega_893,6 = 1.0
# omega_893,7 = 1.0
# omega_893,8 = 1.0
# omega_893,9 = 1.0
# 55 PCT
# 108 Harvest
# 1815 habitat
# 34 Carbon
