# %% [markdown]
# # Write an IP problem in <'lp'> format - deer habitat model

# %%
# %load_ext autoreload
# %autoreload 2

from pulp import * 
import pandas as pd 
import numpy as np 
import math 
import re
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
### This version corrects the constraint on variables alpha, account for split polygons 
### This version checks the constraint for PCT and harvest allocation 
### Add the buffer as close enough polygons  

#Import files 
## Read excel files with panda 
#! pip install xlrd 
#!  pip install docplex
#conda install -c ibmdecisionoptimization docplex
#conda update -c ibmdecisionoptimization docplex

### Parcels, adjacency, area
        ###df_sheet_3 = pd.read_excel('IP_PB_simpledeerhab_SI.xlsx', sheet_name=1)
df_sheet_3 = pd.read_excel('Adj_200mbuffer.xlsx', sheet_name=2)
df_sheet_3 = df_sheet_3.fillna(0)

df_sheet_2 = pd.read_excel('1-Adj_200mbuffer.xlsx', sheet_name=1)
df_sheet_2["Acre"] = df_sheet_2["Acre"].astype(int)
df_sheet_2 = df_sheet_2.fillna(0)
### growth model equations 
equation = pd.read_csv('Growth_volume_inc.csv', delimiter =';')
#df_sheet_3 = df_sheet_3.iloc[:10]

# %%
### TO DO 
##### TASKS ##### 
## initial class age ## 

##### Observations: 
## PCT ### most treatments arrive at the end (no i class age)
#### Overall buget splitted along 14 years 
#### PCT budget - just cost 
###### ANDREW 
#### 2017 cost of PCT/ac = $420/ac

#### harvest budget - cost? - LEV? - etc. close to road network
### find some proxi - maybe scheduling models for harvest 

#### (WK_3) Exclusivity problem 
### carying capacity 

#### OPTION 1: 
#### if cover is selected then sum of adjacent aphas*area (available forage) <= area cover 

#### OPTION 2: 
# Var Co 1 if cover selected 0 otherwise 
#I could set a shelter capacity to each old growth parcel and 
#whenever the forage quantity reached the shelter capacity requirements it would stop the 
#forage allocation (minimize surplus) …  

#Prepare for further research: What to do next? Ex: climate change considerations where snow 
#can kill 33% of fawns (is said to be most critical factor compared to predation), 
#hunt success indicator, forets productivity, wildlife corridor concerns …  

len(A_stands)
# Out:
# 127

# %%
# Volume increment function 
    #### first download the dataframe 
    #### create a dictionary with site class_site index as main key for polynomial equations
    #### then create exponents keys and its corresponding coefficient value for each site class_site index key
    #### {SC+SI : {Exp1:Coeff1;Exp2:Coeff2 etc.}}

### create index "SC_"+str(i)+"_"+str(j)
    # data.frame with 1# SC 2# SI and 3#equation
SC = equation["SC"]
SI = equation["SI"]
eq = equation["eq"]
growth_eq = {}
 
for i in range (len(equation)): 
    # combine SC and SI in index 
    index = ("SC_"+str(SC[i])+"_SI_"+str(SI[i]))
    # extract the equation and transform this into a disctionary object 
    term = str(eq[i])
    term = re.split('[+]|(-)',eq[i])
    term = list(filter(None, term))
    count = []
    r = 0 #element to remove 
    for j in range(len(term)):
        if "E" in term[j]:
            term[j] = term[j]+term[j+1]+term[j+2]  
            count.append(j+1-r)
            r=r+1
            count.append(j+2-r)
    for k in count: 
        term.remove(term[k])
    count = []
    r = 0 
    for j in range(len(term)):
        if "-" == term[j]:
            term[j] = term[j]+term[j+1]
            count.append(j+1-r)
            r = r + 1
    for k in count: 
        term.remove(term[k])
    
    eq_elt = {}
    for j in range(len(term)): 
        info = term[j].split('x')
        info = [i.replace(",", ".") for i in info]
        if "E" in info: 
            exp_number = info[0]
            float_number = float(exp_number)
            info[0] = float_number
        if ' ' in info: 
            info[0] = float(info[0])
            eq_elt.update({1 :info[0], 0:0})
        elif len(info) ==1:
            for l in range(len(info)):
                if info[l] == '': 
                    info[l] = 0
            info = [i.replace(" ", "") for i in info]
            info = [float(i) for i in info]
            eq_elt.update({0 :info[0]})
        else:
            for l in range(len(info)):
                if info[l] == '': 
                    info[l] = 0
            info = [i.replace(" ", "") for i in info]
            info = [float(i) for i in info]
            eq_elt.update({info[1]:info[0]})
        #print(eq_elt, "equ"+str(j))
    #dictionary with SC_SI and it equation encoded as an embeded dictionary 
    growth_eq.update({index: eq_elt})

# Set a function that would read the equations stored in your dictionary 
def eval_poly_dict(poly, x, y):
    return sum([poly[y][power]*x**power for power in poly[y]])

#test 
X = 200
a =eval_poly_dict(growth_eq, X, 'SC_VI_SI_60')  
print(a)
# Out:
# 7513.08

# %%
# Data definition 
mid_point = 2.5 # an action is estimated to happen at the mid-point of 5-year periods 
n_periods = 14 # if the planning horizon is 70 years, and 5-year periods increment then 70/5 = 14 

i_yr = 2015 # starting year 

##PCT
min_yr = 15 # minimal age before PCT
max_yr = 40 # maximal age for PCT treatements 

## Cover 
min_yr_cover = 120 # minimal age for stand to be considered as cover 

## Harvest 
min_hyr = 55 # minimal age before harvesting 
    ### set the number of period after PCT before allowed harvest 
n_harv_pct = 2



#Table with harvets, PCT and neighbor information
HPCT = pd.DataFrame()
HPCT = HPCT.assign(stand_i=df_sheet_2["Stand_Ipid"],  area=df_sheet_2["Acre"],H=df_sheet_2["Harvest"], 
                   PCT=df_sheet_2["PCT_YR"], SI=df_sheet_2["SSIZEC"], 
                   adj_i=df_sheet_2["Neighbor_2"], SC_SI=df_sheet_2["SC_SI"])
HPCT = HPCT.drop_duplicates(subset='stand_i', keep="first")

Buffer = pd.DataFrame()
Buffer = Buffer.assign(stand_i=df_sheet_2["Stand_Ipid"],a_buffer=df_sheet_2["Int_ac"],c_buffer=df_sheet_2["Buffer"])

# %%
Buffer_dic = {}
cell_buffer = {}
cell = []
cell_buff =[]
count = 0 
for m in range(len(Buffer["stand_i"])):
    first = Buffer["stand_i"][m]
    if first not in cell: 
        cell.append(first)
        for i in range(len(Buffer["stand_i"])):
            second = Buffer["stand_i"][i]
            if first == second: 
                cells = Buffer["c_buffer"][i] 
                if cells != first:
                    area = Buffer["a_buffer"][i]
                    cell_buffer.update({cells:area})
        Buffer_dic.update({first:cell_buffer})
        cell_buffer = {}

# %%
N_stands = np.array(HPCT["stand_i"])
N_stands = np.ndarray.tolist(N_stands)

stands_dic = {}
number = 0 # or 1 !!!!
for m in range(len(N_stands)):
    number = number+1 
    stand = N_stands[m]
    stands_dic.update({number:stand})
    
n_stands = len(HPCT)
M = n_stands + 1  # big number 
Yr_harvest = np.array(HPCT["H"])
Yr_PCT = np.array(HPCT["PCT"])
Yr_OG = np.array(HPCT["SI"])
A_stands = np.array(HPCT["area"])
## Area --> dictionary 

area_dic = {}
for m in range(len(N_stands)):
    stand = N_stands[m]
    area = A_stands[m]
    area_dic.update({stand:area})

#Adj_stands[["stand_i","stand_j"]] = df_sheet_3[["Stand_IPid", "Neigbor"]]
Adj_stands = pd.DataFrame()
Adj_stands = Adj_stands.assign(stand_i=np.array(HPCT["stand_i"]), adj_i=np.array(HPCT["adj_i"]))
Adj = Adj_stands["adj_i"].values.tolist()
i_Adj = Adj_stands["stand_i"].values.tolist()

### generate variables for previous harvest - RECORD X m,-t :         
new_Y_m = []
new_Y_p = []
new_Y = {}
for i in range (len(Yr_harvest)): 
    if Yr_harvest[i] != 0: 
        new_Y_m.append(N_stands[i])
        a = math.floor((Yr_harvest[i]-i_yr-1)/5)
        new_Y_p.append(math.floor((Yr_harvest[i]-i_yr-1)/5))
    elif Yr_OG[i] == 4:
        new_Y_m.append(N_stands[i])
        a = -((min_yr_cover/5) +1)
        new_Y_p.append(-((min_yr_cover/5) +1)) #considered min age for old growth (period of 5 years so 5*26)
    else: 
        new_Y_m.append(N_stands[i])
        a = -((min_yr_cover/5) +1)
        new_Y_p.append(-((min_yr_cover/5) +1)) # to think 
    new_Y.update({N_stands[i]:a})

### generate variables for previous PCT - RECORD X m,-t : 
add_var = []
new_X_m = []
new_X_p = []
new_X = {}
for i in range (len(Yr_PCT)): 
    if Yr_PCT[i] != 0: 
        new_X_m.append(N_stands[i])
        a = math.floor((Yr_PCT[i]-i_yr-1)/5)
        new_X_p.append(math.floor((Yr_PCT[i]-i_yr-1)/5))
        new_X.update({N_stands[i]:a})
        
        
#site class and site index of parcels 
SC_SI = pd.DataFrame()
SC_SI = SC_SI.assign(stand_i=np.array(HPCT["stand_i"]), SC_SI=np.array(HPCT["SC_SI"]))
# volume
volume = {}
start_vol = {}
for k in range(len(N_stands)):
    a = []
    start = []
    for i in range(n_periods+1):
        Age_mt = i-new_Y_p[k]
        SC_SIm = SC_SI["SC_SI"][k]
        if SC_SIm == 0:
            SC_SIm =  SC_SI["SC_SI"][1]
        b = eval_poly_dict(growth_eq, Age_mt, SC_SIm)*12/1000
        b=round(b)
        c = eval_poly_dict(growth_eq, i, SC_SIm)*12/1000
        c = round(c)
        if b < 0: 
            b = 0 
        if c < 0: 
            c = 0 
        a.append(b)#MBF/ac
        start.append(c)
    volume.update({N_stands[k]:a})
    start_vol.update({N_stands[k]:start})
min_vol = 20.5 #MBF/ac ! here stump and tip 
### reference 
# https://tind-customer-agecon.s3.amazonaws.com/0d218c56-21cd-4a6f-9ded-711620b176dd?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27tb1273.pdf&response-content-type=application%2Fpdf&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Expires=86400&X-Amz-Credential=AKIAXL7W7Q3XHXDVDQYS%2F20220519%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Date=20220519T211917Z&X-Amz-Signature=2f733b3d86f854ddb3b1fbab86865135966db323573c7649a480441933c66d95
### Info for unmanaged hemlock

# %%
# define a dictionary setting for each age the volume

# %%
# # Model initialization
model= LpProblem("Deer1", LpMaximize)

# %%
# Decision variables 
## X m, t - stand m to be PCTed in time period t  _ Xm,t=1; 0 otherwise 
X_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
DV_X_variables = LpVariable.matrix("X", X_variable_names, cat = "Binary", lowBound= 0 )
X_allocation = np.array(DV_X_variables).reshape(n_stands,14+1)

## Y m, t - stand m to be harvested in time period t _ Ym,t=1; 0 otherwise 
Y_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
DV_Y_variables = LpVariable.matrix("Y", Y_variable_names, cat = "Binary", lowBound= 0 )
Y_allocation = np.array(DV_Y_variables).reshape(n_stands,14+1)

## No action - assume forest left as it is during the entire planning horzion (carbon store) 
C_variable_names = [str(i) for i in N_stands]
DV_C_variables = LpVariable.matrix("C", C_variable_names, cat = "Binary", lowBound= 0 )
C_allocation = np.array(DV_C_variables).reshape(n_stands)


## past activities variables
record_X_variables = [str(j) + ',' + str(new_X_p[new_X_m.index(j)]) for j in new_X_m]
DV_Xr_variables = LpVariable.matrix("X", record_X_variables, cat = "Binary", lowBound= 0 )
Xr_allocation = np.array(DV_Xr_variables).reshape(len(new_X_p))
        
record_Y_variables = [str(j) + ',' + str(new_Y_p[new_Y_m.index(j)]) for j in new_Y_m]
DV_Yr_variables = LpVariable.matrix("Y", record_Y_variables, cat = "Binary", lowBound= 0 )
Yr_allocation = np.array(DV_Yr_variables).reshape(len(new_Y_p))

# Indicator variable 
## delta m,t - is 1 if stand m is to be considered as forage stand in time t; 0 otherwise 
delta_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
IV_delta_variables = LpVariable.matrix("delta", delta_variable_names, cat = "Binary", lowBound= 0 )
delta_allocation = np.array(IV_delta_variables).reshape(n_stands,14+1)

## omega m,t - cover habitat
omega_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
IV_omega_variables = LpVariable.matrix("omega", omega_variable_names, cat = "Binary", lowBound= 0 )
omega_allocation = np.array(IV_omega_variables).reshape(n_stands,14+1) 

## alpha m,t - usable habitat by deer 
alpha_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
IV_alpha_variables = LpVariable.matrix("alpha", alpha_variable_names, cat = "Binary", lowBound= 0 )
alpha_allocation = np.array(IV_alpha_variables).reshape(n_stands,14+1)

alpha_min_variable_names = [str(i) for i in range (n_periods+1)]
IV_alpha_min_variables = LpVariable.matrix("alpha_min", alpha_min_variable_names, cat = "Integer", lowBound= 0 )
alpha_min_allocation = np.array(IV_alpha_min_variables).reshape(14+1)

## First m,t - assess if the parcel is harvested before PCT treatments 
### 
first_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
IV_first_variables = LpVariable.matrix("first", first_variable_names, cat = "Binary", lowBound= 0 )
first_allocation = np.array(IV_first_variables).reshape(n_stands,14+1)

# zeta variable m,t - enable to know if a parcel is PCTed and Harvested during the planning horizon
### zeta = Ym,t * Sum Xm,p for p (0,P) for all t from 0,P 
zeta_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
IV_zeta_variables = LpVariable.matrix("zeta", zeta_variable_names, cat = "Binary", lowBound= 0 )
zeta_allocation = np.array(IV_zeta_variables).reshape(n_stands,14+1)

#Function evaluation variables 
# age
age_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
IV_age_variables = LpVariable.matrix("age", age_variable_names, cat = "Integer", lowBound= 0 )
age_allocation = np.array(IV_age_variables).reshape(n_stands,14+1)

# volume (merchantable timber)
t_volume_variable_names = [str(i) + ',' + str(j) for i in N_stands for j in range (n_periods+1)]
IV_t_volume_variables = LpVariable.matrix("t_volume", t_volume_variable_names, cat = "Integer", lowBound= 0 )
t_volume_allocation = np.array(IV_t_volume_variables).reshape(n_stands,14+1)

# %%
# Constraints 

    ## Constrain 1: Forage habitat 
### delta m,p+1 = Xm,p + Ym,p + Xm,p-1 + Ym,p-1
### delta m,p+2 = Xm,p + Ym,p + Xm,p+1 + Ym,p+1
###  if p = 0 
    ### delta m,p+1 = Xm,p + Ym,p
    ### delta m,p+2 = Xm,p + Ym,p + Xm,p+1 + Ym,p+1
###  if p = n_periods - 1 
    ### delta m,p+1 = Xm,p + Ym,p + Xm,p-1 + Ym,p-1

    ## Constraint 2: One PCT and one harvest 
### SUM Xm,p <= 1 
### SUM Ym,p <= 1 with p >= 0 

    ## Constraint 3 : No action 
### SUM (Xm,p + Ym,p) + Cm >= 1 for all m 
### SUM (Xm,p) + Cm <= 1 for all m 
### SUM (Ym,p) + Cm <= 1 for all m 

    ## Constraint 4 : No harvest for n_periods after PCT treatments 
### SUM Ym,p for all p belonging to (p+1,p+n_periods+1) <= n_periods+1*(1-Xm,p)

    ## Age function 
### Age m,p = p - past_harv_period + Sum(Ym,p'*(past_harv_period-p')) for p' in range (0,p)

    ## Constraint 5: PCT conditions 
### Xm,p * min_n_periods <= Age m,p  HERE min_n_periods = 3 means 15 years
### (40-Age m,p) + (1-Xm,p)*m >= 0 
 
    ## Constraints 6: Old growth - cover type 
# Age m,p - 24*omega m,p >= 0 
######  ==> forces omega to turn 0 if too young 

### m*omega m,p + 24 >= (1- Sum Ym,p) + Age m,p 
##### ==> if age is equal to or greater than 120 years omega would be forced to turn on 

    ## Constraint 7: Habitat availability 

    
## Constraint 7: turn ancient harvest and PCT treatment on 
## Yr and Xr_allocation = 1 

## Constraint 4: Forage constraint, turn off 
### SUM delta m,p <= 2*Sum Xm,p + 2*Sum Ym,p + (1 + Zm - (Sum Xm,p + Sum Ym,p))M 
#### must add an indicator variable Z m,t = Sum Xm,p * Sum Ym,p 
    #### 2*Zm <= Sum Xm,p* Sum Ym,p 
    #### Sum Ym,p + Sum Xm,p - Zm <= 1

# %% [markdown]
# ##### Constraint 1: forage habitat

# %%
for m in range (n_stands):
    for p in range (n_periods+1):
        if p <= n_periods-1 and p>0:  
            model+=(delta_allocation[m][p+1] == X_allocation[m][p] + Y_allocation[m][p] + 
                      X_allocation[m][p-1] + Y_allocation[m][p-1]
                      , "Forhab_p1_" + str(m+1) + "_" + str(p+1))
        elif p == 0: 
            if new_Y[new_Y_m[m]]== -1: 
                index = N_stands.index(new_Y_m[m])
                model+=(delta_allocation[index][p+1] == 1
                      , "Forhab_p1_" + str(m+1) + "_" + str(p+1))
            else: 
                 model+=(delta_allocation[m][p+1] == X_allocation[m][p] + Y_allocation[m][p]
                      , "Forhab_p1_" + str(m+1) + "_" + str(p+1))

# %%
### Initialisation constraint 
for m in new_Y: 
    if new_Y[m] == -2: 
        index = N_stands.index(m)
        model+=(delta_allocation[index][0] <= 1)
    if new_Y[m] == -1: 
        index = N_stands.index(m)
        model+=(delta_allocation[index][0] <= 1)
        # not included delta_allocation[m][1] since conflicts with the first constraint 
    if m in new_X and new_X[m] == -2: 
        index = N_stands.index(m)
        model+=(delta_allocation[index][0] <= 1)
    else: 
        index = N_stands.index(m)
        model+=(delta_allocation[index][0] <= 0)

for m in range(len(N_stands)): 
    model+=(lpSum(delta_allocation[m][p] for p in range(n_periods+1)) <= 6, "tot_delta_m"+str(m))

# %% [markdown]
# ##### Constraint 2: One PCT and One Harvest during the planning horizon

# %%
## Constraint 2: One PCT and one harvest 
### SUM Xm,p <= 1 
### SUM Ym,p <= 1 with p >= 0 

for m in range(n_stands): 
    model += lpSum(X_allocation[m][p] for p in range(0,n_periods+1))<=1, "One_PCT_" + str(m+1)
    model += lpSum(Y_allocation[m][p] for p in range(0,n_periods+1))<=1, "One_harv_" + str(m+1)

# %% [markdown]
# #### Constraint 3: No action constraints

# %%
## Constraint 3: No action constraints 
for m in range(n_stands):
    model+= (lpSum(X_allocation[m][p] + Y_allocation[m][p] for p in range(n_periods+1)) + C_allocation[m] >= 1, 
                 "No_action"+ str(m)+ "_"+ str(p))
    model+= (lpSum(X_allocation[m][p] for p in range(n_periods+1)) + C_allocation[m] <= 1, 
                 "No_actionX"+ str(m)+ "_"+ str(p))
    model+= (lpSum(Y_allocation[m][p] for p in range(n_periods+1)) + C_allocation[m] <= 1, 
                 "No_actionY"+ str(m)+ "_"+ str(p))

# %% [markdown]
# ##### Constraint 4 : No harvest for 2 periods after PCT

# %%
# Constraint 4 : no harvest after 2 periods after PCT 
for m in range(n_stands): 
    for p in range(n_periods+1):
        if p < n_periods-n_harv_pct+1:
            model+=(lpSum(Y_allocation[m][t] for t in range(p+1,p+n_harv_pct+1)) <= (n_harv_pct+1)*(1-X_allocation[m][p]),
                    "harv_PCT_"+str(m)+"_"+str(p))
        elif p < n_periods and p >= n_periods-n_harv_pct+1: 
            model+=(lpSum(Y_allocation[m][t] for t in range(p+1,n_periods+1)) <= 3*(1-X_allocation[m][p]),
                   "harv_PCT_"+str(m)+"_"+str(p))

# %% [markdown]
# ##### Age function

# %%
# Function Age :
for m in range(len(N_stands)): 
    for t in range(n_periods+1): 
        model +=(age_allocation[m][t] == 
               t - new_Y_p[m] + lpSum(Y_allocation[m][p]*(new_Y_p[m]-p) for p in range(0, t)) 
                        , "age_" + str(m) + "_"+ str(t))

# %% [markdown]
# ##### Constraint 5: PCT conditions

# %%
## Constraint 5: PCT conditions 
## a) ensure that stand is over 15 to be allowed to be PCTed 
### Xm,p * 15/5 <= Age m,p 
for m in range(n_stands): 
    for t in range(n_periods + 1):
        model+=(X_allocation[m][t]*min_yr/5 <= t - new_Y[new_Y_m[m]] + 
                         lpSum(Y_allocation[m][p]*(new_Y[new_Y_m[m]]-p) for p in range(0, t)) 
                      , "PCT15_"+ str(m)+ "_"+ str(t))

# %%
## Constraint 5: PCT conditions
### b) make sure that stand is bellow 40 to be allowed to be PCTed 
### (40-Age m,p) + (1-Xm,p)*M >= 0 

for m in range(n_stands): 
    for t in range(n_periods + 1):
        model+=(0 <= (1-X_allocation[m][t])*M + max_yr/5 - 
                          (t - new_Y[new_Y_m[m]] + lpSum(Y_allocation[m][p]*(new_Y[new_Y_m[m]]-p) for p in range(0, t))) 
                     , "PCT40_"+ str(m+1)+ "_"+ str(t))

# %% [markdown]
# #### Constraint 6: Old Growth - cover type

# %%
## Constraints 6: Old growth - cover type 
## a) turn all young stage to 0 
# Age m,p - 24*omega m,p >= 0 

for m in range(n_stands): 
    for t in range(n_periods + 1):
        model += (t - new_Y[new_Y_m[m]] + lpSum(Y_allocation[m][p]*(new_Y[new_Y_m[m]]-p) for p in range(0, t)) 
                    - (omega_allocation[m][t]*min_yr_cover/5) >= 0
                     , "Cover24_"+ str(m) + "_" +str(t))

# %%
## Constraint 6: Old growth - cover type 
### b) ensure that all stands over 24 will turn 1 
### m*omega m,p + 24 >= (1- Sum Ym,p) + Age m,p 

for m in range(n_stands):
    for t in range(n_periods + 1):
        model+= (M*omega_allocation[m][t] + min_yr_cover/5 
                         >= 1-lpSum(Y_allocation[m][t]) + t - new_Y[new_Y_m[m]]
                         + lpSum(Y_allocation[m][p]*(new_Y[new_Y_m[m]]-p) for p in range(0, t)) 
                         , "Cover_on_"+str(m)+ "_" +str(t))

# %%
## Constraint 7: determining accessible habitat for deer 
##### change adjacent, by proxi cells 
for i in Buffer_dic: 
    key_list = list(Buffer_dic[i].keys())
    if key_list != []:
        for p in range(n_periods + 1):
            index = N_stands.index(i)
            index_close = []
            for keys in key_list:
                index_close.append(N_stands.index(keys))
            model+=(alpha_allocation[index][p] 
                    <= (lpSum(omega_allocation[n][p] for n in index_close)
                    + (delta_allocation[index][p]*len(index_close)))/(len(index_close)+1), 
                     "hab_av_" + str(i) + "_" + str(p))

# %%
# Volume function 
for m in range(n_stands):
    for p in range(n_periods +1):
        print(t_volume_allocation[m][p] == 
              volume[N_stands[m]][p] + lpSum(
                    (start_vol[N_stands[m]][p-k]-volume[N_stands[m]][p])*Y_allocation[m][k]
                    +(volume[N_stands[m]][p-1]-volume[N_stands[m]][p])*X_allocation[m][k]
                    +(volume[N_stands[m]][p]-volume[N_stands[m]][p-1])*zeta_allocation[m][k]
                    + start_vol[N_stands[m]][p-1]*first_allocation[m][k]
                    for k in range(0,p)), "volume_func"+str(m)+"_"+str(p))
# Out:
# t_volume_1,0 = 18 volume_func0_0
# X_1,0 + 19*Y_1,0 + t_volume_1,1 - zeta_1,0 = 19 volume_func0_1
# X_1,0 + X_1,1 + 20*Y_1,0 + 20*Y_1,1 + t_volume_1,2 - zeta_1,0 - zeta_1,1 = 20 volume_func0_2
# X_1,0 + X_1,1 + X_1,2 + 21*Y_1,0 + 21*Y_1,1 + 21*Y_1,2 + t_volume_1,3 - zeta_1,0 - zeta_1,1 - zeta_1,2 = 21 volume_func0_3
# X_1,0 + X_1,1 + X_1,2 + X_1,3 + 22*Y_1,0 + 22*Y_1,1 + 22*Y_1,2 + 22*Y_1,3 + t_volume_1,4 - zeta_1,0 - zeta_1,1 - zeta_1,2 - zeta_1,3 = 22 volume_func0_4
# 2*X_1,0 + 2*X_1,1 + 2*X_1,2 + 2*X_1,3 + 2*X_1,4 + 24*Y_1,0 + 24*Y_1,1 + 24*Y_1,2 + 24*Y_1,3 + 24*Y_1,4 + t_volume_1,5 - 2*zeta_1,0 - 2*zeta_1,1 - 2*zeta_1,2 - 2*zeta_1,3 - 2*zeta_1,4 = 24 volume_func0_5
# X_1,0 + X_1,1 + X_1,2 + X_1,3 + X_1,4 + X_1,5 + 25*Y_1,0 + 25*Y_1,1 + 25*Y_1,2 + 25*Y_1,3 + 25*Y_1,4 + 25*Y_1,5 + t_volume_1,6 - zeta_1,0 - zeta_1,1 - zeta_1,2 - zeta_1,3 - zeta_1,4 - zeta_1,5 = 25 volume_func0_6
# X_1,0 + X_1,1 + X_1,2 + X_1,3 + X_1,4 + X_1,5 + X_1,6 + 26*Y_1,0 + 26*Y_1,1 + 26*Y_1,2 + 26*Y_1,3 + 26*Y_1,4 + 26*Y_1,5 + 26*Y_1,6 + t_volume_1,7 - zeta_1,0 - zeta_1,1 - zeta_1,2 - zeta_1,3 - zeta_1,4 - zeta_1,5 - zeta_1,6 = 26 volume_func0_7
# X_1,0 + X_1,1 + X_1,2 + X_1,3 + X_1,4 + X_1,5 + X_1,6 + X_1,7 + 26*Y_1,0 + 27*Y_1,1 + 27*Y_1,2 + 27*Y_1,3 + 27*Y_1,4 + 27*Y_1,5 + 27*Y_1,6 + 27*Y_1,7 + t_volume_1,8 - zeta_1,0 - zeta_1,1 - zeta_1,2 - zeta_1,3 - zeta_1,4 - zeta_1,5 - zeta_1,6 - zeta_1,7 = 27 volume_func0_8
# X_1,0 + X_1,1 + X_1,2 + X_1,3 + X_1,4 + X_1,5 + X_1,6 + X_1,7 + X_1,8 + 26*Y_1,0 + 27*Y_1,1 + 28*Y_1,2 + 28*Y_1,3 + 28*Y_1,4 + 28*Y_1,5 + 28*Y_1,6 + 28*Y_1,7 + 28*Y_1,8 - first_1,0 - first_1,1 - first_1,2 - first_1,3 - first_1,4 - first_1,5 - first_1,6 - first_1,7 - first_1,8 + t_volume_1,9 - zeta_1,0 - zeta_1,1 - zeta_1,2 - zeta_1,3 - zeta_1,4 - zeta_1,5 - zeta_1,6 - zeta_1,7 - zeta_1,8 = 28 volume_func0_9
# X_1,0 + X_1,1 + X_1,2 + X_1,3 + X_1,4 + X_1,5 + X_1,6 + X_1,7 + X_1,8 + X_1,9 + 26*Y_1,0 + 27*Y_1,1 + 28*Y_1,2 + 29*Y_1,3 + 29*Y_1,4 + 29*Y_1,5 + 29*Y_1,6 + 29*Y_1,7 + 29*Y_1,8 + 29*Y_1,9 - 2*first_1,0 - 2*first_1,1 - 2*first_1,2 - 2*first_1,3 - 2*first_1,4 - 2*first_1,5 - 2*first_1,6 - 2*first_1,7 - 2*first_1,8 - 2*first_1,9 + t_volume_1,10 - zeta_1,0 - zeta_1,1 - zeta_1,2 - zeta_1,3 - zeta_1,4 - zeta_1,5 - zeta_1,6 - zeta_1,7 - zeta_1,8 - zeta_1,9 = 29 volume_func0_10
# 2*X_1,0 + 2*X_1,1 + 2*X_1,10 + 2*X_1,2 + 2*X_1,3 + 2*X_1,4 + 2*X_1,5 + 2*X_1,6 + 2*X_1,7 + 2*X_1,8 + 2*X_1,9 + 27*Y_1,0 + 28*Y_1,1 + 31*Y_1,10 + 29*Y_1,2 + 30*Y_1,3 + 31*Y_1,4 + 31*Y_1,5 + 31*Y_1,6 + 31*Y_1,7 + 31*Y_1,8 + 31*Y_1,9 - 3*first_1,0 - 3*first_1,1 - 3*first_1,10 - 3*first_1,2 - 3*first_1,3 - 3*first_1,4 - 3*first_1,5 - 3*first_1,6 - 3*first_1,7 - 3*first_1,8 - 3*first_1,9 + t_volume_1,11 - 2*zeta_1,0 - 2*zeta_1,1 - 2*zeta_1,10 - 2*zeta_1,2 - 2*zeta_1,3 - 2*zeta_1,4 - 2*zeta_1,5 - 2*zeta_1,6 - 2*zeta_1,7 - 2*zeta_1,8 - 2*zeta_1,9 = 31 volume_func0_11
# X_1,0 + X_1,1 + X_1,10 + X_1,11 + X_1,2 + X_1,3 + X_1,4 + X_1,5 + X_1,6 + X_1,7 + X_1,8 + X_1,9 + 28*Y_1,0 + 28*Y_1,1 + 32*Y_1,10 + 32*Y_1,11 + 29*Y_1,2 + 30*Y_1,3 + 31*Y_1,4 + 32*Y_1,5 + 32*Y_1,6 + 32*Y_1,7 + 32*Y_1,8 + 32*Y_1,9 - 4*first_1,0 - 4*first_1,1 - 4*first_1,10 - 4*first_1,11 - 4*first_1,2 - 4*first_1,3 - 4*first_1,4 - 4*first_1,5 - 4*first_1,6 - 4*first_1,7 - 4*first_1,8 - 4*first_1,9 + t_volume_1,12 - zeta_1,0 - zeta_1,1 - zeta_1,10 - zeta_1,11 - zeta_1,2 - zeta_1,3 - zeta_1,4 - zeta_1,5 - zeta_1,6 - zeta_1,7 - zeta_1,8 - zeta_1,9 = 32 volume_func0_12
# X_1,0 + X_1,1 + X_1,10 + X_1,11 + X_1,12 + X_1,2 + X_1,3 + X_1,4 + X_1,5 + X_1,6 + X_1,7 + X_1,8 + X_1,9 + 28*Y_1,0 + 29*Y_1,1 + 33*Y_1,10 + 33*Y_1,11 + 33*Y_1,12 + 29*Y_1,2 + 30*Y_1,3 + 31*Y_1,4 + 32*Y_1,5 + 33*Y_1,6 + 33*Y_1,7 + 33*Y_1,8 + 33*Y_1,9 - 4*first_1,0 - 4*first_1,1 - 4*first_1,10 - 4*first_1,11 - 4*first_1,12 - 4*first_1,2 - 4*first_1,3 - 4*first_1,4 - 4*first_1,5 - 4*first_1,6 - 4*first_1,7 - 4*first_1,8 - 4*first_1,9 + t_volume_1,13 - zeta_1,0 - zeta_1,1 - zeta_1,10 - zeta_1,11 - zeta_1,12 - zeta_1,2 - zeta_1,3 - zeta_1,4 - zeta_1,5 - zeta_1,6 - zeta_1,7 - zeta_1,8 - zeta_1,9 = 33 volume_func0_13
# X_1,0 + X_1,1 + X_1,10 + X_1,11 + X_1,12 + X_1,13 + X_1,2 + X_1,3 + X_1,4 + X_1,5 + X_1,6 + X_1,7 + X_1,8 + X_1,9 + 28*Y_1,0 + 29*Y_1,1 + 34*Y_1,10 + 34*Y_1,11 + 34*Y_1,12 + 34*Y_1,13 + 30*Y_1,2 + 30*Y_1,3 + 31*Y_1,4 + 32*Y_1,5 + 33*Y_1,6 + 34*Y_1,7 + 34*Y_1,8 + 34*Y_1,9 - 5*first_1,0 - 5*first_1,1 - 5*first_1,10 - 5*first_1,11 - 5*first_1,12 - 5*first_1,13 - 5*first_1,2 - 5*first_1,3 - 5*first_1,4 - 5*first_1,5 - 5*first_1,6 - 5*first_1,7 - 5*first_1,8 - 5*first_1,9 + t_volume_1,14 - zeta_1,0 - zeta_1,1 - zeta_1,10 - zeta_1,11 - zeta_1,12 - zeta_1,13 - zeta_1,2 - zeta_1,3 - zeta_1,4 - zeta_1,5 - zeta_1,6 - zeta_1,7 - zeta_1,8 - zeta_1,9 = 34 volume_func0_14
# t_volume_10,0 = 18 volume_func1_0
# X_10,0 + 19*Y_10,0 + t_volume_10,1 - zeta_10,0 = 19 volume_func1_1
# X_10,0 + X_10,1 + 20*Y_10,0 + 20*Y_10,1 + t_volume_10,2 - zeta_10,0 - zeta_10,1 = 20 volume_func1_2
# X_10,0 + X_10,1 + X_10,2 + 21*Y_10,0 + 21*Y_10,1 + 21*Y_10,2 + t_volume_10,3 - zeta_10,0 - zeta_10,1 - zeta_10,2 = 21 volume_func1_3
# X_10,0 + X_10,1 + X_10,2 + X_10,3 + 22*Y_10,0 + 22*Y_10,1 + 22*Y_10,2 + 22*Y_10,3 + t_volume_10,4 - zeta_10,0 - zeta_10,1 - zeta_10,2 - zeta_10,3 = 22 volume_func1_4
# 2*X_10,0 + 2*X_10,1 + 2*X_10,2 + 2*X_10,3 + 2*X_10,4 + 24*Y_10,0 + 24*Y_10,1 + 24*Y_10,2 + 24*Y_10,3 + 24*Y_10,4 + t_volume_10,5 - 2*zeta_10,0 - 2*zeta_10,1 - 2*zeta_10,2 - 2*zeta_10,3 - 2*zeta_10,4 = 24 volume_func1_5
# X_10,0 + X_10,1 + X_10,2 + X_10,3 + X_10,4 + X_10,5 + 25*Y_10,0 + 25*Y_10,1 + 25*Y_10,2 + 25*Y_10,3 + 25*Y_10,4 + 25*Y_10,5 + t_volume_10,6 - zeta_10,0 - zeta_10,1 - zeta_10,2 - zeta_10,3 - zeta_10,4 - zeta_10,5 = 25 volume_func1_6
# X_10,0 + X_10,1 + X_10,2 + X_10,3 + X_10,4 + X_10,5 + X_10,6 + 26*Y_10,0 + 26*Y_10,1 + 26*Y_10,2 + 26*Y_10,3 + 26*Y_10,4 + 26*Y_10,5 + 26*Y_10,6 + t_volume_10,7 - zeta_10,0 - zeta_10,1 - zeta_10,2 - zeta_10,3 - zeta_10,4 - zeta_10,5 - zeta_10,6 = 26 volume_func1_7
# X_10,0 + X_10,1 + X_10,2 + X_10,3 + X_10,4 + X_10,5 + X_10,6 + X_10,7 + 26*Y_10,0 + 27*Y_10,1 + 27*Y_10,2 + 27*Y_10,3 + 27*Y_10,4 + 27*Y_10,5 + 27*Y_10,6 + 27*Y_10,7 + t_volume_10,8 - zeta_10,0 - zeta_10,1 - zeta_10,2 - zeta_10,3 - zeta_10,4 - zeta_10,5 - zeta_10,6 - zeta_10,7 = 27 volume_func1_8
# X_10,0 + X_10,1 + X_10,2 + X_10,3 + X_10,4 + X_10,5 + X_10,6 + X_10,7 + X_10,8 + 26*Y_10,0 + 27*Y_10,1 + 28*Y_10,2 + 28*Y_10,3 + 28*Y_10,4 + 28*Y_10,5 + 28*Y_10,6 + 28*Y_10,7 + 28*Y_10,8 - first_10,0 - first_10,1 - first_10,2 - first_10,3 - first_10,4 - first_10,5 - first_10,6 - first_10,7 - first_10,8 + t_volume_10,9 - zeta_10,0 - zeta_10,1 - zeta_10,2 - zeta_10,3 - zeta_10,4 - zeta_10,5 - zeta_10,6 - zeta_10,7 - zeta_10,8 = 28 volume_func1_9
# X_10,0 + X_10,1 + X_10,2 + X_10,3 + X_10,4 + X_10,5 + X_10,6 + X_10,7 + X_10,8 + X_10,9 + 26*Y_10,0 + 27*Y_10,1 + 28*Y_10,2 + 29*Y_10,3 + 29*Y_10,4 + 29*Y_10,5 + 29*Y_10,6 + 29*Y_10,7 + 29*Y_10,8 + 29*Y_10,9 - 2*first_10,0 - 2*first_10,1 - 2*first_10,2 - 2*first_10,3 - 2*first_10,4 - 2*first_10,5 - 2*first_10,6 - 2*first_10,7 - 2*first_10,8 - 2*first_10,9 + t_volume_10,10 - zeta_10,0 - zeta_10,1 - zeta_10,2 - zeta_10,3 - zeta_10,4 - zeta_10,5 - zeta_10,6 - zeta_10,7 - zeta_10,8 - zeta_10,9 = 29 volume_func1_10
# 2*X_10,0 + 2*X_10,1 + 2*X_10,10 + 2*X_10,2 + 2*X_10,3 + 2*X_10,4 + 2*X_10,5 + 2*X_10,6 + 2*X_10,7 + 2*X_10,8 + 2*X_10,9 + 27*Y_10,0 + 28*Y_10,1 + 31*Y_10,10 + 29*Y_10,2 + 30*Y_10,3 + 31*Y_10,4 + 31*Y_10,5 + 31*Y_10,6 + 31*Y_10,7 + 31*Y_10,8 + 31*Y_10,9 - 3*first_10,0 - 3*first_10,1 - 3*first_10,10 - 3*first_10,2 - 3*first_10,3 - 3*first_10,4 - 3*first_10,5 - 3*first_10,6 - 3*first_10,7 - 3*first_10,8 - 3*first_10,9 + t_volume_10,11 - 2*zeta_10,0 - 2*zeta_10,1 - 2*zeta_10,10 - 2*zeta_10,2 - 2*zeta_10,3 - 2*zeta_10,4 - 2*zeta_10,5 - 2*zeta_10,6 - 2*zeta_10,7 - 2*zeta_10,8 - 2*zeta_10,9 = 31 volume_func1_11
# X_10,0 + X_10,1 + X_10,10 + X_10,11 + X_10,2 + X_10,3 + X_10,4 + X_10,5 + X_10,6 + X_10,7 + X_10,8 + X_10,9 + 28*Y_10,0 + 28*Y_10,1 + 32*Y_10,10 + 32*Y_10,11 + 29*Y_10,2 + 30*Y_10,3 + 31*Y_10,4 + 32*Y_10,5 + 32*Y_10,6 + 32*Y_10,7 + 32*Y_10,8 + 32*Y_10,9 - 4*first_10,0 - 4*first_10,1 - 4*first_10,10 - 4*first_10,11 - 4*first_10,2 - 4*first_10,3 - 4*first_10,4 - 4*first_10,5 - 4*first_10,6 - 4*first_10,7 - 4*first_10,8 - 4*first_10,9 + t_volume_10,12 - zeta_10,0 - zeta_10,1 - zeta_10,10 - zeta_10,11 - zeta_10,2 - zeta_10,3 - zeta_10,4 - zeta_10,5 - zeta_10,6 - zeta_10,7 - zeta_10,8 - zeta_10,9 = 32 volume_func1_12
# X_10,0 + X_10,1 + X_10,10 + X_10,11 + X_10,12 + X_10,2 + X_10,3 + X_10,4 + X_10,5 + X_10,6 + X_10,7 + X_10,8 + X_10,9 + 28*Y_10,0 + 29*Y_10,1 + 33*Y_10,10 + 33*Y_10,11 + 33*Y_10,12 + 29*Y_10,2 + 30*Y_10,3 + 31*Y_10,4 + 32*Y_10,5 + 33*Y_10,6 + 33*Y_10,7 + 33*Y_10,8 + 33*Y_10,9 - 4*first_10,0 - 4*first_10,1 - 4*first_10,10 - 4*first_10,11 - 4*first_10,12 - 4*first_10,2 - 4*first_10,3 - 4*first_10,4 - 4*first_10,5 - 4*first_10,6 - 4*first_10,7 - 4*first_10,8 - 4*first_10,9 + t_volume_10,13 - zeta_10,0 - zeta_10,1 - zeta_10,10 - zeta_10,11 - zeta_10,12 - zeta_10,2 - zeta_10,3 - zeta_10,4 - zeta_10,5 - zeta_10,6 - zeta_10,7 - zeta_10,8 - zeta_10,9 = 33 volume_func1_13
# X_10,0 + X_10,1 + X_10,10 + X_10,11 + X_10,12 + X_10,13 + X_10,2 + X_10,3 + X_10,4 + X_10,5 + X_10,6 + X_10,7 + X_10,8 + X_10,9 + 28*Y_10,0 + 29*Y_10,1 + 34*Y_10,10 + 34*Y_10,11 + 34*Y_10,12 + 34*Y_10,13 + 30*Y_10,2 + 30*Y_10,3 + 31*Y_10,4 + 32*Y_10,5 + 33*Y_10,6 + 34*Y_10,7 + 34*Y_10,8 + 34*Y_10,9 - 5*first_10,0 - 5*first_10,1 - 5*first_10,10 - 5*first_10,11 - 5*first_10,12 - 5*first_10,13 - 5*first_10,2 - 5*first_10,3 - 5*first_10,4 - 5*first_10,5 - 5*first_10,6 - 5*first_10,7 - 5*first_10,8 - 5*first_10,9 + t_volume_10,14 - zeta_10,0 - zeta_10,1 - zeta_10,10 - zeta_10,11 - zeta_10,12 - zeta_10,13 - zeta_10,2 - zeta_10,3 - zeta_10,4 - zeta_10,5 - zeta_10,6 - zeta_10,7 - zeta_10,8 - zeta_10,9 = 34 volume_func1_14
# t_volume_11,0 = 18 volume_func2_0
# X_11,0 + 19*Y_11,0 + t_volume_11,1 - zeta_11,0 = 19 volume_func2_1
# X_11,0 + X_11,1 + 20*Y_11,0 + 20*Y_11,1 + t_volume_11,2 - zeta_11,0 - zeta_11,1 = 20 volume_func2_2
# X_11,0 + X_11,1 + X_11,2 + 21*Y_11,0 + 21*Y_11,1 + 21*Y_11,2 + t_volume_11,3 - zeta_11,0 - zeta_11,1 - zeta_11,2 = 21 volume_func2_3
# X_11,0 + X_11,1 + X_11,2 + X_11,3 + 22*Y_11,0 + 22*Y_11,1 + 22*Y_11,2 + 22*Y_11,3 + t_volume_11,4 - zeta_11,0 - zeta_11,1 - zeta_11,2 - zeta_11,3 = 22 volume_func2_4
# 2*X_11,0 + 2*X_11,1 + 2*X_11,2 + 2*X_11,3 + 2*X_11,4 + 24*Y_11,0 + 24*Y_11,1 + 24*Y_11,2 + 24*Y_11,3 + 24*Y_11,4 + t_volume_11,5 - 2*zeta_11,0 - 2*zeta_11,1 - 2*zeta_11,2 - 2*zeta_11,3 - 2*zeta_11,4 = 24 volume_func2_5
# X_11,0 + X_11,1 + X_11,2 + X_11,3 + X_11,4 + X_11,5 + 25*Y_11,0 + 25*Y_11,1 + 25*Y_11,2 + 25*Y_11,3 + 25*Y_11,4 + 25*Y_11,5 + t_volume_11,6 - zeta_11,0 - zeta_11,1 - zeta_11,2 - zeta_11,3 - zeta_11,4 - zeta_11,5 = 25 volume_func2_6
# X_11,0 + X_11,1 + X_11,2 + X_11,3 + X_11,4 + X_11,5 + X_11,6 + 26*Y_11,0 + 26*Y_11,1 + 26*Y_11,2 + 26*Y_11,3 + 26*Y_11,4 + 26*Y_11,5 + 26*Y_11,6 + t_volume_11,7 - zeta_11,0 - zeta_11,1 - zeta_11,2 - zeta_11,3 - zeta_11,4 - zeta_11,5 - zeta_11,6 = 26 volume_func2_7
# X_11,0 + X_11,1 + X_11,2 + X_11,3 + X_11,4 + X_11,5 + X_11,6 + X_11,7 + 26*Y_11,0 + 27*Y_11,1 + 27*Y_11,2 + 27*Y_11,3 + 27*Y_11,4 + 27*Y_11,5 + 27*Y_11,6 + 27*Y_11,7 + t_volume_11,8 - zeta_11,0 - zeta_11,1 - zeta_11,2 - zeta_11,3 - zeta_11,4 - zeta_11,5 - zeta_11,6 - zeta_11,7 = 27 volume_func2_8
# X_11,0 + X_11,1 + X_11,2 + X_11,3 + X_11,4 + X_11,5 + X_11,6 + X_11,7 + X_11,8 + 26*Y_11,0 + 27*Y_11,1 + 28*Y_11,2 + 28*Y_11,3 + 28*Y_11,4 + 28*Y_11,5 + 28*Y_11,6 + 28*Y_11,7 + 28*Y_11,8 - first_11,0 - first_11,1 - first_11,2 - first_11,3 - first_11,4 - first_11,5 - first_11,6 - first_11,7 - first_11,8 + t_volume_11,9 - zeta_11,0 - zeta_11,1 - zeta_11,2 - zeta_11,3 - zeta_11,4 - zeta_11,5 - zeta_11,6 - zeta_11,7 - zeta_11,8 = 28 volume_func2_9
# X_11,0 + X_11,1 + X_11,2 + X_11,3 + X_11,4 + X_11,5 + X_11,6 + X_11,7 + X_11,8 + X_11,9 + 26*Y_11,0 + 27*Y_11,1 + 28*Y_11,2 + 29*Y_11,3 + 29*Y_11,4 + 29*Y_11,5 + 29*Y_11,6 + 29*Y_11,7 + 29*Y_11,8 + 29*Y_11,9 - 2*first_11,0 - 2*first_11,1 - 2*first_11,2 - 2*first_11,3 - 2*first_11,4 - 2*first_11,5 - 2*first_11,6 - 2*first_11,7 - 2*first_11,8 - 2*first_11,9 + t_volume_11,10 - zeta_11,0 - zeta_11,1 - zeta_11,2 - zeta_11,3 - zeta_11,4 - zeta_11,5 - zeta_11,6 - zeta_11,7 - zeta_11,8 - zeta_11,9 = 29 volume_func2_10
# 2*X_11,0 + 2*X_11,1 + 2*X_11,10 + 2*X_11,2 + 2*X_11,3 + 2*X_11,4 + 2*X_11,5 + 2*X_11,6 + 2*X_11,7 + 2*X_11,8 + 2*X_11,9 + 27*Y_11,0 + 28*Y_11,1 + 31*Y_11,10 + 29*Y_11,2 + 30*Y_11,3 + 31*Y_11,4 + 31*Y_11,5 + 31*Y_11,6 + 31*Y_11,7 + 31*Y_11,8 + 31*Y_11,9 - 3*first_11,0 - 3*first_11,1 - 3*first_11,10 - 3*first_11,2 - 3*first_11,3 - 3*first_11,4 - 3*first_11,5 - 3*first_11,6 - 3*first_11,7 - 3*first_11,8 - 3*first_11,9 + t_volume_11,11 - 2*zeta_11,0 - 2*zeta_11,1 - 2*zeta_11,10 - 2*zeta_11,2 - 2*zeta_11,3 - 2*zeta_11,4 - 2*zeta_11,5 - 2*zeta_11,6 - 2*zeta_11,7 - 2*zeta_11,8 - 2*zeta_11,9 = 31 volume_func2_11
# X_11,0 + X_11,1 + X_11,10 + X_11,11 + X_11,2 + X_11,3 + X_11,4 + X_11,5 + X_11,6 + X_11,7 + X_11,8 + X_11,9 + 28*Y_11,0 + 28*Y_11,1 + 32*Y_11,10 + 32*Y_11,11 + 29*Y_11,2 + 30*Y_11,3 + 31*Y_11,4 + 32*Y_11,5 + 32*Y_11,6 + 32*Y_11,7 + 32*Y_11,8 + 32*Y_11,9 - 4*first_11,0 - 4*first_11,1 - 4*first_11,10 - 4*first_11,11 - 4*first_11,2 - 4*first_11,3 - 4*first_11,4 - 4*first_11,5 - 4*first_11,6 - 4*first_11,7 - 4*first_11,8 - 4*first_11,9 + t_volume_11,12 - zeta_11,0 - zeta_11,1 - zeta_11,10 - zeta_11,11 - zeta_11,2 - zeta_11,3 - zeta_11,4 - zeta_11,5 - zeta_11,6 - zeta_11,7 - zeta_11,8 - zeta_11,9 = 32 volume_func2_12
# X_11,0 + X_11,1 + X_11,10 + X_11,11 + X_11,12 + X_11,2 + X_11,3 + X_11,4 + X_11,5 + X_11,6 + X_11,7 + X_11,8 + X_11,9 + 28*Y_11,0 + 29*Y_11,1 + 33*Y_11,10 + 33*Y_11,11 + 33*Y_11,12 + 29*Y_11,2 + 30*Y_11,3 + 31*Y_11,4 + 32*Y_11,5 + 33*Y_11,6 + 33*Y_11,7 + 33*Y_11,8 + 33*Y_11,9 - 4*first_11,0 - 4*first_11,1 - 4*first_11,10 - 4*first_11,11 - 4*first_11,12 - 4*first_11,2 - 4*first_11,3 - 4*first_11,4 - 4*first_11,5 - 4*first_11,6 - 4*first_11,7 - 4*first_11,8 - 4*first_11,9 + t_volume_11,13 - zeta_11,0 - zeta_11,1 - zeta_11,10 - zeta_11,11 - zeta_11,12 - zeta_11,2 - zeta_11,3 - zeta_11,4 - zeta_11,5 - zeta_11,6 - zeta_11,7 - zeta_11,8 - zeta_11,9 = 33 volume_func2_13
# X_11,0 + X_11,1 + X_11,10 + X_11,11 + X_11,12 + X_11,13 + X_11,2 + X_11,3 + X_11,4 + X_11,5 + X_11,6 + X_11,7 + X_11,8 + X_11,9 + 28*Y_11,0 + 29*Y_11,1 + 34*Y_11,10 + 34*Y_11,11 + 34*Y_11,12 + 34*Y_11,13 + 30*Y_11,2 + 30*Y_11,3 + 31*Y_11,4 + 32*Y_11,5 + 33*Y_11,6 + 34*Y_11,7 + 34*Y_11,8 + 34*Y_11,9 - 5*first_11,0 - 5*first_11,1 - 5*first_11,10 - 5*first_11,11 - 5*first_11,12 - 5*first_11,13 - 5*first_11,2 - 5*first_11,3 - 5*first_11,4 - 5*first_11,5 - 5*first_11,6 - 5*first_11,7 - 5*first_11,8 - 5*first_11,9 + t_volume_11,14 - zeta_11,0 - zeta_11,1 - zeta_11,10 - zeta_11,11 - zeta_11,12 - zeta_11,13 - zeta_11,2 - zeta_11,3 - zeta_11,4 - zeta_11,5 - zeta_11,6 - zeta_11,7 - zeta_11,8 - zeta_11,9 = 34 volume_func2_14
# t_volume_12,0 = 18 volume_func3_0
# X_12,0 + 19*Y_12,0 + t_volume_12,1 - zeta_12,0 = 19 volume_func3_1
# X_12,0 + X_12,1 + 20*Y_12,0 + 20*Y_12,1 + t_volume_12,2 - zeta_12,0 - zeta_12,1 = 20 volume_func3_2
# X_12,0 + X_12,1 + X_12,2 + 21*Y_12,0 + 21*Y_12,1 + 21*Y_12,2 + t_volume_12,3 - zeta_12,0 - zeta_12,1 - zeta_12,2 = 21 volume_func3_3
# X_12,0 + X_12,1 + X_12,2 + X_12,3 + 22*Y_12,0 + 22*Y_12,1 + 22*Y_12,2 + 22*Y_12,3 + t_volume_12,4 - zeta_12,0 - zeta_12,1 - zeta_12,2 - zeta_12,3 = 22 volume_func3_4
# 2*X_12,0 + 2*X_12,1 + 2*X_12,2 + 2*X_12,3 + 2*X_12,4 + 24*Y_12,0 + 24*Y_12,1 + 24*Y_12,2 + 24*Y_12,3 + 24*Y_12,4 + t_volume_12,5 - 2*zeta_12,0 - 2*zeta_12,1 - 2*zeta_12,2 - 2*zeta_12,3 - 2*zeta_12,4 = 24 volume_func3_5
# X_12,0 + X_12,1 + X_12,2 + X_12,3 + X_12,4 + X_12,5 + 25*Y_12,0 + 25*Y_12,1 + 25*Y_12,2 + 25*Y_12,3 + 25*Y_12,4 + 25*Y_12,5 + t_volume_12,6 - zeta_12,0 - zeta_12,1 - zeta_12,2 - zeta_12,3 - zeta_12,4 - zeta_12,5 = 25 volume_func3_6
# X_12,0 + X_12,1 + X_12,2 + X_12,3 + X_12,4 + X_12,5 + X_12,6 + 26*Y_12,0 + 26*Y_12,1 + 26*Y_12,2 + 26*Y_12,3 + 26*Y_12,4 + 26*Y_12,5 + 26*Y_12,6 + t_volume_12,7 - zeta_12,0 - zeta_12,1 - zeta_12,2 - zeta_12,3 - zeta_12,4 - zeta_12,5 - zeta_12,6 = 26 volume_func3_7
# X_12,0 + X_12,1 + X_12,2 + X_12,3 + X_12,4 + X_12,5 + X_12,6 + X_12,7 + 26*Y_12,0 + 27*Y_12,1 + 27*Y_12,2 + 27*Y_12,3 + 27*Y_12,4 + 27*Y_12,5 + 27*Y_12,6 + 27*Y_12,7 + t_volume_12,8 - zeta_12,0 - zeta_12,1 - zeta_12,2 - zeta_12,3 - zeta_12,4 - zeta_12,5 - zeta_12,6 - zeta_12,7 = 27 volume_func3_8
# X_12,0 + X_12,1 + X_12,2 + X_12,3 + X_12,4 + X_12,5 + X_12,6 + X_12,7 + X_12,8 + 26*Y_12,0 + 27*Y_12,1 + 28*Y_12,2 + 28*Y_12,3 + 28*Y_12,4 + 28*Y_12,5 + 28*Y_12,6 + 28*Y_12,7 + 28*Y_12,8 - first_12,0 - first_12,1 - first_12,2 - first_12,3 - first_12,4 - first_12,5 - first_12,6 - first_12,7 - first_12,8 + t_volume_12,9 - zeta_12,0 - zeta_12,1 - zeta_12,2 - zeta_12,3 - zeta_12,4 - zeta_12,5 - zeta_12,6 - zeta_12,7 - zeta_12,8 = 28 volume_func3_9
# X_12,0 + X_12,1 + X_12,2 + X_12,3 + X_12,4 + X_12,5 + X_12,6 + X_12,7 + X_12,8 + X_12,9 + 26*Y_12,0 + 27*Y_12,1 + 28*Y_12,2 + 29*Y_12,3 + 29*Y_12,4 + 29*Y_12,5 + 29*Y_12,6 + 29*Y_12,7 + 29*Y_12,8 + 29*Y_12,9 - 2*first_12,0 - 2*first_12,1 - 2*first_12,2 - 2*first_12,3 - 2*first_12,4 - 2*first_12,5 - 2*first_12,6 - 2*first_12,7 - 2*first_12,8 - 2*first_12,9 + t_volume_12,10 - zeta_12,0 - zeta_12,1 - zeta_12,2 - zeta_12,3 - zeta_12,4 - zeta_12,5 - zeta_12,6 - zeta_12,7 - zeta_12,8 - zeta_12,9 = 29 volume_func3_10
# 2*X_12,0 + 2*X_12,1 + 2*X_12,10 + 2*X_12,2 + 2*X_12,3 + 2*X_12,4 + 2*X_12,5 + 2*X_12,6 + 2*X_12,7 + 2*X_12,8 + 2*X_12,9 + 27*Y_12,0 + 28*Y_12,1 + 31*Y_12,10 + 29*Y_12,2 + 30*Y_12,3 + 31*Y_12,4 + 31*Y_12,5 + 31*Y_12,6 + 31*Y_12,7 + 31*Y_12,8 + 31*Y_12,9 - 3*first_12,0 - 3*first_12,1 - 3*first_12,10 - 3*first_12,2 - 3*first_12,3 - 3*first_12,4 - 3*first_12,5 - 3*first_12,6 - 3*first_12,7 - 3*first_12,8 - 3*first_12,9 + t_volume_12,11 - 2*zeta_12,0 - 2*zeta_12,1 - 2*zeta_12,10 - 2*zeta_12,2 - 2*zeta_12,3 - 2*zeta_12,4 - 2*zeta_12,5 - 2*zeta_12,6 - 2*zeta_12,7 - 2*zeta_12,8 - 2*zeta_12,9 = 31 volume_func3_11
# X_12,0 + X_12,1 + X_12,10 + X_12,11 + X_12,2 + X_12,3 + X_12,4 + X_12,5 + X_12,6 + X_12,7 + X_12,8 + X_12,9 + 28*Y_12,0 + 28*Y_12,1 + 32*Y_12,10 + 32*Y_12,11 + 29*Y_12,2 + 30*Y_12,3 + 31*Y_12,4 + 32*Y_12,5 + 32*Y_12,6 + 32*Y_12,7 + 32*Y_12,8 + 32*Y_12,9 - 4*first_12,0 - 4*first_12,1 - 4*first_12,10 - 4*first_12,11 - 4*first_12,2 - 4*first_12,3 - 4*first_12,4 - 4*first_12,5 - 4*first_12,6 - 4*first_12,7 - 4*first_12,8 - 4*first_12,9 + t_volume_12,12 - zeta_12,0 - zeta_12,1 - zeta_12,10 - zeta_12,11 - zeta_12,2 - zeta_12,3 - zeta_12,4 - zeta_12,5 - zeta_12,6 - zeta_12,7 - zeta_12,8 - zeta_12,9 = 32 volume_func3_12
# X_12,0 + X_12,1 + X_12,10 + X_12,11 + X_12,12 + X_12,2 + X_12,3 + X_12,4 + X_12,5 + X_12,6 + X_12,7 + X_12,8 + X_12,9 + 28*Y_12,0 + 29*Y_12,1 + 33*Y_12,10 + 33*Y_12,11 + 33*Y_12,12 + 29*Y_12,2 + 30*Y_12,3 + 31*Y_12,4 + 32*Y_12,5 + 33*Y_12,6 + 33*Y_12,7 + 33*Y_12,8 + 33*Y_12,9 - 4*first_12,0 - 4*first_12,1 - 4*first_12,10 - 4*first_12,11 - 4*first_12,12 - 4*first_12,2 - 4*first_12,3 - 4*first_12,4 - 4*first_12,5 - 4*first_12,6 - 4*first_12,7 - 4*first_12,8 - 4*first_12,9 + t_volume_12,13 - zeta_12,0 - zeta_12,1 - zeta_12,10 - zeta_12,11 - zeta_12,12 - zeta_12,2 - zeta_12,3 - zeta_12,4 - zeta_12,5 - zeta_12,6 - zeta_12,7 - zeta_12,8 - zeta_12,9 = 33 volume_func3_13
# X_12,0 + X_12,1 + X_12,10 + X_12,11 + X_12,12 + X_12,13 + X_12,2 + X_12,3 + X_12,4 + X_12,5 + X_12,6 + X_12,7 + X_12,8 + X_12,9 + 28*Y_12,0 + 29*Y_12,1 + 34*Y_12,10 + 34*Y_12,11 + 34*Y_12,12 + 34*Y_12,13 + 30*Y_12,2 + 30*Y_12,3 + 31*Y_12,4 + 32*Y_12,5 + 33*Y_12,6 + 34*Y_12,7 + 34*Y_12,8 + 34*Y_12,9 - 5*first_12,0 - 5*first_12,1 - 5*first_12,10 - 5*first_12,11 - 5*first_12,12 - 5*first_12,13 - 5*first_12,2 - 5*first_12,3 - 5*first_12,4 - 5*first_12,5 - 5*first_12,6 - 5*first_12,7 - 5*first_12,8 - 5*first_12,9 + t_volume_12,14 - zeta_12,0 - zeta_12,1 - zeta_12,10 - zeta_12,11 - zeta_12,12 - zeta_12,13 - zeta_12,2 - zeta_12,3 - zeta_12,4 - zeta_12,5 - zeta_12,6 - zeta_12,7 - zeta_12,8 - zeta_12,9 = 34 volume_func3_14
# t_volume_13,0 = 18 volume_func4_0
# X_13,0 + 19*Y_13,0 + t_volume_13,1 - zeta_13,0 = 19 volume_func4_1
# X_13,0 + X_13,1 + 20*Y_13,0 + 20*Y_13,1 + t_volume_13,2 - zeta_13,0 - zeta_13,1 = 20 volume_func4_2
# X_13,0 + X_13,1 + X_13,2 + 21*Y_13,0 + 21*Y_13,1 + 21*Y_13,2 + t_volume_13,3 - zeta_13,0 - zeta_13,1 - zeta_13,2 = 21 volume_func4_3
# X_13,0 + X_13,1 + X_13,2 + X_13,3 + 22*Y_13,0 + 22*Y_13,1 + 22*Y_13,2 + 22*Y_13,3 + t_volume_13,4 - zeta_13,0 - zeta_13,1 - zeta_13,2 - zeta_13,3 = 22 volume_func4_4
# 2*X_13,0 + 2*X_13,1 + 2*X_13,2 + 2*X_13,3 + 2*X_13,4 + 24*Y_13,0 + 24*Y_13,1 + 24*Y_13,2 + 24*Y_13,3 + 24*Y_13,4 + t_volume_13,5 - 2*zeta_13,0 - 2*zeta_13,1 - 2*zeta_13,2 - 2*zeta_13,3 - 2*zeta_13,4 = 24 volume_func4_5
# X_13,0 + X_13,1 + X_13,2 + X_13,3 + X_13,4 + X_13,5 + 25*Y_13,0 + 25*Y_13,1 + 25*Y_13,2 + 25*Y_13,3 + 25*Y_13,4 + 25*Y_13,5 + t_volume_13,6 - zeta_13,0 - zeta_13,1 - zeta_13,2 - zeta_13,3 - zeta_13,4 - zeta_13,5 = 25 volume_func4_6
# X_13,0 + X_13,1 + X_13,2 + X_13,3 + X_13,4 + X_13,5 + X_13,6 + 26*Y_13,0 + 26*Y_13,1 + 26*Y_13,2 + 26*Y_13,3 + 26*Y_13,4 + 26*Y_13,5 + 26*Y_13,6 + t_volume_13,7 - zeta_13,0 - zeta_13,1 - zeta_13,2 - zeta_13,3 - zeta_13,4 - zeta_13,5 - zeta_13,6 = 26 volume_func4_7
# X_13,0 + X_13,1 + X_13,2 + X_13,3 + X_13,4 + X_13,5 + X_13,6 + X_13,7 + 26*Y_13,0 + 27*Y_13,1 + 27*Y_13,2 + 27*Y_13,3 + 27*Y_13,4 + 27*Y_13,5 + 27*Y_13,6 + 27*Y_13,7 + t_volume_13,8 - zeta_13,0 - zeta_13,1 - zeta_13,2 - zeta_13,3 - zeta_13,4 - zeta_13,5 - zeta_13,6 - zeta_13,7 = 27 volume_func4_8
# X_13,0 + X_13,1 + X_13,2 + X_13,3 + X_13,4 + X_13,5 + X_13,6 + X_13,7 + X_13,8 + 26*Y_13,0 + 27*Y_13,1 + 28*Y_13,2 + 28*Y_13,3 + 28*Y_13,4 + 28*Y_13,5 + 28*Y_13,6 + 28*Y_13,7 + 28*Y_13,8 - first_13,0 - first_13,1 - first_13,2 - first_13,3 - first_13,4 - first_13,5 - first_13,6 - first_13,7 - first_13,8 + t_volume_13,9 - zeta_13,0 - zeta_13,1 - zeta_13,2 - zeta_13,3 - zeta_13,4 - zeta_13,5 - zeta_13,6 - zeta_13,7 - zeta_13,8 = 28 volume_func4_9
# X_13,0 + X_13,1 + X_13,2 + X_13,3 + X_13,4 + X_13,5 + X_13,6 + X_13,7 + X_13,8 + X_13,9 + 26*Y_13,0 + 27*Y_13,1 + 28*Y_13,2 + 29*Y_13,3 + 29*Y_13,4 + 29*Y_13,5 + 29*Y_13,6 + 29*Y_13,7 + 29*Y_13,8 + 29*Y_13,9 - 2*first_13,0 - 2*first_13,1 - 2*first_13,2 - 2*first_13,3 - 2*first_13,4 - 2*first_13,5 - 2*first_13,6 - 2*first_13,7 - 2*first_13,8 - 2*first_13,9 + t_volume_13,10 - zeta_13,0 - zeta_13,1 - zeta_13,2 - zeta_13,3 - zeta_13,4 - zeta_13,5 - zeta_13,6 - zeta_13,7 - zeta_13,8 - zeta_13,9 = 29 volume_func4_10
# 2*X_13,0 + 2*X_13,1 + 2*X_13,10 + 2*X_13,2 + 2*X_13,3 + 2*X_13,4 + 2*X_13,5 + 2*X_13,6 + 2*X_13,7 + 2*X_13,8 + 2*X_13,9 + 27*Y_13,0 + 28*Y_13,1 + 31*Y_13,10 + 29*Y_13,2 + 30*Y_13,3 + 31*Y_13,4 + 31*Y_13,5 + 31*Y_13,6 + 31*Y_13,7 + 31*Y_13,8 + 31*Y_13,9 - 3*first_13,0 - 3*first_13,1 - 3*first_13,10 - 3*first_13,2 - 3*first_13,3 - 3*first_13,4 - 3*first_13,5 - 3*first_13,6 - 3*first_13,7 - 3*first_13,8 - 3*first_13,9 + t_volume_13,11 - 2*zeta_13,0 - 2*zeta_13,1 - 2*zeta_13,10 - 2*zeta_13,2 - 2*zeta_13,3 - 2*zeta_13,4 - 2*zeta_13,5 - 2*zeta_13,6 - 2*zeta_13,7 - 2*zeta_13,8 - 2*zeta_13,9 = 31 volume_func4_11
# X_13,0 + X_13,1 + X_13,10 + X_13,11 + X_13,2 + X_13,3 + X_13,4 + X_13,5 + X_13,6 + X_13,7 + X_13,8 + X_13,9 + 28*Y_13,0 + 28*Y_13,1 + 32*Y_13,10 + 32*Y_13,11 + 29*Y_13,2 + 30*Y_13,3 + 31*Y_13,4 + 32*Y_13,5 + 32*Y_13,6 + 32*Y_13,7 + 32*Y_13,8 + 32*Y_13,9 - 4*first_13,0 - 4*first_13,1 - 4*first_13,10 - 4*first_13,11 - 4*first_13,2 - 4*first_13,3 - 4*first_13,4 - 4*first_13,5 - 4*first_13,6 - 4*first_13,7 - 4*first_13,8 - 4*first_13,9 + t_volume_13,12 - zeta_13,0 - zeta_13,1 - zeta_13,10 - zeta_13,11 - zeta_13,2 - zeta_13,3 - zeta_13,4 - zeta_13,5 - zeta_13,6 - zeta_13,7 - zeta_13,8 - zeta_13,9 = 32 volume_func4_12
# X_13,0 + X_13,1 + X_13,10 + X_13,11 + X_13,12 + X_13,2 + X_13,3 + X_13,4 + X_13,5 + X_13,6 + X_13,7 + X_13,8 + X_13,9 + 28*Y_13,0 + 29*Y_13,1 + 33*Y_13,10 + 33*Y_13,11 + 33*Y_13,12 + 29*Y_13,2 + 30*Y_13,3 + 31*Y_13,4 + 32*Y_13,5 + 33*Y_13,6 + 33*Y_13,7 + 33*Y_13,8 + 33*Y_13,9 - 4*first_13,0 - 4*first_13,1 - 4*first_13,10 - 4*first_13,11 - 4*first_13,12 - 4*first_13,2 - 4*first_13,3 - 4*first_13,4 - 4*first_13,5 - 4*first_13,6 - 4*first_13,7 - 4*first_13,8 - 4*first_13,9 + t_volume_13,13 - zeta_13,0 - zeta_13,1 - zeta_13,10 - zeta_13,11 - zeta_13,12 - zeta_13,2 - zeta_13,3 - zeta_13,4 - zeta_13,5 - zeta_13,6 - zeta_13,7 - zeta_13,8 - zeta_13,9 = 33 volume_func4_13
# X_13,0 + X_13,1 + X_13,10 + X_13,11 + X_13,12 + X_13,13 + X_13,2 + X_13,3 + X_13,4 + X_13,5 + X_13,6 + X_13,7 + X_13,8 + X_13,9 + 28*Y_13,0 + 29*Y_13,1 + 34*Y_13,10 + 34*Y_13,11 + 34*Y_13,12 + 34*Y_13,13 + 30*Y_13,2 + 30*Y_13,3 + 31*Y_13,4 + 32*Y_13,5 + 33*Y_13,6 + 34*Y_13,7 + 34*Y_13,8 + 34*Y_13,9 - 5*first_13,0 - 5*first_13,1 - 5*first_13,10 - 5*first_13,11 - 5*first_13,12 - 5*first_13,13 - 5*first_13,2 - 5*first_13,3 - 5*first_13,4 - 5*first_13,5 - 5*first_13,6 - 5*first_13,7 - 5*first_13,8 - 5*first_13,9 + t_volume_13,14 - zeta_13,0 - zeta_13,1 - zeta_13,10 - zeta_13,11 - zeta_13,12 - zeta_13,13 - zeta_13,2 - zeta_13,3 - zeta_13,4 - zeta_13,5 - zeta_13,6 - zeta_13,7 - zeta_13,8 - zeta_13,9 = 34 volume_func4_14
# t_volume_14,0 = 18 volume_func5_0
# X_14,0 + 19*Y_14,0 + t_volume_14,1 - zeta_14,0 = 19 volume_func5_1
# X_14,0 + X_14,1 + 20*Y_14,0 + 20*Y_14,1 + t_volume_14,2 - zeta_14,0 - zeta_14,1 = 20 volume_func5_2
# X_14,0 + X_14,1 + X_14,2 + 21*Y_14,0 + 21*Y_14,1 + 21*Y_14,2 + t_volume_14,3 - zeta_14,0 - zeta_14,1 - zeta_14,2 = 21 volume_func5_3
# X_14,0 + X_14,1 + X_14,2 + X_14,3 + 22*Y_14,0 + 22*Y_14,1 + 22*Y_14,2 + 22*Y_14,3 + t_volume_14,4 - zeta_14,0 - zeta_14,1 - zeta_14,2 - zeta_14,3 = 22 volume_func5_4
# 2*X_14,0 + 2*X_14,1 + 2*X_14,2 + 2*X_14,3 + 2*X_14,4 + 24*Y_14,0 + 24*Y_14,1 + 24*Y_14,2 + 24*Y_14,3 + 24*Y_14,4 + t_volume_14,5 - 2*zeta_14,0 - 2*zeta_14,1 - 2*zeta_14,2 - 2*zeta_14,3 - 2*zeta_14,4 = 24 volume_func5_5
# X_14,0 + X_14,1 + X_14,2 + X_14,3 + X_14,4 + X_14,5 + 25*Y_14,0 + 25*Y_14,1 + 25*Y_14,2 + 25*Y_14,3 + 25*Y_14,4 + 25*Y_14,5 + t_volume_14,6 - zeta_14,0 - zeta_14,1 - zeta_14,2 - zeta_14,3 - zeta_14,4 - zeta_14,5 = 25 volume_func5_6
# X_14,0 + X_14,1 + X_14,2 + X_14,3 + X_14,4 + X_14,5 + X_14,6 + 26*Y_14,0 + 26*Y_14,1 + 26*Y_14,2 + 26*Y_14,3 + 26*Y_14,4 + 26*Y_14,5 + 26*Y_14,6 + t_volume_14,7 - zeta_14,0 - zeta_14,1 - zeta_14,2 - zeta_14,3 - zeta_14,4 - zeta_14,5 - zeta_14,6 = 26 volume_func5_7
# X_14,0 + X_14,1 + X_14,2 + X_14,3 + X_14,4 + X_14,5 + X_14,6 + X_14,7 + 26*Y_14,0 + 27*Y_14,1 + 27*Y_14,2 + 27*Y_14,3 + 27*Y_14,4 + 27*Y_14,5 + 27*Y_14,6 + 27*Y_14,7 + t_volume_14,8 - zeta_14,0 - zeta_14,1 - zeta_14,2 - zeta_14,3 - zeta_14,4 - zeta_14,5 - zeta_14,6 - zeta_14,7 = 27 volume_func5_8
# X_14,0 + X_14,1 + X_14,2 + X_14,3 + X_14,4 + X_14,5 + X_14,6 + X_14,7 + X_14,8 + 26*Y_14,0 + 27*Y_14,1 + 28*Y_14,2 + 28*Y_14,3 + 28*Y_14,4 + 28*Y_14,5 + 28*Y_14,6 + 28*Y_14,7 + 28*Y_14,8 - first_14,0 - first_14,1 - first_14,2 - first_14,3 - first_14,4 - first_14,5 - first_14,6 - first_14,7 - first_14,8 + t_volume_14,9 - zeta_14,0 - zeta_14,1 - zeta_14,2 - zeta_14,3 - zeta_14,4 - zeta_14,5 - zeta_14,6 - zeta_14,7 - zeta_14,8 = 28 volume_func5_9
# X_14,0 + X_14,1 + X_14,2 + X_14,3 + X_14,4 + X_14,5 + X_14,6 + X_14,7 + X_14,8 + X_14,9 + 26*Y_14,0 + 27*Y_14,1 + 28*Y_14,2 + 29*Y_14,3 + 29*Y_14,4 + 29*Y_14,5 + 29*Y_14,6 + 29*Y_14,7 + 29*Y_14,8 + 29*Y_14,9 - 2*first_14,0 - 2*first_14,1 - 2*first_14,2 - 2*first_14,3 - 2*first_14,4 - 2*first_14,5 - 2*first_14,6 - 2*first_14,7 - 2*first_14,8 - 2*first_14,9 + t_volume_14,10 - zeta_14,0 - zeta_14,1 - zeta_14,2 - zeta_14,3 - zeta_14,4 - zeta_14,5 - zeta_14,6 - zeta_14,7 - zeta_14,8 - zeta_14,9 = 29 volume_func5_10
# 2*X_14,0 + 2*X_14,1 + 2*X_14,10 + 2*X_14,2 + 2*X_14,3 + 2*X_14,4 + 2*X_14,5 + 2*X_14,6 + 2*X_14,7 + 2*X_14,8 + 2*X_14,9 + 27*Y_14,0 + 28*Y_14,1 + 31*Y_14,10 + 29*Y_14,2 + 30*Y_14,3 + 31*Y_14,4 + 31*Y_14,5 + 31*Y_14,6 + 31*Y_14,7 + 31*Y_14,8 + 31*Y_14,9 - 3*first_14,0 - 3*first_14,1 - 3*first_14,10 - 3*first_14,2 - 3*first_14,3 - 3*first_14,4 - 3*first_14,5 - 3*first_14,6 - 3*first_14,7 - 3*first_14,8 - 3*first_14,9 + t_volume_14,11 - 2*zeta_14,0 - 2*zeta_14,1 - 2*zeta_14,10 - 2*zeta_14,2 - 2*zeta_14,3 - 2*zeta_14,4 - 2*zeta_14,5 - 2*zeta_14,6 - 2*zeta_14,7 - 2*zeta_14,8 - 2*zeta_14,9 = 31 volume_func5_11
# X_14,0 + X_14,1 + X_14,10 + X_14,11 + X_14,2 + X_14,3 + X_14,4 + X_14,5 + X_14,6 + X_14,7 + X_14,8 + X_14,9 + 28*Y_14,0 + 28*Y_14,1 + 32*Y_14,10 + 32*Y_14,11 + 29*Y_14,2 + 30*Y_14,3 + 31*Y_14,4 + 32*Y_14,5 + 32*Y_14,6 + 32*Y_14,7 + 32*Y_14,8 + 32*Y_14,9 - 4*first_14,0 - 4*first_14,1 - 4*first_14,10 - 4*first_14,11 - 4*first_14,2 - 4*first_14,3 - 4*first_14,4 - 4*first_14,5 - 4*first_14,6 - 4*first_14,7 - 4*first_14,8 - 4*first_14,9 + t_volume_14,12 - zeta_14,0 - zeta_14,1 - zeta_14,10 - zeta_14,11 - zeta_14,2 - zeta_14,3 - zeta_14,4 - zeta_14,5 - zeta_14,6 - zeta_14,7 - zeta_14,8 - zeta_14,9 = 32 volume_func5_12
# X_14,0 + X_14,1 + X_14,10 + X_14,11 + X_14,12 + X_14,2 + X_14,3 + X_14,4 + X_14,5 + X_14,6 + X_14,7 + X_14,8 + X_14,9 + 28*Y_14,0 + 29*Y_14,1 + 33*Y_14,10 + 33*Y_14,11 + 33*Y_14,12 + 29*Y_14,2 + 30*Y_14,3 + 31*Y_14,4 + 32*Y_14,5 + 33*Y_14,6 + 33*Y_14,7 + 33*Y_14,8 + 33*Y_14,9 - 4*first_14,0 - 4*first_14,1 - 4*first_14,10 - 4*first_14,11 - 4*first_14,12 - 4*first_14,2 - 4*first_14,3 - 4*first_14,4 - 4*first_14,5 - 4*first_14,6 - 4*first_14,7 - 4*first_14,8 - 4*first_14,9 + t_volume_14,13 - zeta_14,0 - zeta_14,1 - zeta_14,10 - zeta_14,11 - zeta_14,12 - zeta_14,2 - zeta_14,3 - zeta_14,4 - zeta_14,5 - zeta_14,6 - zeta_14,7 - zeta_14,8 - zeta_14,9 = 33 volume_func5_13
# X_14,0 + X_14,1 + X_14,10 + X_14,11 + X_14,12 + X_14,13 + X_14,2 + X_14,3 + X_14,4 + X_14,5 + X_14,6 + X_14,7 + X_14,8 + X_14,9 + 28*Y_14,0 + 29*Y_14,1 + 34*Y_14,10 + 34*Y_14,11 + 34*Y_14,12 + 34*Y_14,13 + 30*Y_14,2 + 30*Y_14,3 + 31*Y_14,4 + 32*Y_14,5 + 33*Y_14,6 + 34*Y_14,7 + 34*Y_14,8 + 34*Y_14,9 - 5*first_14,0 - 5*first_14,1 - 5*first_14,10 - 5*first_14,11 - 5*first_14,12 - 5*first_14,13 - 5*first_14,2 - 5*first_14,3 - 5*first_14,4 - 5*first_14,5 - 5*first_14,6 - 5*first_14,7 - 5*first_14,8 - 5*first_14,9 + t_volume_14,14 - zeta_14,0 - zeta_14,1 - zeta_14,10 - zeta_14,11 - zeta_14,12 - zeta_14,13 - zeta_14,2 - zeta_14,3 - zeta_14,4 - zeta_14,5 - zeta_14,6 - zeta_14,7 - zeta_14,8 - zeta_14,9 = 34 volume_func5_14
# t_volume_15,0 = 18 volume_func6_0
# X_15,0 + 19*Y_15,0 + t_volume_15,1 - zeta_15,0 = 19 volume_func6_1
# X_15,0 + X_15,1 + 20*Y_15,0 + 20*Y_15,1 + t_volume_15,2 - zeta_15,0 - zeta_15,1 = 20 volume_func6_2
# X_15,0 + X_15,1 + X_15,2 + 21*Y_15,0 + 21*Y_15,1 + 21*Y_15,2 + t_volume_15,3 - zeta_15,0 - zeta_15,1 - zeta_15,2 = 21 volume_func6_3
# X_15,0 + X_15,1 + X_15,2 + X_15,3 + 22*Y_15,0 + 22*Y_15,1 + 22*Y_15,2 + 22*Y_15,3 + t_volume_15,4 - zeta_15,0 - zeta_15,1 - zeta_15,2 - zeta_15,3 = 22 volume_func6_4
# 2*X_15,0 + 2*X_15,1 + 2*X_15,2 + 2*X_15,3 + 2*X_15,4 + 24*Y_15,0 + 24*Y_15,1 + 24*Y_15,2 + 24*Y_15,3 + 24*Y_15,4 + t_volume_15,5 - 2*zeta_15,0 - 2*zeta_15,1 - 2*zeta_15,2 - 2*zeta_15,3 - 2*zeta_15,4 = 24 volume_func6_5
# X_15,0 + X_15,1 + X_15,2 + X_15,3 + X_15,4 + X_15,5 + 25*Y_15,0 + 25*Y_15,1 + 25*Y_15,2 + 25*Y_15,3 + 25*Y_15,4 + 25*Y_15,5 + t_volume_15,6 - zeta_15,0 - zeta_15,1 - zeta_15,2 - zeta_15,3 - zeta_15,4 - zeta_15,5 = 25 volume_func6_6
# X_15,0 + X_15,1 + X_15,2 + X_15,3 + X_15,4 + X_15,5 + X_15,6 + 26*Y_15,0 + 26*Y_15,1 + 26*Y_15,2 + 26*Y_15,3 + 26*Y_15,4 + 26*Y_15,5 + 26*Y_15,6 + t_volume_15,7 - zeta_15,0 - zeta_15,1 - zeta_15,2 - zeta_15,3 - zeta_15,4 - zeta_15,5 - zeta_15,6 = 26 volume_func6_7
# X_15,0 + X_15,1 + X_15,2 + X_15,3 + X_15,4 + X_15,5 + X_15,6 + X_15,7 + 26*Y_15,0 + 27*Y_15,1 + 27*Y_15,2 + 27*Y_15,3 + 27*Y_15,4 + 27*Y_15,5 + 27*Y_15,6 + 27*Y_15,7 + t_volume_15,8 - zeta_15,0 - zeta_15,1 - zeta_15,2 - zeta_15,3 - zeta_15,4 - zeta_15,5 - zeta_15,6 - zeta_15,7 = 27 volume_func6_8
# X_15,0 + X_15,1 + X_15,2 + X_15,3 + X_15,4 + X_15,5 + X_15,6 + X_15,7 + X_15,8 + 26*Y_15,0 + 27*Y_15,1 + 28*Y_15,2 + 28*Y_15,3 + 28*Y_15,4 + 28*Y_15,5 + 28*Y_15,6 + 28*Y_15,7 + 28*Y_15,8 - first_15,0 - first_15,1 - first_15,2 - first_15,3 - first_15,4 - first_15,5 - first_15,6 - first_15,7 - first_15,8 + t_volume_15,9 - zeta_15,0 - zeta_15,1 - zeta_15,2 - zeta_15,3 - zeta_15,4 - zeta_15,5 - zeta_15,6 - zeta_15,7 - zeta_15,8 = 28 volume_func6_9
# X_15,0 + X_15,1 + X_15,2 + X_15,3 + X_15,4 + X_15,5 + X_15,6 + X_15,7 + X_15,8 + X_15,9 + 26*Y_15,0 + 27*Y_15,1 + 28*Y_15,2 + 29*Y_15,3 + 29*Y_15,4 + 29*Y_15,5 + 29*Y_15,6 + 29*Y_15,7 + 29*Y_15,8 + 29*Y_15,9 - 2*first_15,0 - 2*first_15,1 - 2*first_15,2 - 2*first_15,3 - 2*first_15,4 - 2*first_15,5 - 2*first_15,6 - 2*first_15,7 - 2*first_15,8 - 2*first_15,9 + t_volume_15,10 - zeta_15,0 - zeta_15,1 - zeta_15,2 - zeta_15,3 - zeta_15,4 - zeta_15,5 - zeta_15,6 - zeta_15,7 - zeta_15,8 - zeta_15,9 = 29 volume_func6_10
# 2*X_15,0 + 2*X_15,1 + 2*X_15,10 + 2*X_15,2 + 2*X_15,3 + 2*X_15,4 + 2*X_15,5 + 2*X_15,6 + 2*X_15,7 + 2*X_15,8 + 2*X_15,9 + 27*Y_15,0 + 28*Y_15,1 + 31*Y_15,10 + 29*Y_15,2 + 30*Y_15,3 + 31*Y_15,4 + 31*Y_15,5 + 31*Y_15,6 + 31*Y_15,7 + 31*Y_15,8 + 31*Y_15,9 - 3*first_15,0 - 3*first_15,1 - 3*first_15,10 - 3*first_15,2 - 3*first_15,3 - 3*first_15,4 - 3*first_15,5 - 3*first_15,6 - 3*first_15,7 - 3*first_15,8 - 3*first_15,9 + t_volume_15,11 - 2*zeta_15,0 - 2*zeta_15,1 - 2*zeta_15,10 - 2*zeta_15,2 - 2*zeta_15,3 - 2*zeta_15,4 - 2*zeta_15,5 - 2*zeta_15,6 - 2*zeta_15,7 - 2*zeta_15,8 - 2*zeta_15,9 = 31 volume_func6_11
# X_15,0 + X_15,1 + X_15,10 + X_15,11 + X_15,2 + X_15,3 + X_15,4 + X_15,5 + X_15,6 + X_15,7 + X_15,8 + X_15,9 + 28*Y_15,0 + 28*Y_15,1 + 32*Y_15,10 + 32*Y_15,11 + 29*Y_15,2 + 30*Y_15,3 + 31*Y_15,4 + 32*Y_15,5 + 32*Y_15,6 + 32*Y_15,7 + 32*Y_15,8 + 32*Y_15,9 - 4*first_15,0 - 4*first_15,1 - 4*first_15,10 - 4*first_15,11 - 4*first_15,2 - 4*first_15,3 - 4*first_15,4 - 4*first_15,5 - 4*first_15,6 - 4*first_15,7 - 4*first_15,8 - 4*first_15,9 + t_volume_15,12 - zeta_15,0 - zeta_15,1 - zeta_15,10 - zeta_15,11 - zeta_15,2 - zeta_15,3 - zeta_15,4 - zeta_15,5 - zeta_15,6 - zeta_15,7 - zeta_15,8 - zeta_15,9 = 32 volume_func6_12
# X_15,0 + X_15,1 + X_15,10 + X_15,11 + X_15,12 + X_15,2 + X_15,3 + X_15,4 + X_15,5 + X_15,6 + X_15,7 + X_15,8 + X_15,9 + 28*Y_15,0 + 29*Y_15,1 + 33*Y_15,10 + 33*Y_15,11 + 33*Y_15,12 + 29*Y_15,2 + 30*Y_15,3 + 31*Y_15,4 + 32*Y_15,5 + 33*Y_15,6 + 33*Y_15,7 + 33*Y_15,8 + 33*Y_15,9 - 4*first_15,0 - 4*first_15,1 - 4*first_15,10 - 4*first_15,11 - 4*first_15,12 - 4*first_15,2 - 4*first_15,3 - 4*first_15,4 - 4*first_15,5 - 4*first_15,6 - 4*first_15,7 - 4*first_15,8 - 4*first_15,9 + t_volume_15,13 - zeta_15,0 - zeta_15,1 - zeta_15,10 - zeta_15,11 - zeta_15,12 - zeta_15,2 - zeta_15,3 - zeta_15,4 - zeta_15,5 - zeta_15,6 - zeta_15,7 - zeta_15,8 - zeta_15,9 = 33 volume_func6_13
# X_15,0 + X_15,1 + X_15,10 + X_15,11 + X_15,12 + X_15,13 + X_15,2 + X_15,3 + X_15,4 + X_15,5 + X_15,6 + X_15,7 + X_15,8 + X_15,9 + 28*Y_15,0 + 29*Y_15,1 + 34*Y_15,10 + 34*Y_15,11 + 34*Y_15,12 + 34*Y_15,13 + 30*Y_15,2 + 30*Y_15,3 + 31*Y_15,4 + 32*Y_15,5 + 33*Y_15,6 + 34*Y_15,7 + 34*Y_15,8 + 34*Y_15,9 - 5*first_15,0 - 5*first_15,1 - 5*first_15,10 - 5*first_15,11 - 5*first_15,12 - 5*first_15,13 - 5*first_15,2 - 5*first_15,3 - 5*first_15,4 - 5*first_15,5 - 5*first_15,6 - 5*first_15,7 - 5*first_15,8 - 5*first_15,9 + t_volume_15,14 - zeta_15,0 - zeta_15,1 - zeta_15,10 - zeta_15,11 - zeta_15,12 - zeta_15,13 - zeta_15,2 - zeta_15,3 - zeta_15,4 - zeta_15,5 - zeta_15,6 - zeta_15,7 - zeta_15,8 - zeta_15,9 = 34 volume_func6_14
# t_volume_16,0 = 18 volume_func7_0
# X_16,0 + 19*Y_16,0 + t_volume_16,1 - zeta_16,0 = 19 volume_func7_1
# X_16,0 + X_16,1 + 20*Y_16,0 + 20*Y_16,1 + t_volume_16,2 - zeta_16,0 - zeta_16,1 = 20 volume_func7_2
# X_16,0 + X_16,1 + X_16,2 + 21*Y_16,0 + 21*Y_16,1 + 21*Y_16,2 + t_volume_16,3 - zeta_16,0 - zeta_16,1 - zeta_16,2 = 21 volume_func7_3
# X_16,0 + X_16,1 + X_16,2 + X_16,3 + 22*Y_16,0 + 22*Y_16,1 + 22*Y_16,2 + 22*Y_16,3 + t_volume_16,4 - zeta_16,0 - zeta_16,1 - zeta_16,2 - zeta_16,3 = 22 volume_func7_4
# 2*X_16,0 + 2*X_16,1 + 2*X_16,2 + 2*X_16,3 + 2*X_16,4 + 24*Y_16,0 + 24*Y_16,1 + 24*Y_16,2 + 24*Y_16,3 + 24*Y_16,4 + t_volume_16,5 - 2*zeta_16,0 - 2*zeta_16,1 - 2*zeta_16,2 - 2*zeta_16,3 - 2*zeta_16,4 = 24 volume_func7_5
# X_16,0 + X_16,1 + X_16,2 + X_16,3 + X_16,4 + X_16,5 + 25*Y_16,0 + 25*Y_16,1 + 25*Y_16,2 + 25*Y_16,3 + 25*Y_16,4 + 25*Y_16,5 + t_volume_16,6 - zeta_16,0 - zeta_16,1 - zeta_16,2 - zeta_16,3 - zeta_16,4 - zeta_16,5 = 25 volume_func7_6
# X_16,0 + X_16,1 + X_16,2 + X_16,3 + X_16,4 + X_16,5 + X_16,6 + 26*Y_16,0 + 26*Y_16,1 + 26*Y_16,2 + 26*Y_16,3 + 26*Y_16,4 + 26*Y_16,5 + 26*Y_16,6 + t_volume_16,7 - zeta_16,0 - zeta_16,1 - zeta_16,2 - zeta_16,3 - zeta_16,4 - zeta_16,5 - zeta_16,6 = 26 volume_func7_7
# X_16,0 + X_16,1 + X_16,2 + X_16,3 + X_16,4 + X_16,5 + X_16,6 + X_16,7 + 26*Y_16,0 + 27*Y_16,1 + 27*Y_16,2 + 27*Y_16,3 + 27*Y_16,4 + 27*Y_16,5 + 27*Y_16,6 + 27*Y_16,7 + t_volume_16,8 - zeta_16,0 - zeta_16,1 - zeta_16,2 - zeta_16,3 - zeta_16,4 - zeta_16,5 - zeta_16,6 - zeta_16,7 = 27 volume_func7_8
# X_16,0 + X_16,1 + X_16,2 + X_16,3 + X_16,4 + X_16,5 + X_16,6 + X_16,7 + X_16,8 + 26*Y_16,0 + 27*Y_16,1 + 28*Y_16,2 + 28*Y_16,3 + 28*Y_16,4 + 28*Y_16,5 + 28*Y_16,6 + 28*Y_16,7 + 28*Y_16,8 - first_16,0 - first_16,1 - first_16,2 - first_16,3 - first_16,4 - first_16,5 - first_16,6 - first_16,7 - first_16,8 + t_volume_16,9 - zeta_16,0 - zeta_16,1 - zeta_16,2 - zeta_16,3 - zeta_16,4 - zeta_16,5 - zeta_16,6 - zeta_16,7 - zeta_16,8 = 28 volume_func7_9
# X_16,0 + X_16,1 + X_16,2 + X_16,3 + X_16,4 + X_16,5 + X_16,6 + X_16,7 + X_16,8 + X_16,9 + 26*Y_16,0 + 27*Y_16,1 + 28*Y_16,2 + 29*Y_16,3 + 29*Y_16,4 + 29*Y_16,5 + 29*Y_16,6 + 29*Y_16,7 + 29*Y_16,8 + 29*Y_16,9 - 2*first_16,0 - 2*first_16,1 - 2*first_16,2 - 2*first_16,3 - 2*first_16,4 - 2*first_16,5 - 2*first_16,6 - 2*first_16,7 - 2*first_16,8 - 2*first_16,9 + t_volume_16,10 - zeta_16,0 - zeta_16,1 - zeta_16,2 - zeta_16,3 - zeta_16,4 - zeta_16,5 - zeta_16,6 - zeta_16,7 - zeta_16,8 - zeta_16,9 = 29 volume_func7_10
# 2*X_16,0 + 2*X_16,1 + 2*X_16,10 + 2*X_16,2 + 2*X_16,3 + 2*X_16,4 + 2*X_16,5 + 2*X_16,6 + 2*X_16,7 + 2*X_16,8 + 2*X_16,9 + 27*Y_16,0 + 28*Y_16,1 + 31*Y_16,10 + 29*Y_16,2 + 30*Y_16,3 + 31*Y_16,4 + 31*Y_16,5 + 31*Y_16,6 + 31*Y_16,7 + 31*Y_16,8 + 31*Y_16,9 - 3*first_16,0 - 3*first_16,1 - 3*first_16,10 - 3*first_16,2 - 3*first_16,3 - 3*first_16,4 - 3*first_16,5 - 3*first_16,6 - 3*first_16,7 - 3*first_16,8 - 3*first_16,9 + t_volume_16,11 - 2*zeta_16,0 - 2*zeta_16,1 - 2*zeta_16,10 - 2*zeta_16,2 - 2*zeta_16,3 - 2*zeta_16,4 - 2*zeta_16,5 - 2*zeta_16,6 - 2*zeta_16,7 - 2*zeta_16,8 - 2*zeta_16,9 = 31 volume_func7_11
# X_16,0 + X_16,1 + X_16,10 + X_16,11 + X_16,2 + X_16,3 + X_16,4 + X_16,5 + X_16,6 + X_16,7 + X_16,8 + X_16,9 + 28*Y_16,0 + 28*Y_16,1 + 32*Y_16,10 + 32*Y_16,11 + 29*Y_16,2 + 30*Y_16,3 + 31*Y_16,4 + 32*Y_16,5 + 32*Y_16,6 + 32*Y_16,7 + 32*Y_16,8 + 32*Y_16,9 - 4*first_16,0 - 4*first_16,1 - 4*first_16,10 - 4*first_16,11 - 4*first_16,2 - 4*first_16,3 - 4*first_16,4 - 4*first_16,5 - 4*first_16,6 - 4*first_16,7 - 4*first_16,8 - 4*first_16,9 + t_volume_16,12 - zeta_16,0 - zeta_16,1 - zeta_16,10 - zeta_16,11 - zeta_16,2 - zeta_16,3 - zeta_16,4 - zeta_16,5 - zeta_16,6 - zeta_16,7 - zeta_16,8 - zeta_16,9 = 32 volume_func7_12
# X_16,0 + X_16,1 + X_16,10 + X_16,11 + X_16,12 + X_16,2 + X_16,3 + X_16,4 + X_16,5 + X_16,6 + X_16,7 + X_16,8 + X_16,9 + 28*Y_16,0 + 29*Y_16,1 + 33*Y_16,10 + 33*Y_16,11 + 33*Y_16,12 + 29*Y_16,2 + 30*Y_16,3 + 31*Y_16,4 + 32*Y_16,5 + 33*Y_16,6 + 33*Y_16,7 + 33*Y_16,8 + 33*Y_16,9 - 4*first_16,0 - 4*first_16,1 - 4*first_16,10 - 4*first_16,11 - 4*first_16,12 - 4*first_16,2 - 4*first_16,3 - 4*first_16,4 - 4*first_16,5 - 4*first_16,6 - 4*first_16,7 - 4*first_16,8 - 4*first_16,9 + t_volume_16,13 - zeta_16,0 - zeta_16,1 - zeta_16,10 - zeta_16,11 - zeta_16,12 - zeta_16,2 - zeta_16,3 - zeta_16,4 - zeta_16,5 - zeta_16,6 - zeta_16,7 - zeta_16,8 - zeta_16,9 = 33 volume_func7_13
# X_16,0 + X_16,1 + X_16,10 + X_16,11 + X_16,12 + X_16,13 + X_16,2 + X_16,3 + X_16,4 + X_16,5 + X_16,6 + X_16,7 + X_16,8 + X_16,9 + 28*Y_16,0 + 29*Y_16,1 + 34*Y_16,10 + 34*Y_16,11 + 34*Y_16,12 + 34*Y_16,13 + 30*Y_16,2 + 30*Y_16,3 + 31*Y_16,4 + 32*Y_16,5 + 33*Y_16,6 + 34*Y_16,7 + 34*Y_16,8 + 34*Y_16,9 - 5*first_16,0 - 5*first_16,1 - 5*first_16,10 - 5*first_16,11 - 5*first_16,12 - 5*first_16,13 - 5*first_16,2 - 5*first_16,3 - 5*first_16,4 - 5*first_16,5 - 5*first_16,6 - 5*first_16,7 - 5*first_16,8 - 5*first_16,9 + t_volume_16,14 - zeta_16,0 - zeta_16,1 - zeta_16,10 - zeta_16,11 - zeta_16,12 - zeta_16,13 - zeta_16,2 - zeta_16,3 - zeta_16,4 - zeta_16,5 - zeta_16,6 - zeta_16,7 - zeta_16,8 - zeta_16,9 = 34 volume_func7_14
# t_volume_17,0 = 18 volume_func8_0
# X_17,0 + 19*Y_17,0 + t_volume_17,1 - zeta_17,0 = 19 volume_func8_1
# X_17,0 + X_17,1 + 20*Y_17,0 + 20*Y_17,1 + t_volume_17,2 - zeta_17,0 - zeta_17,1 = 20 volume_func8_2
# X_17,0 + X_17,1 + X_17,2 + 21*Y_17,0 + 21*Y_17,1 + 21*Y_17,2 + t_volume_17,3 - zeta_17,0 - zeta_17,1 - zeta_17,2 = 21 volume_func8_3
# X_17,0 + X_17,1 + X_17,2 + X_17,3 + 22*Y_17,0 + 22*Y_17,1 + 22*Y_17,2 + 22*Y_17,3 + t_volume_17,4 - zeta_17,0 - zeta_17,1 - zeta_17,2 - zeta_17,3 = 22 volume_func8_4
# 2*X_17,0 + 2*X_17,1 + 2*X_17,2 + 2*X_17,3 + 2*X_17,4 + 24*Y_17,0 + 24*Y_17,1 + 24*Y_17,2 + 24*Y_17,3 + 24*Y_17,4 + t_volume_17,5 - 2*zeta_17,0 - 2*zeta_17,1 - 2*zeta_17,2 - 2*zeta_17,3 - 2*zeta_17,4 = 24 volume_func8_5
# X_17,0 + X_17,1 + X_17,2 + X_17,3 + X_17,4 + X_17,5 + 25*Y_17,0 + 25*Y_17,1 + 25*Y_17,2 + 25*Y_17,3 + 25*Y_17,4 + 25*Y_17,5 + t_volume_17,6 - zeta_17,0 - zeta_17,1 - zeta_17,2 - zeta_17,3 - zeta_17,4 - zeta_17,5 = 25 volume_func8_6
# X_17,0 + X_17,1 + X_17,2 + X_17,3 + X_17,4 + X_17,5 + X_17,6 + 26*Y_17,0 + 26*Y_17,1 + 26*Y_17,2 + 26*Y_17,3 + 26*Y_17,4 + 26*Y_17,5 + 26*Y_17,6 + t_volume_17,7 - zeta_17,0 - zeta_17,1 - zeta_17,2 - zeta_17,3 - zeta_17,4 - zeta_17,5 - zeta_17,6 = 26 volume_func8_7
# X_17,0 + X_17,1 + X_17,2 + X_17,3 + X_17,4 + X_17,5 + X_17,6 + X_17,7 + 26*Y_17,0 + 27*Y_17,1 + 27*Y_17,2 + 27*Y_17,3 + 27*Y_17,4 + 27*Y_17,5 + 27*Y_17,6 + 27*Y_17,7 + t_volume_17,8 - zeta_17,0 - zeta_17,1 - zeta_17,2 - zeta_17,3 - zeta_17,4 - zeta_17,5 - zeta_17,6 - zeta_17,7 = 27 volume_func8_8
# X_17,0 + X_17,1 + X_17,2 + X_17,3 + X_17,4 + X_17,5 + X_17,6 + X_17,7 + X_17,8 + 26*Y_17,0 + 27*Y_17,1 + 28*Y_17,2 + 28*Y_17,3 + 28*Y_17,4 + 28*Y_17,5 + 28*Y_17,6 + 28*Y_17,7 + 28*Y_17,8 - first_17,0 - first_17,1 - first_17,2 - first_17,3 - first_17,4 - first_17,5 - first_17,6 - first_17,7 - first_17,8 + t_volume_17,9 - zeta_17,0 - zeta_17,1 - zeta_17,2 - zeta_17,3 - zeta_17,4 - zeta_17,5 - zeta_17,6 - zeta_17,7 - zeta_17,8 = 28 volume_func8_9
# X_17,0 + X_17,1 + X_17,2 + X_17,3 + X_17,4 + X_17,5 + X_17,6 + X_17,7 + X_17,8 + X_17,9 + 26*Y_17,0 + 27*Y_17,1 + 28*Y_17,2 + 29*Y_17,3 + 29*Y_17,4 + 29*Y_17,5 + 29*Y_17,6 + 29*Y_17,7 + 29*Y_17,8 + 29*Y_17,9 - 2*first_17,0 - 2*first_17,1 - 2*first_17,2 - 2*first_17,3 - 2*first_17,4 - 2*first_17,5 - 2*first_17,6 - 2*first_17,7 - 2*first_17,8 - 2*first_17,9 + t_volume_17,10 - zeta_17,0 - zeta_17,1 - zeta_17,2 - zeta_17,3 - zeta_17,4 - zeta_17,5 - zeta_17,6 - zeta_17,7 - zeta_17,8 - zeta_17,9 = 29 volume_func8_10
# 2*X_17,0 + 2*X_17,1 + 2*X_17,10 + 2*X_17,2 + 2*X_17,3 + 2*X_17,4 + 2*X_17,5 + 2*X_17,6 + 2*X_17,7 + 2*X_17,8 + 2*X_17,9 + 27*Y_17,0 + 28*Y_17,1 + 31*Y_17,10 + 29*Y_17,2 + 30*Y_17,3 + 31*Y_17,4 + 31*Y_17,5 + 31*Y_17,6 + 31*Y_17,7 + 31*Y_17,8 + 31*Y_17,9 - 3*first_17,0 - 3*first_17,1 - 3*first_17,10 - 3*first_17,2 - 3*first_17,3 - 3*first_17,4 - 3*first_17,5 - 3*first_17,6 - 3*first_17,7 - 3*first_17,8 - 3*first_17,9 + t_volume_17,11 - 2*zeta_17,0 - 2*zeta_17,1 - 2*zeta_17,10 - 2*zeta_17,2 - 2*zeta_17,3 - 2*zeta_17,4 - 2*zeta_17,5 - 2*zeta_17,6 - 2*zeta_17,7 - 2*zeta_17,8 - 2*zeta_17,9 = 31 volume_func8_11
# X_17,0 + X_17,1 + X_17,10 + X_17,11 + X_17,2 + X_17,3 + X_17,4 + X_17,5 + X_17,6 + X_17,7 + X_17,8 + X_17,9 + 28*Y_17,0 + 28*Y_17,1 + 32*Y_17,10 + 32*Y_17,11 + 29*Y_17,2 + 30*Y_17,3 + 31*Y_17,4 + 32*Y_17,5 + 32*Y_17,6 + 32*Y_17,7 + 32*Y_17,8 + 32*Y_17,9 - 4*first_17,0 - 4*first_17,1 - 4*first_17,10 - 4*first_17,11 - 4*first_17,2 - 4*first_17,3 - 4*first_17,4 - 4*first_17,5 - 4*first_17,6 - 4*first_17,7 - 4*first_17,8 - 4*first_17,9 + t_volume_17,12 - zeta_17,0 - zeta_17,1 - zeta_17,10 - zeta_17,11 - zeta_17,2 - zeta_17,3 - zeta_17,4 - zeta_17,5 - zeta_17,6 - zeta_17,7 - zeta_17,8 - zeta_17,9 = 32 volume_func8_12
# X_17,0 + X_17,1 + X_17,10 + X_17,11 + X_17,12 + X_17,2 + X_17,3 + X_17,4 + X_17,5 + X_17,6 + X_17,7 + X_17,8 + X_17,9 + 28*Y_17,0 + 29*Y_17,1 + 33*Y_17,10 + 33*Y_17,11 + 33*Y_17,12 + 29*Y_17,2 + 30*Y_17,3 + 31*Y_17,4 + 32*Y_17,5 + 33*Y_17,6 + 33*Y_17,7 + 33*Y_17,8 + 33*Y_17,9 - 4*first_17,0 - 4*first_17,1 - 4*first_17,10 - 4*first_17,11 - 4*first_17,12 - 4*first_17,2 - 4*first_17,3 - 4*first_17,4 - 4*first_17,5 - 4*first_17,6 - 4*first_17,7 - 4*first_17,8 - 4*first_17,9 + t_volume_17,13 - zeta_17,0 - zeta_17,1 - zeta_17,10 - zeta_17,11 - zeta_17,12 - zeta_17,2 - zeta_17,3 - zeta_17,4 - zeta_17,5 - zeta_17,6 - zeta_17,7 - zeta_17,8 - zeta_17,9 = 33 volume_func8_13
# X_17,0 + X_17,1 + X_17,10 + X_17,11 + X_17,12 + X_17,13 + X_17,2 + X_17,3 + X_17,4 + X_17,5 + X_17,6 + X_17,7 + X_17,8 + X_17,9 + 28*Y_17,0 + 29*Y_17,1 + 34*Y_17,10 + 34*Y_17,11 + 34*Y_17,12 + 34*Y_17,13 + 30*Y_17,2 + 30*Y_17,3 + 31*Y_17,4 + 32*Y_17,5 + 33*Y_17,6 + 34*Y_17,7 + 34*Y_17,8 + 34*Y_17,9 - 5*first_17,0 - 5*first_17,1 - 5*first_17,10 - 5*first_17,11 - 5*first_17,12 - 5*first_17,13 - 5*first_17,2 - 5*first_17,3 - 5*first_17,4 - 5*first_17,5 - 5*first_17,6 - 5*first_17,7 - 5*first_17,8 - 5*first_17,9 + t_volume_17,14 - zeta_17,0 - zeta_17,1 - zeta_17,10 - zeta_17,11 - zeta_17,12 - zeta_17,13 - zeta_17,2 - zeta_17,3 - zeta_17,4 - zeta_17,5 - zeta_17,6 - zeta_17,7 - zeta_17,8 - zeta_17,9 = 34 volume_func8_14
# t_volume_18,0 = 18 volume_func9_0
# X_18,0 + 19*Y_18,0 + t_volume_18,1 - zeta_18,0 = 19 volume_func9_1
# X_18,0 + X_18,1 + 20*Y_18,0 + 20*Y_18,1 + t_volume_18,2 - zeta_18,0 - zeta_18,1 = 20 volume_func9_2
# X_18,0 + X_18,1 + X_18,2 + 21*Y_18,0 + 21*Y_18,1 + 21*Y_18,2 + t_volume_18,3 - zeta_18,0 - zeta_18,1 - zeta_18,2 = 21 volume_func9_3
# X_18,0 + X_18,1 + X_18,2 + X_18,3 + 22*Y_18,0 + 22*Y_18,1 + 22*Y_18,2 + 22*Y_18,3 + t_volume_18,4 - zeta_18,0 - zeta_18,1 - zeta_18,2 - zeta_18,3 = 22 volume_func9_4
# 2*X_18,0 + 2*X_18,1 + 2*X_18,2 + 2*X_18,3 + 2*X_18,4 + 24*Y_18,0 + 24*Y_18,1 + 24*Y_18,2 + 24*Y_18,3 + 24*Y_18,4 + t_volume_18,5 - 2*zeta_18,0 - 2*zeta_18,1 - 2*zeta_18,2 - 2*zeta_18,3 - 2*zeta_18,4 = 24 volume_func9_5
# X_18,0 + X_18,1 + X_18,2 + X_18,3 + X_18,4 + X_18,5 + 25*Y_18,0 + 25*Y_18,1 + 25*Y_18,2 + 25*Y_18,3 + 25*Y_18,4 + 25*Y_18,5 + t_volume_18,6 - zeta_18,0 - zeta_18,1 - zeta_18,2 - zeta_18,3 - zeta_18,4 - zeta_18,5 = 25 volume_func9_6
# X_18,0 + X_18,1 + X_18,2 + X_18,3 + X_18,4 + X_18,5 + X_18,6 + 26*Y_18,0 + 26*Y_18,1 + 26*Y_18,2 + 26*Y_18,3 + 26*Y_18,4 + 26*Y_18,5 + 26*Y_18,6 + t_volume_18,7 - zeta_18,0 - zeta_18,1 - zeta_18,2 - zeta_18,3 - zeta_18,4 - zeta_18,5 - zeta_18,6 = 26 volume_func9_7
# X_18,0 + X_18,1 + X_18,2 + X_18,3 + X_18,4 + X_18,5 + X_18,6 + X_18,7 + 26*Y_18,0 + 27*Y_18,1 + 27*Y_18,2 + 27*Y_18,3 + 27*Y_18,4 + 27*Y_18,5 + 27*Y_18,6 + 27*Y_18,7 + t_volume_18,8 - zeta_18,0 - zeta_18,1 - zeta_18,2 - zeta_18,3 - zeta_18,4 - zeta_18,5 - zeta_18,6 - zeta_18,7 = 27 volume_func9_8
# X_18,0 + X_18,1 + X_18,2 + X_18,3 + X_18,4 + X_18,5 + X_18,6 + X_18,7 + X_18,8 + 26*Y_18,0 + 27*Y_18,1 + 28*Y_18,2 + 28*Y_18,3 + 28*Y_18,4 + 28*Y_18,5 + 28*Y_18,6 + 28*Y_18,7 + 28*Y_18,8 - first_18,0 - first_18,1 - first_18,2 - first_18,3 - first_18,4 - first_18,5 - first_18,6 - first_18,7 - first_18,8 + t_volume_18,9 - zeta_18,0 - zeta_18,1 - zeta_18,2 - zeta_18,3 - zeta_18,4 - zeta_18,5 - zeta_18,6 - zeta_18,7 - zeta_18,8 = 28 volume_func9_9
# ...
# X_893,0 + X_893,1 + X_893,10 + X_893,11 + X_893,12 + X_893,13 + X_893,2 + X_893,3 + X_893,4 + X_893,5 + X_893,6 + X_893,7 + X_893,8 + X_893,9 + 13*Y_893,0 + 14*Y_893,1 + 23*Y_893,10 + 23*Y_893,11 + 23*Y_893,12 + 23*Y_893,13 + 16*Y_893,2 + 17*Y_893,3 + 18*Y_893,4 + 20*Y_893,5 + 21*Y_893,6 + 22*Y_893,7 + 23*Y_893,8 + 23*Y_893,9 - 9*first_893,0 - 9*first_893,1 - 9*first_893,10 - 9*first_893,11 - 9*first_893,12 - 9*first_893,13 - 9*first_893,2 - 9*first_893,3 - 9*first_893,4 - 9*first_893,5 - 9*first_893,6 - 9*first_893,7 - 9*first_893,8 - 9*first_893,9 + t_volume_893,14 - zeta_893,0 - zeta_893,1 - zeta_893,10 - zeta_893,11 - zeta_893,12 - zeta_893,13 - zeta_893,2 - zeta_893,3 - zeta_893,4 - zeta_893,5 - zeta_893,6 - zeta_893,7 - zeta_893,8 - zeta_893,9 = 23 volume_func123_14
# t_volume_9,0 = 26 volume_func124_0
# 2*X_9,0 + 28*Y_9,0 + t_volume_9,1 - 2*zeta_9,0 = 28 volume_func124_1
# X_9,0 + X_9,1 + 29*Y_9,0 + 29*Y_9,1 + t_volume_9,2 - zeta_9,0 - zeta_9,1 = 29 volume_func124_2
# 2*X_9,0 + 2*X_9,1 + 2*X_9,2 + 31*Y_9,0 + 31*Y_9,1 + 31*Y_9,2 + t_volume_9,3 - 2*zeta_9,0 - 2*zeta_9,1 - 2*zeta_9,2 = 31 volume_func124_3
# 2*X_9,0 + 2*X_9,1 + 2*X_9,2 + 2*X_9,3 + 33*Y_9,0 + 33*Y_9,1 + 33*Y_9,2 + 33*Y_9,3 + t_volume_9,4 - 2*zeta_9,0 - 2*zeta_9,1 - 2*zeta_9,2 - 2*zeta_9,3 = 33 volume_func124_4
# X_9,0 + X_9,1 + X_9,2 + X_9,3 + X_9,4 + 34*Y_9,0 + 34*Y_9,1 + 34*Y_9,2 + 34*Y_9,3 + 34*Y_9,4 + t_volume_9,5 - zeta_9,0 - zeta_9,1 - zeta_9,2 - zeta_9,3 - zeta_9,4 = 34 volume_func124_5
# 2*X_9,0 + 2*X_9,1 + 2*X_9,2 + 2*X_9,3 + 2*X_9,4 + 2*X_9,5 + 36*Y_9,0 + 36*Y_9,1 + 36*Y_9,2 + 36*Y_9,3 + 36*Y_9,4 + 36*Y_9,5 + t_volume_9,6 - 2*zeta_9,0 - 2*zeta_9,1 - 2*zeta_9,2 - 2*zeta_9,3 - 2*zeta_9,4 - 2*zeta_9,5 = 36 volume_func124_6
# X_9,0 + X_9,1 + X_9,2 + X_9,3 + X_9,4 + X_9,5 + X_9,6 + 36*Y_9,0 + 37*Y_9,1 + 37*Y_9,2 + 37*Y_9,3 + 37*Y_9,4 + 37*Y_9,5 + 37*Y_9,6 + t_volume_9,7 - zeta_9,0 - zeta_9,1 - zeta_9,2 - zeta_9,3 - zeta_9,4 - zeta_9,5 - zeta_9,6 = 37 volume_func124_7
# 2*X_9,0 + 2*X_9,1 + 2*X_9,2 + 2*X_9,3 + 2*X_9,4 + 2*X_9,5 + 2*X_9,6 + 2*X_9,7 + 37*Y_9,0 + 38*Y_9,1 + 39*Y_9,2 + 39*Y_9,3 + 39*Y_9,4 + 39*Y_9,5 + 39*Y_9,6 + 39*Y_9,7 - first_9,0 - first_9,1 - first_9,2 - first_9,3 - first_9,4 - first_9,5 - first_9,6 - first_9,7 + t_volume_9,8 - 2*zeta_9,0 - 2*zeta_9,1 - 2*zeta_9,2 - 2*zeta_9,3 - 2*zeta_9,4 - 2*zeta_9,5 - 2*zeta_9,6 - 2*zeta_9,7 = 39 volume_func124_8
# 2*X_9,0 + 2*X_9,1 + 2*X_9,2 + 2*X_9,3 + 2*X_9,4 + 2*X_9,5 + 2*X_9,6 + 2*X_9,7 + 2*X_9,8 + 38*Y_9,0 + 39*Y_9,1 + 40*Y_9,2 + 41*Y_9,3 + 41*Y_9,4 + 41*Y_9,5 + 41*Y_9,6 + 41*Y_9,7 + 41*Y_9,8 - 2*first_9,0 - 2*first_9,1 - 2*first_9,2 - 2*first_9,3 - 2*first_9,4 - 2*first_9,5 - 2*first_9,6 - 2*first_9,7 - 2*first_9,8 + t_volume_9,9 - 2*zeta_9,0 - 2*zeta_9,1 - 2*zeta_9,2 - 2*zeta_9,3 - 2*zeta_9,4 - 2*zeta_9,5 - 2*zeta_9,6 - 2*zeta_9,7 - 2*zeta_9,8 = 41 volume_func124_9
# X_9,0 + X_9,1 + X_9,2 + X_9,3 + X_9,4 + X_9,5 + X_9,6 + X_9,7 + X_9,8 + X_9,9 + 37*Y_9,0 + 39*Y_9,1 + 40*Y_9,2 + 41*Y_9,3 + 42*Y_9,4 + 42*Y_9,5 + 42*Y_9,6 + 42*Y_9,7 + 42*Y_9,8 + 42*Y_9,9 - 3*first_9,0 - 3*first_9,1 - 3*first_9,2 - 3*first_9,3 - 3*first_9,4 - 3*first_9,5 - 3*first_9,6 - 3*first_9,7 - 3*first_9,8 - 3*first_9,9 + t_volume_9,10 - zeta_9,0 - zeta_9,1 - zeta_9,2 - zeta_9,3 - zeta_9,4 - zeta_9,5 - zeta_9,6 - zeta_9,7 - zeta_9,8 - zeta_9,9 = 42 volume_func124_10
# 2*X_9,0 + 2*X_9,1 + 2*X_9,10 + 2*X_9,2 + 2*X_9,3 + 2*X_9,4 + 2*X_9,5 + 2*X_9,6 + 2*X_9,7 + 2*X_9,8 + 2*X_9,9 + 38*Y_9,0 + 39*Y_9,1 + 44*Y_9,10 + 41*Y_9,2 + 42*Y_9,3 + 43*Y_9,4 + 44*Y_9,5 + 44*Y_9,6 + 44*Y_9,7 + 44*Y_9,8 + 44*Y_9,9 - 5*first_9,0 - 5*first_9,1 - 5*first_9,10 - 5*first_9,2 - 5*first_9,3 - 5*first_9,4 - 5*first_9,5 - 5*first_9,6 - 5*first_9,7 - 5*first_9,8 - 5*first_9,9 + t_volume_9,11 - 2*zeta_9,0 - 2*zeta_9,1 - 2*zeta_9,10 - 2*zeta_9,2 - 2*zeta_9,3 - 2*zeta_9,4 - 2*zeta_9,5 - 2*zeta_9,6 - 2*zeta_9,7 - 2*zeta_9,8 - 2*zeta_9,9 = 44 volume_func124_11
# X_9,0 + X_9,1 + X_9,10 + X_9,11 + X_9,2 + X_9,3 + X_9,4 + X_9,5 + X_9,6 + X_9,7 + X_9,8 + X_9,9 + 38*Y_9,0 + 39*Y_9,1 + 45*Y_9,10 + 45*Y_9,11 + 40*Y_9,2 + 42*Y_9,3 + 43*Y_9,4 + 44*Y_9,5 + 45*Y_9,6 + 45*Y_9,7 + 45*Y_9,8 + 45*Y_9,9 - 6*first_9,0 - 6*first_9,1 - 6*first_9,10 - 6*first_9,11 - 6*first_9,2 - 6*first_9,3 - 6*first_9,4 - 6*first_9,5 - 6*first_9,6 - 6*first_9,7 - 6*first_9,8 - 6*first_9,9 + t_volume_9,12 - zeta_9,0 - zeta_9,1 - zeta_9,10 - zeta_9,11 - zeta_9,2 - zeta_9,3 - zeta_9,4 - zeta_9,5 - zeta_9,6 - zeta_9,7 - zeta_9,8 - zeta_9,9 = 45 volume_func124_12
# 2*X_9,0 + 2*X_9,1 + 2*X_9,10 + 2*X_9,11 + 2*X_9,12 + 2*X_9,2 + 2*X_9,3 + 2*X_9,4 + 2*X_9,5 + 2*X_9,6 + 2*X_9,7 + 2*X_9,8 + 2*X_9,9 + 38*Y_9,0 + 40*Y_9,1 + 47*Y_9,10 + 47*Y_9,11 + 47*Y_9,12 + 41*Y_9,2 + 42*Y_9,3 + 44*Y_9,4 + 45*Y_9,5 + 46*Y_9,6 + 47*Y_9,7 + 47*Y_9,8 + 47*Y_9,9 - 7*first_9,0 - 7*first_9,1 - 7*first_9,10 - 7*first_9,11 - 7*first_9,12 - 7*first_9,2 - 7*first_9,3 - 7*first_9,4 - 7*first_9,5 - 7*first_9,6 - 7*first_9,7 - 7*first_9,8 - 7*first_9,9 + t_volume_9,13 - 2*zeta_9,0 - 2*zeta_9,1 - 2*zeta_9,10 - 2*zeta_9,11 - 2*zeta_9,12 - 2*zeta_9,2 - 2*zeta_9,3 - 2*zeta_9,4 - 2*zeta_9,5 - 2*zeta_9,6 - 2*zeta_9,7 - 2*zeta_9,8 - 2*zeta_9,9 = 47 volume_func124_13
# 2*X_9,0 + 2*X_9,1 + 2*X_9,10 + 2*X_9,11 + 2*X_9,12 + 2*X_9,13 + 2*X_9,2 + 2*X_9,3 + 2*X_9,4 + 2*X_9,5 + 2*X_9,6 + 2*X_9,7 + 2*X_9,8 + 2*X_9,9 + 39*Y_9,0 + 40*Y_9,1 + 49*Y_9,10 + 49*Y_9,11 + 49*Y_9,12 + 49*Y_9,13 + 42*Y_9,2 + 43*Y_9,3 + 44*Y_9,4 + 46*Y_9,5 + 47*Y_9,6 + 48*Y_9,7 + 49*Y_9,8 + 49*Y_9,9 - 9*first_9,0 - 9*first_9,1 - 9*first_9,10 - 9*first_9,11 - 9*first_9,12 - 9*first_9,13 - 9*first_9,2 - 9*first_9,3 - 9*first_9,4 - 9*first_9,5 - 9*first_9,6 - 9*first_9,7 - 9*first_9,8 - 9*first_9,9 + t_volume_9,14 - 2*zeta_9,0 - 2*zeta_9,1 - 2*zeta_9,10 - 2*zeta_9,11 - 2*zeta_9,12 - 2*zeta_9,13 - 2*zeta_9,2 - 2*zeta_9,3 - 2*zeta_9,4 - 2*zeta_9,5 - 2*zeta_9,6 - 2*zeta_9,7 - 2*zeta_9,8 - 2*zeta_9,9 = 49 volume_func124_14
# t_volume_90,0 = 6 volume_func125_0
# X_90,0 + 7*Y_90,0 + t_volume_90,1 - zeta_90,0 = 7 volume_func125_1
# 2*X_90,0 + 2*X_90,1 + 9*Y_90,0 + 9*Y_90,1 + t_volume_90,2 - 2*zeta_90,0 - 2*zeta_90,1 = 9 volume_func125_2
# X_90,0 + X_90,1 + X_90,2 + 10*Y_90,0 + 10*Y_90,1 + 10*Y_90,2 + t_volume_90,3 - zeta_90,0 - zeta_90,1 - zeta_90,2 = 10 volume_func125_3
# X_90,0 + X_90,1 + X_90,2 + X_90,3 + 11*Y_90,0 + 11*Y_90,1 + 11*Y_90,2 + 11*Y_90,3 + t_volume_90,4 - zeta_90,0 - zeta_90,1 - zeta_90,2 - zeta_90,3 = 11 volume_func125_4
# 2*X_90,0 + 2*X_90,1 + 2*X_90,2 + 2*X_90,3 + 2*X_90,4 + 13*Y_90,0 + 13*Y_90,1 + 13*Y_90,2 + 13*Y_90,3 + 13*Y_90,4 + t_volume_90,5 - 2*zeta_90,0 - 2*zeta_90,1 - 2*zeta_90,2 - 2*zeta_90,3 - 2*zeta_90,4 = 13 volume_func125_5
# X_90,0 + X_90,1 + X_90,2 + X_90,3 + X_90,4 + X_90,5 + 14*Y_90,0 + 14*Y_90,1 + 14*Y_90,2 + 14*Y_90,3 + 14*Y_90,4 + 14*Y_90,5 + t_volume_90,6 - zeta_90,0 - zeta_90,1 - zeta_90,2 - zeta_90,3 - zeta_90,4 - zeta_90,5 = 14 volume_func125_6
# 2*X_90,0 + 2*X_90,1 + 2*X_90,2 + 2*X_90,3 + 2*X_90,4 + 2*X_90,5 + 2*X_90,6 + 15*Y_90,0 + 16*Y_90,1 + 16*Y_90,2 + 16*Y_90,3 + 16*Y_90,4 + 16*Y_90,5 + 16*Y_90,6 + t_volume_90,7 - 2*zeta_90,0 - 2*zeta_90,1 - 2*zeta_90,2 - 2*zeta_90,3 - 2*zeta_90,4 - 2*zeta_90,5 - 2*zeta_90,6 = 16 volume_func125_7
# X_90,0 + X_90,1 + X_90,2 + X_90,3 + X_90,4 + X_90,5 + X_90,6 + X_90,7 + 15*Y_90,0 + 16*Y_90,1 + 17*Y_90,2 + 17*Y_90,3 + 17*Y_90,4 + 17*Y_90,5 + 17*Y_90,6 + 17*Y_90,7 - first_90,0 - first_90,1 - first_90,2 - first_90,3 - first_90,4 - first_90,5 - first_90,6 - first_90,7 + t_volume_90,8 - zeta_90,0 - zeta_90,1 - zeta_90,2 - zeta_90,3 - zeta_90,4 - zeta_90,5 - zeta_90,6 - zeta_90,7 = 17 volume_func125_8
# 2*X_90,0 + 2*X_90,1 + 2*X_90,2 + 2*X_90,3 + 2*X_90,4 + 2*X_90,5 + 2*X_90,6 + 2*X_90,7 + 2*X_90,8 + 16*Y_90,0 + 17*Y_90,1 + 18*Y_90,2 + 19*Y_90,3 + 19*Y_90,4 + 19*Y_90,5 + 19*Y_90,6 + 19*Y_90,7 + 19*Y_90,8 - 2*first_90,0 - 2*first_90,1 - 2*first_90,2 - 2*first_90,3 - 2*first_90,4 - 2*first_90,5 - 2*first_90,6 - 2*first_90,7 - 2*first_90,8 + t_volume_90,9 - 2*zeta_90,0 - 2*zeta_90,1 - 2*zeta_90,2 - 2*zeta_90,3 - 2*zeta_90,4 - 2*zeta_90,5 - 2*zeta_90,6 - 2*zeta_90,7 - 2*zeta_90,8 = 19 volume_func125_9
# X_90,0 + X_90,1 + X_90,2 + X_90,3 + X_90,4 + X_90,5 + X_90,6 + X_90,7 + X_90,8 + X_90,9 + 15*Y_90,0 + 17*Y_90,1 + 18*Y_90,2 + 19*Y_90,3 + 20*Y_90,4 + 20*Y_90,5 + 20*Y_90,6 + 20*Y_90,7 + 20*Y_90,8 + 20*Y_90,9 - 3*first_90,0 - 3*first_90,1 - 3*first_90,2 - 3*first_90,3 - 3*first_90,4 - 3*first_90,5 - 3*first_90,6 - 3*first_90,7 - 3*first_90,8 - 3*first_90,9 + t_volume_90,10 - zeta_90,0 - zeta_90,1 - zeta_90,2 - zeta_90,3 - zeta_90,4 - zeta_90,5 - zeta_90,6 - zeta_90,7 - zeta_90,8 - zeta_90,9 = 20 volume_func125_10
# 2*X_90,0 + 2*X_90,1 + 2*X_90,10 + 2*X_90,2 + 2*X_90,3 + 2*X_90,4 + 2*X_90,5 + 2*X_90,6 + 2*X_90,7 + 2*X_90,8 + 2*X_90,9 + 16*Y_90,0 + 17*Y_90,1 + 22*Y_90,10 + 19*Y_90,2 + 20*Y_90,3 + 21*Y_90,4 + 22*Y_90,5 + 22*Y_90,6 + 22*Y_90,7 + 22*Y_90,8 + 22*Y_90,9 - 5*first_90,0 - 5*first_90,1 - 5*first_90,10 - 5*first_90,2 - 5*first_90,3 - 5*first_90,4 - 5*first_90,5 - 5*first_90,6 - 5*first_90,7 - 5*first_90,8 - 5*first_90,9 + t_volume_90,11 - 2*zeta_90,0 - 2*zeta_90,1 - 2*zeta_90,10 - 2*zeta_90,2 - 2*zeta_90,3 - 2*zeta_90,4 - 2*zeta_90,5 - 2*zeta_90,6 - 2*zeta_90,7 - 2*zeta_90,8 - 2*zeta_90,9 = 22 volume_func125_11
# X_90,0 + X_90,1 + X_90,10 + X_90,11 + X_90,2 + X_90,3 + X_90,4 + X_90,5 + X_90,6 + X_90,7 + X_90,8 + X_90,9 + 16*Y_90,0 + 17*Y_90,1 + 23*Y_90,10 + 23*Y_90,11 + 18*Y_90,2 + 20*Y_90,3 + 21*Y_90,4 + 22*Y_90,5 + 23*Y_90,6 + 23*Y_90,7 + 23*Y_90,8 + 23*Y_90,9 - 6*first_90,0 - 6*first_90,1 - 6*first_90,10 - 6*first_90,11 - 6*first_90,2 - 6*first_90,3 - 6*first_90,4 - 6*first_90,5 - 6*first_90,6 - 6*first_90,7 - 6*first_90,8 - 6*first_90,9 + t_volume_90,12 - zeta_90,0 - zeta_90,1 - zeta_90,10 - zeta_90,11 - zeta_90,2 - zeta_90,3 - zeta_90,4 - zeta_90,5 - zeta_90,6 - zeta_90,7 - zeta_90,8 - zeta_90,9 = 23 volume_func125_12
# 2*X_90,0 + 2*X_90,1 + 2*X_90,10 + 2*X_90,11 + 2*X_90,12 + 2*X_90,2 + 2*X_90,3 + 2*X_90,4 + 2*X_90,5 + 2*X_90,6 + 2*X_90,7 + 2*X_90,8 + 2*X_90,9 + 16*Y_90,0 + 18*Y_90,1 + 25*Y_90,10 + 25*Y_90,11 + 25*Y_90,12 + 19*Y_90,2 + 20*Y_90,3 + 22*Y_90,4 + 23*Y_90,5 + 24*Y_90,6 + 25*Y_90,7 + 25*Y_90,8 + 25*Y_90,9 - 7*first_90,0 - 7*first_90,1 - 7*first_90,10 - 7*first_90,11 - 7*first_90,12 - 7*first_90,2 - 7*first_90,3 - 7*first_90,4 - 7*first_90,5 - 7*first_90,6 - 7*first_90,7 - 7*first_90,8 - 7*first_90,9 + t_volume_90,13 - 2*zeta_90,0 - 2*zeta_90,1 - 2*zeta_90,10 - 2*zeta_90,11 - 2*zeta_90,12 - 2*zeta_90,2 - 2*zeta_90,3 - 2*zeta_90,4 - 2*zeta_90,5 - 2*zeta_90,6 - 2*zeta_90,7 - 2*zeta_90,8 - 2*zeta_90,9 = 25 volume_func125_13
# X_90,0 + X_90,1 + X_90,10 + X_90,11 + X_90,12 + X_90,13 + X_90,2 + X_90,3 + X_90,4 + X_90,5 + X_90,6 + X_90,7 + X_90,8 + X_90,9 + 16*Y_90,0 + 17*Y_90,1 + 26*Y_90,10 + 26*Y_90,11 + 26*Y_90,12 + 26*Y_90,13 + 19*Y_90,2 + 20*Y_90,3 + 21*Y_90,4 + 23*Y_90,5 + 24*Y_90,6 + 25*Y_90,7 + 26*Y_90,8 + 26*Y_90,9 - 9*first_90,0 - 9*first_90,1 - 9*first_90,10 - 9*first_90,11 - 9*first_90,12 - 9*first_90,13 - 9*first_90,2 - 9*first_90,3 - 9*first_90,4 - 9*first_90,5 - 9*first_90,6 - 9*first_90,7 - 9*first_90,8 - 9*first_90,9 + t_volume_90,14 - zeta_90,0 - zeta_90,1 - zeta_90,10 - zeta_90,11 - zeta_90,12 - zeta_90,13 - zeta_90,2 - zeta_90,3 - zeta_90,4 - zeta_90,5 - zeta_90,6 - zeta_90,7 - zeta_90,8 - zeta_90,9 = 26 volume_func125_14
# t_volume_91,0 = 1 volume_func126_0
# X_91,0 + 2*Y_91,0 + t_volume_91,1 - zeta_91,0 = 2 volume_func126_1
# 2*Y_91,0 + 2*Y_91,1 + t_volume_91,2 = 2 volume_func126_2
# X_91,0 + X_91,1 + X_91,2 + 3*Y_91,0 + 3*Y_91,1 + 3*Y_91,2 + t_volume_91,3 - zeta_91,0 - zeta_91,1 - zeta_91,2 = 3 volume_func126_3
# X_91,0 + X_91,1 + X_91,2 + X_91,3 + 4*Y_91,0 + 4*Y_91,1 + 4*Y_91,2 + 4*Y_91,3 + t_volume_91,4 - zeta_91,0 - zeta_91,1 - zeta_91,2 - zeta_91,3 = 4 volume_func126_4
# 3*Y_91,0 + 4*Y_91,1 + 4*Y_91,2 + 4*Y_91,3 + 4*Y_91,4 + t_volume_91,5 = 4 volume_func126_5
# X_91,0 + X_91,1 + X_91,2 + X_91,3 + X_91,4 + X_91,5 + 4*Y_91,0 + 4*Y_91,1 + 5*Y_91,2 + 5*Y_91,3 + 5*Y_91,4 + 5*Y_91,5 - first_91,0 - first_91,1 - first_91,2 - first_91,3 - first_91,4 - first_91,5 + t_volume_91,6 - zeta_91,0 - zeta_91,1 - zeta_91,2 - zeta_91,3 - zeta_91,4 - zeta_91,5 = 5 volume_func126_6
# X_91,0 + X_91,1 + X_91,2 + X_91,3 + X_91,4 + X_91,5 + X_91,6 + 4*Y_91,0 + 5*Y_91,1 + 5*Y_91,2 + 6*Y_91,3 + 6*Y_91,4 + 6*Y_91,5 + 6*Y_91,6 - first_91,0 - first_91,1 - first_91,2 - first_91,3 - first_91,4 - first_91,5 - first_91,6 + t_volume_91,7 - zeta_91,0 - zeta_91,1 - zeta_91,2 - zeta_91,3 - zeta_91,4 - zeta_91,5 - zeta_91,6 = 6 volume_func126_7
# X_91,0 + X_91,1 + X_91,2 + X_91,3 + X_91,4 + X_91,5 + X_91,6 + X_91,7 + 5*Y_91,0 + 5*Y_91,1 + 6*Y_91,2 + 6*Y_91,3 + 7*Y_91,4 + 7*Y_91,5 + 7*Y_91,6 + 7*Y_91,7 - 2*first_91,0 - 2*first_91,1 - 2*first_91,2 - 2*first_91,3 - 2*first_91,4 - 2*first_91,5 - 2*first_91,6 - 2*first_91,7 + t_volume_91,8 - zeta_91,0 - zeta_91,1 - zeta_91,2 - zeta_91,3 - zeta_91,4 - zeta_91,5 - zeta_91,6 - zeta_91,7 = 7 volume_func126_8
# 4*Y_91,0 + 5*Y_91,1 + 5*Y_91,2 + 6*Y_91,3 + 6*Y_91,4 + 7*Y_91,5 + 7*Y_91,6 + 7*Y_91,7 + 7*Y_91,8 - 2*first_91,0 - 2*first_91,1 - 2*first_91,2 - 2*first_91,3 - 2*first_91,4 - 2*first_91,5 - 2*first_91,6 - 2*first_91,7 - 2*first_91,8 + t_volume_91,9 = 7 volume_func126_9
# X_91,0 + X_91,1 + X_91,2 + X_91,3 + X_91,4 + X_91,5 + X_91,6 + X_91,7 + X_91,8 + X_91,9 + 4*Y_91,0 + 5*Y_91,1 + 6*Y_91,2 + 6*Y_91,3 + 7*Y_91,4 + 7*Y_91,5 + 8*Y_91,6 + 8*Y_91,7 + 8*Y_91,8 + 8*Y_91,9 - 3*first_91,0 - 3*first_91,1 - 3*first_91,2 - 3*first_91,3 - 3*first_91,4 - 3*first_91,5 - 3*first_91,6 - 3*first_91,7 - 3*first_91,8 - 3*first_91,9 + t_volume_91,10 - zeta_91,0 - zeta_91,1 - zeta_91,2 - zeta_91,3 - zeta_91,4 - zeta_91,5 - zeta_91,6 - zeta_91,7 - zeta_91,8 - zeta_91,9 = 8 volume_func126_10
# X_91,0 + X_91,1 + X_91,10 + X_91,2 + X_91,3 + X_91,4 + X_91,5 + X_91,6 + X_91,7 + X_91,8 + X_91,9 + 5*Y_91,0 + 5*Y_91,1 + 9*Y_91,10 + 6*Y_91,2 + 7*Y_91,3 + 7*Y_91,4 + 8*Y_91,5 + 8*Y_91,6 + 9*Y_91,7 + 9*Y_91,8 + 9*Y_91,9 - 4*first_91,0 - 4*first_91,1 - 4*first_91,10 - 4*first_91,2 - 4*first_91,3 - 4*first_91,4 - 4*first_91,5 - 4*first_91,6 - 4*first_91,7 - 4*first_91,8 - 4*first_91,9 + t_volume_91,11 - zeta_91,0 - zeta_91,1 - zeta_91,10 - zeta_91,2 - zeta_91,3 - zeta_91,4 - zeta_91,5 - zeta_91,6 - zeta_91,7 - zeta_91,8 - zeta_91,9 = 9 volume_func126_11
# X_91,0 + X_91,1 + X_91,10 + X_91,11 + X_91,2 + X_91,3 + X_91,4 + X_91,5 + X_91,6 + X_91,7 + X_91,8 + X_91,9 + 5*Y_91,0 + 6*Y_91,1 + 10*Y_91,10 + 10*Y_91,11 + 6*Y_91,2 + 7*Y_91,3 + 8*Y_91,4 + 8*Y_91,5 + 9*Y_91,6 + 9*Y_91,7 + 10*Y_91,8 + 10*Y_91,9 - 4*first_91,0 - 4*first_91,1 - 4*first_91,10 - 4*first_91,11 - 4*first_91,2 - 4*first_91,3 - 4*first_91,4 - 4*first_91,5 - 4*first_91,6 - 4*first_91,7 - 4*first_91,8 - 4*first_91,9 + t_volume_91,12 - zeta_91,0 - zeta_91,1 - zeta_91,10 - zeta_91,11 - zeta_91,2 - zeta_91,3 - zeta_91,4 - zeta_91,5 - zeta_91,6 - zeta_91,7 - zeta_91,8 - zeta_91,9 = 10 volume_func126_12
# 4*Y_91,0 + 5*Y_91,1 + 10*Y_91,10 + 10*Y_91,11 + 10*Y_91,12 + 6*Y_91,2 + 6*Y_91,3 + 7*Y_91,4 + 8*Y_91,5 + 8*Y_91,6 + 9*Y_91,7 + 9*Y_91,8 + 10*Y_91,9 - 5*first_91,0 - 5*first_91,1 - 5*first_91,10 - 5*first_91,11 - 5*first_91,12 - 5*first_91,2 - 5*first_91,3 - 5*first_91,4 - 5*first_91,5 - 5*first_91,6 - 5*first_91,7 - 5*first_91,8 - 5*first_91,9 + t_volume_91,13 = 10 volume_func126_13
# X_91,0 + X_91,1 + X_91,10 + X_91,11 + X_91,12 + X_91,13 + X_91,2 + X_91,3 + X_91,4 + X_91,5 + X_91,6 + X_91,7 + X_91,8 + X_91,9 + 4*Y_91,0 + 5*Y_91,1 + 11*Y_91,10 + 11*Y_91,11 + 11*Y_91,12 + 11*Y_91,13 + 6*Y_91,2 + 7*Y_91,3 + 7*Y_91,4 + 8*Y_91,5 + 9*Y_91,6 + 9*Y_91,7 + 10*Y_91,8 + 10*Y_91,9 - 6*first_91,0 - 6*first_91,1 - 6*first_91,10 - 6*first_91,11 - 6*first_91,12 - 6*first_91,13 - 6*first_91,2 - 6*first_91,3 - 6*first_91,4 - 6*first_91,5 - 6*first_91,6 - 6*first_91,7 - 6*first_91,8 - 6*first_91,9 + t_volume_91,14 - zeta_91,0 - zeta_91,1 - zeta_91,10 - zeta_91,11 - zeta_91,12 - zeta_91,13 - zeta_91,2 - zeta_91,3 - zeta_91,4 - zeta_91,5 - zeta_91,6 - zeta_91,7 - zeta_91,8 - zeta_91,9 = 11 volume_func126_14

# %%
# zeta variable 
for m in range(n_stands):
    for p in range(n_periods+1):
        model+=(Y_allocation[m][p] + lpSum(X_allocation[m][k] for k in range(p+1))
           >= 2*zeta_allocation[m][p], "zeta_con1_" + str(m)+ "_"+ str(p))  
#### Sum Ym,t + Sum Xm,t - Zm <= 1 
for m in range(n_stands):
    for p in range(n_periods+1):
        model+=(Y_allocation[m][p]+ lpSum(X_allocation[m][k] for k in range(0,p+1)) 
         - zeta_allocation[m][p] <= 1, "zeta_con2_" + str(m)+ "_"+ str(p))

# %%
# First variable 
for m in range (n_stands): 
    for p in range(n_periods):
        model+=(first_allocation[m][p]*M >=
                lpSum(X_allocation[m][k]*k - Y_allocation[m][k]*k for k in range(0,p+1)),
                "first_con1"+ str(m)+ "_"+ str(p))
        model+=(first_allocation[m][p] <= lpSum(X_allocation[m][k] for k in range(0,p+1)),
             "first_con2"+ str(m)+ "_"+ str(p))
        model+=(first_allocation[m][p] <= lpSum(Y_allocation[m][k] for k in range(0,p+1)),
             "first_con3"+ str(m)+ "_"+ str(p))

# %%
#Constraint 8 : recorded PCT and harvest treatment = 1 
for m in range(len(new_Y_m)): 
    model += (Yr_allocation[m] == 1), "rec_harv_" + str(m)    
for m in range(len(new_X_m)):
    model += (Xr_allocation[m] == 1), "rec_PCT" + str(m)

# %%
#Constraint 9 : maximize min 
for p in range(n_periods+1):
      model+=(lpSum(alpha_allocation[m][p] for m in range(n_stands)) >= alpha_min_allocation[p],
        "period_con_" + str(m) + "_" + str(p))

# %%
# Constraint 10 : no harvest before stand attains merchantable age (+55) or min vol  
### Ym,p * 55/5 <= Age m,p 
### and/or 
### min vol : Ym,p*volume[m][t]

for m in range(n_stands): 
    for t in range(n_periods + 1):
        model+=((Y_allocation[m][t]*min_vol <= t_volume_allocation[m][t], "Harv_vol" + str(m)+ "_"+ str(t)))
# volume[N_stands[m]][t] - sum (X_allocation[m][p]*volume[N_stands[m]][p]
for m in range(n_stands+1): 
    for k in range(len(new_Y_p)): 
        if new_Y_m[k] == m:
            for t in range(n_periods + 1):
                model+=(Y_allocation[m-1][t]*min_hyr/5 <= t - new_Y_p[k] + 
                         lpSum(Y_allocation[m-1][p]*(new_Y_p[k]-p) for p in range(0, t)) 
                      , "Harv55_"+ str(m)+ "_"+ str(t))

# %%
#Constraint 11: 
for p in range(1, n_periods+1):
    (lpSum(alpha_allocation[m][p] for m in range(n_stands)) 
     <= (1.25)*lpSum(alpha_allocation[m][p-1] for m in range(n_stands))
         , "alpha_bound_plus25_"+str(p))
    #### Harvest 
    model+=(lpSum(Y_allocation[m][p] for m in range(n_stands)) 
     <= (1.25)*lpSum(Y_allocation[m][p-1] for m in range(n_stands))
          ,"Y_bound_plus25_"+str(p))
    model+=(lpSum(Y_allocation[m][p] for m in range(n_stands)) 
     >= (0.75)*lpSum(Y_allocation[m][p-1] for m in range(n_stands))
          ,"Y_bound_minus25_"+str(p))
    
    (lpSum(alpha_allocation[m][p] for m in range(n_stands)) 
     >= (0.75)*lpSum(alpha_allocation[m][p-1] for m in range(n_stands))
         , "alpha_bound_minus25_"+str(p))
    
    #### PCT 
    (lpSum(X_allocation[m][p] for m in range(n_stands)) 
     <= (1.5)*lpSum(X_allocation[m][p-1] for m in range(n_stands))
          ,"X_bound_plus25_"+str(p))
    (lpSum(X_allocation[m][p] for m in range(n_stands)) 
     >= (0.85)*lpSum(X_allocation[m][p-1] for m in range(n_stands))
          ,"X_bound_minus25_"+str(p))

# %%
# Evaluation functions 
area_variable_names = [str(i) for i in range (n_periods+1)]
area_variables = LpVariable.matrix("Area", area_variable_names, cat = "Continuous", lowBound= 0 )
area_allocation = np.array(area_variables).reshape(n_periods+1)

#number of harvest activities 
NH_variable_names = [str(i) for i in range (n_periods+1)]
NH_variables = LpVariable.matrix("NH", NH_variable_names, cat = "Continuous", lowBound= 0 )
NH_allocation = np.array(NH_variables).reshape(n_periods+1)

#number of forage habitat 
ND_variable_names = [str(i) for i in range (n_periods+1)]
ND_variables = LpVariable.matrix("ND", ND_variable_names, cat = "Continuous", lowBound= 0 )
ND_allocation = np.array(ND_variables).reshape(n_periods+1)

#number of accessible forage habitat 
NAF_variable_names = [str(i) for i in range (n_periods+1)]
NAF_variables = LpVariable.matrix("NAF", NAF_variable_names, cat = "Continuous", lowBound= 0 )
NAF_allocation = np.array(NAF_variables).reshape(n_periods+1)

#number of PCT
NPCT_variable_names = [str(i) for i in range (n_periods+1)]
NPCT_variables = LpVariable.matrix("NPCT", NPCT_variable_names, cat = "Continuous", lowBound= 0 )
NPCT_allocation = np.array(NPCT_variables).reshape(n_periods+1)

Vharv_variable_names = [str(i) for i in range (n_periods+1)]
Vharv_variables = LpVariable.matrix("Vharv", Vharv_variable_names, cat = "Continuous", lowBound= 0 )
Vharv_allocation = np.array(Vharv_variables).reshape(n_periods+1)

### could convert that to biomass 
VC_variable_names = [str(i) for i in range (n_stands+1)]
VC_variables = LpVariable.matrix("VC", VC_variable_names, cat = "Continuous", lowBound= 0 )
VC_allocation = np.array(VC_variables).reshape(n_stands+1)

AREA = LpVariable("AREA", cat="Continuous", lowBound=0)

for p in range(n_periods +1):
    model+= (lpSum(Y_allocation[m][p] for m in range(len(N_stands)))==NH_allocation[p], "TOT_NH_"+str(p))
    model+= (lpSum(alpha_allocation[m][p] for m in range(len(N_stands)))==NAF_allocation[p], "TOT_NAF_"+str(p))
    model+= (lpSum(delta_allocation[m][p] for m in range(len(N_stands)))==ND_allocation[p], "TOT_ND_"+str(p))
    model+= (lpSum(X_allocation[m][p] for m in range(len(N_stands)))==NPCT_allocation[p], "TOT_NPCT_"+str(p))
model+= (lpSum(area_dic[i] for i in N_stands)==AREA, "TOT_AREA")


for j in range(n_periods+1):
    # sum just alpha 
    model+= (lpSum(alpha_allocation[i][j]*area_dic[N_stands[i]] 
                for i in range(n_stands))==area_allocation[j], "Area"+str(j))
for j in range(n_periods+1):
    model += (lpSum(Y_allocation[i][j]*volume[N_stands[i]][j]*area_dic[N_stands[i]]  
                for i in range(n_stands))==Vharv_allocation[j], "VolHarv"+str(j))
for i in range(n_stands):
    model += (lpSum(C_allocation[i]*volume[N_stands[i]][n_periods]*area_dic[N_stands[i]]
                   ) == VC_allocation[i+1], "VolCarb"+str(i+1))

# %%
# Objective function 
obj_func = lpSum(alpha_min_allocation)
#obj_func = (lpSum(alpha_allocation[i][j]*area_dic[N_stands[i]] for i in range(n_stands) 
                 #for j in range(n_periods+1)))
#obj_func = lpSum(alpha_min_allocation)
model += obj_func

# %%
#Save code into a lp file 
model.writeLP("model_0627_bis.lp")
1
# Out:
# 1

# %%
#play around with CBC solver 
model.solve(PULP_CBC_CMD(msg=1))

status =  LpStatus[model.status]

print(status)

# %%
print("Total:", model.objective.value())

# Decision Variables
count_X = 0 
count_Y = 0 
count_alpha = 0 
count_C = 0 
for v in model.variables():
    try:
        print(v.name,"=", v.value())
        match_X = re.search('^X',v.name)
        match_Y = re.search('^Y', v.name)
        match_alpha = re.search('^(al)', v.name)
        match_age = re.search('^(age)', v.name)
        match_area = re.search('^(Area)', v.name)
        match_vol = re.search('^(V)', v.name)
        match_C = re.search('^(C)', v.name)
        if match_X:
            if v.value()== 1.0:
                count_X += 1
                print(v.name)
        if match_Y:
            if v.value()== 1.0:
                count_Y += 1
                print(v.name)
        if match_alpha:
            if v.value() <= 1.0:    
                count_alpha +=1 
                print(v.name)
        if match_age:
            #print(v.name, "=", v.value() )
            1
        if match_area:
            print(v.name, "=", v.value())
        if match_vol:
            print(v.name, "=", v.value())
        if match_C:
            if v.value() == 1.0:    
                count_C +=1 
                print(v.name)
            
    except:
        print("error couldnt find value")
print(count_X-2, "PCT")
print(count_Y-91, "Harvest")
print(count_alpha, "habitat")
print(count_C, "Carbon")
#Cplex.conflict.refine
