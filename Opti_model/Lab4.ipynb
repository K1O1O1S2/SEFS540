# %% [markdown]
# # Write an IP problem in <'lp'> format

# %%
# %load_ext autoreload
# %autoreload 2
#! pip install pulp
## https://towardsdatascience.com/linear-programming-using-python-priyansh-22b5ee888fe0

# %%
# To be a real programmer : get a black screen 
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme('chesterish')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #cdd2e9;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #a2b0c7;
#  background-color: #1a2028;
#  background: #1a2028;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1a2028;
#  background: #1a2028;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #a2b0c7;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #dbe1ea;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
#  min-height: 27px;
#  padding-top: 2px;
#  padding-bottom: 0px;
# }
# #maintoolbar .container {
#  width: 75%;
#  margin-right: auto;
#  margin-left: auto;
# }
# .list_header,
# div#notebook_list_header.row.list_header {
#  font-size: 14pt;
#  color: #dbe1ea;
#  background-color: transparent;
#  height: 35px;
# }
# i.fa.fa-folder {
#  display: inline-block;
#  font: normal normal normal 14px "FontAwesome";
#  font-family: "FontAwesome" !important;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  font-size: 18px;
#  -moz-osx-font-smoothing: grayscale;
# }
# #running .panel-group .panel .panel-heading {
#  font-size: 14pt;
#  color: #a2b0c7;
#  padding: 8px 8px;
#  background: #252b35;
#  background-color: #252b35;
# }
# #running .panel-group .panel .panel-heading a {
#  font-size: 14pt;
#  color: #a2b0c7;
# }
# #running .panel-group .panel .panel-heading a:focus,
# #running .panel-group .panel .panel-heading a:hover {
#  font-size: 14pt;
#  color: #a2b0c7;
# }
# #running .panel-group .panel .panel-body .list_container .list_item {
#  background: #2d3846;
#  background-color: #2d3846;
#  padding: 2px;
#  border-bottom: 2px solid rgba(75,95,118,.30);
# }
# #running .panel-group .panel .panel-body .list_container .list_item:hover {
#  background: #2d3846;
#  background-color: #2d3846;
# }
# #running .panel-group .panel .panel-body {
#  padding: 2px;
# }
# button#refresh_running_list {
#  border: none !important;
# }
# button#refresh_cluster_list {
#  border: none !important;
# }
# div.running_list_info.toolbar_info {
#  font-size: 15px;
#  padding: 4px 0 4px 0;
#  margin-top: 5px;
#  margin-bottom: 8px;
#  height: 24px;
#  line-height: 24px;
#  text-shadow: none;
# }
# .list_placeholder {
#  font-weight: normal;
# }
# #tree-selector {
#  padding: 0px;
#  border-color: transparent;
# }
# #project_name > ul > li > a > i.fa.fa-home {
#  color: #0b98c8;
#  font-size: 17pt;
#  display: inline-block;
#  position: static;
#  padding: 0px 0px;
#  font-weight: normal;
#  text-align: center;
#  vertical-align: text-top;
# }
# .fa-folder:before {
#  color: #4c8be2;
# }
# .fa-arrow-up:before {
#  font-size: 14px;
# }
# .fa-arrow-down:before {
#  font-size: 14px;
# }
# span#last-modified.btn.btn-xs.btn-default.sort-action:hover .fa,
# span#sort-name.btn.btn-xs.btn-default.sort-action:hover .fa {
#  color: #009cd1;
# }
# .folder_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f07b";
#  color: #4c8be2;
# }
# .notebook_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f02d";
#  position: relative;
#  color: #48a667 !important;
#  top: 0px;
# }
# .file_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f15b";
#  position: relative;
#  top: 0px;
#  color: #92a2bd !important;
# }
# #project_name a {
#  display: inline-flex;
#  padding-left: 7px;
#  margin-left: -2px;
#  text-align: -webkit-auto;
#  vertical-align: baseline;
#  font-size: 18px;
# }
# div#notebook_toolbar div.dynamic-instructions {
#  font-family: sans-serif;
#  font-size: 17px;
#  color: #546386;
# }
# span#login_widget > .button,
# #logout {
#  font-family: "Proxima Nova", sans-serif;
#  color: #a2b0c7;
#  background: transparent;
#  background-color: transparent;
#  border: 2px solid #252e3a;
#  font-weight: normal;
#  box-shadow: none;
#  text-shadow: none;
#  border-radius: 3px;
#  margin-right: 10px;
#  padding: 2px 7px;
# }
# span#login_widget > .button:hover,
# #logout:hover {
#  color: #009cd1;
#  background-color: transparent;
#  background: transparent;
#  border: 2px solid #009cd1;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 3px;
# }
# span#login_widget > .button:focus,
# #logout:focus,
# span#login_widget > .button.focus,
# #logout.focus,
# span#login_widget > .button:active,
# #logout:active,
# span#login_widget > .button.active,
# #logout.active,
# .open > .dropdown-togglespan#login_widget > .button,
# .open > .dropdown-toggle#logout {
#  color: #fefefe;
#  background-color: #a2b0c7;
#  background: #a2b0c7;
#  border-color: #a2b0c7;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 2px;
# }
# body > #header #header-container {
#  padding-bottom: 0px;
#  padding-top: 4px;
#  box-sizing: border-box;
#  -moz-box-sizing: border-box;
#  -webkit-box-sizing: border-box;
# }
# body > #header {
#  background: #1a2028;
#  background-color: #1a2028;
#  position: relative;
#  z-index: 100;
# }
# .list_container {
#  font-size: 13pt;
#  color: #a2b0c7;
#  border: none;
#  text-shadow: none !important;
# }
# .list_container > div {
#  border-bottom: 1px solid rgba(75,95,118,.30);
#  font-size: 13pt;
# }
# .list_header > div,
# .list_item > div {
#  padding-top: 6px;
#  padding-bottom: 2px;
#  padding-left: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 22px;
#  font-size: 13pt;
# }
# .item_icon {
#  color: #4c8be2;
#  font-size: 13pt;
#  vertical-align: middle;
# }
# .list_item input:not([type="checkbox"]) {
#  padding-right: 0px;
#  height: 1.75em;
#  width: 25%;
#  margin: 0px 0 0;
#  margin-top: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 1.5em;
#  font-size: 12pt;
#  display: inline-table;
#  position: static;
# }
# #button-select-all {
#  height: 34px;
#  min-width: 55px;
#  z-index: 0;
#  border: none !important;
#  padding-top: 0px;
#  padding-bottom: 0px;
#  margin-bottom: 0px;
#  margin-top: 0px;
#  left: -3px;
#  border-radius: 0px !important;
# }
# #button-select-all:focus,
# #button-select-all:active:focus,
# #button-select-all.active:focus,
# #button-select-all.focus,
# #button-select-all:active.focus,
# #button-select-all.active.focus {
#  background-color: #252e3a !important;
#  background: #252e3a !important;
# }
# button#tree-selector-btn {
#  height: 34px;
#  font-size: 12.0pt;
#  border: none;
#  left: 0px;
#  border-radius: 0px !important;
# }
# input#select-all.pull-left.tree-selector {
#  margin-left: 7px;
#  margin-right: 2px;
#  margin-top: 2px;
#  top: 4px;
# }
# input[type="radio"],
# input[type="checkbox"] {
#  margin-top: 1px;
#  line-height: normal;
# }
# .delete-button {
#  border: none !important;
# }
# i.fa.fa-trash {
#  font-size: 13.5pt;
# }
# .list_container a {
#  font-size: 16px;
#  color: #a2b0c7;
#  border: none;
#  text-shadow: none !important;
#  font-weight: normal;
#  font-style: normal;
# }
# div.list_container a:hover {
#  color: #dbe1ea;
# }
# .list_header > div input,
# .list_item > div input {
#  margin-right: 7px;
#  margin-left: 12px;
#  vertical-align: baseline;
#  line-height: 22px;
#  position: relative;
#  top: -1px;
# }
# div.list_item:hover {
#  background-color: rgba(75,95,118,.10);
# }
# .breadcrumb > li {
#  font-size: 12.0pt;
#  color: #a2b0c7;
#  border: none;
#  text-shadow: none !important;
# }
# .breadcrumb > li + li:before {
#  content: "/\00a0";
#  padding: 0px;
#  color: #a2b0c7;
#  font-size: 18px;
# }
# #project_name > .breadcrumb {
#  padding: 0px;
#  margin-bottom: 0px;
#  background-color: transparent;
#  font-weight: normal;
#  margin-top: -2px;
# }
# ul#tabs a {
#  font-family: sans-serif;
#  font-size: 13.5p

# %%
from pulp import *
import pandas as pd 
import numpy as np

# %%
# Import files 
adjacency = np.loadtxt('Adjacency.txt', delimiter = ",")
parcels = np.loadtxt('Parcels.txt', delimiter = ",")
adjacency = adjacency.astype(int)

# %%
# Data definition 

n_parcels = 120 
B = 1000000
m = 121 #Big Number !! just need to be big enough 

# Parcels 
parcel = parcels[:,0]

# Cost Matrix 
cost_matrix = parcels[:,2]

# Area Matrix 
area_matrix = parcels[:,1]

# Parcels i adjacent to j 
adj1 = adjacency[:,0]

# Parcels j adjacent to i 
adj2 = adjacency[:,1]

# %%
# Model initialization
model= LpProblem("Lab4", LpMaximize)

# %%
# Decision variables 
variable_names = [str(i) for i in range(1,n_parcels+1)]

DV_variables = LpVariable.matrix("X", variable_names, cat = "Binary", lowBound= 0 )
X_allocation = np.array(DV_variables).reshape(120)

# Flow variables
adj_variable_names = [str(adj1[i]) + '_' + str(adj2[j]) for i in range (len(adj1)) for j in range (len(adj2))]
Flow_variables = LpVariable.matrix("Y", adj_variable_names, cat = "Binary", lowBound = 0)
Yij_allocation = np.array(Flow_variables).reshape(260,260)

#Tail variables 

Zij_variable_names = [str(adj1[i]) + '_' + str(adj2[i]) for i in range (len(adj1))]
Zij_variables = LpVariable.matrix("Z", Zij_variable_names, cat = "Integer", lowBound = 0)
Zij_allocation = np.array(Zij_variables).reshape(260)

W_variable_names = [str(i) for i in range(1,n_parcels+1)]
W_variables = LpVariable.matrix("W", W_variable_names, cat = "Integer", lowBound= 0 )
W_allocation = np.array(W_variables).reshape(120)

# %%
# Constraints 

## Constraint 1: Budget constraint 
### SUM pi*Xi <= B 

## Constraint 2: 4 adjacent cells 
### SUM Yij (i e Ij)<= [|hdhdhd]*Xj for all j 

## Constraint 3: Max 1 connection from i
#### SUM Yij (j e Ii) <= Xi 

## Constraint 4: Number of arcs must be less or equal to the number of nodes 
#### SUM Yij (i,j) <= SUM Xi - 1 (i)

## Constraint 5: tail function 
### Zij >= Wi + 1 - m(1-Yij) for all i, j adjacent, i != j 

## Constraint 6: cycle breaking constraint 
### Wj >= SUM (ieIj) Zij for all j 

## Constraint 7: ensure that zij is minimal 
### Zij <= m*Yij 

## Constraint 8:ensure that zij is minimal
### Zij <= Wi+1 

#core parcel :  parcel 10, 32.031, 0.00

# %%
## Constraint 1: Budget constraint 
### SUM pi*Xi <= B 

model += lpSum(X_allocation*cost_matrix) <= B, "Budget constraint"

# %%
## Constraint 2: 4 adjacent cells 
### SUM Yij (i e Ij)<= 4*Xj for all j  !!! change to cardinality of Aj number of parcels adjacent to j 
count = [] 
c = 0 
for j in range(n_parcels):
    for k in range(len(adj2)): 
        if adj2[k] == parcel[j]:
            count.append(k) 
            c += 1 
            #print(count)
            #print(adj2[k])
            #print(parcel[j])
    if count != []:
        #print(lpSum(Yij_allocation[count[i]][count[i]] for i in range(len(count)) ) <= c*X_allocation[j])
        model += lpSum(Yij_allocation[count[i]][count[i]] for i in range(len(count))) <= c*X_allocation[j], "Max connection to j" + str(j)
    count = []
    c = 0

# %%
model
# Out:
# Lab4:
# MAXIMIZE
# None
# SUBJECT TO
# Budget_constraint: 337671 X_1 + 38751 X_100 + 6822 X_101 + 22859 X_102
#  + 177000 X_103 + 46342 X_104 + 266826 X_105 + 119105 X_106 + 896336 X_107
#  + 257229 X_108 + 44718 X_109 + 5436 X_11 + 19224 X_110 + 25747 X_111
#  + 26763 X_112 + 68715 X_113 + 416481 X_114 + 40642 X_115 + 100080 X_116
#  + 74920 X_117 + 70705 X_118 + 20598 X_119 + 182715 X_12 + 309145 X_120
#  + 152280 X_13 + 37921 X_14 + 107408 X_15 + 204360 X_16 + 180330 X_17
#  + 163980 X_18 + 25005 X_19 + 19860 X_2 + 213367 X_20 + 46555 X_21
#  + 15025 X_22 + 43240 X_23 + 16490 X_24 + 849971 X_25 + 12635 X_26
#  + 40166 X_27 + 47970 X_28 + 19350 X_29 + 48252 X_3 + 28832 X_30 + 104752 X_31
#  + 98049 X_32 + 22824 X_33 + 127848 X_34 + 155445 X_35 + 48420 X_36
#  + 113676 X_37 + 26160 X_38 + 11070 X_39 + 80685 X_4 + 13920 X_40 + 25335 X_41
#  + 19899 X_42 + 837704 X_43 + 128910 X_44 + 497513 X_45 + 118480 X_46
#  + 90828 X_47 + 72005 X_48 + 253632 X_49 + 49008 X_5 + 235680 X_50
#  + 45305 X_51 + 72344 X_52 + 112566 X_53 + 20755 X_54 + 66224 X_55
#  + 202734 X_56 + 62703 X_57 + 17770 X_58 + 79120 X_59 + 14517 X_6 + 71952 X_60
#  + 14248 X_61 + 415996 X_62 + 242160 X_63 + 361905 X_64 + 65004 X_65
#  + 33236 X_66 + 20016 X_67 + 51036 X_68 + 14765 X_69 + 185520 X_7 + 48040 X_70
#  + 99015 X_71 + 66180 X_72 + 98610 X_73 + 154800 X_74 + 404940 X_75
#  + 596595 X_76 + 26676 X_77 + 151105 X_78 + 210224 X_79 + 30220 X_8
#  + 288255 X_80 + 84963 X_81 + 411247 X_82 + 52908 X_83 + 124500 X_84
#  + 276765 X_85 + 31527 X_86 + 60057 X_87 + 63560 X_88 + 36789 X_89 + 8172 X_9
#  + 25271 X_90 + 57674 X_91 + 59668 X_92 + 116788 X_93 + 221753 X_94
#  + 96031 X_95 + 47906 X_96 + 333975 X_97 + 83088 X_98 + 53640 X_99 <= 1000000
#
# Max_connection_to_j1: - X_2 + Y_51_2 <= 0
#
# Max_connection_to_j2: - 3 X_3 + Y_50_3 + Y_55_3 + Y_60_3 <= 0
#
# Max_connection_to_j3: - 3 X_4 + Y_48_4 + Y_5_4 + Y_6_4 <= 0
#
# Max_connection_to_j4: - 2 X_5 + Y_4_5 + Y_54_5 <= 0
#
# Max_connection_to_j5: - 3 X_6 + Y_47_6 + Y_4_6 + Y_56_6 <= 0
#
# Max_connection_to_j6: - 2 X_7 + Y_57_7 + Y_58_7 <= 0
#
# Max_connection_to_j7: - 3 X_8 + Y_60_8 + Y_66_8 + Y_68_8 <= 0
#
# Max_connection_to_j9: - X_10 + Y_13_10 <= 0
#
# Max_connection_to_j11: - 2 X_12 + Y_63_12 + Y_73_12 <= 0
#
# Max_connection_to_j12: - 2 X_13 + Y_10_13 + Y_16_13 <= 0
#
# Max_connection_to_j13: - 5 X_14 + Y_17_14 + Y_19_14 + Y_21_14 + Y_22_14
#  + Y_24_14 <= 0
#
# Max_connection_to_j14: - 4 X_15 + Y_17_15 + Y_18_15 + Y_23_15 + Y_75_15 <= 0
#
# Max_connection_to_j15: - 3 X_16 + Y_13_16 + Y_20_16 + Y_76_16 <= 0
#
# Max_connection_to_j16: - 5 X_17 + Y_14_17 + Y_15_17 + Y_19_17 + Y_23_17
#  + Y_64_17 <= 0
#
# Max_connection_to_j17: - 3 X_18 + Y_15_18 + Y_73_18 + Y_75_18 <= 0
#
# Max_connection_to_j18: - 4 X_19 + Y_14_19 + Y_17_19 + Y_22_19 + Y_23_19 <= 0
#
# Max_connection_to_j19: - 2 X_20 + Y_16_20 + Y_76_20 <= 0
#
# Max_connection_to_j20: - X_21 + Y_14_21 <= 0
#
# Max_connection_to_j21: - 4 X_22 + Y_14_22 + Y_19_22 + Y_23_22 + Y_24_22 <= 0
#
# Max_connection_to_j22: - 7 X_23 + Y_15_23 + Y_17_23 + Y_19_23 + Y_22_23
#  + Y_26_23 + Y_27_23 + Y_75_23 <= 0
#
# Max_connection_to_j23: - 2 X_24 + Y_14_24 + Y_22_24 <= 0
#
# Max_connection_to_j24: - 2 X_25 + Y_77_25 + Y_78_25 <= 0
#
# Max_connection_to_j25: - 2 X_26 + Y_23_26 + Y_27_26 <= 0
#
# Max_connection_to_j26: - 5 X_27 + Y_23_27 + Y_26_27 + Y_28_27 + Y_32_27
#  + Y_75_27 <= 0
#
# Max_connection_to_j27: - 4 X_28 + Y_27_28 + Y_31_28 + Y_32_28 + Y_33_28 <= 0
#
# Max_connection_to_j28: - 2 X_29 + Y_31_29 + Y_76_29 <= 0
#
# Max_connection_to_j30: - 6 X_31 + Y_28_31 + Y_29_31 + Y_33_31 + Y_35_31
#  + Y_37_31 + Y_76_31 <= 0
#
# Max_connection_to_j31: - 4 X_32 + Y_27_32 + Y_28_32 + Y_33_32 + Y_38_32 <= 0
#
# Max_connection_to_j32: - 6 X_33 + Y_28_33 + Y_31_33 + Y_32_33 + Y_35_33
#  + Y_38_33 + Y_82_33 <= 0
#
# Max_connection_to_j33: - X_34 + Y_91_34 <= 0
#
# Max_connection_to_j34: - 4 X_35 + Y_31_35 + Y_33_35 + Y_37_35 + Y_82_35 <= 0
#
# Max_connection_to_j35: - 4 X_36 + Y_37_36 + Y_76_36 + Y_78_36 + Y_79_36 <= 0
#
# Max_connection_to_j36: - 6 X_37 + Y_31_37 + Y_35_37 + Y_36_37 + Y_76_37
#  + Y_79_37 + Y_82_37 <= 0
#
# Max_connection_to_j37: - 2 X_38 + Y_32_38 + Y_33_38 <= 0
#
# Max_connection_to_j38: - 2 X_39 + Y_80_39 + Y_83_39 <= 0
#
# Max_connection_to_j39: - 3 X_40 + Y_79_40 + Y_84_40 + Y_86_40 <= 0
#
# Max_connection_to_j41: - X_42 + Y_88_42 <= 0
#
# Max_connection_to_j44: - 2 X_45 + Y_47_45 + Y_49_45 <= 0
#
# Max_connection_to_j45: - 2 X_46 + Y_47_46 + Y_48_46 <= 0
#
# Max_connection_to_j46: - 4 X_47 + Y_45_47 + Y_46_47 + Y_48_47 + Y_6_47 <= 0
#
# Max_connection_to_j47: - 3 X_48 + Y_46_48 + Y_47_48 + Y_4_48 <= 0
#
# Max_connection_to_j48: - 3 X_49 + Y_45_49 + Y_51_49 + Y_56_49 <= 0
#
# Max_connection_to_j49: - 2 X_50 + Y_3_50 + Y_55_50 <= 0
#
# Max_connection_to_j50: - 2 X_51 + Y_2_51 + Y_49_51 <= 0
#
# Max_connection_to_j52: - X_53 + Y_54_53 <= 0
#
# Max_connection_to_j53: - 2 X_54 + Y_53_54 + Y_5_54 <= 0
#
# Max_connection_to_j54: - 3 X_55 + Y_3_55 + Y_50_55 + Y_60_55 <= 0
#
# Max_connection_to_j55: - 3 X_56 + Y_49_56 + Y_63_56 + Y_6_56 <= 0
#
# Max_connection_to_j56: - 2 X_57 + Y_58_57 + Y_7_57 <= 0
#
# Max_connection_to_j57: - 4 X_58 + Y_57_58 + Y_59_58 + Y_64_58 + Y_7_58 <= 0
#
# Max_connection_to_j58: - 2 X_59 + Y_58_59 + Y_64_59 <= 0
#
# Max_connection_to_j59: - 6 X_60 + Y_3_60 + Y_55_60 + Y_65_60 + Y_66_60
#  + Y_68_60 + Y_8_60 <= 0
#
# Max_connection_to_j61: - 3 X_62 + Y_65_62 + Y_67_62 + Y_72_62 <= 0
#
# Max_connection_to_j62: - 3 X_63 + Y_12_63 + Y_56_63 + Y_64_63 <= 0
#
# Max_connection_to_j63: - 4 X_64 + Y_17_64 + Y_58_64 + Y_59_64 + Y_63_64 <= 0
#
# Max_connection_to_j64: - 4 X_65 + Y_60_65 + Y_62_65 + Y_67_65 + Y_68_65 <= 0
#
# Max_connection_to_j65: - 2 X_66 + Y_60_66 + Y_8_66 <= 0
#
# Max_connection_to_j66: - 2 X_67 + Y_62_67 + Y_65_67 <= 0
#
# Max_connection_to_j67: - 3 X_68 + Y_60_68 + Y_65_68 + Y_8_68 <= 0
#
# Max_connection_to_j69: - 2 X_70 + Y_71_70 + Y_72_70 <= 0
#
# Max_connection_to_j70: - 2 X_71 + Y_70_71 + Y_96_71 <= 0
#
# Max_connection_to_j71: - 2 X_72 + Y_62_72 + Y_70_72 <= 0
#
# Max_connection_to_j72: - 3 X_73 + Y_12_73 + Y_18_73 + Y_75_73 <= 0
#
# Max_connection_to_j73: - X_74 + Y_91_74 <= 0
#
# Max_connection_to_j74: - 5 X_75 + Y_15_75 + Y_18_75 + Y_23_75 + Y_27_75
#  + Y_73_75 <= 0
#
# Max_connection_to_j75: - 8 X_76 + Y_16_76 + Y_20_76 + Y_29_76 + Y_31_76
#  + Y_36_76 + Y_37_76 + Y_77_76 + Y_78_76 <= 0
#
# Max_connection_to_j76: - 3 X_77 + Y_25_77 + Y_76_77 + Y_78_77 <= 0
#
# Max_connection_to_j77: - 5 X_78 + Y_25_78 + Y_36_78 + Y_76_78 + Y_77_78
#  + Y_79_78 <= 0
#
# Max_connection_to_j78: - 8 X_79 + Y_36_79 + Y_37_79 + Y_40_79 + Y_78_79
#  + Y_81_79 + Y_82_79 + Y_84_79 + Y_86_79 <= 0
#
# Max_connection_to_j79: - 3 X_80 + Y_39_80 + Y_83_80 + Y_98_80 <= 0
#
# Max_connection_to_j80: - 3 X_81 + Y_79_81 + Y_84_81 + Y_86_81 <= 0
#
# Max_connection_to_j81: - 4 X_82 + Y_33_82 + Y_35_82 + Y_37_82 + Y_79_82 <= 0
#
# Max_connection_to_j82: - 2 X_83 + Y_39_83 + Y_80_83 <= 0
#
# Max_connection_to_j83: - 4 X_84 + Y_40_84 + Y_79_84 + Y_81_84 + Y_86_84 <= 0
#
# Max_connection_to_j84: - X_85 + Y_87_85 <= 0
#
# Max_connection_to_j85: - 5 X_86 + Y_40_86 + Y_79_86 + Y_81_86 + Y_84_86
#  + Y_88_86 <= 0
#
# Max_connection_to_j86: - X_87 + Y_85_87 <= 0
#
# Max_connection_to_j87: - 2 X_88 + Y_42_88 + Y_86_88 <= 0
#
# Max_connection_to_j88: - X_89 + Y_90_89 <= 0
#
# Max_connection_to_j89: - 2 X_90 + Y_100_90 + Y_89_90 <= 0
#
# Max_connection_to_j90: - 2 X_91 + Y_34_91 + Y_74_91 <= 0
#
# Max_connection_to_j91: - 2 X_92 + Y_93_92 + Y_94_92 <= 0
#
# Max_connection_to_j92: - X_93 + Y_92_93 <= 0
#
# Max_connection_to_j93: - X_94 + Y_92_94 <= 0
#
# Max_connection_to_j95: - 2 X_96 + Y_71_96 + Y_98_96 <= 0
#
# Max_connection_to_j96: - X_97 + Y_99_97 <= 0
#
# Max_connection_to_j97: - 3 X_98 + Y_80_98 + Y_96_98 + Y_99_98 <= 0
#
# Max_connection_to_j98: - 2 X_99 + Y_97_99 + Y_98_99 <= 0
#
# Max_connection_to_j99: - X_100 + Y_90_100 <= 0
#
# VARIABLES
# 0 <= X_1 <= 1 Integer
# 0 <= X_10 <= 1 Integer
# 0 <= X_100 <= 1 Integer
# 0 <= X_101 <= 1 Integer
# 0 <= X_102 <= 1 Integer
# 0 <= X_103 <= 1 Integer
# 0 <= X_104 <= 1 Integer
# 0 <= X_105 <= 1 Integer
# 0 <= X_106 <= 1 Integer
# 0 <= X_107 <= 1 Integer
# 0 <= X_108 <= 1 Integer
# 0 <= X_109 <= 1 Integer
# 0 <= X_11 <= 1 Integer
# 0 <= X_110 <= 1 Integer
# 0 <= X_111 <= 1 Integer
# 0 <= X_112 <= 1 Integer
# 0 <= X_113 <= 1 Integer
# 0 <= X_114 <= 1 Integer
# 0 <= X_115 <= 1 Integer
# 0 <= X_116 <= 1 Integer
# 0 <= X_117 <= 1 Integer
# 0 <= X_118 <= 1 Integer
# 0 <= X_119 <= 1 Integer
# 0 <= X_12 <= 1 Integer
# 0 <= X_120 <= 1 Integer
# 0 <= X_13 <= 1 Integer
# 0 <= X_14 <= 1 Integer
# 0 <= X_15 <= 1 Integer
# 0 <= X_16 <= 1 Integer
# 0 <= X_17 <= 1 Integer
# 0 <= X_18 <= 1 Integer
# 0 <= X_19 <= 1 Integer
# 0 <= X_2 <= 1 Integer
# 0 <= X_20 <= 1 Integer
# 0 <= X_21 <= 1 Integer
# 0 <= X_22 <= 1 Integer
# 0 <= X_23 <= 1 Integer
# 0 <= X_24 <= 1 Integer
# 0 <= X_25 <= 1 Integer
# 0 <= X_26 <= 1 Integer
# 0 <= X_27 <= 1 Integer
# 0 <= X_28 <= 1 Integer
# 0 <= X_29 <= 1 Integer
# 0 <= X_3 <= 1 Integer
# 0 <= X_30 <= 1 Integer
# 0 <= X_31 <= 1 Integer
# 0 <= X_32 <= 1 Integer
# 0 <= X_33 <= 1 Integer
# 0 <= X_34 <= 1 Integer
# 0 <= X_35 <= 1 Integer
# 0 <= X_36 <= 1 Integer
# 0 <= X_37 <= 1 Integer
# 0 <= X_38 <= 1 Integer
# 0 <= X_39 <= 1 Integer
# 0 <= X_4 <= 1 Integer
# 0 <= X_40 <= 1 Integer
# 0 <= X_41 <= 1 Integer
# 0 <= X_42 <= 1 Integer
# 0 <= X_43 <= 1 Integer
# 0 <= X_44 <= 1 Integer
# 0 <= X_45 <= 1 Integer
# 0 <= X_46 <= 1 Integer
# 0 <= X_47 <= 1 Integer
# 0 <= X_48 <= 1 Integer
# 0 <= X_49 <= 1 Integer
# 0 <= X_5 <= 1 Integer
# 0 <= X_50 <= 1 Integer
# 0 <= X_51 <= 1 Integer
# 0 <= X_52 <= 1 Integer
# 0 <= X_53 <= 1 Integer
# 0 <= X_54 <= 1 Integer
# 0 <= X_55 <= 1 Integer
# 0 <= X_56 <= 1 Integer
# 0 <= X_57 <= 1 Integer
# 0 <= X_58 <= 1 Integer
# 0 <= X_59 <= 1 Integer
# 0 <= X_6 <= 1 Integer
# 0 <= X_60 <= 1 Integer
# 0 <= X_61 <= 1 Integer
# 0 <= X_62 <= 1 Integer
# 0 <= X_63 <= 1 Integer
# 0 <= X_64 <= 1 Integer
# 0 <= X_65 <= 1 Integer
# 0 <= X_66 <= 1 Integer
# 0 <= X_67 <= 1 Integer
# 0 <= X_68 <= 1 Integer
# 0 <= X_69 <= 1 Integer
# 0 <= X_7 <= 1 Integer
# 0 <= X_70 <= 1 Integer
# 0 <= X_71 <= 1 Integer
# 0 <= X_72 <= 1 Integer
# 0 <= X_73 <= 1 Integer
# 0 <= X_74 <= 1 Integer
# 0 <= X_75 <= 1 Integer
# 0 <= X_76 <= 1 Integer
# 0 <= X_77 <= 1 Integer
# 0 <= X_78 <= 1 Integer
# 0 <= X_79 <= 1 Integer
# 0 <= X_8 <= 1 Integer
# 0 <= X_80 <= 1 Integer
# 0 <= X_81 <= 1 Integer
# 0 <= X_82 <= 1 Integer
# 0 <= X_83 <= 1 Integer
# 0 <= X_84 <= 1 Integer
# 0 <= X_85 <= 1 Integer
# 0 <= X_86 <= 1 Integer
# 0 <= X_87 <= 1 Integer
# 0 <= X_88 <= 1 Integer
# 0 <= X_89 <= 1 Integer
# 0 <= X_9 <= 1 Integer
# 0 <= X_90 <= 1 Integer
# 0 <= X_91 <= 1 Integer
# 0 <= X_92 <= 1 Integer
# 0 <= X_93 <= 1 Integer
# 0 <= X_94 <= 1 Integer
# 0 <= X_95 <= 1 Integer
# 0 <= X_96 <= 1 Integer
# 0 <= X_97 <= 1 Integer
# 0 <= X_98 <= 1 Integer
# 0 <= X_99 <= 1 Integer
# 0 <= Y_100_90 <= 1 Integer
# 0 <= Y_10_13 <= 1 Integer
# 0 <= Y_12_63 <= 1 Integer
# 0 <= Y_12_73 <= 1 Integer
# 0 <= Y_13_10 <= 1 Integer
# 0 <= Y_13_16 <= 1 Integer
# 0 <= Y_14_17 <= 1 Integer
# 0 <= Y_14_19 <= 1 Integer
# 0 <= Y_14_21 <= 1 Integer
# 0 <= Y_14_22 <= 1 Integer
# 0 <= Y_14_24 <= 1 Integer
# 0 <= Y_15_17 <= 1 Integer
# 0 <= Y_15_18 <= 1 Integer
# 0 <= Y_15_23 <= 1 Integer
# 0 <= Y_15_75 <= 1 Integer
# 0 <= Y_16_13 <= 1 Integer
# 0 <= Y_16_20 <= 1 Integer
# 0 <= Y_16_76 <= 1 Integer
# 0 <= Y_17_14 <= 1 Integer
# 0 <= Y_17_15 <= 1 Integer
# 0 <= Y_17_19 <= 1 Integer
# 0 <= Y_17_23 <= 1 Integer
# 0 <= Y_17_64 <= 1 Integer
# 0 <= Y_18_15 <= 1 Integer
# 0 <= Y_18_73 <= 1 Integer
# 0 <= Y_18_75 <= 1 Integer
# 0 <= Y_19_14 <= 1 Integer
# 0 <= Y_19_17 <= 1 Integer
# 0 <= Y_19_22 <= 1 Integer
# 0 <= Y_19_23 <= 1 Integer
# 0 <= Y_20_16 <= 1 Integer
# 0 <= Y_20_76 <= 1 Integer
# 0 <= Y_21_14 <= 1 Integer
# 0 <= Y_22_14 <= 1 Integer
# 0 <= Y_22_19 <= 1 Integer
# 0 <= Y_22_23 <= 1 Integer
# 0 <= Y_22_24 <= 1 Integer
# 0 <= Y_23_15 <= 1 Integer
# 0 <= Y_23_17 <= 1 Integer
# 0 <= Y_23_19 <= 1 Integer
# 0 <= Y_23_22 <= 1 Integer
# 0 <= Y_23_26 <= 1 Integer
# 0 <= Y_23_27 <= 1 Integer
# 0 <= Y_23_75 <= 1 Integer
# 0 <= Y_24_14 <= 1 Integer
# 0 <= Y_24_22 <= 1 Integer
# 0 <= Y_25_77 <= 1 Integer
# 0 <= Y_25_78 <= 1 Integer
# 0 <= Y_26_23 <= 1 Integer
# 0 <= Y_26_27 <= 1 Integer
# 0 <= Y_27_23 <= 1 Integer
# 0 <= Y_27_26 <= 1 Integer
# 0 <= Y_27_28 <= 1 Integer
# 0 <= Y_27_32 <= 1 Integer
# 0 <= Y_27_75 <= 1 Integer
# 0 <= Y_28_27 <= 1 Integer
# 0 <= Y_28_31 <= 1 Integer
# 0 <= Y_28_32 <= 1 Integer
# 0 <= Y_28_33 <= 1 Integer
# 0 <= Y_29_31 <= 1 Integer
# 0 <= Y_29_76 <= 1 Integer
# 0 <= Y_2_51 <= 1 Integer
# 0 <= Y_31_28 <= 1 Integer
# 0 <= Y_31_29 <= 1 Integer
# 0 <= Y_31_33 <= 1 Integer
# 0 <= Y_31_35 <= 1 Integer
# 0 <= Y_31_37 <= 1 Integer
# 0 <= Y_31_76 <= 1 Integer
# 0 <= Y_32_27 <= 1 Integer
# 0 <= Y_32_28 <= 1 Integer
# 0 <= Y_32_33 <= 1 Integer
# 0 <= Y_32_38 <= 1 Integer
# 0 <= Y_33_28 <= 1 Integer
# 0 <= Y_33_31 <= 1 Integer
# 0 <= Y_33_32 <= 1 Integer
# 0 <= Y_33_35 <= 1 Integer
# 0 <= Y_33_38 <= 1 Integer
# 0 <= Y_33_82 <= 1 Integer
# 0 <= Y_34_91 <= 1 Integer
# 0 <= Y_35_31 <= 1 Integer
# 0 <= Y_35_33 <= 1 Integer
# 0 <= Y_35_37 <= 1 Integer
# 0 <= Y_35_82 <= 1 Integer
# 0 <= Y_36_37 <= 1 Integer
# 0 <= Y_36_76 <= 1 Integer
# 0 <= Y_36_78 <= 1 Integer
# 0 <= Y_36_79 <= 1 Integer
# 0 <= Y_37_31 <= 1 Integer
# 0 <= Y_37_35 <= 1 Integer
# 0 <= Y_37_36 <= 1 Integer
# 0 <= Y_37_76 <= 1 Integer
# 0 <= Y_37_79 <= 1 Integer
# 0 <= Y_37_82 <= 1 Integer
# 0 <= Y_38_32 <= 1 Integer
# 0 <= Y_38_33 <= 1 Integer
# 0 <= Y_39_80 <= 1 Integer
# 0 <= Y_39_83 <= 1 Integer
# 0 <= Y_3_50 <= 1 Integer
# 0 <= Y_3_55 <= 1 Integer
# 0 <= Y_3_60 <= 1 Integer
# 0 <= Y_40_79 <= 1 Integer
# 0 <= Y_40_84 <= 1 Integer
# 0 <= Y_40_86 <= 1 Integer
# 0 <= Y_42_88 <= 1 Integer
# 0 <= Y_45_47 <= 1 Integer
# 0 <= Y_45_49 <= 1 Integer
# 0 <= Y_46_47 <= 1 Integer
# 0 <= Y_46_48 <= 1 Integer
# 0 <= Y_47_45 <= 1 Integer
# 0 <= Y_47_46 <= 1 Integer
# 0 <= Y_47_48 <= 1 Integer
# 0 <= Y_47_6 <= 1 Integer
# 0 <= Y_48_4 <= 1 Integer
# 0 <= Y_48_46 <= 1 Integer
# 0 <= Y_48_47 <= 1 Integer
# 0 <= Y_49_45 <= 1 Integer
# 0 <= Y_49_51 <= 1 Integer
# 0 <= Y_49_56 <= 1 Integer
# 0 <= Y_4_48 <= 1 Integer
# 0 <= Y_4_5 <= 1 Integer
# 0 <= Y_4_6 <= 1 Integer
# 0 <= Y_50_3 <= 1 Integer
# 0 <= Y_50_55 <= 1 Integer
# 0 <= Y_51_2 <= 1 Integer
# 0 <= Y_51_49 <= 1 Integer
# 0 <= Y_53_54 <= 1 Integer
# 0 <= Y_54_5 <= 1 Integer
# 0 <= Y_54_53 <= 1 Integer
# 0 <= Y_55_3 <= 1 Integer
# 0 <= Y_55_50 <= 1 Integer
# 0 <= Y_55_60 <= 1 Integer
# 0 <= Y_56_49 <= 1 Integer
# 0 <= Y_56_6 <= 1 Integer
# 0 <= Y_56_63 <= 1 Integer
# 0 <= Y_57_58 <= 1 Integer
# 0 <= Y_57_7 <= 1 Integer
# 0 <= Y_58_57 <= 1 Integer
# 0 <= Y_58_59 <= 1 Integer
# 0 <= Y_58_64 <= 1 Integer
# 0 <= Y_58_7 <= 1 Integer
# 0 <= Y_59_58 <= 1 Integer
# 0 <= Y_59_64 <= 1 Integer
# 0 <= Y_5_4 <= 1 Integer
# 0 <= Y_5_54 <= 1 Integer
# 0 <= Y_60_3 <= 1 Integer
# 0 <= Y_60_55 <= 1 Integer
# 0 <= Y_60_65 <= 1 Integer
# 0 <= Y_60_66 <= 1 Integer
# 0 <= Y_60_68 <= 1 Integer
# 0 <= Y_60_8 <= 1 Integer
# 0 <= Y_62_65 <= 1 Integer
# 0 <= Y_62_67 <= 1 Integer
# 0 <= Y_62_72 <= 1 Integer
# 0 <= Y_63_12 <= 1 Integer
# 0 <= Y_63_56 <= 1 Integer
# 0 <= Y_63_64 <= 1 Integer
# 0 <= Y_64_17 <= 1 Integer
# 0 <= Y_64_58 <= 1 Integer
# 0 <= Y_64_59 <= 1 Integer
# 0 <= Y_64_63 <= 1 Integer
# 0 <= Y_65_60 <= 1 Integer
# 0 <= Y_65_62 <= 1 Integer
# 0 <= Y_65_67 <= 1 Integer
# 0 <= Y_65_68 <= 1 Integer
# 0 <= Y_66_60 <= 1 Integer
# 0 <= Y_66_8 <= 1 Integer
# 0 <= Y_67_62 <= 1 Integer
# 0 <= Y_67_65 <= 1 Integer
# 0 <= Y_68_60 <= 1 Integer
# 0 <= Y_68_65 <= 1 Integer
# 0 <= Y_68_8 <= 1 Integer
# 0 <= Y_6_4 <= 1 Integer
# 0 <= Y_6_47 <= 1 Integer
# 0 <= Y_6_56 <= 1 Integer
# 0 <= Y_70_71 <= 1 Integer
# 0 <= Y_70_72 <= 1 Integer
# 0 <= Y_71_70 <= 1 Integer
# 0 <= Y_71_96 <= 1 Integer
# 0 <= Y_72_62 <= 1 Integer
# 0 <= Y_72_70 <= 1 Integer
# 0 <= Y_73_12 <= 1 Integer
# 0 <= Y_73_18 <= 1 Integer
# 0 <= Y_73_75 <= 1 Integer
# 0 <= Y_74_91 <= 1 Integer
# 0 <= Y_75_15 <= 1 Integer
# 0 <= Y_75_18 <= 1 Integer
# 0 <= Y_75_23 <= 1 Integer
# 0 <= Y_75_27 <= 1 Integer
# 0 <= Y_75_73 <= 1 Integer
# 0 <= Y_76_16 <= 1 Integer
# 0 <= Y_76_20 <= 1 Integer
# 0 <= Y_76_29 <= 1 Integer
# 0 <= Y_76_31 <= 1 Integer
# 0 <= Y_76_36 <= 1 Integer
# 0 <= Y_76_37 <= 1 Integer
# 0 <= Y_76_77 <= 1 Integer
# 0 <= Y_76_78 <= 1 Integer
# 0 <= Y_77_25 <= 1 Integer
# 0 <= Y_77_76 <= 1 Integer
# 0 <= Y_77_78 <= 1 Integer
# 0 <= Y_78_25 <= 1 Integer
# 0 <= Y_78_36 <= 1 Integer
# 0 <= Y_78_76 <= 1 Integer
# 0 <= Y_78_77 <= 1 Integer
# 0 <= Y_78_79 <= 1 Integer
# 0 <= Y_79_36 <= 1 Integer
# 0 <= Y_79_37 <= 1 Integer
# 0 <= Y_79_40 <= 1 Integer
# 0 <= Y_79_78 <= 1 Integer
# 0 <= Y_79_81 <= 1 Integer
# 0 <= Y_79_82 <= 1 Integer
# 0 <= Y_79_84 <= 1 Integer
# 0 <= Y_79_86 <= 1 Integer
# 0 <= Y_7_57 <= 1 Integer
# 0 <= Y_7_58 <= 1 Integer
# 0 <= Y_80_39 <= 1 Integer
# 0 <= Y_80_83 <= 1 Integer
# 0 <= Y_80_98 <= 1 Integer
# 0 <= Y_81_79 <= 1 Integer
# 0 <= Y_81_84 <= 1 Integer
# 0 <= Y_81_86 <= 1 Integer
# 0 <= Y_82_33 <= 1 Integer
# 0 <= Y_82_35 <= 1 Integer
# 0 <= Y_82_37 <= 1 Integer
# 0 <= Y_82_79 <= 1 Integer
# 0 <= Y_83_39 <= 1 Integer
# 0 <= Y_83_80 <= 1 Integer
# 0 <= Y_84_40 <= 1 Integer
# 0 <= Y_84_79 <= 1 Integer
# 0 <= Y_84_81 <= 1 Integer
# 0 <= Y_84_86 <= 1 Integer
# 0 <= Y_85_87 <= 1 Integer
# 0 <= Y_86_40 <= 1 Integer
# 0 <= Y_86_79 <= 1 Integer
# 0 <= Y_86_81 <= 1 Integer
# 0 <= Y_86_84 <= 1 Integer
# 0 <= Y_86_88 <= 1 Integer
# 0 <= Y_87_85 <= 1 Integer
# 0 <= Y_88_42 <= 1 Integer
# 0 <= Y_88_86 <= 1 Integer
# 0 <= Y_89_90 <= 1 Integer
# 0 <= Y_8_60 <= 1 Integer
# 0 <= Y_8_66 <= 1 Integer
# 0 <= Y_8_68 <= 1 Integer
# 0 <= Y_90_100 <= 1 Integer
# 0 <= Y_90_89 <= 1 Integer
# 0 <= Y_91_34 <= 1 Integer
# 0 <= Y_91_74 <= 1 Integer
# 0 <= Y_92_93 <= 1 Integer
# 0 <= Y_92_94 <= 1 Integer
# 0 <= Y_93_92 <= 1 Integer
# 0 <= Y_94_92 <= 1 Integer
# 0 <= Y_96_71 <= 1 Integer
# 0 <= Y_96_98 <= 1 Integer
# 0 <= Y_97_99 <= 1 Integer
# 0 <= Y_98_80 <= 1 Integer
# 0 <= Y_98_96 <= 1 Integer
# 0 <= Y_98_99 <= 1 Integer
# 0 <= Y_99_97 <= 1 Integer
# 0 <= Y_99_98 <= 1 Integer

# %%
## Constraint 3: Max 1 connection from i
#### SUM Yij (j e Ii) <= Xi 

count = [] 
for i in range(n_parcels):
    for k in range(len(adj1)): 
        if adj1[k] == parcel[i]:
            count.append(k) 
            #print(count)
            #print(adj2[k])
            #print(parcel[j])
    if count != []:
        #print(lpSum(Yij_allocation[count[i]][count[i]] for i in range(len(count)) ) <= X_allocation[i])
        model += lpSum(Yij_allocation[count[j]][count[j]] for j in range(len(count))) <= X_allocation[i], "Max connection from i" + str(i)
    count = []

# %%
## Constraint 4: Number of arcs must be less or equal to the number of nodes 
model += lpSum(Yij_allocation[j][j] for j in range(len(Yij_allocation))) == lpSum(X_allocation[i] for i in range(0,120))-1, "Number of arcs"

# %%
## Constraint 5: Number of arcs must be less or equal to the number of nodes 
### Zij >= Wi + 1 - m(1-Yij) for all i, j adjacent, i != j 

for i in range(n_parcels):
    for k in range(len(adj1)):
        if adj1[k] == i :
            count.append(k)
    if count != []:
        for j in range(len(count)):
            Zij_allocation[count[j]] >= W_allocation[i-1] + 1 - m*(1-Yij_allocation[count[j]][count[j]])
            model += Zij_allocation[count[j]] >= W_allocation[i-1] + 1 - m*(1-Yij_allocation[count[j]][count[j]]), "Tail function" + str(i) + '_'+ str(j)
    count = []

# %%
## Constraint 6: Cycle breaking constraint 
### Wj >= SUM (ieIj) Zij for all j 

count = []
for i in range(n_parcels):
    for j in range(len(adj2)):
        if adj2[j] == i: 
            count.append(j)
    if count != []:
        W_allocation[i-1] == lpSum(Zij_allocation[count[k]] for k in range(len(count)) )
        model += W_allocation[i-1] == lpSum(Zij_allocation[count[k]] for k in range(len(count)) ), "Loop_break function" + str(i)
    count = []

# %%
## Consraint 7: Ensure that zij is minimal 
### Zij <= m*Yij 
count = []
ab = 0 
for i in range(n_parcels): 
    for j in range(len(adj2)): 
        if adj2[j] == i: 
            count.append(j)
    if count != []: 
        for k in range(len(count)): 
            Zij_allocation[count[k]] <= m*Yij_allocation[count[k]][count[k]]
            ab = ab+1
            model += Zij_allocation[count[k]] <= m*Yij_allocation[count[k]][count[k]], "Ensure_min_Zij" +  str(ab)
            
    count = []

# %%
## Constraint 8: Ensure that zij is minimal 
### Zij <= Wi+1 
count = []
ab = 0 
a = 0 
for i in range(n_parcels): 
    for j in range(len(adj1)): 
        if adj1[j] == i: 
            count.append(j)
    if count != []:
        a = a + 1
        for k in range(len(count)): 
            Zij_allocation[count[k]] <= W_allocation[i-1]+1
            ab = ab+1
            model += Zij_allocation[count[k]] <= W_allocation[i-1]+1, "Ensure_min_Zij_2" + str(ab)
            
    count = []

# %%
#core parcel : parcel 10, 32.031, 0.00
model += X_allocation[22] == 1, "Core parcel"

# %%
# Objective function 

obj_func = lpSum(X_allocation*area_matrix)
model += obj_func
#print(model)

# %%
print(model)
# Out:
# Lab4:
# MAXIMIZE
# 37.519*X_1 + 32.031*X_10 + 12.917*X_100 + 2.274*X_101 + 22.859*X_102 + 11.8*X_103 + 23.171*X_104 + 19.059*X_105 + 23.821*X_106 + 56.021*X_107 + 36.747*X_108 + 14.906*X_109 + 1.359*X_11 + 19.224*X_110 + 25.747*X_111 + 26.763*X_112 + 22.905*X_113 + 32.037*X_114 + 20.321*X_115 + 11.12*X_116 + 18.73*X_117 + 14.141*X_118 + 6.866*X_119 + 12.181*X_12 + 18.185*X_120 + 25.38*X_13 + 37.921*X_14 + 7.672*X_15 + 34.06*X_16 + 12.022*X_17 + 10.932*X_18 + 5.001*X_19 + 6.62*X_2 + 30.481*X_20 + 9.311*X_21 + 3.005*X_22 + 8.648*X_23 + 3.298*X_24 + 20.731*X_25 + 2.527*X_26 + 5.738*X_27 + 3.198*X_28 + 6.45*X_29 + 24.126*X_3 + 7.208*X_30 + 26.188*X_31 + 14.007*X_32 + 11.412*X_33 + 18.264*X_34 + 10.363*X_35 + 9.684*X_36 + 18.946*X_37 + 13.08*X_38 + 1.845*X_39 + 5.379*X_4 + 1.74*X_40 + 1.689*X_41 + 6.633*X_42 + 59.836*X_43 + 42.97*X_44 + 21.631*X_45 + 29.62*X_46 + 30.276*X_47 + 14.401*X_48 + 42.272*X_49 + 12.252*X_5 + 58.92*X_50 + 9.061*X_51 + 18.086*X_52 + 18.761*X_53 + 4.151*X_54 + 16.556*X_55 + 33.789*X_56 + 6.967*X_57 + 17.77*X_58 + 4.945*X_59 + 4.839*X_6 + 17.988*X_60 + 7.124*X_61 + 59.428*X_62 + 15.135*X_63 + 24.127*X_64 + 16.251*X_65 + 8.309*X_66 + 5.004*X_67 + 12.759*X_68 + 2.953*X_69 + 30.92*X_7 + 9.608*X_70 + 6.601*X_71 + 13.236*X_72 + 6.574*X_73 + 30.96*X_74 + 26.996*X_75 + 39.773*X_76 + 8.892*X_77 + 30.221*X_78 + 52.556*X_79 + 7.555*X_8 + 19.217*X_80 + 28.321*X_81 + 24.191*X_82 + 52.908*X_83 + 8.3*X_84 + 18.451*X_85 + 31.527*X_86 + 20.019*X_87 + 12.712*X_88 + 12.263*X_89 + 2.043*X_9 + 25.271*X_90 + 28.837*X_91 + 29.834*X_92 + 16.684*X_93 + 31.679*X_94 + 7.387*X_95 + 47.906*X_96 + 22.265*X_97 + 27.696*X_98 + 13.41*X_99 + 0.0
# SUBJECT TO
# Budget_constraint: 337671 X_1 + 38751 X_100 + 6822 X_101 + 22859 X_102
#  + 177000 X_103 + 46342 X_104 + 266826 X_105 + 119105 X_106 + 896336 X_107
#  + 257229 X_108 + 44718 X_109 + 5436 X_11 + 19224 X_110 + 25747 X_111
#  + 26763 X_112 + 68715 X_113 + 416481 X_114 + 40642 X_115 + 100080 X_116
#  + 74920 X_117 + 70705 X_118 + 20598 X_119 + 182715 X_12 + 309145 X_120
#  + 152280 X_13 + 37921 X_14 + 107408 X_15 + 204360 X_16 + 180330 X_17
#  + 163980 X_18 + 25005 X_19 + 19860 X_2 + 213367 X_20 + 46555 X_21
#  + 15025 X_22 + 43240 X_23 + 16490 X_24 + 849971 X_25 + 12635 X_26
#  + 40166 X_27 + 47970 X_28 + 19350 X_29 + 48252 X_3 + 28832 X_30 + 104752 X_31
#  + 98049 X_32 + 22824 X_33 + 127848 X_34 + 155445 X_35 + 48420 X_36
#  + 113676 X_37 + 26160 X_38 + 11070 X_39 + 80685 X_4 + 13920 X_40 + 25335 X_41
#  + 19899 X_42 + 837704 X_43 + 128910 X_44 + 497513 X_45 + 118480 X_46
#  + 90828 X_47 + 72005 X_48 + 253632 X_49 + 49008 X_5 + 235680 X_50
#  + 45305 X_51 + 72344 X_52 + 112566 X_53 + 20755 X_54 + 66224 X_55
#  + 202734 X_56 + 62703 X_57 + 17770 X_58 + 79120 X_59 + 14517 X_6 + 71952 X_60
#  + 14248 X_61 + 415996 X_62 + 242160 X_63 + 361905 X_64 + 65004 X_65
#  + 33236 X_66 + 20016 X_67 + 51036 X_68 + 14765 X_69 + 185520 X_7 + 48040 X_70
#  + 99015 X_71 + 66180 X_72 + 98610 X_73 + 154800 X_74 + 404940 X_75
#  + 596595 X_76 + 26676 X_77 + 151105 X_78 + 210224 X_79 + 30220 X_8
#  + 288255 X_80 + 84963 X_81 + 411247 X_82 + 52908 X_83 + 124500 X_84
#  + 276765 X_85 + 31527 X_86 + 60057 X_87 + 63560 X_88 + 36789 X_89 + 8172 X_9
#  + 25271 X_90 + 57674 X_91 + 59668 X_92 + 116788 X_93 + 221753 X_94
#  + 96031 X_95 + 47906 X_96 + 333975 X_97 + 83088 X_98 + 53640 X_99 <= 1000000
#
# Max_connection_to_j1: - X_2 + Y_51_2 <= 0
#
# Max_connection_to_j2: - 3 X_3 + Y_50_3 + Y_55_3 + Y_60_3 <= 0
#
# Max_connection_to_j3: - 3 X_4 + Y_48_4 + Y_5_4 + Y_6_4 <= 0
#
# Max_connection_to_j4: - 2 X_5 + Y_4_5 + Y_54_5 <= 0
#
# Max_connection_to_j5: - 3 X_6 + Y_47_6 + Y_4_6 + Y_56_6 <= 0
#
# Max_connection_to_j6: - 2 X_7 + Y_57_7 + Y_58_7 <= 0
#
# Max_connection_to_j7: - 3 X_8 + Y_60_8 + Y_66_8 + Y_68_8 <= 0
#
# Max_connection_to_j9: - X_10 + Y_13_10 <= 0
#
# Max_connection_to_j11: - 2 X_12 + Y_63_12 + Y_73_12 <= 0
#
# Max_connection_to_j12: - 2 X_13 + Y_10_13 + Y_16_13 <= 0
#
# Max_connection_to_j13: - 5 X_14 + Y_17_14 + Y_19_14 + Y_21_14 + Y_22_14
#  + Y_24_14 <= 0
#
# Max_connection_to_j14: - 4 X_15 + Y_17_15 + Y_18_15 + Y_23_15 + Y_75_15 <= 0
#
# Max_connection_to_j15: - 3 X_16 + Y_13_16 + Y_20_16 + Y_76_16 <= 0
#
# Max_connection_to_j16: - 5 X_17 + Y_14_17 + Y_15_17 + Y_19_17 + Y_23_17
#  + Y_64_17 <= 0
#
# Max_connection_to_j17: - 3 X_18 + Y_15_18 + Y_73_18 + Y_75_18 <= 0
#
# Max_connection_to_j18: - 4 X_19 + Y_14_19 + Y_17_19 + Y_22_19 + Y_23_19 <= 0
#
# Max_connection_to_j19: - 2 X_20 + Y_16_20 + Y_76_20 <= 0
#
# Max_connection_to_j20: - X_21 + Y_14_21 <= 0
#
# Max_connection_to_j21: - 4 X_22 + Y_14_22 + Y_19_22 + Y_23_22 + Y_24_22 <= 0
#
# Max_connection_to_j22: - 7 X_23 + Y_15_23 + Y_17_23 + Y_19_23 + Y_22_23
#  + Y_26_23 + Y_27_23 + Y_75_23 <= 0
#
# Max_connection_to_j23: - 2 X_24 + Y_14_24 + Y_22_24 <= 0
#
# Max_connection_to_j24: - 2 X_25 + Y_77_25 + Y_78_25 <= 0
#
# Max_connection_to_j25: - 2 X_26 + Y_23_26 + Y_27_26 <= 0
#
# Max_connection_to_j26: - 5 X_27 + Y_23_27 + Y_26_27 + Y_28_27 + Y_32_27
#  + Y_75_27 <= 0
#
# Max_connection_to_j27: - 4 X_28 + Y_27_28 + Y_31_28 + Y_32_28 + Y_33_28 <= 0
#
# Max_connection_to_j28: - 2 X_29 + Y_31_29 + Y_76_29 <= 0
#
# Max_connection_to_j30: - 6 X_31 + Y_28_31 + Y_29_31 + Y_33_31 + Y_35_31
#  + Y_37_31 + Y_76_31 <= 0
#
# Max_connection_to_j31: - 4 X_32 + Y_27_32 + Y_28_32 + Y_33_32 + Y_38_32 <= 0
#
# Max_connection_to_j32: - 6 X_33 + Y_28_33 + Y_31_33 + Y_32_33 + Y_35_33
#  + Y_38_33 + Y_82_33 <= 0
#
# Max_connection_to_j33: - X_34 + Y_91_34 <= 0
#
# Max_connection_to_j34: - 4 X_35 + Y_31_35 + Y_33_35 + Y_37_35 + Y_82_35 <= 0
#
# Max_connection_to_j35: - 4 X_36 + Y_37_36 + Y_76_36 + Y_78_36 + Y_79_36 <= 0
#
# Max_connection_to_j36: - 6 X_37 + Y_31_37 + Y_35_37 + Y_36_37 + Y_76_37
#  + Y_79_37 + Y_82_37 <= 0
#
# Max_connection_to_j37: - 2 X_38 + Y_32_38 + Y_33_38 <= 0
#
# Max_connection_to_j38: - 2 X_39 + Y_80_39 + Y_83_39 <= 0
#
# Max_connection_to_j39: - 3 X_40 + Y_79_40 + Y_84_40 + Y_86_40 <= 0
#
# Max_connection_to_j41: - X_42 + Y_88_42 <= 0
#
# Max_connection_to_j44: - 2 X_45 + Y_47_45 + Y_49_45 <= 0
#
# Max_connection_to_j45: - 2 X_46 + Y_47_46 + Y_48_46 <= 0
#
# Max_connection_to_j46: - 4 X_47 + Y_45_47 + Y_46_47 + Y_48_47 + Y_6_47 <= 0
#
# Max_connection_to_j47: - 3 X_48 + Y_46_48 + Y_47_48 + Y_4_48 <= 0
#
# Max_connection_to_j48: - 3 X_49 + Y_45_49 + Y_51_49 + Y_56_49 <= 0
#
# Max_connection_to_j49: - 2 X_50 + Y_3_50 + Y_55_50 <= 0
#
# Max_connection_to_j50: - 2 X_51 + Y_2_51 + Y_49_51 <= 0
#
# Max_connection_to_j52: - X_53 + Y_54_53 <= 0
#
# Max_connection_to_j53: - 2 X_54 + Y_53_54 + Y_5_54 <= 0
#
# Max_connection_to_j54: - 3 X_55 + Y_3_55 + Y_50_55 + Y_60_55 <= 0
#
# Max_connection_to_j55: - 3 X_56 + Y_49_56 + Y_63_56 + Y_6_56 <= 0
#
# Max_connection_to_j56: - 2 X_57 + Y_58_57 + Y_7_57 <= 0
#
# Max_connection_to_j57: - 4 X_58 + Y_57_58 + Y_59_58 + Y_64_58 + Y_7_58 <= 0
#
# Max_connection_to_j58: - 2 X_59 + Y_58_59 + Y_64_59 <= 0
#
# Max_connection_to_j59: - 6 X_60 + Y_3_60 + Y_55_60 + Y_65_60 + Y_66_60
#  + Y_68_60 + Y_8_60 <= 0
#
# Max_connection_to_j61: - 3 X_62 + Y_65_62 + Y_67_62 + Y_72_62 <= 0
#
# Max_connection_to_j62: - 3 X_63 + Y_12_63 + Y_56_63 + Y_64_63 <= 0
#
# Max_connection_to_j63: - 4 X_64 + Y_17_64 + Y_58_64 + Y_59_64 + Y_63_64 <= 0
#
# Max_connection_to_j64: - 4 X_65 + Y_60_65 + Y_62_65 + Y_67_65 + Y_68_65 <= 0
#
# Max_connection_to_j65: - 2 X_66 + Y_60_66 + Y_8_66 <= 0
#
# Max_connection_to_j66: - 2 X_67 + Y_62_67 + Y_65_67 <= 0
#
# Max_connection_to_j67: - 3 X_68 + Y_60_68 + Y_65_68 + Y_8_68 <= 0
#
# Max_connection_to_j69: - 2 X_70 + Y_71_70 + Y_72_70 <= 0
#
# Max_connection_to_j70: - 2 X_71 + Y_70_71 + Y_96_71 <= 0
#
# Max_connection_to_j71: - 2 X_72 + Y_62_72 + Y_70_72 <= 0
#
# Max_connection_to_j72: - 3 X_73 + Y_12_73 + Y_18_73 + Y_75_73 <= 0
#
# Max_connection_to_j73: - X_74 + Y_91_74 <= 0
#
# Max_connection_to_j74: - 5 X_75 + Y_15_75 + Y_18_75 + Y_23_75 + Y_27_75
#  + Y_73_75 <= 0
#
# Max_connection_to_j75: - 8 X_76 + Y_16_76 + Y_20_76 + Y_29_76 + Y_31_76
#  + Y_36_76 + Y_37_76 + Y_77_76 + Y_78_76 <= 0
#
# Max_connection_to_j76: - 3 X_77 + Y_25_77 + Y_76_77 + Y_78_77 <= 0
#
# Max_connection_to_j77: - 5 X_78 + Y_25_78 + Y_36_78 + Y_76_78 + Y_77_78
#  + Y_79_78 <= 0
#
# Max_connection_to_j78: - 8 X_79 + Y_36_79 + Y_37_79 + Y_40_79 + Y_78_79
#  + Y_81_79 + Y_82_79 + Y_84_79 + Y_86_79 <= 0
#
# Max_connection_to_j79: - 3 X_80 + Y_39_80 + Y_83_80 + Y_98_80 <= 0
#
# Max_connection_to_j80: - 3 X_81 + Y_79_81 + Y_84_81 + Y_86_81 <= 0
#
# Max_connection_to_j81: - 4 X_82 + Y_33_82 + Y_35_82 + Y_37_82 + Y_79_82 <= 0
#
# Max_connection_to_j82: - 2 X_83 + Y_39_83 + Y_80_83 <= 0
#
# Max_connection_to_j83: - 4 X_84 + Y_40_84 + Y_79_84 + Y_81_84 + Y_86_84 <= 0
#
# Max_connection_to_j84: - X_85 + Y_87_85 <= 0
#
# Max_connection_to_j85: - 5 X_86 + Y_40_86 + Y_79_86 + Y_81_86 + Y_84_86
#  + Y_88_86 <= 0
#
# Max_connection_to_j86: - X_87 + Y_85_87 <= 0
#
# Max_connection_to_j87: - 2 X_88 + Y_42_88 + Y_86_88 <= 0
#
# Max_connection_to_j88: - X_89 + Y_90_89 <= 0
#
# Max_connection_to_j89: - 2 X_90 + Y_100_90 + Y_89_90 <= 0
#
# Max_connection_to_j90: - 2 X_91 + Y_34_91 + Y_74_91 <= 0
#
# Max_connection_to_j91: - 2 X_92 + Y_93_92 + Y_94_92 <= 0
#
# Max_connection_to_j92: - X_93 + Y_92_93 <= 0
#
# Max_connection_to_j93: - X_94 + Y_92_94 <= 0
#
# Max_connection_to_j95: - 2 X_96 + Y_71_96 + Y_98_96 <= 0
#
# Max_connection_to_j96: - X_97 + Y_99_97 <= 0
#
# Max_connection_to_j97: - 3 X_98 + Y_80_98 + Y_96_98 + Y_99_98 <= 0
#
# Max_connection_to_j98: - 2 X_99 + Y_97_99 + Y_98_99 <= 0
#
# Max_connection_to_j99: - X_100 + Y_90_100 <= 0
#
# Max_connection_from_i1: - X_2 + Y_2_51 <= 0
#
# Max_connection_from_i2: - X_3 + Y_3_50 + Y_3_55 + Y_3_60 <= 0
#
# Max_connection_from_i3: - X_4 + Y_4_48 + Y_4_5 + Y_4_6 <= 0
#
# Max_connection_from_i4: - X_5 + Y_5_4 + Y_5_54 <= 0
#
# Max_connection_from_i5: - X_6 + Y_6_4 + Y_6_47 + Y_6_56 <= 0
#
# Max_connection_from_i6: - X_7 + Y_7_57 + Y_7_58 <= 0
#
# Max_connection_from_i7: - X_8 + Y_8_60 + Y_8_66 + Y_8_68 <= 0
#
# Max_connection_from_i9: - X_10 + Y_10_13 <= 0
#
# Max_connection_from_i11: - X_12 + Y_12_63 + Y_12_73 <= 0
#
# Max_connection_from_i12: - X_13 + Y_13_10 + Y_13_16 <= 0
#
# Max_connection_from_i13: - X_14 + Y_14_17 + Y_14_19 + Y_14_21 + Y_14_22
#  + Y_14_24 <= 0
#
# Max_connection_from_i14: - X_15 + Y_15_17 + Y_15_18 + Y_15_23 + Y_15_75 <= 0
#
# Max_connection_from_i15: - X_16 + Y_16_13 + Y_16_20 + Y_16_76 <= 0
#
# Max_connection_from_i16: - X_17 + Y_17_14 + Y_17_15 + Y_17_19 + Y_17_23
#  + Y_17_64 <= 0
#
# Max_connection_from_i17: - X_18 + Y_18_15 + Y_18_73 + Y_18_75 <= 0
#
# Max_connection_from_i18: - X_19 + Y_19_14 + Y_19_17 + Y_19_22 + Y_19_23 <= 0
#
# Max_connection_from_i19: - X_20 + Y_20_16 + Y_20_76 <= 0
#
# Max_connection_from_i20: - X_21 + Y_21_14 <= 0
#
# Max_connection_from_i21: - X_22 + Y_22_14 + Y_22_19 + Y_22_23 + Y_22_24 <= 0
#
# Max_connection_from_i22: - X_23 + Y_23_15 + Y_23_17 + Y_23_19 + Y_23_22
#  + Y_23_26 + Y_23_27 + Y_23_75 <= 0
#
# Max_connection_from_i23: - X_24 + Y_24_14 + Y_24_22 <= 0
#
# Max_connection_from_i24: - X_25 + Y_25_77 + Y_25_78 <= 0
#
# Max_connection_from_i25: - X_26 + Y_26_23 + Y_26_27 <= 0
#
# Max_connection_from_i26: - X_27 + Y_27_23 + Y_27_26 + Y_27_28 + Y_27_32
#  + Y_27_75 <= 0
#
# Max_connection_from_i27: - X_28 + Y_28_27 + Y_28_31 + Y_28_32 + Y_28_33 <= 0
#
# Max_connection_from_i28: - X_29 + Y_29_31 + Y_29_76 <= 0
#
# Max_connection_from_i30: - X_31 + Y_31_28 + Y_31_29 + Y_31_33 + Y_31_35
#  + Y_31_37 + Y_31_76 <= 0
#
# Max_connection_from_i31: - X_32 + Y_32_27 + Y_32_28 + Y_32_33 + Y_32_38 <= 0
#
# Max_connection_from_i32: - X_33 + Y_33_28 + Y_33_31 + Y_33_32 + Y_33_35
#  + Y_33_38 + Y_33_82 <= 0
#
# Max_connection_from_i33: - X_34 + Y_34_91 <= 0
#
# Max_connection_from_i34: - X_35 + Y_35_31 + Y_35_33 + Y_35_37 + Y_35_82 <= 0
#
# Max_connection_from_i35: - X_36 + Y_36_37 + Y_36_76 + Y_36_78 + Y_36_79 <= 0
#
# Max_connection_from_i36: - X_37 + Y_37_31 + Y_37_35 + Y_37_36 + Y_37_76
#  + Y_37_79 + Y_37_82 <= 0
#
# Max_connection_from_i37: - X_38 + Y_38_32 + Y_38_33 <= 0
#
# Max_connection_from_i38: - X_39 + Y_39_80 + Y_39_83 <= 0
#
# Max_connection_from_i39: - X_40 + Y_40_79 + Y_40_84 + Y_40_86 <= 0
#
# Max_connection_from_i41: - X_42 + Y_42_88 <= 0
#
# Max_connection_from_i44: - X_45 + Y_45_47 + Y_45_49 <= 0
#
# Max_connection_from_i45: - X_46 + Y_46_47 + Y_46_48 <= 0
#
# Max_connection_from_i46: - X_47 + Y_47_45 + Y_47_46 + Y_47_48 + Y_47_6 <= 0
#
# Max_connection_from_i47: - X_48 + Y_48_4 + Y_48_46 + Y_48_47 <= 0
#
# Max_connection_from_i48: - X_49 + Y_49_45 + Y_49_51 + Y_49_56 <= 0
#
# Max_connection_from_i49: - X_50 + Y_50_3 + Y_50_55 <= 0
#
# Max_connection_from_i50: - X_51 + Y_51_2 + Y_51_49 <= 0
#
# Max_connection_from_i52: - X_53 + Y_53_54 <= 0
#
# Max_connection_from_i53: - X_54 + Y_54_5 + Y_54_53 <= 0
#
# Max_connection_from_i54: - X_55 + Y_55_3 + Y_55_50 + Y_55_60 <= 0
#
# Max_connection_from_i55: - X_56 + Y_56_49 + Y_56_6 + Y_56_63 <= 0
#
# Max_connection_from_i56: - X_57 + Y_57_58 + Y_57_7 <= 0
#
# Max_connection_from_i57: - X_58 + Y_58_57 + Y_58_59 + Y_58_64 + Y_58_7 <= 0
#
# Max_connection_from_i58: - X_59 + Y_59_58 + Y_59_64 <= 0
#
# Max_connection_from_i59: - X_60 + Y_60_3 + Y_60_55 + Y_60_65 + Y_60_66
#  + Y_60_68 + Y_60_8 <= 0
#
# Max_connection_from_i61: - X_62 + Y_62_65 + Y_62_67 + Y_62_72 <= 0
#
# Max_connection_from_i62: - X_63 + Y_63_12 + Y_63_56 + Y_63_64 <= 0
#
# Max_connection_from_i63: - X_64 + Y_64_17 + Y_64_58 + Y_64_59 + Y_64_63 <= 0
#
# Max_connection_from_i64: - X_65 + Y_65_60 + Y_65_62 + Y_65_67 + Y_65_68 <= 0
#
# Max_connection_from_i65: - X_66 + Y_66_60 + Y_66_8 <= 0
#
# Max_connection_from_i66: - X_67 + Y_67_62 + Y_67_65 <= 0
#
# Max_connection_from_i67: - X_68 + Y_68_60 + Y_68_65 + Y_68_8 <= 0
#
# Max_connection_from_i69: - X_70 + Y_70_71 + Y_70_72 <= 0
#
# Max_connection_from_i70: - X_71 + Y_71_70 + Y_71_96 <= 0
#
# Max_connection_from_i71: - X_72 + Y_72_62 + Y_72_70 <= 0
#
# Max_connection_from_i72: - X_73 + Y_73_12 + Y_73_18 + Y_73_75 <= 0
#
# Max_connection_from_i73: - X_74 + Y_74_91 <= 0
#
# Max_connection_from_i74: - X_75 + Y_75_15 + Y_75_18 + Y_75_23 + Y_75_27
#  + Y_75_73 <= 0
#
# Max_connection_from_i75: - X_76 + Y_76_16 + Y_76_20 + Y_76_29 + Y_76_31
#  + Y_76_36 + Y_76_37 + Y_76_77 + Y_76_78 <= 0
#
# Max_connection_from_i76: - X_77 + Y_77_25 + Y_77_76 + Y_77_78 <= 0
#
# Max_connection_from_i77: - X_78 + Y_78_25 + Y_78_36 + Y_78_76 + Y_78_77
#  + Y_78_79 <= 0
#
# Max_connection_from_i78: - X_79 + Y_79_36 + Y_79_37 + Y_79_40 + Y_79_78
#  + Y_79_81 + Y_79_82 + Y_79_84 + Y_79_86 <= 0
#
# Max_connection_from_i79: - X_80 + Y_80_39 + Y_80_83 + Y_80_98 <= 0
#
# Max_connection_from_i80: - X_81 + Y_81_79 + Y_81_84 + Y_81_86 <= 0
#
# Max_connection_from_i81: - X_82 + Y_82_33 + Y_82_35 + Y_82_37 + Y_82_79 <= 0
#
# Max_connection_from_i82: - X_83 + Y_83_39 + Y_83_80 <= 0
#
# Max_connection_from_i83: - X_84 + Y_84_40 + Y_84_79 + Y_84_81 + Y_84_86 <= 0
#
# Max_connection_from_i84: - X_85 + Y_85_87 <= 0
#
# Max_connection_from_i85: - X_86 + Y_86_40 + Y_86_79 + Y_86_81 + Y_86_84
#  + Y_86_88 <= 0
#
# Max_connection_from_i86: - X_87 + Y_87_85 <= 0
#
# Max_connection_from_i87: - X_88 + Y_88_42 + Y_88_86 <= 0
#
# Max_connection_from_i88: - X_89 + Y_89_90 <= 0
#
# Max_connection_from_i89: - X_90 + Y_90_100 + Y_90_89 <= 0
#
# Max_connection_from_i90: - X_91 + Y_91_34 + Y_91_74 <= 0
#
# Max_connection_from_i91: - X_92 + Y_92_93 + Y_92_94 <= 0
#
# Max_connection_from_i92: - X_93 + Y_93_92 <= 0
#
# Max_connection_from_i93: - X_94 + Y_94_92 <= 0
#
# Max_connection_from_i95: - X_96 + Y_96_71 + Y_96_98 <= 0
#
# Max_connection_from_i96: - X_97 + Y_97_99 <= 0
#
# Max_connection_from_i97: - X_98 + Y_98_80 + Y_98_96 + Y_98_99 <= 0
#
# Max_connection_from_i98: - X_99 + Y_99_97 + Y_99_98 <= 0
#
# Max_connection_from_i99: - X_100 + Y_100_90 <= 0
#
# Number_of_arcs: - X_1 - X_10 - X_100 - X_101 - X_102 - X_103 - X_104 - X_105
#  - X_106 - X_107 - X_108 - X_109 - X_11 - X_110 - X_111 - X_112 - X_113
#  - X_114 - X_115 - X_116 - X_117 - X_118 - X_119 - X_12 - X_120 - X_13 - X_14
#  - X_15 - X_16 - X_17 - X_18 - X_19 - X_2 - X_20 - X_21 - X_22 - X_23 - X_24
#  - X_25 - X_26 - X_27 - X_28 - X_29 - X_3 - X_30 - X_31 - X_32 - X_33 - X_34
#  - X_35 - X_36 - X_37 - X_38 - X_39 - X_4 - X_40 - X_41 - X_42 - X_43 - X_44
#  - X_45 - X_46 - X_47 - X_48 - X_49 - X_5 - X_50 - X_51 - X_52 - X_53 - X_54
#  - X_55 - X_56 - X_57 - X_58 - X_59 - X_6 - X_60 - X_61 - X_62 - X_63 - X_64
#  - X_65 - X_66 - X_67 - X_68 - X_69 - X_7 - X_70 - X_71 - X_72 - X_73 - X_74
#  - X_75 - X_76 - X_77 - X_78 - X_79 - X_8 - X_80 - X_81 - X_82 - X_83 - X_84
#  - X_85 - X_86 - X_87 - X_88 - X_89 - X_9 - X_90 - X_91 - X_92 - X_93 - X_94
#  - X_95 - X_96 - X_97 - X_98 - X_99 + Y_100_90 + Y_10_13 + Y_12_63 + Y_12_73
#  + Y_13_10 + Y_13_16 + Y_14_17 + Y_14_19 + Y_14_21 + Y_14_22 + Y_14_24
#  + Y_15_17 + Y_15_18 + Y_15_23 + Y_15_75 + Y_16_13 + Y_16_20 + Y_16_76
#  + Y_17_14 + Y_17_15 + Y_17_19 + Y_17_23 + Y_17_64 + Y_18_15 + Y_18_73
#  + Y_18_75 + Y_19_14 + Y_19_17 + Y_19_22 + Y_19_23 + Y_20_16 + Y_20_76
#  + Y_21_14 + Y_22_14 + Y_22_19 + Y_22_23 + Y_22_24 + Y_23_15 + Y_23_17
#  + Y_23_19 + Y_23_22 + Y_23_26 + Y_23_27 + Y_23_75 + Y_24_14 + Y_24_22
#  + Y_25_77 + Y_25_78 + Y_26_23 + Y_26_27 + Y_27_23 + Y_27_26 + Y_27_28
#  + Y_27_32 + Y_27_75 + Y_28_27 + Y_28_31 + Y_28_32 + Y_28_33 + Y_29_31
#  + Y_29_76 + Y_2_51 + Y_31_28 + Y_31_29 + Y_31_33 + Y_31_35 + Y_31_37
#  + Y_31_76 + Y_32_27 + Y_32_28 + Y_32_33 + Y_32_38 + Y_33_28 + Y_33_31
#  + Y_33_32 + Y_33_35 + Y_33_38 + Y_33_82 + Y_34_91 + Y_35_31 + Y_35_33
#  + Y_35_37 + Y_35_82 + Y_36_37 + Y_36_76 + Y_36_78 + Y_36_79 + Y_37_31
#  + Y_37_35 + Y_37_36 + Y_37_76 + Y_37_79 + Y_37_82 + Y_38_32 + Y_38_33
#  + Y_39_80 + Y_39_83 + Y_3_50 + Y_3_55 + Y_3_60 + Y_40_79 + Y_40_84 + Y_40_86
#  + Y_42_88 + Y_45_47 + Y_45_49 + Y_46_47 + Y_46_48 + Y_47_45 + Y_47_46
#  + Y_47_48 + Y_47_6 + Y_48_4 + Y_48_46 + Y_48_47 + Y_49_45 + Y_49_51 + Y_49_56
#  + Y_4_48 + Y_4_5 + Y_4_6 + Y_50_3 + Y_50_55 + Y_51_2 + Y_51_49 + Y_53_54
#  + Y_54_5 + Y_54_53 + Y_55_3 + Y_55_50 + Y_55_60 + Y_56_49 + Y_56_6 + Y_56_63
#  + Y_57_58 + Y_57_7 + Y_58_57 + Y_58_59 + Y_58_64 + Y_58_7 + Y_59_58 + Y_59_64
#  + Y_5_4 + Y_5_54 + Y_60_3 + Y_60_55 + Y_60_65 + Y_60_66 + Y_60_68 + Y_60_8
#  + Y_62_65 + Y_62_67 + Y_62_72 + Y_63_12 + Y_63_56 + Y_63_64 + Y_64_17
#  + Y_64_58 + Y_64_59 + Y_64_63 + Y_65_60 + Y_65_62 + Y_65_67 + Y_65_68
#  + Y_66_60 + Y_66_8 + Y_67_62 + Y_67_65 + Y_68_60 + Y_68_65 + Y_68_8 + Y_6_4
#  + Y_6_47 + Y_6_56 + Y_70_71 + Y_70_72 + Y_71_70 + Y_71_96 + Y_72_62 + Y_72_70
#  + Y_73_12 + Y_73_18 + Y_73_75 + Y_74_91 + Y_75_15 + Y_75_18 + Y_75_23
#  + Y_75_27 + Y_75_73 + Y_76_16 + Y_76_20 + Y_76_29 + Y_76_31 + Y_76_36
#  + Y_76_37 + Y_76_77 + Y_76_78 + Y_77_25 + Y_77_76 + Y_77_78 + Y_78_25
#  + Y_78_36 + Y_78_76 + Y_78_77 + Y_78_79 + Y_79_36 + Y_79_37 + Y_79_40
#  + Y_79_78 + Y_79_81 + Y_79_82 + Y_79_84 + Y_79_86 + Y_7_57 + Y_7_58 + Y_80_39
#  + Y_80_83 + Y_80_98 + Y_81_79 + Y_81_84 + Y_81_86 + Y_82_33 + Y_82_35
#  + Y_82_37 + Y_82_79 + Y_83_39 + Y_83_80 + Y_84_40 + Y_84_79 + Y_84_81
#  + Y_84_86 + Y_85_87 + Y_86_40 + Y_86_79 + Y_86_81 + Y_86_84 + Y_86_88
#  + Y_87_85 + Y_88_42 + Y_88_86 + Y_89_90 + Y_8_60 + Y_8_66 + Y_8_68 + Y_90_100
#  + Y_90_89 + Y_91_34 + Y_91_74 + Y_92_93 + Y_92_94 + Y_93_92 + Y_94_92
#  + Y_96_71 + Y_96_98 + Y_97_99 + Y_98_80 + Y_98_96 + Y_98_99 + Y_99_97
#  + Y_99_98 = -1
#
# Tail_function2_0: - W_2 - 1000000 Y_2_51 + Z_2_51 >= -999999
#
# Tail_function3_0: - W_3 - 1000000 Y_3_50 + Z_3_50 >= -999999
#
# Tail_function3_1: - W_3 - 1000000 Y_3_55 + Z_3_55 >= -999999
#
# Tail_function3_2: - W_3 - 1000000 Y_3_60 + Z_3_60 >= -999999
#
# Tail_function4_0: - W_4 - 1000000 Y_4_5 + Z_4_5 >= -999999
#
# Tail_function4_1: - W_4 - 1000000 Y_4_6 + Z_4_6 >= -999999
#
# Tail_function4_2: - W_4 - 1000000 Y_4_48 + Z_4_48 >= -999999
#
# Tail_function5_0: - W_5 - 1000000 Y_5_4 + Z_5_4 >= -999999
#
# Tail_function5_1: - W_5 - 1000000 Y_5_54 + Z_5_54 >= -999999
#
# Tail_function6_0: - W_6 - 1000000 Y_6_4 + Z_6_4 >= -999999
#
# Tail_function6_1: - W_6 - 1000000 Y_6_47 + Z_6_47 >= -999999
#
# Tail_function6_2: - W_6 - 1000000 Y_6_56 + Z_6_56 >= -999999
#
# Tail_function7_0: - W_7 - 1000000 Y_7_57 + Z_7_57 >= -999999
#
# Tail_function7_1: - W_7 - 1000000 Y_7_58 + Z_7_58 >= -999999
#
# Tail_function8_0: - W_8 - 1000000 Y_8_60 + Z_8_60 >= -999999
#
# Tail_function8_1: - W_8 - 1000000 Y_8_66 + Z_8_66 >= -999999
#
# Tail_function8_2: - W_8 - 1000000 Y_8_68 + Z_8_68 >= -999999
#
# Tail_function10_0: - W_10 - 1000000 Y_10_13 + Z_10_13 >= -999999
#
# Tail_function12_0: - W_12 - 1000000 Y_12_63 + Z_12_63 >= -999999
#
# Tail_function12_1: - W_12 - 1000000 Y_12_73 + Z_12_73 >= -999999
#
# Tail_function13_0: - W_13 - 1000000 Y_13_10 + Z_13_10 >= -999999
#
# Tail_function13_1: - W_13 - 1000000 Y_13_16 + Z_13_16 >= -999999
#
# Tail_function14_0: - W_14 - 1000000 Y_14_17 + Z_14_17 >= -999999
#
# Tail_function14_1: - W_14 - 1000000 Y_14_19 + Z_14_19 >= -999999
#
# Tail_function14_2: - W_14 - 1000000 Y_14_21 + Z_14_21 >= -999999
#
# Tail_function14_3: - W_14 - 1000000 Y_14_22 + Z_14_22 >= -999999
#
# Tail_function14_4: - W_14 - 1000000 Y_14_24 + Z_14_24 >= -999999
#
# Tail_function15_0: - W_15 - 1000000 Y_15_17 + Z_15_17 >= -999999
#
# Tail_function15_1: - W_15 - 1000000 Y_15_18 + Z_15_18 >= -999999
#
# Tail_function15_2: - W_15 - 1000000 Y_15_23 + Z_15_23 >= -999999
#
# Tail_function15_3: - W_15 - 1000000 Y_15_75 + Z_15_75 >= -999999
#
# Tail_function16_0: - W_16 - 1000000 Y_16_13 + Z_16_13 >= -999999
#
# Tail_function16_1: - W_16 - 1000000 Y_16_20 + Z_16_20 >= -999999
#
# Tail_function16_2: - W_16 - 1000000 Y_16_76 + Z_16_76 >= -999999
#
# Tail_function17_0: - W_17 - 1000000 Y_17_14 + Z_17_14 >= -999999
#
# Tail_function17_1: - W_17 - 1000000 Y_17_15 + Z_17_15 >= -999999
#
# Tail_function17_2: - W_17 - 1000000 Y_17_19 + Z_17_19 >= -999999
#
# Tail_function17_3: - W_17 - 1000000 Y_17_23 + Z_17_23 >= -999999
#
# Tail_function17_4: - W_17 - 1000000 Y_17_64 + Z_17_64 >= -999999
#
# Tail_function18_0: - W_18 - 1000000 Y_18_15 + Z_18_15 >= -999999
#
# Tail_function18_1: - W_18 - 1000000 Y_18_73 + Z_18_73 >= -999999
#
# Tail_function18_2: - W_18 - 1000000 Y_18_75 + Z_18_75 >= -999999
#
# Tail_function19_0: - W_19 - 1000000 Y_19_14 + Z_19_14 >= -999999
#
# Tail_function19_1: - W_19 - 1000000 Y_19_17 + Z_19_17 >= -999999
#
# Tail_function19_2: - W_19 - 1000000 Y_19_22 + Z_19_22 >= -999999
#
# Tail_function19_3: - W_19 - 1000000 Y_19_23 + Z_19_23 >= -999999
#
# Tail_function20_0: - W_20 - 1000000 Y_20_16 + Z_20_16 >= -999999
#
# Tail_function20_1: - W_20 - 1000000 Y_20_76 + Z_20_76 >= -999999
#
# Tail_function21_0: - W_21 - 1000000 Y_21_14 + Z_21_14 >= -999999
#
# Tail_function22_0: - W_22 - 1000000 Y_22_14 + Z_22_14 >= -999999
#
# Tail_function22_1: - W_22 - 1000000 Y_22_19 + Z_22_19 >= -999999
#
# Tail_function22_2: - W_22 - 1000000 Y_22_23 + Z_22_23 >= -999999
#
# Tail_function22_3: - W_22 - 1000000 Y_22_24 + Z_22_24 >= -999999
#
# Tail_function23_0: - W_23 - 1000000 Y_23_15 + Z_23_15 >= -999999
#
# Tail_function23_1: - W_23 - 1000000 Y_23_17 + Z_23_17 >= -999999
#
# Tail_function23_2: - W_23 - 1000000 Y_23_19 + Z_23_19 >= -999999
#
# Tail_function23_3: - W_23 - 1000000 Y_23_22 + Z_23_22 >= -999999
#
# Tail_function23_4: - W_23 - 1000000 Y_23_26 + Z_23_26 >= -999999
#
# Tail_function23_5: - W_23 - 1000000 Y_23_27 + Z_23_27 >= -999999
#
# Tail_function23_6: - W_23 - 1000000 Y_23_75 + Z_23_75 >= -999999
#
# Tail_function24_0: - W_24 - 1000000 Y_24_14 + Z_24_14 >= -999999
#
# Tail_function24_1: - W_24 - 1000000 Y_24_22 + Z_24_22 >= -999999
#
# Tail_function25_0: - W_25 - 1000000 Y_25_77 + Z_25_77 >= -999999
#
# Tail_function25_1: - W_25 - 1000000 Y_25_78 + Z_25_78 >= -999999
#
# Tail_function26_0: - W_26 - 1000000 Y_26_23 + Z_26_23 >= -999999
#
# Tail_function26_1: - W_26 - 1000000 Y_26_27 + Z_26_27 >= -999999
#
# Tail_function27_0: - W_27 - 1000000 Y_27_23 + Z_27_23 >= -999999
#
# Tail_function27_1: - W_27 - 1000000 Y_27_26 + Z_27_26 >= -999999
#
# Tail_function27_2: - W_27 - 1000000 Y_27_28 + Z_27_28 >= -999999
#
# Tail_function27_3: - W_27 - 1000000 Y_27_32 + Z_27_32 >= -999999
#
# Tail_function27_4: - W_27 - 1000000 Y_27_75 + Z_27_75 >= -999999
#
# Tail_function28_0: - W_28 - 1000000 Y_28_27 + Z_28_27 >= -999999
#
# Tail_function28_1: - W_28 - 1000000 Y_28_31 + Z_28_31 >= -999999
#
# Tail_function28_2: - W_28 - 1000000 Y_28_32 + Z_28_32 >= -999999
#
# Tail_function28_3: - W_28 - 1000000 Y_28_33 + Z_28_33 >= -999999
#
# Tail_function29_0: - W_29 - 1000000 Y_29_31 + Z_29_31 >= -999999
#
# Tail_function29_1: - W_29 - 1000000 Y_29_76 + Z_29_76 >= -999999
#
# Tail_function31_0: - W_31 - 1000000 Y_31_28 + Z_31_28 >= -999999
#
# Tail_function31_1: - W_31 - 1000000 Y_31_29 + Z_31_29 >= -999999
#
# Tail_function31_2: - W_31 - 1000000 Y_31_33 + Z_31_33 >= -999999
#
# Tail_function31_3: - W_31 - 1000000 Y_31_35 + Z_31_35 >= -999999
#
# Tail_function31_4: - W_31 - 1000000 Y_31_37 + Z_31_37 >= -999999
#
# Tail_function31_5: - W_31 - 1000000 Y_31_76 + Z_31_76 >= -999999
#
# Tail_function32_0: - W_32 - 1000000 Y_32_27 + Z_32_27 >= -999999
#
# Tail_function32_1: - W_32 - 1000000 Y_32_28 + Z_32_28 >= -999999
#
# Tail_function32_2: - W_32 - 1000000 Y_32_33 + Z_32_33 >= -999999
#
# Tail_function32_3: - W_32 - 1000000 Y_32_38 + Z_32_38 >= -999999
#
# Tail_function33_0: - W_33 - 1000000 Y_33_28 + Z_33_28 >= -999999
#
# Tail_function33_1: - W_33 - 1000000 Y_33_31 + Z_33_31 >= -999999
#
# Tail_function33_2: - W_33 - 1000000 Y_33_32 + Z_33_32 >= -999999
#
# Tail_function33_3: - W_33 - 1000000 Y_33_35 + Z_33_35 >= -999999
#
# Tail_function33_4: - W_33 - 1000000 Y_33_38 + Z_33_38 >= -999999
#
# Tail_function33_5: - W_33 - 1000000 Y_33_82 + Z_33_82 >= -999999
#
# Tail_function34_0: - W_34 - 1000000 Y_34_91 + Z_34_91 >= -999999
#
# Tail_function35_0: - W_35 - 1000000 Y_35_31 + Z_35_31 >= -999999
#
# Tail_function35_1: - W_35 - 1000000 Y_35_33 + Z_35_33 >= -999999
#
# Tail_function35_2: - W_35 - 1000000 Y_35_37 + Z_35_37 >= -999999
#
# Tail_function35_3: - W_35 - 1000000 Y_35_82 + Z_35_82 >= -999999
#
# Tail_function36_0: - W_36 - 1000000 Y_36_37 + Z_36_37 >= -999999
#
# Tail_function36_1: - W_36 - 1000000 Y_36_76 + Z_36_76 >= -999999
#
# Tail_function36_2: - W_36 - 1000000 Y_36_78 + Z_36_78 >= -999999
#
# Tail_function36_3: - W_36 - 1000000 Y_36_79 + Z_36_79 >= -999999
#
# Tail_function37_0: - W_37 - 1000000 Y_37_31 + Z_37_31 >= -999999
#
# Tail_function37_1: - W_37 - 1000000 Y_37_35 + Z_37_35 >= -999999
#
# Tail_function37_2: - W_37 - 1000000 Y_37_36 + Z_37_36 >= -999999
#
# Tail_function37_3: - W_37 - 1000000 Y_37_76 + Z_37_76 >= -999999
#
# Tail_function37_4: - W_37 - 1000000 Y_37_79 + Z_37_79 >= -999999
#
# Tail_function37_5: - W_37 - 1000000 Y_37_82 + Z_37_82 >= -999999
#
# Tail_function38_0: - W_38 - 1000000 Y_38_32 + Z_38_32 >= -999999
#
# Tail_function38_1: - W_38 - 1000000 Y_38_33 + Z_38_33 >= -999999
#
# Tail_function39_0: - W_39 - 1000000 Y_39_80 + Z_39_80 >= -999999
#
# Tail_function39_1: - W_39 - 1000000 Y_39_83 + Z_39_83 >= -999999
#
# Tail_function40_0: - W_40 - 1000000 Y_40_79 + Z_40_79 >= -999999
#
# Tail_function40_1: - W_40 - 1000000 Y_40_84 + Z_40_84 >= -999999
#
# Tail_function40_2: - W_40 - 1000000 Y_40_86 + Z_40_86 >= -999999
#
# Tail_function42_0: - W_42 - 1000000 Y_42_88 + Z_42_88 >= -999999
#
# Tail_function45_0: - W_45 - 1000000 Y_45_47 + Z_45_47 >= -999999
#
# Tail_function45_1: - W_45 - 1000000 Y_45_49 + Z_45_49 >= -999999
#
# Tail_function46_0: - W_46 - 1000000 Y_46_47 + Z_46_47 >= -999999
#
# Tail_function46_1: - W_46 - 1000000 Y_46_48 + Z_46_48 >= -999999
#
# Tail_function47_0: - W_47 - 1000000 Y_47_6 + Z_47_6 >= -999999
#
# Tail_function47_1: - W_47 - 1000000 Y_47_45 + Z_47_45 >= -999999
#
# Tail_function47_2: - W_47 - 1000000 Y_47_46 + Z_47_46 >= -999999
#
# Tail_function47_3: - W_47 - 1000000 Y_47_48 + Z_47_48 >= -999999
#
# Tail_function48_0: - W_48 - 1000000 Y_48_4 + Z_48_4 >= -999999
#
# Tail_function48_1: - W_48 - 1000000 Y_48_46 + Z_48_46 >= -999999
#
# Tail_function48_2: - W_48 - 1000000 Y_48_47 + Z_48_47 >= -999999
#
# Tail_function49_0: - W_49 - 1000000 Y_49_45 + Z_49_45 >= -999999
#
# Tail_function49_1: - W_49 - 1000000 Y_49_51 + Z_49_51 >= -999999
#
# Tail_function49_2: - W_49 - 1000000 Y_49_56 + Z_49_56 >= -999999
#
# Tail_function50_0: - W_50 - 1000000 Y_50_3 + Z_50_3 >= -999999
#
# Tail_function50_1: - W_50 - 1000000 Y_50_55 + Z_50_55 >= -999999
#
# Tail_function51_0: - W_51 - 1000000 Y_51_2 + Z_51_2 >= -999999
#
# Tail_function51_1: - W_51 - 1000000 Y_51_49 + Z_51_49 >= -999999
#
# Tail_function53_0: - W_53 - 1000000 Y_53_54 + Z_53_54 >= -999999
#
# Tail_function54_0: - W_54 - 1000000 Y_54_5 + Z_54_5 >= -999999
#
# Tail_function54_1: - W_54 - 1000000 Y_54_53 + Z_54_53 >= -999999
#
# Tail_function55_0: - W_55 - 1000000 Y_55_3 + Z_55_3 >= -999999
#
# Tail_function55_1: - W_55 - 1000000 Y_55_50 + Z_55_50 >= -999999
#
# Tail_function55_2: - W_55 - 1000000 Y_55_60 + Z_55_60 >= -999999
#
# Tail_function56_0: - W_56 - 1000000 Y_56_6 + Z_56_6 >= -999999
#
# Tail_function56_1: - W_56 - 1000000 Y_56_49 + Z_56_49 >= -999999
#
# Tail_function56_2: - W_56 - 1000000 Y_56_63 + Z_56_63 >= -999999
#
# Tail_function57_0: - W_57 - 1000000 Y_57_7 + Z_57_7 >= -999999
#
# Tail_function57_1: - W_57 - 1000000 Y_57_58 + Z_57_58 >= -999999
#
# Tail_function58_0: - W_58 - 1000000 Y_58_7 + Z_58_7 >= -999999
#
# Tail_function58_1: - W_58 - 1000000 Y_58_57 + Z_58_57 >= -999999
#
# Tail_function58_2: - W_58 - 1000000 Y_58_59 + Z_58_59 >= -999999
#
# Tail_function58_3: - W_58 - 1000000 Y_58_64 + Z_58_64 >= -999999
#
# Tail_function59_0: - W_59 - 1000000 Y_59_58 + Z_59_58 >= -999999
#
# Tail_function59_1: - W_59 - 1000000 Y_59_64 + Z_59_64 >= -999999
#
# Tail_function60_0: - W_60 - 1000000 Y_60_3 + Z_60_3 >= -999999
#
# Tail_function60_1: - W_60 - 1000000 Y_60_8 + Z_60_8 >= -999999
#
# Tail_function60_2: - W_60 - 1000000 Y_60_55 + Z_60_55 >= -999999
#
# Tail_function60_3: - W_60 - 1000000 Y_60_65 + Z_60_65 >= -999999
#
# Tail_function60_4: - W_60 - 1000000 Y_60_66 + Z_60_66 >= -999999
#
# Tail_function60_5: - W_60 - 1000000 Y_60_68 + Z_60_68 >= -999999
#
# Tail_function62_0: - W_62 - 1000000 Y_62_65 + Z_62_65 >= -999999
#
# Tail_function62_1: - W_62 - 1000000 Y_62_67 + Z_62_67 >= -999999
#
# Tail_function62_2: - W_62 - 1000000 Y_62_72 + Z_62_72 >= -999999
#
# Tail_function63_0: - W_63 - 1000000 Y_63_12 + Z_63_12 >= -999999
#
# Tail_function63_1: - W_63 - 1000000 Y_63_56 + Z_63_56 >= -999999
#
# Tail_function63_2: - W_63 - 1000000 Y_63_64 + Z_63_64 >= -999999
#
# Tail_function64_0: - W_64 - 1000000 Y_64_17 + Z_64_17 >= -999999
#
# Tail_function64_1: - W_64 - 1000000 Y_64_58 + Z_64_58 >= -999999
#
# Tail_function64_2: - W_64 - 1000000 Y_64_59 + Z_64_59 >= -999999
#
# Tail_function64_3: - W_64 - 1000000 Y_64_63 + Z_64_63 >= -999999
#
# Tail_function65_0: - W_65 - 1000000 Y_65_60 + Z_65_60 >= -999999
#
# Tail_function65_1: - W_65 - 1000000 Y_65_62 + Z_65_62 >= -999999
#
# Tail_function65_2: - W_65 - 1000000 Y_65_67 + Z_65_67 >= -999999
#
# Tail_function65_3: - W_65 - 1000000 Y_65_68 + Z_65_68 >= -999999
#
# Tail_function66_0: - W_66 - 1000000 Y_66_8 + Z_66_8 >= -999999
#
# Tail_function66_1: - W_66 - 1000000 Y_66_60 + Z_66_60 >= -999999
#
# Tail_function67_0: - W_67 - 1000000 Y_67_62 + Z_67_62 >= -999999
#
# Tail_function67_1: - W_67 - 1000000 Y_67_65 + Z_67_65 >= -999999
#
# Tail_function68_0: - W_68 - 1000000 Y_68_8 + Z_68_8 >= -999999
#
# Tail_function68_1: - W_68 - 1000000 Y_68_60 + Z_68_60 >= -999999
#
# Tail_function68_2: - W_68 - 1000000 Y_68_65 + Z_68_65 >= -999999
#
# Tail_function70_0: - W_70 - 1000000 Y_70_71 + Z_70_71 >= -999999
#
# Tail_function70_1: - W_70 - 1000000 Y_70_72 + Z_70_72 >= -999999
#
# Tail_function71_0: - W_71 - 1000000 Y_71_70 + Z_71_70 >= -999999
#
# Tail_function71_1: - W_71 - 1000000 Y_71_96 + Z_71_96 >= -999999
#
# Tail_function72_0: - W_72 - 1000000 Y_72_62 + Z_72_62 >= -999999
#
# Tail_function72_1: - W_72 - 1000000 Y_72_70 + Z_72_70 >= -999999
#
# Tail_function73_0: - W_73 - 1000000 Y_73_12 + Z_73_12 >= -999999
#
# Tail_function73_1: - W_73 - 1000000 Y_73_18 + Z_73_18 >= -999999
#
# Tail_function73_2: - W_73 - 1000000 Y_73_75 + Z_73_75 >= -999999
#
# Tail_function74_0: - W_74 - 1000000 Y_74_91 + Z_74_91 >= -999999
#
# Tail_function75_0: - W_75 - 1000000 Y_75_15 + Z_75_15 >= -999999
#
# Tail_function75_1: - W_75 - 1000000 Y_75_18 + Z_75_18 >= -999999
#
# Tail_function75_2: - W_75 - 1000000 Y_75_23 + Z_75_23 >= -999999
#
# Tail_function75_3: - W_75 - 1000000 Y_75_27 + Z_75_27 >= -999999
#
# Tail_function75_4: - W_75 - 1000000 Y_75_73 + Z_75_73 >= -999999
#
# Tail_function76_0: - W_76 - 1000000 Y_76_16 + Z_76_16 >= -999999
#
# Tail_function76_1: - W_76 - 1000000 Y_76_20 + Z_76_20 >= -999999
#
# Tail_function76_2: - W_76 - 1000000 Y_76_29 + Z_76_29 >= -999999
#
# Tail_function76_3: - W_76 - 1000000 Y_76_31 + Z_76_31 >= -999999
#
# Tail_function76_4: - W_76 - 1000000 Y_76_36 + Z_76_36 >= -999999
#
# Tail_function76_5: - W_76 - 1000000 Y_76_37 + Z_76_37 >= -999999
#
# Tail_function76_6: - W_76 - 1000000 Y_76_77 + Z_76_77 >= -999999
#
# Tail_function76_7: - W_76 - 1000000 Y_76_78 + Z_76_78 >= -999999
#
# Tail_function77_0: - W_77 - 1000000 Y_77_25 + Z_77_25 >= -999999
#
# Tail_function77_1: - W_77 - 1000000 Y_77_76 + Z_77_76 >= -999999
#
# Tail_function77_2: - W_77 - 1000000 Y_77_78 + Z_77_78 >= -999999
#
# Tail_function78_0: - W_78 - 1000000 Y_78_25 + Z_78_25 >= -999999
#
# Tail_function78_1: - W_78 - 1000000 Y_78_36 + Z_78_36 >= -999999
#
# Tail_function78_2: - W_78 - 1000000 Y_78_76 + Z_78_76 >= -999999
#
# Tail_function78_3: - W_78 - 1000000 Y_78_77 + Z_78_77 >= -999999
#
# Tail_function78_4: - W_78 - 1000000 Y_78_79 + Z_78_79 >= -999999
#
# Tail_function79_0: - W_79 - 1000000 Y_79_36 + Z_79_36 >= -999999
#
# Tail_function79_1: - W_79 - 1000000 Y_79_37 + Z_79_37 >= -999999
#
# Tail_function79_2: - W_79 - 1000000 Y_79_40 + Z_79_40 >= -999999
#
# Tail_function79_3: - W_79 - 1000000 Y_79_78 + Z_79_78 >= -999999
#
# Tail_function79_4: - W_79 - 1000000 Y_79_81 + Z_79_81 >= -999999
#
# Tail_function79_5: - W_79 - 1000000 Y_79_82 + Z_79_82 >= -999999
#
# Tail_function79_6: - W_79 - 1000000 Y_79_84 + Z_79_84 >= -999999
#
# Tail_function79_7: - W_79 - 1000000 Y_79_86 + Z_79_86 >= -999999
#
# Tail_function80_0: - W_80 - 1000000 Y_80_39 + Z_80_39 >= -999999
#
# Tail_function80_1: - W_80 - 1000000 Y_80_83 + Z_80_83 >= -999999
#
# Tail_function80_2: - W_80 - 1000000 Y_80_98 + Z_80_98 >= -999999
#
# Tail_function81_0: - W_81 - 1000000 Y_81_79 + Z_81_79 >= -999999
#
# Tail_function81_1: - W_81 - 1000000 Y_81_84 + Z_81_84 >= -999999
#
# Tail_function81_2: - W_81 - 1000000 Y_81_86 + Z_81_86 >= -999999
#
# Tail_function82_0: - W_82 - 1000000 Y_82_33 + Z_82_33 >= -999999
#
# Tail_function82_1: - W_82 - 1000000 Y_82_35 + Z_82_35 >= -999999
#
# Tail_function82_2: - W_82 - 1000000 Y_82_37 + Z_82_37 >= -999999
#
# Tail_function82_3: - W_82 - 1000000 Y_82_79 + Z_82_79 >= -999999
#
# Tail_function83_0: - W_83 - 1000000 Y_83_39 + Z_83_39 >= -999999
#
# Tail_function83_1: - W_83 - 1000000 Y_83_80 + Z_83_80 >= -999999
#
# Tail_function84_0: - W_84 - 1000000 Y_84_40 + Z_84_40 >= -999999
#
# Tail_function84_1: - W_84 - 1000000 Y_84_79 + Z_84_79 >= -999999
#
# Tail_function84_2: - W_84 - 1000000 Y_84_81 + Z_84_81 >= -999999
#
# Tail_function84_3: - W_84 - 1000000 Y_84_86 + Z_84_86 >= -999999
#
# Tail_function85_0: - W_85 - 1000000 Y_85_87 + Z_85_87 >= -999999
#
# Tail_function86_0: - W_86 - 1000000 Y_86_40 + Z_86_40 >= -999999
#
# Tail_function86_1: - W_86 - 1000000 Y_86_79 + Z_86_79 >= -999999
#
# Tail_function86_2: - W_86 - 1000000 Y_86_81 + Z_86_81 >= -999999
#
# Tail_function86_3: - W_86 - 1000000 Y_86_84 + Z_86_84 >= -999999
#
# Tail_function86_4: - W_86 - 1000000 Y_86_88 + Z_86_88 >= -999999
#
# Tail_function87_0: - W_87 - 1000000 Y_87_85 + Z_87_85 >= -999999
#
# Tail_function88_0: - W_88 - 1000000 Y_88_42 + Z_88_42 >= -999999
#
# Tail_function88_1: - W_88 - 1000000 Y_88_86 + Z_88_86 >= -999999
#
# Tail_function89_0: - W_89 - 1000000 Y_89_90 + Z_89_90 >= -999999
#
# Tail_function90_0: - W_90 - 1000000 Y_90_89 + Z_90_89 >= -999999
#
# Tail_function90_1: - W_90 - 1000000 Y_90_100 + Z_90_100 >= -999999
#
# Tail_function91_0: - W_91 - 1000000 Y_91_34 + Z_91_34 >= -999999
#
# Tail_function91_1: - W_91 - 1000000 Y_91_74 + Z_91_74 >= -999999
#
# Tail_function92_0: - W_92 - 1000000 Y_92_93 + Z_92_93 >= -999999
#
# Tail_function92_1: - W_92 - 1000000 Y_92_94 + Z_92_94 >= -999999
#
# Tail_function93_0: - W_93 - 1000000 Y_93_92 + Z_93_92 >= -999999
#
# Tail_function94_0: - W_94 - 1000000 Y_94_92 + Z_94_92 >= -999999
#
# Tail_function96_0: - W_96 - 1000000 Y_96_71 + Z_96_71 >= -999999
#
# Tail_function96_1: - W_96 - 1000000 Y_96_98 + Z_96_98 >= -999999
#
# Tail_function97_0: - W_97 - 1000000 Y_97_99 + Z_97_99 >= -999999
#
# Tail_function98_0: - W_98 - 1000000 Y_98_80 + Z_98_80 >= -999999
#
# Tail_function98_1: - W_98 - 1000000 Y_98_96 + Z_98_96 >= -999999
#
# Tail_function98_2: - W_98 - 1000000 Y_98_99 + Z_98_99 >= -999999
#
# Tail_function99_0: - W_99 - 1000000 Y_99_97 + Z_99_97 >= -999999
#
# Tail_function99_1: - W_99 - 1000000 Y_99_98 + Z_99_98 >= -999999
#
# Tail_function100_0: - W_100 - 1000000 Y_100_90 + Z_100_90 >= -999999
#
# Loop_break_function2: W_2 - Z_51_2 = 0
#
# Loop_break_function3: W_3 - Z_50_3 - Z_55_3 - Z_60_3 = 0
#
# Loop_break_function4: W_4 - Z_48_4 - Z_5_4 - Z_6_4 = 0
#
# Loop_break_function5: W_5 - Z_4_5 - Z_54_5 = 0
#
# Loop_break_function6: W_6 - Z_47_6 - Z_4_6 - Z_56_6 = 0
#
# Loop_break_function7: W_7 - Z_57_7 - Z_58_7 = 0
#
# Loop_break_function8: W_8 - Z_60_8 - Z_66_8 - Z_68_8 = 0
#
# Loop_break_function10: W_10 - Z_13_10 = 0
#
# Loop_break_function12: W_12 - Z_63_12 - Z_73_12 = 0
#
# Loop_break_function13: W_13 - Z_10_13 - Z_16_13 = 0
#
# Loop_break_function14: W_14 - Z_17_14 - Z_19_14 - Z_21_14 - Z_22_14 - Z_24_14
#  = 0
#
# Loop_break_function15: W_15 - Z_17_15 - Z_18_15 - Z_23_15 - Z_75_15 = 0
#
# Loop_break_function16: W_16 - Z_13_16 - Z_20_16 - Z_76_16 = 0
#
# Loop_break_function17: W_17 - Z_14_17 - Z_15_17 - Z_19_17 - Z_23_17 - Z_64_17
#  = 0
#
# Loop_break_function18: W_18 - Z_15_18 - Z_73_18 - Z_75_18 = 0
#
# Loop_break_function19: W_19 - Z_14_19 - Z_17_19 - Z_22_19 - Z_23_19 = 0
#
# Loop_break_function20: W_20 - Z_16_20 - Z_76_20 = 0
#
# Loop_break_function21: W_21 - Z_14_21 = 0
#
# Loop_break_function22: W_22 - Z_14_22 - Z_19_22 - Z_23_22 - Z_24_22 = 0
#
# Loop_break_function23: W_23 - Z_15_23 - Z_17_23 - Z_19_23 - Z_22_23 - Z_26_23
#  - Z_27_23 - Z_75_23 = 0
#
# Loop_break_function24: W_24 - Z_14_24 - Z_22_24 = 0
#
# Loop_break_function25: W_25 - Z_77_25 - Z_78_25 = 0
#
# Loop_break_function26: W_26 - Z_23_26 - Z_27_26 = 0
#
# Loop_break_function27: W_27 - Z_23_27 - Z_26_27 - Z_28_27 - Z_32_27 - Z_75_27
#  = 0
#
# Loop_break_function28: W_28 - Z_27_28 - Z_31_28 - Z_32_28 - Z_33_28 = 0
#
# Loop_break_function29: W_29 - Z_31_29 - Z_76_29 = 0
#
# Loop_break_function31: W_31 - Z_28_31 - Z_29_31 - Z_33_31 - Z_35_31 - Z_37_31
#  - Z_76_31 = 0
#
# Loop_break_function32: W_32 - Z_27_32 - Z_28_32 - Z_33_32 - Z_38_32 = 0
#
# Loop_break_function33: W_33 - Z_28_33 - Z_31_33 - Z_32_33 - Z_35_33 - Z_38_33
#  - Z_82_33 = 0
#
# Loop_break_function34: W_34 - Z_91_34 = 0
#
# Loop_break_function35: W_35 - Z_31_35 - Z_33_35 - Z_37_35 - Z_82_35 = 0
#
# Loop_break_function36: W_36 - Z_37_36 - Z_76_36 - Z_78_36 - Z_79_36 = 0
#
# Loop_break_function37: W_37 - Z_31_37 - Z_35_37 - Z_36_37 - Z_76_37 - Z_79_37
#  - Z_82_37 = 0
#
# Loop_break_function38: W_38 - Z_32_38 - Z_33_38 = 0
#
# Loop_break_function39: W_39 - Z_80_39 - Z_83_39 = 0
#
# Loop_break_function40: W_40 - Z_79_40 - Z_84_40 - Z_86_40 = 0
#
# Loop_break_function42: W_42 - Z_88_42 = 0
#
# Loop_break_function45: W_45 - Z_47_45 - Z_49_45 = 0
#
# Loop_break_function46: W_46 - Z_47_46 - Z_48_46 = 0
#
# Loop_break_function47: W_47 - Z_45_47 - Z_46_47 - Z_48_47 - Z_6_47 = 0
#
# Loop_break_function48: W_48 - Z_46_48 - Z_47_48 - Z_4_48 = 0
#
# Loop_break_function49: W_49 - Z_45_49 - Z_51_49 - Z_56_49 = 0
#
# Loop_break_function50: W_50 - Z_3_50 - Z_55_50 = 0
#
# Loop_break_function51: W_51 - Z_2_51 - Z_49_51 = 0
#
# Loop_break_function53: W_53 - Z_54_53 = 0
#
# Loop_break_function54: W_54 - Z_53_54 - Z_5_54 = 0
#
# Loop_break_function55: W_55 - Z_3_55 - Z_50_55 - Z_60_55 = 0
#
# Loop_break_function56: W_56 - Z_49_56 - Z_63_56 - Z_6_56 = 0
#
# Loop_break_function57: W_57 - Z_58_57 - Z_7_57 = 0
#
# Loop_break_function58: W_58 - Z_57_58 - Z_59_58 - Z_64_58 - Z_7_58 = 0
#
# Loop_break_function59: W_59 - Z_58_59 - Z_64_59 = 0
#
# Loop_break_function60: W_60 - Z_3_60 - Z_55_60 - Z_65_60 - Z_66_60 - Z_68_60
#  - Z_8_60 = 0
#
# Loop_break_function62: W_62 - Z_65_62 - Z_67_62 - Z_72_62 = 0
#
# Loop_break_function63: W_63 - Z_12_63 - Z_56_63 - Z_64_63 = 0
#
# Loop_break_function64: W_64 - Z_17_64 - Z_58_64 - Z_59_64 - Z_63_64 = 0
#
# Loop_break_function65: W_65 - Z_60_65 - Z_62_65 - Z_67_65 - Z_68_65 = 0
#
# Loop_break_function66: W_66 - Z_60_66 - Z_8_66 = 0
#
# Loop_break_function67: W_67 - Z_62_67 - Z_65_67 = 0
#
# Loop_break_function68: W_68 - Z_60_68 - Z_65_68 - Z_8_68 = 0
#
# Loop_break_function70: W_70 - Z_71_70 - Z_72_70 = 0
#
# Loop_break_function71: W_71 - Z_70_71 - Z_96_71 = 0
#
# Loop_break_function72: W_72 - Z_62_72 - Z_70_72 = 0
#
# Loop_break_function73: W_73 - Z_12_73 - Z_18_73 - Z_75_73 = 0
#
# Loop_break_function74: W_74 - Z_91_74 = 0
#
# Loop_break_function75: W_75 - Z_15_75 - Z_18_75 - Z_23_75 - Z_27_75 - Z_73_75
#  = 0
#
# Loop_break_function76: W_76 - Z_16_76 - Z_20_76 - Z_29_76 - Z_31_76 - Z_36_76
#  - Z_37_76 - Z_77_76 - Z_78_76 = 0
#
# Loop_break_function77: W_77 - Z_25_77 - Z_76_77 - Z_78_77 = 0
#
# Loop_break_function78: W_78 - Z_25_78 - Z_36_78 - Z_76_78 - Z_77_78 - Z_79_78
#  = 0
#
# Loop_break_function79: W_79 - Z_36_79 - Z_37_79 - Z_40_79 - Z_78_79 - Z_81_79
#  - Z_82_79 - Z_84_79 - Z_86_79 = 0
#
# Loop_break_function80: W_80 - Z_39_80 - Z_83_80 - Z_98_80 = 0
#
# Loop_break_function81: W_81 - Z_79_81 - Z_84_81 - Z_86_81 = 0
#
# Loop_break_function82: W_82 - Z_33_82 - Z_35_82 - Z_37_82 - Z_79_82 = 0
#
# Loop_break_function83: W_83 - Z_39_83 - Z_80_83 = 0
#
# Loop_break_function84: W_84 - Z_40_84 - Z_79_84 - Z_81_84 - Z_86_84 = 0
#
# Loop_break_function85: W_85 - Z_87_85 = 0
#
# Loop_break_function86: W_86 - Z_40_86 - Z_79_86 - Z_81_86 - Z_84_86 - Z_88_86
#  = 0
#
# Loop_break_function87: W_87 - Z_85_87 = 0
#
# Loop_break_function88: W_88 - Z_42_88 - Z_86_88 = 0
#
# Loop_break_function89: W_89 - Z_90_89 = 0
#
# Loop_break_function90: W_90 - Z_100_90 - Z_89_90 = 0
#
# Loop_break_function91: W_91 - Z_34_91 - Z_74_91 = 0
#
# Loop_break_function92: W_92 - Z_93_92 - Z_94_92 = 0
#
# Loop_break_function93: W_93 - Z_92_93 = 0
#
# Loop_break_function94: W_94 - Z_92_94 = 0
#
# Loop_break_function96: W_96 - Z_71_96 - Z_98_96 = 0
#
# Loop_break_function97: W_97 - Z_99_97 = 0
#
# Loop_break_function98: W_98 - Z_80_98 - Z_96_98 - Z_99_98 = 0
#
# Loop_break_function99: W_99 - Z_97_99 - Z_98_99 = 0
#
# Loop_break_function100: W_100 - Z_90_100 = 0
#
# Ensure_min_Zij1: - 1000000 Y_51_2 + Z_51_2 <= 0
#
# Ensure_min_Zij2: - 1000000 Y_50_3 + Z_50_3 <= 0
#
# Ensure_min_Zij3: - 1000000 Y_55_3 + Z_55_3 <= 0
#
# Ensure_min_Zij4: - 1000000 Y_60_3 + Z_60_3 <= 0
#
# Ensure_min_Zij5: - 1000000 Y_5_4 + Z_5_4 <= 0
#
# Ensure_min_Zij6: - 1000000 Y_6_4 + Z_6_4 <= 0
#
# Ensure_min_Zij7: - 1000000 Y_48_4 + Z_48_4 <= 0
#
# Ensure_min_Zij8: - 1000000 Y_4_5 + Z_4_5 <= 0
#
# Ensure_min_Zij9: - 1000000 Y_54_5 + Z_54_5 <= 0
#
# Ensure_min_Zij10: - 1000000 Y_4_6 + Z_4_6 <= 0
#
# Ensure_min_Zij11: - 1000000 Y_47_6 + Z_47_6 <= 0
#
# Ensure_min_Zij12: - 1000000 Y_56_6 + Z_56_6 <= 0
#
# Ensure_min_Zij13: - 1000000 Y_57_7 + Z_57_7 <= 0
#
# Ensure_min_Zij14: - 1000000 Y_58_7 + Z_58_7 <= 0
#
# Ensure_min_Zij15: - 1000000 Y_60_8 + Z_60_8 <= 0
#
# Ensure_min_Zij16: - 1000000 Y_66_8 + Z_66_8 <= 0
#
# Ensure_min_Zij17: - 1000000 Y_68_8 + Z_68_8 <= 0
#
# Ensure_min_Zij18: - 1000000 Y_13_10 + Z_13_10 <= 0
#
# Ensure_min_Zij19: - 1000000 Y_63_12 + Z_63_12 <= 0
#
# Ensure_min_Zij20: - 1000000 Y_73_12 + Z_73_12 <= 0
#
# Ensure_min_Zij21: - 1000000 Y_10_13 + Z_10_13 <= 0
#
# Ensure_min_Zij22: - 1000000 Y_16_13 + Z_16_13 <= 0
#
# Ensure_min_Zij23: - 1000000 Y_17_14 + Z_17_14 <= 0
#
# Ensure_min_Zij24: - 1000000 Y_19_14 + Z_19_14 <= 0
#
# Ensure_min_Zij25: - 1000000 Y_21_14 + Z_21_14 <= 0
#
# Ensure_min_Zij26: - 1000000 Y_22_14 + Z_22_14 <= 0
#
# Ensure_min_Zij27: - 1000000 Y_24_14 + Z_24_14 <= 0
#
# Ensure_min_Zij28: - 1000000 Y_17_15 + Z_17_15 <= 0
#
# Ensure_min_Zij29: - 1000000 Y_18_15 + Z_18_15 <= 0
#
# Ensure_min_Zij30: - 1000000 Y_23_15 + Z_23_15 <= 0
#
# Ensure_min_Zij31: - 1000000 Y_75_15 + Z_75_15 <= 0
#
# Ensure_min_Zij32: - 1000000 Y_13_16 + Z_13_16 <= 0
#
# Ensure_min_Zij33: - 1000000 Y_20_16 + Z_20_16 <= 0
#
# Ensure_min_Zij34: - 1000000 Y_76_16 + Z_76_16 <= 0
#
# Ensure_min_Zij35: - 1000000 Y_14_17 + Z_14_17 <= 0
#
# Ensure_min_Zij36: - 1000000 Y_15_17 + Z_15_17 <= 0
#
# Ensure_min_Zij37: - 1000000 Y_19_17 + Z_19_17 <= 0
#
# Ensure_min_Zij38: - 1000000 Y_23_17 + Z_23_17 <= 0
#
# Ensure_min_Zij39: - 1000000 Y_64_17 + Z_64_17 <= 0
#
# Ensure_min_Zij40: - 1000000 Y_15_18 + Z_15_18 <= 0
#
# Ensure_min_Zij41: - 1000000 Y_73_18 + Z_73_18 <= 0
#
# Ensure_min_Zij42: - 1000000 Y_75_18 + Z_75_18 <= 0
#
# Ensure_min_Zij43: - 1000000 Y_14_19 + Z_14_19 <= 0
#
# Ensure_min_Zij44: - 1000000 Y_17_19 + Z_17_19 <= 0
#
# Ensure_min_Zij45: - 1000000 Y_22_19 + Z_22_19 <= 0
#
# Ensure_min_Zij46: - 1000000 Y_23_19 + Z_23_19 <= 0
#
# Ensure_min_Zij47: - 1000000 Y_16_20 + Z_16_20 <= 0
#
# Ensure_min_Zij48: - 1000000 Y_76_20 + Z_76_20 <= 0
#
# Ensure_min_Zij49: - 1000000 Y_14_21 + Z_14_21 <= 0
#
# Ensure_min_Zij50: - 1000000 Y_14_22 + Z_14_22 <= 0
#
# Ensure_min_Zij51: - 1000000 Y_19_22 + Z_19_22 <= 0
#
# Ensure_min_Zij52: - 1000000 Y_23_22 + Z_23_22 <= 0
#
# Ensure_min_Zij53: - 1000000 Y_24_22 + Z_24_22 <= 0
#
# Ensure_min_Zij54: - 1000000 Y_15_23 + Z_15_23 <= 0
#
# Ensure_min_Zij55: - 1000000 Y_17_23 + Z_17_23 <= 0
#
# Ensure_min_Zij56: - 1000000 Y_19_23 + Z_19_23 <= 0
#
# Ensure_min_Zij57: - 1000000 Y_22_23 + Z_22_23 <= 0
#
# Ensure_min_Zij58: - 1000000 Y_26_23 + Z_26_23 <= 0
#
# Ensure_min_Zij59: - 1000000 Y_27_23 + Z_27_23 <= 0
#
# Ensure_min_Zij60: - 1000000 Y_75_23 + Z_75_23 <= 0
#
# Ensure_min_Zij61: - 1000000 Y_14_24 + Z_14_24 <= 0
#
# Ensure_min_Zij62: - 1000000 Y_22_24 + Z_22_24 <= 0
#
# Ensure_min_Zij63: - 1000000 Y_77_25 + Z_77_25 <= 0
#
# Ensure_min_Zij64: - 1000000 Y_78_25 + Z_78_25 <= 0
#
# Ensure_min_Zij65: - 1000000 Y_23_26 + Z_23_26 <= 0
#
# Ensure_min_Zij66: - 1000000 Y_27_26 + Z_27_26 <= 0
#
# Ensure_min_Zij67: - 1000000 Y_23_27 + Z_23_27 <= 0
#
# Ensure_min_Zij68: - 1000000 Y_26_27 + Z_26_27 <= 0
#
# Ensure_min_Zij69: - 1000000 Y_28_27 + Z_28_27 <= 0
#
# Ensure_min_Zij70: - 1000000 Y_32_27 + Z_32_27 <= 0
#
# Ensure_min_Zij71: - 1000000 Y_75_27 + Z_75_27 <= 0
#
# Ensure_min_Zij72: - 1000000 Y_27_28 + Z_27_28 <= 0
#
# Ensure_min_Zij73: - 1000000 Y_31_28 + Z_31_28 <= 0
#
# Ensure_min_Zij74: - 1000000 Y_32_28 + Z_32_28 <= 0
#
# Ensure_min_Zij75: - 1000000 Y_33_28 + Z_33_28 <= 0
#
# Ensure_min_Zij76: - 1000000 Y_31_29 + Z_31_29 <= 0
#
# Ensure_min_Zij77: - 1000000 Y_76_29 + Z_76_29 <= 0
#
# Ensure_min_Zij78: - 1000000 Y_28_31 + Z_28_31 <= 0
#
# Ensure_min_Zij79: - 1000000 Y_29_31 + Z_29_31 <= 0
#
# Ensure_min_Zij80: - 1000000 Y_33_31 + Z_33_31 <= 0
#
# Ensure_min_Zij81: - 1000000 Y_35_31 + Z_35_31 <= 0
#
# Ensure_min_Zij82: - 1000000 Y_37_31 + Z_37_31 <= 0
#
# Ensure_min_Zij83: - 1000000 Y_76_31 + Z_76_31 <= 0
#
# Ensure_min_Zij84: - 1000000 Y_27_32 + Z_27_32 <= 0
#
# Ensure_min_Zij85: - 1000000 Y_28_32 + Z_28_32 <= 0
#
# Ensure_min_Zij86: - 1000000 Y_33_32 + Z_33_32 <= 0
#
# Ensure_min_Zij87: - 1000000 Y_38_32 + Z_38_32 <= 0
#
# Ensure_min_Zij88: - 1000000 Y_28_33 + Z_28_33 <= 0
#
# Ensure_min_Zij89: - 1000000 Y_31_33 + Z_31_33 <= 0
#
# Ensure_min_Zij90: - 1000000 Y_32_33 + Z_32_33 <= 0
#
# Ensure_min_Zij91: - 1000000 Y_35_33 + Z_35_33 <= 0
#
# Ensure_min_Zij92: - 1000000 Y_38_33 + Z_38_33 <= 0
#
# Ensure_min_Zij93: - 1000000 Y_82_33 + Z_82_33 <= 0
#
# Ensure_min_Zij94: - 1000000 Y_91_34 + Z_91_34 <= 0
#
# Ensure_min_Zij95: - 1000000 Y_31_35 + Z_31_35 <= 0
#
# Ensure_min_Zij96: - 1000000 Y_33_35 + Z_33_35 <= 0
#
# Ensure_min_Zij97: - 1000000 Y_37_35 + Z_37_35 <= 0
#
# Ensure_min_Zij98: - 1000000 Y_82_35 + Z_82_35 <= 0
#
# Ensure_min_Zij99: - 1000000 Y_37_36 + Z_37_36 <= 0
#
# Ensure_min_Zij100: - 1000000 Y_76_36 + Z_76_36 <= 0
#
# Ensure_min_Zij101: - 1000000 Y_78_36 + Z_78_36 <= 0
#
# Ensure_min_Zij102: - 1000000 Y_79_36 + Z_79_36 <= 0
#
# Ensure_min_Zij103: - 1000000 Y_31_37 + Z_31_37 <= 0
#
# Ensure_min_Zij104: - 1000000 Y_35_37 + Z_35_37 <= 0
#
# Ensure_min_Zij105: - 1000000 Y_36_37 + Z_36_37 <= 0
#
# Ensure_min_Zij106: - 1000000 Y_76_37 + Z_76_37 <= 0
#
# Ensure_min_Zij107: - 1000000 Y_79_37 + Z_79_37 <= 0
#
# Ensure_min_Zij108: - 1000000 Y_82_37 + Z_82_37 <= 0
#
# Ensure_min_Zij109: - 1000000 Y_32_38 + Z_32_38 <= 0
#
# Ensure_min_Zij110: - 1000000 Y_33_38 + Z_33_38 <= 0
#
# Ensure_min_Zij111: - 1000000 Y_80_39 + Z_80_39 <= 0
#
# Ensure_min_Zij112: - 1000000 Y_83_39 + Z_83_39 <= 0
#
# Ensure_min_Zij113: - 1000000 Y_79_40 + Z_79_40 <= 0
#
# Ensure_min_Zij114: - 1000000 Y_84_40 + Z_84_40 <= 0
#
# Ensure_min_Zij115: - 1000000 Y_86_40 + Z_86_40 <= 0
#
# Ensure_min_Zij116: - 1000000 Y_88_42 + Z_88_42 <= 0
#
# Ensure_min_Zij117: - 1000000 Y_47_45 + Z_47_45 <= 0
#
# Ensure_min_Zij118: - 1000000 Y_49_45 + Z_49_45 <= 0
#
# Ensure_min_Zij119: - 1000000 Y_47_46 + Z_47_46 <= 0
#
# Ensure_min_Zij120: - 1000000 Y_48_46 + Z_48_46 <= 0
#
# Ensure_min_Zij121: - 1000000 Y_6_47 + Z_6_47 <= 0
#
# Ensure_min_Zij122: - 1000000 Y_45_47 + Z_45_47 <= 0
#
# Ensure_min_Zij123: - 1000000 Y_46_47 + Z_46_47 <= 0
#
# Ensure_min_Zij124: - 1000000 Y_48_47 + Z_48_47 <= 0
#
# Ensure_min_Zij125: - 1000000 Y_4_48 + Z_4_48 <= 0
#
# Ensure_min_Zij126: - 1000000 Y_46_48 + Z_46_48 <= 0
#
# Ensure_min_Zij127: - 1000000 Y_47_48 + Z_47_48 <= 0
#
# Ensure_min_Zij128: - 1000000 Y_45_49 + Z_45_49 <= 0
#
# Ensure_min_Zij129: - 1000000 Y_51_49 + Z_51_49 <= 0
#
# Ensure_min_Zij130: - 1000000 Y_56_49 + Z_56_49 <= 0
#
# ...
# 0 <= W_39 Integer
# 0 <= W_4 Integer
# 0 <= W_40 Integer
# 0 <= W_42 Integer
# 0 <= W_45 Integer
# 0 <= W_46 Integer
# 0 <= W_47 Integer
# 0 <= W_48 Integer
# 0 <= W_49 Integer
# 0 <= W_5 Integer
# 0 <= W_50 Integer
# 0 <= W_51 Integer
# 0 <= W_53 Integer
# 0 <= W_54 Integer
# 0 <= W_55 Integer
# 0 <= W_56 Integer
# 0 <= W_57 Integer
# 0 <= W_58 Integer
# 0 <= W_59 Integer
# 0 <= W_6 Integer
# 0 <= W_60 Integer
# 0 <= W_62 Integer
# 0 <= W_63 Integer
# 0 <= W_64 Integer
# 0 <= W_65 Integer
# 0 <= W_66 Integer
# 0 <= W_67 Integer
# 0 <= W_68 Integer
# 0 <= W_7 Integer
# 0 <= W_70 Integer
# 0 <= W_71 Integer
# 0 <= W_72 Integer
# 0 <= W_73 Integer
# 0 <= W_74 Integer
# 0 <= W_75 Integer
# 0 <= W_76 Integer
# 0 <= W_77 Integer
# 0 <= W_78 Integer
# 0 <= W_79 Integer
# 0 <= W_8 Integer
# 0 <= W_80 Integer
# 0 <= W_81 Integer
# 0 <= W_82 Integer
# 0 <= W_83 Integer
# 0 <= W_84 Integer
# 0 <= W_85 Integer
# 0 <= W_86 Integer
# 0 <= W_87 Integer
# 0 <= W_88 Integer
# 0 <= W_89 Integer
# 0 <= W_90 Integer
# 0 <= W_91 Integer
# 0 <= W_92 Integer
# 0 <= W_93 Integer
# 0 <= W_94 Integer
# 0 <= W_96 Integer
# 0 <= W_97 Integer
# 0 <= W_98 Integer
# 0 <= W_99 Integer
# 0 <= X_1 <= 1 Integer
# 0 <= X_10 <= 1 Integer
# 0 <= X_100 <= 1 Integer
# 0 <= X_101 <= 1 Integer
# 0 <= X_102 <= 1 Integer
# 0 <= X_103 <= 1 Integer
# 0 <= X_104 <= 1 Integer
# 0 <= X_105 <= 1 Integer
# 0 <= X_106 <= 1 Integer
# 0 <= X_107 <= 1 Integer
# 0 <= X_108 <= 1 Integer
# 0 <= X_109 <= 1 Integer
# 0 <= X_11 <= 1 Integer
# 0 <= X_110 <= 1 Integer
# 0 <= X_111 <= 1 Integer
# 0 <= X_112 <= 1 Integer
# 0 <= X_113 <= 1 Integer
# 0 <= X_114 <= 1 Integer
# 0 <= X_115 <= 1 Integer
# 0 <= X_116 <= 1 Integer
# 0 <= X_117 <= 1 Integer
# 0 <= X_118 <= 1 Integer
# 0 <= X_119 <= 1 Integer
# 0 <= X_12 <= 1 Integer
# 0 <= X_120 <= 1 Integer
# 0 <= X_13 <= 1 Integer
# 0 <= X_14 <= 1 Integer
# 0 <= X_15 <= 1 Integer
# 0 <= X_16 <= 1 Integer
# 0 <= X_17 <= 1 Integer
# 0 <= X_18 <= 1 Integer
# 0 <= X_19 <= 1 Integer
# 0 <= X_2 <= 1 Integer
# 0 <= X_20 <= 1 Integer
# 0 <= X_21 <= 1 Integer
# 0 <= X_22 <= 1 Integer
# 0 <= X_23 <= 1 Integer
# 0 <= X_24 <= 1 Integer
# 0 <= X_25 <= 1 Integer
# 0 <= X_26 <= 1 Integer
# 0 <= X_27 <= 1 Integer
# 0 <= X_28 <= 1 Integer
# 0 <= X_29 <= 1 Integer
# 0 <= X_3 <= 1 Integer
# 0 <= X_30 <= 1 Integer
# 0 <= X_31 <= 1 Integer
# 0 <= X_32 <= 1 Integer
# 0 <= X_33 <= 1 Integer
# 0 <= X_34 <= 1 Integer
# 0 <= X_35 <= 1 Integer
# 0 <= X_36 <= 1 Integer
# 0 <= X_37 <= 1 Integer
# 0 <= X_38 <= 1 Integer
# 0 <= X_39 <= 1 Integer
# 0 <= X_4 <= 1 Integer
# 0 <= X_40 <= 1 Integer
# 0 <= X_41 <= 1 Integer
# 0 <= X_42 <= 1 Integer
# 0 <= X_43 <= 1 Integer
# 0 <= X_44 <= 1 Integer
# 0 <= X_45 <= 1 Integer
# 0 <= X_46 <= 1 Integer
# 0 <= X_47 <= 1 Integer
# 0 <= X_48 <= 1 Integer
# 0 <= X_49 <= 1 Integer
# 0 <= X_5 <= 1 Integer
# 0 <= X_50 <= 1 Integer
# 0 <= X_51 <= 1 Integer
# 0 <= X_52 <= 1 Integer
# 0 <= X_53 <= 1 Integer
# 0 <= X_54 <= 1 Integer
# 0 <= X_55 <= 1 Integer
# 0 <= X_56 <= 1 Integer
# 0 <= X_57 <= 1 Integer
# 0 <= X_58 <= 1 Integer
# 0 <= X_59 <= 1 Integer
# 0 <= X_6 <= 1 Integer
# 0 <= X_60 <= 1 Integer
# 0 <= X_61 <= 1 Integer
# 0 <= X_62 <= 1 Integer
# 0 <= X_63 <= 1 Integer
# 0 <= X_64 <= 1 Integer
# 0 <= X_65 <= 1 Integer
# 0 <= X_66 <= 1 Integer
# 0 <= X_67 <= 1 Integer
# 0 <= X_68 <= 1 Integer
# 0 <= X_69 <= 1 Integer
# 0 <= X_7 <= 1 Integer
# 0 <= X_70 <= 1 Integer
# 0 <= X_71 <= 1 Integer
# 0 <= X_72 <= 1 Integer
# 0 <= X_73 <= 1 Integer
# 0 <= X_74 <= 1 Integer
# 0 <= X_75 <= 1 Integer
# 0 <= X_76 <= 1 Integer
# 0 <= X_77 <= 1 Integer
# 0 <= X_78 <= 1 Integer
# 0 <= X_79 <= 1 Integer
# 0 <= X_8 <= 1 Integer
# 0 <= X_80 <= 1 Integer
# 0 <= X_81 <= 1 Integer
# 0 <= X_82 <= 1 Integer
# 0 <= X_83 <= 1 Integer
# 0 <= X_84 <= 1 Integer
# 0 <= X_85 <= 1 Integer
# 0 <= X_86 <= 1 Integer
# 0 <= X_87 <= 1 Integer
# 0 <= X_88 <= 1 Integer
# 0 <= X_89 <= 1 Integer
# 0 <= X_9 <= 1 Integer
# 0 <= X_90 <= 1 Integer
# 0 <= X_91 <= 1 Integer
# 0 <= X_92 <= 1 Integer
# 0 <= X_93 <= 1 Integer
# 0 <= X_94 <= 1 Integer
# 0 <= X_95 <= 1 Integer
# 0 <= X_96 <= 1 Integer
# 0 <= X_97 <= 1 Integer
# 0 <= X_98 <= 1 Integer
# 0 <= X_99 <= 1 Integer
# 0 <= Y_100_90 <= 1 Integer
# 0 <= Y_10_13 <= 1 Integer
# 0 <= Y_12_63 <= 1 Integer
# 0 <= Y_12_73 <= 1 Integer
# 0 <= Y_13_10 <= 1 Integer
# 0 <= Y_13_16 <= 1 Integer
# 0 <= Y_14_17 <= 1 Integer
# 0 <= Y_14_19 <= 1 Integer
# 0 <= Y_14_21 <= 1 Integer
# 0 <= Y_14_22 <= 1 Integer
# 0 <= Y_14_24 <= 1 Integer
# 0 <= Y_15_17 <= 1 Integer
# 0 <= Y_15_18 <= 1 Integer
# 0 <= Y_15_23 <= 1 Integer
# 0 <= Y_15_75 <= 1 Integer
# 0 <= Y_16_13 <= 1 Integer
# 0 <= Y_16_20 <= 1 Integer
# 0 <= Y_16_76 <= 1 Integer
# 0 <= Y_17_14 <= 1 Integer
# 0 <= Y_17_15 <= 1 Integer
# 0 <= Y_17_19 <= 1 Integer
# 0 <= Y_17_23 <= 1 Integer
# 0 <= Y_17_64 <= 1 Integer
# 0 <= Y_18_15 <= 1 Integer
# 0 <= Y_18_73 <= 1 Integer
# 0 <= Y_18_75 <= 1 Integer
# 0 <= Y_19_14 <= 1 Integer
# 0 <= Y_19_17 <= 1 Integer
# 0 <= Y_19_22 <= 1 Integer
# 0 <= Y_19_23 <= 1 Integer
# 0 <= Y_20_16 <= 1 Integer
# 0 <= Y_20_76 <= 1 Integer
# 0 <= Y_21_14 <= 1 Integer
# 0 <= Y_22_14 <= 1 Integer
# 0 <= Y_22_19 <= 1 Integer
# 0 <= Y_22_23 <= 1 Integer
# 0 <= Y_22_24 <= 1 Integer
# 0 <= Y_23_15 <= 1 Integer
# 0 <= Y_23_17 <= 1 Integer
# 0 <= Y_23_19 <= 1 Integer
# 0 <= Y_23_22 <= 1 Integer
# 0 <= Y_23_26 <= 1 Integer
# 0 <= Y_23_27 <= 1 Integer
# 0 <= Y_23_75 <= 1 Integer
# 0 <= Y_24_14 <= 1 Integer
# 0 <= Y_24_22 <= 1 Integer
# 0 <= Y_25_77 <= 1 Integer
# 0 <= Y_25_78 <= 1 Integer
# 0 <= Y_26_23 <= 1 Integer
# 0 <= Y_26_27 <= 1 Integer
# 0 <= Y_27_23 <= 1 Integer
# 0 <= Y_27_26 <= 1 Integer
# 0 <= Y_27_28 <= 1 Integer
# 0 <= Y_27_32 <= 1 Integer
# 0 <= Y_27_75 <= 1 Integer
# 0 <= Y_28_27 <= 1 Integer
# 0 <= Y_28_31 <= 1 Integer
# 0 <= Y_28_32 <= 1 Integer
# 0 <= Y_28_33 <= 1 Integer
# 0 <= Y_29_31 <= 1 Integer
# 0 <= Y_29_76 <= 1 Integer
# 0 <= Y_2_51 <= 1 Integer
# 0 <= Y_31_28 <= 1 Integer
# 0 <= Y_31_29 <= 1 Integer
# 0 <= Y_31_33 <= 1 Integer
# 0 <= Y_31_35 <= 1 Integer
# 0 <= Y_31_37 <= 1 Integer
# 0 <= Y_31_76 <= 1 Integer
# 0 <= Y_32_27 <= 1 Integer
# 0 <= Y_32_28 <= 1 Integer
# 0 <= Y_32_33 <= 1 Integer
# 0 <= Y_32_38 <= 1 Integer
# 0 <= Y_33_28 <= 1 Integer
# 0 <= Y_33_31 <= 1 Integer
# 0 <= Y_33_32 <= 1 Integer
# 0 <= Y_33_35 <= 1 Integer
# 0 <= Y_33_38 <= 1 Integer
# 0 <= Y_33_82 <= 1 Integer
# 0 <= Y_34_91 <= 1 Integer
# 0 <= Y_35_31 <= 1 Integer
# 0 <= Y_35_33 <= 1 Integer
# 0 <= Y_35_37 <= 1 Integer
# 0 <= Y_35_82 <= 1 Integer
# 0 <= Y_36_37 <= 1 Integer
# 0 <= Y_36_76 <= 1 Integer
# 0 <= Y_36_78 <= 1 Integer
# 0 <= Y_36_79 <= 1 Integer
# 0 <= Y_37_31 <= 1 Integer
# 0 <= Y_37_35 <= 1 Integer
# 0 <= Y_37_36 <= 1 Integer
# 0 <= Y_37_76 <= 1 Integer
# 0 <= Y_37_79 <= 1 Integer
# 0 <= Y_37_82 <= 1 Integer
# 0 <= Y_38_32 <= 1 Integer
# 0 <= Y_38_33 <= 1 Integer
# 0 <= Y_39_80 <= 1 Integer
# 0 <= Y_39_83 <= 1 Integer
# 0 <= Y_3_50 <= 1 Integer
# 0 <= Y_3_55 <= 1 Integer
# 0 <= Y_3_60 <= 1 Integer
# 0 <= Y_40_79 <= 1 Integer
# 0 <= Y_40_84 <= 1 Integer
# 0 <= Y_40_86 <= 1 Integer
# 0 <= Y_42_88 <= 1 Integer
# 0 <= Y_45_47 <= 1 Integer
# 0 <= Y_45_49 <= 1 Integer
# 0 <= Y_46_47 <= 1 Integer
# 0 <= Y_46_48 <= 1 Integer
# 0 <= Y_47_45 <= 1 Integer
# 0 <= Y_47_46 <= 1 Integer
# 0 <= Y_47_48 <= 1 Integer
# 0 <= Y_47_6 <= 1 Integer
# 0 <= Y_48_4 <= 1 Integer
# 0 <= Y_48_46 <= 1 Integer
# 0 <= Y_48_47 <= 1 Integer
# 0 <= Y_49_45 <= 1 Integer
# 0 <= Y_49_51 <= 1 Integer
# 0 <= Y_49_56 <= 1 Integer
# 0 <= Y_4_48 <= 1 Integer
# 0 <= Y_4_5 <= 1 Integer
# 0 <= Y_4_6 <= 1 Integer
# 0 <= Y_50_3 <= 1 Integer
# 0 <= Y_50_55 <= 1 Integer
# 0 <= Y_51_2 <= 1 Integer
# 0 <= Y_51_49 <= 1 Integer
# 0 <= Y_53_54 <= 1 Integer
# 0 <= Y_54_5 <= 1 Integer
# 0 <= Y_54_53 <= 1 Integer
# 0 <= Y_55_3 <= 1 Integer
# 0 <= Y_55_50 <= 1 Integer
# 0 <= Y_55_60 <= 1 Integer
# 0 <= Y_56_49 <= 1 Integer
# 0 <= Y_56_6 <= 1 Integer
# 0 <= Y_56_63 <= 1 Integer
# 0 <= Y_57_58 <= 1 Integer
# 0 <= Y_57_7 <= 1 Integer
# 0 <= Y_58_57 <= 1 Integer
# 0 <= Y_58_59 <= 1 Integer
# 0 <= Y_58_64 <= 1 Integer
# 0 <= Y_58_7 <= 1 Integer
# 0 <= Y_59_58 <= 1 Integer
# 0 <= Y_59_64 <= 1 Integer
# 0 <= Y_5_4 <= 1 Integer
# 0 <= Y_5_54 <= 1 Integer
# 0 <= Y_60_3 <= 1 Integer
# 0 <= Y_60_55 <= 1 Integer
# 0 <= Y_60_65 <= 1 Integer
# 0 <= Y_60_66 <= 1 Integer
# 0 <= Y_60_68 <= 1 Integer
# 0 <= Y_60_8 <= 1 Integer
# 0 <= Y_62_65 <= 1 Integer
# 0 <= Y_62_67 <= 1 Integer
# 0 <= Y_62_72 <= 1 Integer
# 0 <= Y_63_12 <= 1 Integer
# 0 <= Y_63_56 <= 1 Integer
# 0 <= Y_63_64 <= 1 Integer
# 0 <= Y_64_17 <= 1 Integer
# 0 <= Y_64_58 <= 1 Integer
# 0 <= Y_64_59 <= 1 Integer
# 0 <= Y_64_63 <= 1 Integer
# 0 <= Y_65_60 <= 1 Integer
# 0 <= Y_65_62 <= 1 Integer
# 0 <= Y_65_67 <= 1 Integer
# 0 <= Y_65_68 <= 1 Integer
# 0 <= Y_66_60 <= 1 Integer
# 0 <= Y_66_8 <= 1 Integer
# 0 <= Y_67_62 <= 1 Integer
# 0 <= Y_67_65 <= 1 Integer
# 0 <= Y_68_60 <= 1 Integer
# 0 <= Y_68_65 <= 1 Integer
# 0 <= Y_68_8 <= 1 Integer
# 0 <= Y_6_4 <= 1 Integer
# 0 <= Y_6_47 <= 1 Integer
# 0 <= Y_6_56 <= 1 Integer
# 0 <= Y_70_71 <= 1 Integer
# 0 <= Y_70_72 <= 1 Integer
# 0 <= Y_71_70 <= 1 Integer
# 0 <= Y_71_96 <= 1 Integer
# 0 <= Y_72_62 <= 1 Integer
# 0 <= Y_72_70 <= 1 Integer
# 0 <= Y_73_12 <= 1 Integer
# 0 <= Y_73_18 <= 1 Integer
# 0 <= Y_73_75 <= 1 Integer
# 0 <= Y_74_91 <= 1 Integer
# 0 <= Y_75_15 <= 1 Integer
# 0 <= Y_75_18 <= 1 Integer
# 0 <= Y_75_23 <= 1 Integer
# 0 <= Y_75_27 <= 1 Integer
# 0 <= Y_75_73 <= 1 Integer
# 0 <= Y_76_16 <= 1 Integer
# 0 <= Y_76_20 <= 1 Integer
# 0 <= Y_76_29 <= 1 Integer
# 0 <= Y_76_31 <= 1 Integer
# 0 <= Y_76_36 <= 1 Integer
# 0 <= Y_76_37 <= 1 Integer
# 0 <= Y_76_77 <= 1 Integer
# 0 <= Y_76_78 <= 1 Integer
# 0 <= Y_77_25 <= 1 Integer
# 0 <= Y_77_76 <= 1 Integer
# 0 <= Y_77_78 <= 1 Integer
# 0 <= Y_78_25 <= 1 Integer
# 0 <= Y_78_36 <= 1 Integer
# 0 <= Y_78_76 <= 1 Integer
# 0 <= Y_78_77 <= 1 Integer
# 0 <= Y_78_79 <= 1 Integer
# 0 <= Y_79_36 <= 1 Integer
# 0 <= Y_79_37 <= 1 Integer
# 0 <= Y_79_40 <= 1 Integer
# 0 <= Y_79_78 <= 1 Integer
# 0 <= Y_79_81 <= 1 Integer
# 0 <= Y_79_82 <= 1 Integer
# 0 <= Y_79_84 <= 1 Integer
# 0 <= Y_79_86 <= 1 Integer
# 0 <= Y_7_57 <= 1 Integer
# 0 <= Y_7_58 <= 1 Integer
# 0 <= Y_80_39 <= 1 Integer
# 0 <= Y_80_83 <= 1 Integer
# 0 <= Y_80_98 <= 1 Integer
# 0 <= Y_81_79 <= 1 Integer
# 0 <= Y_81_84 <= 1 Integer
# 0 <= Y_81_86 <= 1 Integer
# 0 <= Y_82_33 <= 1 Integer
# 0 <= Y_82_35 <= 1 Integer
# 0 <= Y_82_37 <= 1 Integer
# 0 <= Y_82_79 <= 1 Integer
# 0 <= Y_83_39 <= 1 Integer
# 0 <= Y_83_80 <= 1 Integer
# 0 <= Y_84_40 <= 1 Integer
# 0 <= Y_84_79 <= 1 Integer
# 0 <= Y_84_81 <= 1 Integer
# 0 <= Y_84_86 <= 1 Integer
# 0 <= Y_85_87 <= 1 Integer
# 0 <= Y_86_40 <= 1 Integer
# 0 <= Y_86_79 <= 1 Integer
# 0 <= Y_86_81 <= 1 Integer
# 0 <= Y_86_84 <= 1 Integer
# 0 <= Y_86_88 <= 1 Integer
# 0 <= Y_87_85 <= 1 Integer
# 0 <= Y_88_42 <= 1 Integer
# 0 <= Y_88_86 <= 1 Integer
# 0 <= Y_89_90 <= 1 Integer
# 0 <= Y_8_60 <= 1 Integer
# 0 <= Y_8_66 <= 1 Integer
# 0 <= Y_8_68 <= 1 Integer
# 0 <= Y_90_100 <= 1 Integer
# 0 <= Y_90_89 <= 1 Integer
# 0 <= Y_91_34 <= 1 Integer
# 0 <= Y_91_74 <= 1 Integer
# 0 <= Y_92_93 <= 1 Integer
# 0 <= Y_92_94 <= 1 Integer
# 0 <= Y_93_92 <= 1 Integer
# 0 <= Y_94_92 <= 1 Integer
# 0 <= Y_96_71 <= 1 Integer
# 0 <= Y_96_98 <= 1 Integer
# 0 <= Y_97_99 <= 1 Integer
# 0 <= Y_98_80 <= 1 Integer
# 0 <= Y_98_96 <= 1 Integer
# 0 <= Y_98_99 <= 1 Integer
# 0 <= Y_99_97 <= 1 Integer
# 0 <= Y_99_98 <= 1 Integer
# 0 <= Z_100_90 Integer
# 0 <= Z_10_13 Integer
# 0 <= Z_12_63 Integer
# 0 <= Z_12_73 Integer
# 0 <= Z_13_10 Integer
# 0 <= Z_13_16 Integer
# 0 <= Z_14_17 Integer
# 0 <= Z_14_19 Integer
# 0 <= Z_14_21 Integer
# 0 <= Z_14_22 Integer
# 0 <= Z_14_24 Integer
# 0 <= Z_15_17 Integer
# 0 <= Z_15_18 Integer
# 0 <= Z_15_23 Integer
# 0 <= Z_15_75 Integer
# 0 <= Z_16_13 Integer
# 0 <= Z_16_20 Integer
# 0 <= Z_16_76 Integer
# 0 <= Z_17_14 Integer
# 0 <= Z_17_15 Integer
# 0 <= Z_17_19 Integer
# 0 <= Z_17_23 Integer
# 0 <= Z_17_64 Integer
# 0 <= Z_18_15 Integer
# 0 <= Z_18_73 Integer
# 0 <= Z_18_75 Integer
# 0 <= Z_19_14 Integer
# 0 <= Z_19_17 Integer
# 0 <= Z_19_22 Integer
# 0 <= Z_19_23 Integer
# 0 <= Z_20_16 Integer
# 0 <= Z_20_76 Integer
# 0 <= Z_21_14 Integer
# 0 <= Z_22_14 Integer
# 0 <= Z_22_19 Integer
# 0 <= Z_22_23 Integer
# 0 <= Z_22_24 Integer
# 0 <= Z_23_15 Integer
# 0 <= Z_23_17 Integer
# 0 <= Z_23_19 Integer
# 0 <= Z_23_22 Integer
# 0 <= Z_23_26 Integer
# 0 <= Z_23_27 Integer
# 0 <= Z_23_75 Integer
# 0 <= Z_24_14 Integer
# 0 <= Z_24_22 Integer
# 0 <= Z_25_77 Integer
# 0 <= Z_25_78 Integer
# 0 <= Z_26_23 Integer
# 0 <= Z_26_27 Integer
# 0 <= Z_27_23 Integer
# 0 <= Z_27_26 Integer
# 0 <= Z_27_28 Integer
# 0 <= Z_27_32 Integer
# 0 <= Z_27_75 Integer
# 0 <= Z_28_27 Integer
# 0 <= Z_28_31 Integer
# 0 <= Z_28_32 Integer
# 0 <= Z_28_33 Integer
# 0 <= Z_29_31 Integer
# 0 <= Z_29_76 Integer
# 0 <= Z_2_51 Integer
# 0 <= Z_31_28 Integer
# 0 <= Z_31_29 Integer
# 0 <= Z_31_33 Integer
# 0 <= Z_31_35 Integer
# 0 <= Z_31_37 Integer
# 0 <= Z_31_76 Integer
# 0 <= Z_32_27 Integer
# 0 <= Z_32_28 Integer
# 0 <= Z_32_33 Integer
# 0 <= Z_32_38 Integer
# 0 <= Z_33_28 Integer
# 0 <= Z_33_31 Integer
# 0 <= Z_33_32 Integer
# 0 <= Z_33_35 Integer
# 0 <= Z_33_38 Integer
# 0 <= Z_33_82 Integer
# 0 <= Z_34_91 Integer
# 0 <= Z_35_31 Integer
# 0 <= Z_35_33 Integer
# 0 <= Z_35_37 Integer
# 0 <= Z_35_82 Integer
# 0 <= Z_36_37 Integer
# 0 <= Z_36_76 Integer
# 0 <= Z_36_78 Integer
# 0 <= Z_36_79 Integer
# 0 <= Z_37_31 Integer
# 0 <= Z_37_35 Integer
# 0 <= Z_37_36 Integer
# 0 <= Z_37_76 Integer
# 0 <= Z_37_79 Integer
# 0 <= Z_37_82 Integer
# 0 <= Z_38_32 Integer
# 0 <= Z_38_33 Integer
# 0 <= Z_39_80 Integer
# 0 <= Z_39_83 Integer
# 0 <= Z_3_50 Integer
# 0 <= Z_3_55 Integer
# 0 <= Z_3_60 Integer
# 0 <= Z_40_79 Integer
# 0 <= Z_40_84 Integer
# 0 <= Z_40_86 Integer
# 0 <= Z_42_88 Integer
# 0 <= Z_45_47 Integer
# 0 <= Z_45_49 Integer
# 0 <= Z_46_47 Integer
# 0 <= Z_46_48 Integer
# 0 <= Z_47_45 Integer
# 0 <= Z_47_46 Integer
# 0 <= Z_47_48 Integer
# 0 <= Z_47_6 Integer
# 0 <= Z_48_4 Integer
# 0 <= Z_48_46 Integer
# 0 <= Z_48_47 Integer
# 0 <= Z_49_45 Integer
# 0 <= Z_49_51 Integer
# 0 <= Z_49_56 Integer
# 0 <= Z_4_48 Integer
# 0 <= Z_4_5 Integer
# 0 <= Z_4_6 Integer
# 0 <= Z_50_3 Integer
# 0 <= Z_50_55 Integer
# 0 <= Z_51_2 Integer
# 0 <= Z_51_49 Integer
# 0 <= Z_53_54 Integer
# 0 <= Z_54_5 Integer
# 0 <= Z_54_53 Integer
# 0 <= Z_55_3 Integer
# 0 <= Z_55_50 Integer
# 0 <= Z_55_60 Integer
# 0 <= Z_56_49 Integer
# 0 <= Z_56_6 Integer
# 0 <= Z_56_63 Integer
# 0 <= Z_57_58 Integer
# 0 <= Z_57_7 Integer
# 0 <= Z_58_57 Integer
# 0 <= Z_58_59 Integer
# 0 <= Z_58_64 Integer
# 0 <= Z_58_7 Integer
# 0 <= Z_59_58 Integer
# 0 <= Z_59_64 Integer
# 0 <= Z_5_4 Integer
# 0 <= Z_5_54 Integer
# 0 <= Z_60_3 Integer
# 0 <= Z_60_55 Integer
# 0 <= Z_60_65 Integer
# 0 <= Z_60_66 Integer
# 0 <= Z_60_68 Integer
# 0 <= Z_60_8 Integer
# 0 <= Z_62_65 Integer
# 0 <= Z_62_67 Integer
# 0 <= Z_62_72 Integer
# 0 <= Z_63_12 Integer
# 0 <= Z_63_56 Integer
# 0 <= Z_63_64 Integer
# 0 <= Z_64_17 Integer
# 0 <= Z_64_58 Integer
# 0 <= Z_64_59 Integer
# 0 <= Z_64_63 Integer
# 0 <= Z_65_60 Integer
# 0 <= Z_65_62 Integer
# 0 <= Z_65_67 Integer
# 0 <= Z_65_68 Integer
# 0 <= Z_66_60 Integer
# 0 <= Z_66_8 Integer
# 0 <= Z_67_62 Integer
# 0 <= Z_67_65 Integer
# 0 <= Z_68_60 Integer
# 0 <= Z_68_65 Integer
# 0 <= Z_68_8 Integer
# 0 <= Z_6_4 Integer
# 0 <= Z_6_47 Integer
# 0 <= Z_6_56 Integer
# 0 <= Z_70_71 Integer
# 0 <= Z_70_72 Integer
# 0 <= Z_71_70 Integer
# 0 <= Z_71_96 Integer
# 0 <= Z_72_62 Integer
# 0 <= Z_72_70 Integer
# 0 <= Z_73_12 Integer
# 0 <= Z_73_18 Integer
# 0 <= Z_73_75 Integer
# 0 <= Z_74_91 Integer
# 0 <= Z_75_15 Integer
# 0 <= Z_75_18 Integer
# 0 <= Z_75_23 Integer
# 0 <= Z_75_27 Integer
# 0 <= Z_75_73 Integer
# 0 <= Z_76_16 Integer
# 0 <= Z_76_20 Integer
# 0 <= Z_76_29 Integer
# 0 <= Z_76_31 Integer
# 0 <= Z_76_36 Integer
# 0 <= Z_76_37 Integer
# 0 <= Z_76_77 Integer
# 0 <= Z_76_78 Integer
# 0 <= Z_77_25 Integer
# 0 <= Z_77_76 Integer
# 0 <= Z_77_78 Integer
# 0 <= Z_78_25 Integer
# 0 <= Z_78_36 Integer
# 0 <= Z_78_76 Integer
# 0 <= Z_78_77 Integer
# 0 <= Z_78_79 Integer
# 0 <= Z_79_36 Integer
# 0 <= Z_79_37 Integer
# 0 <= Z_79_40 Integer
# 0 <= Z_79_78 Integer
# 0 <= Z_79_81 Integer
# 0 <= Z_79_82 Integer
# 0 <= Z_79_84 Integer
# 0 <= Z_79_86 Integer
# 0 <= Z_7_57 Integer
# 0 <= Z_7_58 Integer
# 0 <= Z_80_39 Integer
# 0 <= Z_80_83 Integer
# 0 <= Z_80_98 Integer
# 0 <= Z_81_79 Integer
# 0 <= Z_81_84 Integer
# 0 <= Z_81_86 Integer
# 0 <= Z_82_33 Integer
# 0 <= Z_82_35 Integer
# 0 <= Z_82_37 Integer
# 0 <= Z_82_79 Integer
# 0 <= Z_83_39 Integer
# 0 <= Z_83_80 Integer
# 0 <= Z_84_40 Integer
# 0 <= Z_84_79 Integer
# 0 <= Z_84_81 Integer
# 0 <= Z_84_86 Integer
# 0 <= Z_85_87 Integer
# 0 <= Z_86_40 Integer
# 0 <= Z_86_79 Integer
# 0 <= Z_86_81 Integer
# 0 <= Z_86_84 Integer
# 0 <= Z_86_88 Integer
# 0 <= Z_87_85 Integer
# 0 <= Z_88_42 Integer
# 0 <= Z_88_86 Integer
# 0 <= Z_89_90 Integer
# 0 <= Z_8_60 Integer
# 0 <= Z_8_66 Integer
# 0 <= Z_8_68 Integer
# 0 <= Z_90_100 Integer
# 0 <= Z_90_89 Integer
# 0 <= Z_91_34 Integer
# 0 <= Z_91_74 Integer
# 0 <= Z_92_93 Integer
# 0 <= Z_92_94 Integer
# 0 <= Z_93_92 Integer
# 0 <= Z_94_92 Integer
# 0 <= Z_96_71 Integer
# 0 <= Z_96_98 Integer
# 0 <= Z_97_99 Integer
# 0 <= Z_98_80 Integer
# 0 <= Z_98_96 Integer
# 0 <= Z_98_99 Integer
# 0 <= Z_99_97 Integer
# 0 <= Z_99_98 Integer

# %%
#Save code into a lp file 
model.writeLP("model_lab4_test.lp")
# Out:
# [W_10,
#  W_100,
#  W_12,
#  W_13,
#  W_14,
#  W_15,
#  W_16,
#  W_17,
#  W_18,
#  W_19,
#  W_2,
#  W_20,
#  W_21,
#  W_22,
#  W_23,
#  W_24,
#  W_25,
#  W_26,
#  W_27,
#  W_28,
#  W_29,
#  W_3,
#  W_31,
#  W_32,
#  W_33,
#  W_34,
#  W_35,
#  W_36,
#  W_37,
#  W_38,
#  W_39,
#  W_4,
#  W_40,
#  W_42,
#  W_45,
#  W_46,
#  W_47,
#  W_48,
#  W_49,
#  W_5,
#  W_50,
#  W_51,
#  W_53,
#  W_54,
#  W_55,
#  W_56,
#  W_57,
#  W_58,
#  W_59,
#  W_6,
#  W_60,
#  W_62,
#  W_63,
#  W_64,
#  W_65,
#  W_66,
#  W_67,
#  W_68,
#  W_7,
#  W_70,
#  W_71,
#  W_72,
#  W_73,
#  W_74,
#  W_75,
#  W_76,
#  W_77,
#  W_78,
#  W_79,
#  W_8,
#  W_80,
#  W_81,
#  W_82,
#  W_83,
#  W_84,
#  W_85,
#  W_86,
#  W_87,
#  W_88,
#  W_89,
#  W_90,
#  W_91,
#  W_92,
#  W_93,
#  W_94,
#  W_96,
#  W_97,
#  W_98,
#  W_99,
#  X_1,
#  X_10,
#  X_100,
#  X_101,
#  X_102,
#  X_103,
#  X_104,
#  X_105,
#  X_106,
#  X_107,
#  X_108,
#  X_109,
#  X_11,
#  X_110,
#  X_111,
#  X_112,
#  X_113,
#  X_114,
#  X_115,
#  X_116,
#  X_117,
#  X_118,
#  X_119,
#  X_12,
#  X_120,
#  X_13,
#  X_14,
#  X_15,
#  X_16,
#  X_17,
#  X_18,
#  X_19,
#  X_2,
#  X_20,
#  X_21,
#  X_22,
#  X_23,
#  X_24,
#  X_25,
#  X_26,
#  X_27,
#  X_28,
#  X_29,
#  X_3,
#  X_30,
#  X_31,
#  X_32,
#  X_33,
#  X_34,
#  X_35,
#  X_36,
#  X_37,
#  X_38,
#  X_39,
#  X_4,
#  X_40,
#  X_41,
#  X_42,
#  X_43,
#  X_44,
#  X_45,
#  X_46,
#  X_47,
#  X_48,
#  X_49,
#  X_5,
#  X_50,
#  X_51,
#  X_52,
#  X_53,
#  X_54,
#  X_55,
#  X_56,
#  X_57,
#  X_58,
#  X_59,
#  X_6,
#  X_60,
#  X_61,
#  X_62,
#  X_63,
#  X_64,
#  X_65,
#  X_66,
#  X_67,
#  X_68,
#  X_69,
#  X_7,
#  X_70,
#  X_71,
#  X_72,
#  X_73,
#  X_74,
#  X_75,
#  X_76,
#  X_77,
#  X_78,
#  X_79,
#  X_8,
#  X_80,
#  X_81,
#  X_82,
#  X_83,
#  X_84,
#  X_85,
#  X_86,
#  X_87,
#  X_88,
#  X_89,
#  X_9,
#  X_90,
#  X_91,
#  X_92,
#  X_93,
#  X_94,
#  X_95,
#  X_96,
#  X_97,
#  X_98,
#  X_99,
#  Y_100_90,
#  Y_10_13,
#  Y_12_63,
#  Y_12_73,
#  Y_13_10,
#  Y_13_16,
#  Y_14_17,
#  Y_14_19,
#  Y_14_21,
#  Y_14_22,
#  Y_14_24,
#  Y_15_17,
#  Y_15_18,
#  Y_15_23,
#  Y_15_75,
#  Y_16_13,
#  Y_16_20,
#  Y_16_76,
#  Y_17_14,
#  Y_17_15,
#  Y_17_19,
#  Y_17_23,
#  Y_17_64,
#  Y_18_15,
#  Y_18_73,
#  Y_18_75,
#  Y_19_14,
#  Y_19_17,
#  Y_19_22,
#  Y_19_23,
#  Y_20_16,
#  Y_20_76,
#  Y_21_14,
#  Y_22_14,
#  Y_22_19,
#  Y_22_23,
#  Y_22_24,
#  Y_23_15,
#  Y_23_17,
#  Y_23_19,
#  Y_23_22,
#  Y_23_26,
#  Y_23_27,
#  Y_23_75,
#  Y_24_14,
#  Y_24_22,
#  Y_25_77,
#  Y_25_78,
#  Y_26_23,
#  Y_26_27,
#  Y_27_23,
#  Y_27_26,
#  Y_27_28,
#  Y_27_32,
#  Y_27_75,
#  Y_28_27,
#  Y_28_31,
#  Y_28_32,
#  Y_28_33,
#  Y_29_31,
#  Y_29_76,
#  Y_2_51,
#  Y_31_28,
#  Y_31_29,
#  Y_31_33,
#  Y_31_35,
#  Y_31_37,
#  Y_31_76,
#  Y_32_27,
#  Y_32_28,
#  Y_32_33,
#  Y_32_38,
#  Y_33_28,
#  Y_33_31,
#  Y_33_32,
#  Y_33_35,
#  Y_33_38,
#  Y_33_82,
#  Y_34_91,
#  Y_35_31,
#  Y_35_33,
#  Y_35_37,
#  Y_35_82,
#  Y_36_37,
#  Y_36_76,
#  Y_36_78,
#  Y_36_79,
#  Y_37_31,
#  Y_37_35,
#  Y_37_36,
#  Y_37_76,
#  Y_37_79,
#  Y_37_82,
#  Y_38_32,
#  Y_38_33,
#  Y_39_80,
#  Y_39_83,
#  Y_3_50,
#  Y_3_55,
#  Y_3_60,
#  Y_40_79,
#  Y_40_84,
#  Y_40_86,
#  Y_42_88,
#  Y_45_47,
#  Y_45_49,
#  Y_46_47,
#  Y_46_48,
#  Y_47_45,
#  Y_47_46,
#  Y_47_48,
#  Y_47_6,
#  Y_48_4,
#  Y_48_46,
#  Y_48_47,
#  Y_49_45,
#  Y_49_51,
#  Y_49_56,
#  Y_4_48,
#  Y_4_5,
#  Y_4_6,
#  Y_50_3,
#  Y_50_55,
#  Y_51_2,
#  Y_51_49,
#  Y_53_54,
#  Y_54_5,
#  Y_54_53,
#  Y_55_3,
#  Y_55_50,
#  Y_55_60,
#  Y_56_49,
#  Y_56_6,
#  Y_56_63,
#  Y_57_58,
#  Y_57_7,
#  Y_58_57,
#  Y_58_59,
#  Y_58_64,
#  Y_58_7,
#  Y_59_58,
#  Y_59_64,
#  Y_5_4,
#  Y_5_54,
#  Y_60_3,
#  Y_60_55,
#  Y_60_65,
#  Y_60_66,
#  Y_60_68,
#  Y_60_8,
#  Y_62_65,
#  Y_62_67,
#  Y_62_72,
#  Y_63_12,
#  Y_63_56,
#  Y_63_64,
#  Y_64_17,
#  Y_64_58,
#  Y_64_59,
#  Y_64_63,
#  Y_65_60,
#  Y_65_62,
#  Y_65_67,
#  Y_65_68,
#  Y_66_60,
#  Y_66_8,
#  Y_67_62,
#  Y_67_65,
#  Y_68_60,
#  Y_68_65,
#  Y_68_8,
#  Y_6_4,
#  Y_6_47,
#  Y_6_56,
#  Y_70_71,
#  Y_70_72,
#  Y_71_70,
#  Y_71_96,
#  Y_72_62,
#  Y_72_70,
#  Y_73_12,
#  Y_73_18,
#  Y_73_75,
#  Y_74_91,
#  Y_75_15,
#  Y_75_18,
#  Y_75_23,
#  Y_75_27,
#  Y_75_73,
#  Y_76_16,
#  Y_76_20,
#  Y_76_29,
#  Y_76_31,
#  Y_76_36,
#  Y_76_37,
#  Y_76_77,
#  Y_76_78,
#  Y_77_25,
#  Y_77_76,
#  Y_77_78,
#  Y_78_25,
#  Y_78_36,
#  Y_78_76,
#  Y_78_77,
#  Y_78_79,
#  Y_79_36,
#  Y_79_37,
#  Y_79_40,
#  Y_79_78,
#  Y_79_81,
#  Y_79_82,
#  Y_79_84,
#  Y_79_86,
#  Y_7_57,
#  Y_7_58,
#  Y_80_39,
#  Y_80_83,
#  Y_80_98,
#  Y_81_79,
#  Y_81_84,
#  Y_81_86,
#  Y_82_33,
#  Y_82_35,
#  Y_82_37,
#  Y_82_79,
#  Y_83_39,
#  Y_83_80,
#  Y_84_40,
#  Y_84_79,
#  Y_84_81,
#  Y_84_86,
#  Y_85_87,
#  Y_86_40,
#  Y_86_79,
#  Y_86_81,
#  Y_86_84,
#  Y_86_88,
#  Y_87_85,
#  Y_88_42,
#  Y_88_86,
#  Y_89_90,
#  Y_8_60,
#  Y_8_66,
#  Y_8_68,
#  Y_90_100,
#  Y_90_89,
#  Y_91_34,
#  Y_91_74,
#  Y_92_93,
#  Y_92_94,
#  Y_93_92,
#  Y_94_92,
#  Y_96_71,
#  Y_96_98,
#  Y_97_99,
#  Y_98_80,
#  Y_98_96,
#  Y_98_99,
#  Y_99_97,
#  Y_99_98,
#  Z_100_90,
#  Z_10_13,
#  Z_12_63,
#  Z_12_73,
#  Z_13_10,
#  Z_13_16,
#  Z_14_17,
#  Z_14_19,
#  Z_14_21,
#  Z_14_22,
#  Z_14_24,
#  Z_15_17,
#  Z_15_18,
#  Z_15_23,
#  Z_15_75,
#  Z_16_13,
#  Z_16_20,
#  Z_16_76,
#  Z_17_14,
#  Z_17_15,
#  Z_17_19,
#  Z_17_23,
#  Z_17_64,
#  Z_18_15,
#  Z_18_73,
#  Z_18_75,
#  Z_19_14,
#  Z_19_17,
#  Z_19_22,
#  Z_19_23,
#  Z_20_16,
#  Z_20_76,
#  Z_21_14,
#  Z_22_14,
#  Z_22_19,
#  Z_22_23,
#  Z_22_24,
#  Z_23_15,
#  Z_23_17,
#  Z_23_19,
#  Z_23_22,
#  Z_23_26,
#  Z_23_27,
#  Z_23_75,
#  Z_24_14,
#  Z_24_22,
#  Z_25_77,
#  Z_25_78,
#  Z_26_23,
#  Z_26_27,
#  Z_27_23,
#  Z_27_26,
#  Z_27_28,
#  Z_27_32,
#  Z_27_75,
#  Z_28_27,
#  Z_28_31,
#  Z_28_32,
#  Z_28_33,
#  Z_29_31,
#  Z_29_76,
#  Z_2_51,
#  Z_31_28,
#  Z_31_29,
#  Z_31_33,
#  Z_31_35,
#  Z_31_37,
#  Z_31_76,
#  Z_32_27,
#  Z_32_28,
#  Z_32_33,
#  Z_32_38,
#  Z_33_28,
#  Z_33_31,
#  Z_33_32,
#  Z_33_35,
#  Z_33_38,
#  Z_33_82,
#  Z_34_91,
#  Z_35_31,
#  Z_35_33,
#  Z_35_37,
#  Z_35_82,
#  Z_36_37,
#  Z_36_76,
#  Z_36_78,
#  Z_36_79,
#  Z_37_31,
#  Z_37_35,
#  Z_37_36,
#  Z_37_76,
#  Z_37_79,
#  Z_37_82,
#  Z_38_32,
#  Z_38_33,
#  Z_39_80,
#  Z_39_83,
#  Z_3_50,
#  Z_3_55,
#  Z_3_60,
#  Z_40_79,
#  Z_40_84,
#  Z_40_86,
#  Z_42_88,
#  Z_45_47,
#  Z_45_49,
#  Z_46_47,
#  Z_46_48,
#  Z_47_45,
#  Z_47_46,
#  Z_47_48,
#  Z_47_6,
#  Z_48_4,
#  Z_48_46,
#  Z_48_47,
#  Z_49_45,
#  Z_49_51,
#  Z_49_56,
#  Z_4_48,
#  Z_4_5,
#  Z_4_6,
#  Z_50_3,
#  Z_50_55,
#  Z_51_2,
#  Z_51_49,
#  Z_53_54,
#  Z_54_5,
#  Z_54_53,
#  Z_55_3,
#  Z_55_50,
#  Z_55_60,
#  Z_56_49,
#  Z_56_6,
#  Z_56_63,
#  Z_57_58,
#  Z_57_7,
#  Z_58_57,
#  Z_58_59,
#  Z_58_64,
#  Z_58_7,
#  Z_59_58,
#  Z_59_64,
#  Z_5_4,
#  Z_5_54,
#  Z_60_3,
#  Z_60_55,
#  Z_60_65,
#  Z_60_66,
#  Z_60_68,
#  Z_60_8,
#  Z_62_65,
#  Z_62_67,
#  Z_62_72,
#  Z_63_12,
#  Z_63_56,
#  Z_63_64,
#  Z_64_17,
#  Z_64_58,
#  Z_64_59,
#  Z_64_63,
#  Z_65_60,
#  Z_65_62,
#  Z_65_67,
#  Z_65_68,
#  Z_66_60,
#  Z_66_8,
#  Z_67_62,
#  Z_67_65,
#  Z_68_60,
#  Z_68_65,
#  Z_68_8,
#  Z_6_4,
#  Z_6_47,
#  Z_6_56,
#  Z_70_71,
#  Z_70_72,
#  Z_71_70,
#  Z_71_96,
#  Z_72_62,
#  Z_72_70,
#  Z_73_12,
#  Z_73_18,
#  Z_73_75,
#  Z_74_91,
#  Z_75_15,
#  Z_75_18,
#  Z_75_23,
#  Z_75_27,
#  Z_75_73,
#  Z_76_16,
#  Z_76_20,
#  Z_76_29,
#  Z_76_31,
#  Z_76_36,
#  Z_76_37,
#  Z_76_77,
#  Z_76_78,
#  Z_77_25,
#  Z_77_76,
#  Z_77_78,
#  Z_78_25,
#  Z_78_36,
#  Z_78_76,
#  Z_78_77,
#  Z_78_79,
#  Z_79_36,
#  Z_79_37,
#  Z_79_40,
#  Z_79_78,
#  Z_79_81,
#  Z_79_82,
#  Z_79_84,
#  Z_79_86,
#  Z_7_57,
#  Z_7_58,
#  Z_80_39,
#  Z_80_83,
#  Z_80_98,
#  Z_81_79,
#  Z_81_84,
#  Z_81_86,
#  Z_82_33,
#  Z_82_35,
#  Z_82_37,
#  Z_82_79,
#  Z_83_39,
#  Z_83_80,
#  Z_84_40,
#  Z_84_79,
#  Z_84_81,
#  Z_84_86,
#  Z_85_87,
#  Z_86_40,
#  Z_86_79,
#  Z_86_81,
#  Z_86_84,
#  Z_86_88,
#  Z_87_85,
#  Z_88_42,
#  Z_88_86,
#  Z_89_90,
#  Z_8_60,
#  Z_8_66,
#  Z_8_68,
#  Z_90_100,
#  Z_90_89,
#  Z_91_34,
#  Z_91_74,
#  Z_92_93,
#  Z_92_94,
#  Z_93_92,
#  Z_94_92,
#  Z_96_71,
#  Z_96_98,
#  Z_97_99,
#  Z_98_80,
#  Z_98_96,
#  Z_98_99,
#  Z_99_97,
#  Z_99_98]

# %%
#play around with CBC solver 
model.solve(PULP_CBC_CMD())

status =  LpStatus[model.status]

print(status)
